# %%
import numpy as np
import pywt
import matplotlib.pyplot as plt
import nibabel as nib
import random
from scipy import stats
from scipy import fft
import random
import pywt.data
from PIL import Image
import pandas as pd
import seaborn as sns
import os
import pickle

# %%
np. __version__
# Out:
# '1.26.3'

# %%
# assign directory
import os
BRANDON = '/Users/brandonmarks/Desktop/Research Materials/hierarchical-bayesian-model-validation/'
YASH = '/Users/yashd/Desktop/hierarchical-bayesian-model-validation/'

ROOT_DIR = BRANDON
data_dir = ROOT_DIR + 'raw-data/first_21_mri_3d'
# iterate over files in that directory
file_list = [os.path.join(data_dir, filename) for filename in os.listdir(data_dir)]
file_names = os.listdir(data_dir)
n = len(file_list)

# %%
image = nib.load(file_list[0]).get_fdata()

# %%
def getIndexDF_3d(image, no_zero =False):
    x_freqs = fft.fftfreq(image.shape[0])
    y_freqs = fft.fftfreq(image.shape[1])
    z_freqs = fft.fftfreq(image.shape[2])
    coord_df = pd.DataFrame()
    coord_df["index_coords"] = [(x,y,z) for x in np.arange(image.shape[0]) for y in np.arange(image.shape[1]) for z in np.arange(image.shape[2])]
    coord_df["x_index"] = [x for x in np.arange(image.shape[0]) for y in np.arange(image.shape[1]) for z in np.arange(image.shape[2])]
    coord_df["y_index"] = [y for x in np.arange(image.shape[0]) for y in np.arange(image.shape[1]) for z in np.arange(image.shape[2])]
    coord_df["z_index"] = [z for x in np.arange(image.shape[0]) for y in np.arange(image.shape[1]) for z in np.arange(image.shape[2])]
    coord_df["x_freq"] = [x_freqs[x] for x in np.arange(image.shape[0]) for y in np.arange(image.shape[1]) for z in np.arange(image.shape[2])]
    coord_df["y_freq"] = [y_freqs[y] for x in np.arange(image.shape[0]) for y in np.arange(image.shape[1]) for z in np.arange(image.shape[2])]
    coord_df["z_freq"] = [z_freqs[z] for x in np.arange(image.shape[0]) for y in np.arange(image.shape[1]) for z in np.arange(image.shape[2])]
    coord_df["magnitude"] = np.sqrt(coord_df["x_freq"] ** 2 + coord_df["y_freq"] **2 + coord_df["z_freq"] ** 2)
    coord_df = coord_df.set_index(["index_coords"])
    coord_df = coord_df[(coord_df["x_freq"] >= 0 )& (coord_df["y_freq"] >= 0) & (coord_df["z_freq"] >= 0)]
    if no_zero:
        coord_df = coord_df[(coord_df["x_freq"] != 0 )| (coord_df["y_freq"] != 0)|(coord_df["z_freq"] != 0)]
    return coord_df

# %%
getIndexDF_3d(image)
# Out:
#                x_index  y_index  z_index   x_freq    y_freq   z_freq  \
# index_coords
# (0, 0, 0)            0        0        0  0.00000  0.000000  0.00000
# (0, 0, 1)            0        0        1  0.00000  0.000000  0.00625
# (0, 0, 2)            0        0        2  0.00000  0.000000  0.01250
# (0, 0, 3)            0        0        3  0.00000  0.000000  0.01875
# (0, 0, 4)            0        0        4  0.00000  0.000000  0.02500
# ...                ...      ...      ...      ...       ...      ...
# (79, 111, 75)       79      111       75  0.49375  0.495536  0.46875
# (79, 111, 76)       79      111       76  0.49375  0.495536  0.47500
# (79, 111, 77)       79      111       77  0.49375  0.495536  0.48125
# (79, 111, 78)       79      111       78  0.49375  0.495536  0.48750
# (79, 111, 79)       79      111       79  0.49375  0.495536  0.49375
#
#                magnitude
# index_coords
# (0, 0, 0)       0.000000
# (0, 0, 1)       0.006250
# (0, 0, 2)       0.012500
# (0, 0, 3)       0.018750
# (0, 0, 4)       0.025000
# ...                  ...
# (79, 111, 75)   0.842064
# (79, 111, 76)   0.845559
# (79, 111, 77)   0.849086
# (79, 111, 78)   0.852644
# (79, 111, 79)   0.856232
#
# [716800 rows x 7 columns]

# %%
file_list = [os.path.join(data_dir, filename) for filename in os.listdir(data_dir)]
image = nib.load(file_list[0]).get_fdata()
coord_df = getIndexDF_3d(image, no_zero =False).sort_values(["magnitude"])
x = coord_df["x_index"].to_numpy()
y = coord_df["y_index"].to_numpy()
z = coord_df["z_index"].to_numpy()
magnitudes = coord_df["magnitude"]
freq_arr = [0]*len(file_list)
mag_arr = [0]*len(file_list)
for k in range(len(file_list)):
        image = nib.load(file_list[0]).get_fdata()
        transformed = np.array(fft.fftn(image))
        freq_arr[k] = transformed[tuple(x), tuple(y), tuple(z)]
        mag_arr[k] = magnitudes
sample = np.concatenate(np.array(freq_arr).T)
mag_flat = np.concatenate(np.array(mag_arr).T)
sample, mag_flat
# Out:
# (array([4.77799335e+10    -0.j        , 4.77799335e+10    -0.j        ,
#         4.77799335e+10    -0.j        , ...,
#         1.80688674e+05-93447.97935265j, 1.80688674e+05-93447.97935265j,
#         1.80688674e+05-93447.97935265j]),
#  array([0.        , 0.        , 0.        , ..., 0.85623231, 0.85623231,
#         0.85623231]))

# %%
def convert_fourier_list_3d(folder_dir, ):
    file_list = [os.path.join(folder_dir, filename) for filename in os.listdir(folder_dir)]
    image = nib.load(file_list[0]).get_fdata()
    coord_df = getIndexDF_3d(image, no_zero =False).sort_values(["magnitude"])
    x = coord_df["x_index"].to_numpy()
    y = coord_df["y_index"].to_numpy()
    z = coord_df["z_index"].to_numpy()
    magnitudes = coord_df["magnitude"]
    freq_arr = [0]*len(file_list)
    mag_arr = [0]*len(file_list)
    for k in range(len(file_list)):
        image = nib.load(file_list[0]).get_fdata()
        transformed = np.array(fft.fftn(image))
        freq_arr[k] = transformed[tuple(x), tuple(y), tuple(z)]
        mag_arr[k] = magnitudes
    sample = np.concatenate(np.array(freq_arr).T)
    mag_flat = np.concatenate(np.array(mag_arr).T)
    return sample, mag_flat

# %%
def recursive_split(freqs, mags, threshold =0.05, max_depth = 5, presplit = 0):
    magnitude_splits = []
    def recursive_helper(freqs, mags, magnitude_splits, depth, presplit):
        if depth > 0 and mags[0] != mags[-1]:
            n = (mags[-1] + mags[0])/2
            idx = np.argmax(mags>n)
            if presplit > 0:
                stat = threshold + 1
            else:
                first_sample = np.concatenate([np.real(freqs[:idx]),np.imag(freqs[:idx])])
                second_sample = np.concatenate([np.real(freqs[idx:]),np.imag(freqs[idx:])])
                stat = stats.ks_2samp(first_sample, second_sample).statistic
            if stat > threshold:
                magnitude_splits.append(n)
                recursive_helper(freqs[:idx], mags[:idx], magnitude_splits, depth-1, max(presplit-1, 0))
                recursive_helper(freqs[idx:], mags[idx:], magnitude_splits, depth-1, max(presplit-1, 0))
        elif mags[0] == mags[-1]:
            print(f"Both Endpoints Are The Same {mags[0]} and {mags[-1]} Recursion Depth of {max_depth - depth}")
        elif depth == 0:
            print(f"Recursion Depth Exceeded Endpoints are {mags[0]} and {mags[-1]}")
    recursive_helper(freqs, mags, magnitude_splits, max_depth, presplit)
    return magnitude_splits

# %%
def convert_to_fourier_basis_3d(folder_dir, threshold =0.05, max_depth = 5, presplit = 0, split_list = None):
    freqs, mags = convert_fourier_list_3d(folder_dir)
    df = pd.DataFrame(columns=["band", "magnitude_endpoints","unique_magnitudes", "data"])

    if split_list == None:
        mag_splits = recursive_split(freqs, mags, threshold, max_depth, presplit)
    else:
        mag_splits = split_list
    
    sorted_mag_split = np.sort(mag_splits)
    print(sorted_mag_split)
    prev = 0
    for i in range(len(mag_splits)):
        next_idx = np.argmax(mags>=sorted_mag_split[i])
        next_freqs = np.concatenate([np.real(freqs[prev:next_idx]),np.imag(freqs[prev:next_idx])])
        num_mags = len(np.unique(mags[prev:next_idx]))
        mag_endpoints = (min(mags[prev:next_idx]), max(mags[prev:next_idx]))

        df.loc[len(df.index)] = [i+1, mag_endpoints, num_mags, next_freqs]
        prev = next_idx

    return df

# %%
converted = convert_to_fourier_basis_3d(data_dir, threshold =0.02, max_depth = 9, presplit= 2)
converted["number_of_coefficents"] = converted["data"].apply(lambda x:len(x))/(2 *n)
converted
# Out:
# Both Endpoints Are The Same 0.0 and 0.0 Recursion Depth of 8
# Both Endpoints Are The Same 0.004464285714285714 and 0.004464285714285714 Recursion Depth of 9
# Both Endpoints Are The Same 0.00625 and 0.00625 Recursion Depth of 9
# Both Endpoints Are The Same 0.007680647559859488 and 0.007680647559859488 Recursion Depth of 9
# Recursion Depth Exceeded Endpoints are 0.008838834764831846 and 0.00990226473786555
# Both Endpoints Are The Same 0.010898710371190806 and 0.010898710371190806 Recursion Depth of 9
# Recursion Depth Exceeded Endpoints are 0.0125 and 0.013273275667248667
# Recursion Depth Exceeded Endpoints are 0.013392857142857142 and 0.01477941549754183
# Recursion Depth Exceeded Endpoints are 0.015361295119718977 and 0.01658408537589885
# Recursion Depth Exceeded Endpoints are 0.01767766952966369 and 0.018750000000000003
# Recursion Depth Exceeded Endpoints are 0.018919303661086687 and 0.019924922861090533
# Recursion Depth Exceeded Endpoints are 0.02026215306769682 and 0.021687424645519857
# Recursion Depth Exceeded Endpoints are 0.021797420742381612 and 0.023179919617405658
# Recursion Depth Exceeded Endpoints are 0.023874539209144535 and 0.02512722728476837
# Recursion Depth Exceeded Endpoints are 0.02539546902379981 and 0.02663648908960053
# Recursion Depth Exceeded Endpoints are 0.026785714285714284 and 0.028206373212377348
# Recursion Depth Exceeded Endpoints are 0.028305120507406 and 0.0298139426019
# Recursion Depth Exceeded Endpoints are 0.030212364849443982 and 0.03171842797916359
# Recursion Depth Exceeded Endpoints are 0.03186887195995491 and 0.03328812836126294
# Recursion Depth Exceeded Endpoints are 0.033514864962720464 and 0.035004099614129744
# Recursion Depth Exceeded Endpoints are 0.03535533905932738 and 0.036715866419557305
# Recursion Depth Exceeded Endpoints are 0.03679178174649378 and 0.03840323779929744
# Recursion Depth Exceeded Endpoints are 0.0385275875185561 and 0.040019526483955306
# Recursion Depth Exceeded Endpoints are 0.040178571428571425 and 0.041735699616143734
# Recursion Depth Exceeded Endpoints are 0.041812033835600344 and 0.04337484929103971
# Recursion Depth Exceeded Endpoints are 0.043594841484763225 and 0.045087075617687856
# Recursion Depth Exceeded Endpoints are 0.04522830407826407 and 0.04677923891939191
# Recursion Depth Exceeded Endpoints are 0.047017216234577094 and 0.048478114144636535
# Recursion Depth Exceeded Endpoints are 0.048814060474416596 and 0.050198902845966425
# Recursion Depth Exceeded Endpoints are 0.05025445456953674 and 0.05178571428571429
# Recursion Depth Exceeded Endpoints are 0.051924076244816826 and 0.053459704928295375
# Recursion Depth Exceeded Endpoints are 0.053519319895163245 and 0.05511178343575345
# Recursion Depth Exceeded Endpoints are 0.05519850541454905 and 0.05682108063106186
# Recursion Depth Exceeded Endpoints are 0.05694020986965187 and 0.05854174988494824
# Recursion Depth Exceeded Endpoints are 0.058636995095908105 and 0.06019340639529706
# Recursion Depth Exceeded Endpoints are 0.06027281725620597 and 0.06187184335382292
# Recursion Depth Exceeded Endpoints are 0.061923360301427505 and 0.0635435833880646
# Recursion Depth Exceeded Endpoints are 0.06373774391990981 and 0.06530076608295196
# Recursion Depth Exceeded Endpoints are 0.065349579968358 and 0.06686897979768851
# Recursion Depth Exceeded Endpoints are 0.06692260607658396 and 0.06852933045530987
# Recursion Depth Exceeded Endpoints are 0.06863394657492004 and 0.07021854550368486
# Recursion Depth Exceeded Endpoints are 0.07024692236703908 and 0.07181813411496503
# Recursion Depth Exceeded Endpoints are 0.07196783046923799 and 0.07354563521503961
# Recursion Depth Exceeded Endpoints are 0.07358356349298756 and 0.0751327481657551
# Recursion Depth Exceeded Endpoints are 0.07525996611745185 and 0.0768583543452048
# Recursion Depth Exceeded Endpoints are 0.07691538055100633 and 0.07856128181235335
# Recursion Depth Exceeded Endpoints are 0.07861707278100007 and 0.08023303908755103
# Recursion Depth Exceeded Endpoints are 0.08028270361665706 and 0.0818755355178
# Recursion Depth Exceeded Endpoints are 0.08196798155377501 and 0.08357161935265159
# Recursion Depth Exceeded Endpoints are 0.08362406767120069 and 0.08518250215548608
# Recursion Depth Exceeded Endpoints are 0.08527603737874086 and 0.08686908106396635
# Recursion Depth Exceeded Endpoints are 0.08694246572842743 and 0.08851902971931505
# Recursion Depth Exceeded Endpoints are 0.0886090429922364 and 0.09024926507700093
# Recursion Depth Exceeded Endpoints are 0.09030224899452609 and 0.09190358607069184
# Recursion Depth Exceeded Endpoints are 0.09198162111231233 and 0.09357977743560816
# Recursion Depth Exceeded Endpoints are 0.09369896570117191 and 0.09530178302077447
# Recursion Depth Exceeded Endpoints are 0.09533105582170813 and 0.09695622828927307
# Recursion Depth Exceeded Endpoints are 0.09702609185162515 and 0.09865970426115192
# Recursion Depth Exceeded Endpoints are 0.09868798104146632 and 0.10034220783633072
# Recursion Depth Exceeded Endpoints are 0.10038986502630631 and 0.10199696123924877
# Recursion Depth Exceeded Endpoints are 0.1020243130787151 and 0.10364452469860624
# Recursion Depth Exceeded Endpoints are 0.10370603937110323 and 0.10536092608219595
# Recursion Depth Exceeded Endpoints are 0.10541009565172646 and 0.10701629429623302
# Recursion Depth Exceeded Endpoints are 0.10703863979032649 and 0.10869779417809579
# Recursion Depth Exceeded Endpoints are 0.10871979406919874 and 0.11036089915012695
# Recursion Depth Exceeded Endpoints are 0.11037534523948132 and 0.11200998725514595
# Recursion Depth Exceeded Endpoints are 0.1120811363363567 and 0.11370878374162657
# Recursion Depth Exceeded Endpoints are 0.11374733681565061 and 0.11537911665992459
# Recursion Depth Exceeded Endpoints are 0.11541365820387117 and 0.11705285632341225
# Recursion Depth Exceeded Endpoints are 0.11707328617893449 and 0.11869292398488476
# Recursion Depth Exceeded Endpoints are 0.11873321578485206 and 0.12039012371351357
# Recursion Depth Exceeded Endpoints are 0.1204430861020919 and 0.1220996425223335
# Recursion Depth Exceeded Endpoints are 0.12211269991115518 and 0.12377267365981055
# Recursion Depth Exceeded Endpoints are 0.12377911428287512 and 0.12543610150680104
# Recursion Depth Exceeded Endpoints are 0.12544881161945973 and 0.12710598381842209
# Recursion Depth Exceeded Endpoints are 0.12713106887566622 and 0.12877278379742663
# Recursion Depth Exceeded Endpoints are 0.12879444943040688 and 0.13044578688607206
# Recursion Depth Exceeded Endpoints are 0.13048550431651285 and 0.1321307909548995
# Recursion Depth Exceeded Endpoints are 0.13214587351769674 and 0.13378265861051633
# Recursion Depth Exceeded Endpoints are 0.1338005340354188 and 0.13537905024374325
# Recursion Depth Exceeded Endpoints are 0.13546146564048903 and 0.13708483240501193
# Recursion Depth Exceeded Endpoints are 0.13714587980299944 and 0.13879836902823448
# Recursion Depth Exceeded Endpoints are 0.1388155985765406 and 0.14045128158902645
# Recursion Depth Exceeded Endpoints are 0.14049384473407817 and 0.14213545386320037
# Recursion Depth Exceeded Endpoints are 0.1421719056821921 and 0.14381930450026095
# Recursion Depth Exceeded Endpoints are 0.14384978790249167 and 0.14550558408528522
# Recursion Depth Exceeded Endpoints are 0.14551654124363386 and 0.1471698354255507
# Recursion Depth Exceeded Endpoints are 0.14717525215517308 and 0.14882886779034202
# Recursion Depth Exceeded Endpoints are 0.14885296984828036 and 0.1505119876234692
# Recursion Depth Exceeded Endpoints are 0.1505199322349037 and 0.15218173128445706
# Recursion Depth Exceeded Endpoints are 0.15218958873184246 and 0.1538488980082969
# Recursion Depth Exceeded Endpoints are 0.153885165408018 and 0.1555391995673143
# Recursion Depth Exceeded Endpoints are 0.15554432483956437 and 0.15719611516334933
# Recursion Depth Exceeded Endpoints are 0.15723161048826884 and 0.15886334937772842
# Recursion Depth Exceeded Endpoints are 0.15889094658967598 and 0.16054058073030786
# Recursion Depth Exceeded Endpoints are 0.16055795968548972 and 0.162217670751622
# Recursion Depth Exceeded Endpoints are 0.16222749914731424 and 0.16388975964448338
# Recursion Depth Exceeded Endpoints are 0.16390435161883846 and 0.16556422161684525
# Recursion Depth Exceeded Endpoints are 0.16556662910583578 and 0.16722430097547036
# Recursion Depth Exceeded Endpoints are 0.16724813534240138 and 0.16890818360812457
# Recursion Depth Exceeded Endpoints are 0.16891762271979238 and 0.17058011762984643
# Recursion Depth Exceeded Endpoints are 0.17058479099370888 and 0.17224045099564642
# Recursion Depth Exceeded Endpoints are 0.17225664955619718 and 0.17391702073701937
# Recursion Depth Exceeded Endpoints are 0.17393306315701934 and 0.17558212218974076
# Recursion Depth Exceeded Endpoints are 0.1756229800522955 and 0.1772698097792844
# Recursion Depth Exceeded Endpoints are 0.17728330046129268 and 0.17893044267627164
# Recursion Depth Exceeded Endpoints are 0.17897276329095443 and 0.18060670499113568
# Recursion Depth Exceeded Endpoints are 0.18063760018899946 and 0.18228723269631814
# Recursion Depth Exceeded Endpoints are 0.18230253854849218 and 0.18396324222462465
# Recursion Depth Exceeded Endpoints are 0.18397407550843592 and 0.1856176774821772
# Recursion Depth Exceeded Endpoints are 0.18563485595355728 and 0.1872936790013949
# Recursion Depth Exceeded Endpoints are 0.18730857575407597 and 0.1889716903266147
# Recursion Depth Exceeded Endpoints are 0.1889843456695905 and 0.1906474769284495
# Recursion Depth Exceeded Endpoints are 0.19066211164341626 and 0.1923231695106241
# Recursion Depth Exceeded Endpoints are 0.19233353191786398 and 0.19398849705535612
# Recursion Depth Exceeded Endpoints are 0.19399671586216638 and 0.19565798525457007
# Recursion Depth Exceeded Endpoints are 0.19566409679731794 and 0.19732546860763941
# Recursion Depth Exceeded Endpoints are 0.1973396080830388 and 0.1990010127140676
# Recursion Depth Exceeded Endpoints are 0.1990090245107862 and 0.2006764707641814
# Recursion Depth Exceeded Endpoints are 0.20068441567266143 and 0.20235184489560026
# Recursion Depth Exceeded Endpoints are 0.20236169376154375 and 0.20402127615140775
# Recursion Depth Exceeded Endpoints are 0.2040271371756258 and 0.2056810333988042
# Recursion Depth Exceeded Endpoints are 0.2056965363126477 and 0.20736402909189552
# Recursion Depth Exceeded Endpoints are 0.20737748411620618 and 0.20902012645988452
# Recursion Depth Exceeded Endpoints are 0.20903347488488294 and 0.21068780099900403
# Recursion Depth Exceeded Endpoints are 0.21072185216439188 and 0.21238930189918817
# Recursion Depth Exceeded Endpoints are 0.21239868533164757 and 0.21405679736929636
# Recursion Depth Exceeded Endpoints are 0.25419628744539213 and 0.2558421343408502
# Recursion Depth Exceeded Endpoints are 0.25586394513171906 and 0.2575269948203964
# Recursion Depth Exceeded Endpoints are 0.2608824066548774 and 0.26254858636846945
# Recursion Depth Exceeded Endpoints are 0.2625546590323467 and 0.2642178363604933
# Recursion Depth Exceeded Endpoints are 0.26757574504565 and 0.2692434364310939
# Recursion Depth Exceeded Endpoints are 0.26924935809902073 and 0.27091410360225293
# Recursion Depth Exceeded Endpoints are 0.27092293128097805 and 0.2725906163694067
# Recursion Depth Exceeded Endpoints are 0.2725964653258792 and 0.27425978765114106
# Recursion Depth Exceeded Endpoints are 0.2943301912471635 and 0.2959952728180169
# Recursion Depth Exceeded Endpoints are 0.29600200590536546 and 0.29767112639588666
# Recursion Depth Exceeded Endpoints are 0.30102265110717474 and 0.3026904232824996
# Recursion Depth Exceeded Endpoints are 0.3026956906241795 and 0.3043634625689141
# Recursion Depth Exceeded Endpoints are 0.3043726296894674 and 0.30603647283302954
# Recursion Depth Exceeded Endpoints are 0.30604168258521885 and 0.30770556842009655
# Recursion Depth Exceeded Endpoints are 0.38129495385689893 and 0.3829628635350153
# Recursion Depth Exceeded Endpoints are 0.382968067619647 and 0.38463493989729525
# Recursion Depth Exceeded Endpoints are 0.3846390850723651 and 0.38630700160597137
# Recursion Depth Exceeded Endpoints are 0.38631112883957425 and 0.38797904885050016
# [0.003125   0.00535714 0.00663664 0.00879146 0.01047696 0.01208599
#  0.01331824 0.01498847 0.01665889 0.0188013  0.02001467 0.02172104
#  0.02344932 0.02525551 0.02672985 0.02829983 0.03003692 0.03175025
#  0.03340262 0.03511537 0.0367672  0.03840565 0.04012271 0.04177671
#  0.04347891 0.04518704 0.04681914 0.04860806 0.05023846 0.05185708
#  0.05350815 0.0551702  0.05685636 0.05856681 0.06019415 0.0619082
#  0.0635709  0.06530336 0.06687618 0.06857058 0.07023412 0.07189628
#  0.07357782 0.07522096 0.0769083  0.07857421 0.08026781 0.08192716
#  0.08357589 0.08524657 0.08693124 0.08859587 0.09026112 0.09194101
#  0.0936495  0.0953276  0.09702059 0.09868415 0.10035763 0.10201719
#  0.10370308 0.10536117 0.1070284  0.10869977 0.11037371 0.11204206
#  0.11371438 0.1154001  0.11706873 0.1187317  0.12041065 0.12210788
#  0.12377453 0.12544255 0.12711287 0.12878843 0.13045686 0.13213408
#  0.13378961 0.13544268 0.13712591 0.13879858 0.14048518 0.14215657
#  0.14383184 0.14550981 0.14717056 0.14884362 0.15051208 0.15218442
#  0.15385792 0.15554064 0.15721287 0.1588861  0.16054772 0.16222386
#  0.16389113 0.16556433 0.16723749 0.16891413 0.17058258 0.17225091
#  0.17392582 0.17560144 0.17726988 0.178945   0.18061337 0.18230042
#  0.18396564 0.18563388 0.18730738 0.18897803 0.19064854 0.1923253
#  0.19399252 0.19566109 0.19733659 0.19900804 0.20068269 0.20235285
#  0.20402422 0.20569558 0.20737061 0.20903264 0.21071714 0.21238932
#  0.21405773 0.22743104 0.23411838 0.24081273 0.25419091 0.25586164
#  0.25753858 0.26088155 0.26255012 0.26422461 0.26756991 0.26924492
#  0.27091777 0.27259136 0.27426044 0.28095026 0.29432845 0.29600066
#  0.29767245 0.30101788 0.30269306 0.30436411 0.3060391  0.30770568
#  0.3143979  0.32108706 0.3344619  0.34784171 0.36122015 0.37460203
#  0.38129278 0.38296495 0.384637   0.38630907 0.38798271 0.39132412
#  0.39467103 0.40136098 0.40804929 0.41473867 0.42811616 0.44149507
#  0.45487367 0.48163105 0.49501021 0.50838906 0.5217675  0.5351451
#  0.56190265 0.58865958 0.60203738 0.61541663 0.64217481 0.69568408
#  0.74920383]
#     band                           magnitude_endpoints unique_magnitudes  \
# 0      1                                    (0.0, 0.0)                 1
# 1      2  (0.004464285714285714, 0.004464285714285714)                 1
# 2      3                            (0.00625, 0.00625)                 1
# 3      4  (0.007680647559859488, 0.007680647559859488)                 1
# 4      5   (0.008838834764831846, 0.00990226473786555)                 3
# ..   ...                                           ...               ...
# 176  177       (0.588660382494327, 0.6020360331442642)              6237
# 177  178      (0.6020386814645649, 0.6154143752922308)              6060
# 178  179      (0.6154182614121813, 0.6421728749141544)             11160
# 179  180       (0.6421753577108206, 0.695682980008473)             17806
# 180  181      (0.6956869907009993, 0.7491928054205256)              9709
#
#                                                   data  number_of_coefficents
# 0    [47779933484.0, 47779933484.0, 47779933484.0, ...                    1.0
# 1    [-16214758521.574413, -16214758521.574413, -16...                    1.0
# 2    [-9879205199.709785, -9879205199.709785, -9879...                    2.0
# 3    [2829991022.1984396, 2829991022.1984396, 28299...                    2.0
# 4    [3513628056.67588, 3513628056.67588, 351362805...                    3.0
# ..                                                 ...                    ...
# 176  [925462.3097729231, 925462.3097729231, 925462....                21719.0
# 177  [1010516.5748960951, 1010516.5748960951, 10105...                20236.0
# 178  [-492288.67960672657, -492288.67960672657, -49...                35646.0
# 179  [-584576.5780511233, -584576.5780511233, -5845...                49514.0
# 180  [-288305.1917897236, -288305.1917897236, -2883...                21000.0
#
# [181 rows x 5 columns]

# %%
converted = convert_to_fourier_basis_3d(data_dir, threshold =0.02, max_depth = 9, presplit= 0)
converted["number_of_coefficents"] = converted["data"].apply(lambda x:len(x))/(2 *n)
converted
# Out:
# Both Endpoints Are The Same 0.0 and 0.0 Recursion Depth of 8
# Both Endpoints Are The Same 0.004464285714285714 and 0.004464285714285714 Recursion Depth of 9
# Both Endpoints Are The Same 0.00625 and 0.00625 Recursion Depth of 9
# Both Endpoints Are The Same 0.007680647559859488 and 0.007680647559859488 Recursion Depth of 9
# Recursion Depth Exceeded Endpoints are 0.008838834764831846 and 0.00990226473786555
# Both Endpoints Are The Same 0.010898710371190806 and 0.010898710371190806 Recursion Depth of 9
# Recursion Depth Exceeded Endpoints are 0.0125 and 0.013273275667248667
# Recursion Depth Exceeded Endpoints are 0.013392857142857142 and 0.01477941549754183
# Recursion Depth Exceeded Endpoints are 0.015361295119718977 and 0.01658408537589885
# Recursion Depth Exceeded Endpoints are 0.01767766952966369 and 0.018750000000000003
# Recursion Depth Exceeded Endpoints are 0.018919303661086687 and 0.019924922861090533
# Recursion Depth Exceeded Endpoints are 0.02026215306769682 and 0.021687424645519857
# Recursion Depth Exceeded Endpoints are 0.021797420742381612 and 0.023179919617405658
# Recursion Depth Exceeded Endpoints are 0.023874539209144535 and 0.02512722728476837
# Recursion Depth Exceeded Endpoints are 0.02539546902379981 and 0.02663648908960053
# Recursion Depth Exceeded Endpoints are 0.026785714285714284 and 0.028206373212377348
# Recursion Depth Exceeded Endpoints are 0.028305120507406 and 0.0298139426019
# Recursion Depth Exceeded Endpoints are 0.030212364849443982 and 0.03171842797916359
# Recursion Depth Exceeded Endpoints are 0.03186887195995491 and 0.03328812836126294
# Recursion Depth Exceeded Endpoints are 0.033514864962720464 and 0.035004099614129744
# Recursion Depth Exceeded Endpoints are 0.03535533905932738 and 0.036715866419557305
# Recursion Depth Exceeded Endpoints are 0.03679178174649378 and 0.03840323779929744
# Recursion Depth Exceeded Endpoints are 0.0385275875185561 and 0.040019526483955306
# Recursion Depth Exceeded Endpoints are 0.040178571428571425 and 0.041735699616143734
# Recursion Depth Exceeded Endpoints are 0.041812033835600344 and 0.04337484929103971
# Recursion Depth Exceeded Endpoints are 0.043594841484763225 and 0.045087075617687856
# Recursion Depth Exceeded Endpoints are 0.04522830407826407 and 0.04677923891939191
# Recursion Depth Exceeded Endpoints are 0.047017216234577094 and 0.048478114144636535
# Recursion Depth Exceeded Endpoints are 0.048814060474416596 and 0.050198902845966425
# Recursion Depth Exceeded Endpoints are 0.05025445456953674 and 0.05178571428571429
# Recursion Depth Exceeded Endpoints are 0.051924076244816826 and 0.053459704928295375
# Recursion Depth Exceeded Endpoints are 0.053519319895163245 and 0.05511178343575345
# Recursion Depth Exceeded Endpoints are 0.05519850541454905 and 0.05682108063106186
# Recursion Depth Exceeded Endpoints are 0.05694020986965187 and 0.05854174988494824
# Recursion Depth Exceeded Endpoints are 0.058636995095908105 and 0.06019340639529706
# Recursion Depth Exceeded Endpoints are 0.06027281725620597 and 0.06187184335382292
# Recursion Depth Exceeded Endpoints are 0.061923360301427505 and 0.0635435833880646
# Recursion Depth Exceeded Endpoints are 0.06373774391990981 and 0.06530076608295196
# Recursion Depth Exceeded Endpoints are 0.065349579968358 and 0.06686897979768851
# Recursion Depth Exceeded Endpoints are 0.06692260607658396 and 0.06852933045530987
# Recursion Depth Exceeded Endpoints are 0.06863394657492004 and 0.07021854550368486
# Recursion Depth Exceeded Endpoints are 0.07024692236703908 and 0.07181813411496503
# Recursion Depth Exceeded Endpoints are 0.07196783046923799 and 0.07354563521503961
# Recursion Depth Exceeded Endpoints are 0.07358356349298756 and 0.0751327481657551
# Recursion Depth Exceeded Endpoints are 0.07525996611745185 and 0.0768583543452048
# Recursion Depth Exceeded Endpoints are 0.07691538055100633 and 0.07856128181235335
# Recursion Depth Exceeded Endpoints are 0.07861707278100007 and 0.08023303908755103
# Recursion Depth Exceeded Endpoints are 0.08028270361665706 and 0.0818755355178
# Recursion Depth Exceeded Endpoints are 0.08196798155377501 and 0.08357161935265159
# Recursion Depth Exceeded Endpoints are 0.08362406767120069 and 0.08518250215548608
# Recursion Depth Exceeded Endpoints are 0.08527603737874086 and 0.08686908106396635
# Recursion Depth Exceeded Endpoints are 0.08694246572842743 and 0.08851902971931505
# Recursion Depth Exceeded Endpoints are 0.0886090429922364 and 0.09024926507700093
# Recursion Depth Exceeded Endpoints are 0.09030224899452609 and 0.09190358607069184
# Recursion Depth Exceeded Endpoints are 0.09198162111231233 and 0.09357977743560816
# Recursion Depth Exceeded Endpoints are 0.09369896570117191 and 0.09530178302077447
# Recursion Depth Exceeded Endpoints are 0.09533105582170813 and 0.09695622828927307
# Recursion Depth Exceeded Endpoints are 0.09702609185162515 and 0.09865970426115192
# Recursion Depth Exceeded Endpoints are 0.09868798104146632 and 0.10034220783633072
# Recursion Depth Exceeded Endpoints are 0.10038986502630631 and 0.10199696123924877
# Recursion Depth Exceeded Endpoints are 0.1020243130787151 and 0.10364452469860624
# Recursion Depth Exceeded Endpoints are 0.10370603937110323 and 0.10536092608219595
# Recursion Depth Exceeded Endpoints are 0.10541009565172646 and 0.10701629429623302
# Recursion Depth Exceeded Endpoints are 0.10703863979032649 and 0.10869779417809579
# Recursion Depth Exceeded Endpoints are 0.10871979406919874 and 0.11036089915012695
# Recursion Depth Exceeded Endpoints are 0.11037534523948132 and 0.11200998725514595
# Recursion Depth Exceeded Endpoints are 0.1120811363363567 and 0.11370878374162657
# Recursion Depth Exceeded Endpoints are 0.11374733681565061 and 0.11537911665992459
# Recursion Depth Exceeded Endpoints are 0.11541365820387117 and 0.11705285632341225
# Recursion Depth Exceeded Endpoints are 0.11707328617893449 and 0.11869292398488476
# Recursion Depth Exceeded Endpoints are 0.11873321578485206 and 0.12039012371351357
# Recursion Depth Exceeded Endpoints are 0.1204430861020919 and 0.1220996425223335
# Recursion Depth Exceeded Endpoints are 0.12211269991115518 and 0.12377267365981055
# Recursion Depth Exceeded Endpoints are 0.12377911428287512 and 0.12543610150680104
# Recursion Depth Exceeded Endpoints are 0.12544881161945973 and 0.12710598381842209
# Recursion Depth Exceeded Endpoints are 0.12713106887566622 and 0.12877278379742663
# Recursion Depth Exceeded Endpoints are 0.12879444943040688 and 0.13044578688607206
# Recursion Depth Exceeded Endpoints are 0.13048550431651285 and 0.1321307909548995
# Recursion Depth Exceeded Endpoints are 0.13214587351769674 and 0.13378265861051633
# Recursion Depth Exceeded Endpoints are 0.1338005340354188 and 0.13537905024374325
# Recursion Depth Exceeded Endpoints are 0.13546146564048903 and 0.13708483240501193
# Recursion Depth Exceeded Endpoints are 0.13714587980299944 and 0.13879836902823448
# Recursion Depth Exceeded Endpoints are 0.1388155985765406 and 0.14045128158902645
# Recursion Depth Exceeded Endpoints are 0.14049384473407817 and 0.14213545386320037
# Recursion Depth Exceeded Endpoints are 0.1421719056821921 and 0.14381930450026095
# Recursion Depth Exceeded Endpoints are 0.14384978790249167 and 0.14550558408528522
# Recursion Depth Exceeded Endpoints are 0.14551654124363386 and 0.1471698354255507
# Recursion Depth Exceeded Endpoints are 0.14717525215517308 and 0.14882886779034202
# Recursion Depth Exceeded Endpoints are 0.14885296984828036 and 0.1505119876234692
# Recursion Depth Exceeded Endpoints are 0.1505199322349037 and 0.15218173128445706
# Recursion Depth Exceeded Endpoints are 0.15218958873184246 and 0.1538488980082969
# Recursion Depth Exceeded Endpoints are 0.153885165408018 and 0.1555391995673143
# Recursion Depth Exceeded Endpoints are 0.15554432483956437 and 0.15719611516334933
# Recursion Depth Exceeded Endpoints are 0.15723161048826884 and 0.15886334937772842
# Recursion Depth Exceeded Endpoints are 0.15889094658967598 and 0.16054058073030786
# Recursion Depth Exceeded Endpoints are 0.16055795968548972 and 0.162217670751622
# Recursion Depth Exceeded Endpoints are 0.16222749914731424 and 0.16388975964448338
# Recursion Depth Exceeded Endpoints are 0.16390435161883846 and 0.16556422161684525
# Recursion Depth Exceeded Endpoints are 0.16556662910583578 and 0.16722430097547036
# Recursion Depth Exceeded Endpoints are 0.16724813534240138 and 0.16890818360812457
# Recursion Depth Exceeded Endpoints are 0.16891762271979238 and 0.17058011762984643
# Recursion Depth Exceeded Endpoints are 0.17058479099370888 and 0.17224045099564642
# Recursion Depth Exceeded Endpoints are 0.17225664955619718 and 0.17391702073701937
# Recursion Depth Exceeded Endpoints are 0.17393306315701934 and 0.17558212218974076
# Recursion Depth Exceeded Endpoints are 0.1756229800522955 and 0.1772698097792844
# Recursion Depth Exceeded Endpoints are 0.17728330046129268 and 0.17893044267627164
# Recursion Depth Exceeded Endpoints are 0.17897276329095443 and 0.18060670499113568
# Recursion Depth Exceeded Endpoints are 0.18063760018899946 and 0.18228723269631814
# Recursion Depth Exceeded Endpoints are 0.18230253854849218 and 0.18396324222462465
# Recursion Depth Exceeded Endpoints are 0.18397407550843592 and 0.1856176774821772
# Recursion Depth Exceeded Endpoints are 0.18563485595355728 and 0.1872936790013949
# Recursion Depth Exceeded Endpoints are 0.18730857575407597 and 0.1889716903266147
# Recursion Depth Exceeded Endpoints are 0.1889843456695905 and 0.1906474769284495
# Recursion Depth Exceeded Endpoints are 0.19066211164341626 and 0.1923231695106241
# Recursion Depth Exceeded Endpoints are 0.19233353191786398 and 0.19398849705535612
# Recursion Depth Exceeded Endpoints are 0.19399671586216638 and 0.19565798525457007
# Recursion Depth Exceeded Endpoints are 0.19566409679731794 and 0.19732546860763941
# Recursion Depth Exceeded Endpoints are 0.1973396080830388 and 0.1990010127140676
# Recursion Depth Exceeded Endpoints are 0.1990090245107862 and 0.2006764707641814
# Recursion Depth Exceeded Endpoints are 0.20068441567266143 and 0.20235184489560026
# Recursion Depth Exceeded Endpoints are 0.20236169376154375 and 0.20402127615140775
# Recursion Depth Exceeded Endpoints are 0.2040271371756258 and 0.2056810333988042
# Recursion Depth Exceeded Endpoints are 0.2056965363126477 and 0.20736402909189552
# Recursion Depth Exceeded Endpoints are 0.20737748411620618 and 0.20902012645988452
# Recursion Depth Exceeded Endpoints are 0.20903347488488294 and 0.21068780099900403
# Recursion Depth Exceeded Endpoints are 0.21072185216439188 and 0.21238930189918817
# Recursion Depth Exceeded Endpoints are 0.21239868533164757 and 0.21405679736929636
# Recursion Depth Exceeded Endpoints are 0.25419628744539213 and 0.2558421343408502
# Recursion Depth Exceeded Endpoints are 0.25586394513171906 and 0.2575269948203964
# Recursion Depth Exceeded Endpoints are 0.2608824066548774 and 0.26254858636846945
# Recursion Depth Exceeded Endpoints are 0.2625546590323467 and 0.2642178363604933
# Recursion Depth Exceeded Endpoints are 0.26757574504565 and 0.2692434364310939
# Recursion Depth Exceeded Endpoints are 0.26924935809902073 and 0.27091410360225293
# Recursion Depth Exceeded Endpoints are 0.27092293128097805 and 0.2725906163694067
# Recursion Depth Exceeded Endpoints are 0.2725964653258792 and 0.27425978765114106
# Recursion Depth Exceeded Endpoints are 0.2943301912471635 and 0.2959952728180169
# Recursion Depth Exceeded Endpoints are 0.29600200590536546 and 0.29767112639588666
# Recursion Depth Exceeded Endpoints are 0.30102265110717474 and 0.3026904232824996
# Recursion Depth Exceeded Endpoints are 0.3026956906241795 and 0.3043634625689141
# Recursion Depth Exceeded Endpoints are 0.3043726296894674 and 0.30603647283302954
# Recursion Depth Exceeded Endpoints are 0.30604168258521885 and 0.30770556842009655
# Recursion Depth Exceeded Endpoints are 0.38129495385689893 and 0.3829628635350153
# Recursion Depth Exceeded Endpoints are 0.382968067619647 and 0.38463493989729525
# Recursion Depth Exceeded Endpoints are 0.3846390850723651 and 0.38630700160597137
# Recursion Depth Exceeded Endpoints are 0.38631112883957425 and 0.38797904885050016
# [0.003125   0.00535714 0.00663664 0.00879146 0.01047696 0.01208599
#  0.01331824 0.01498847 0.01665889 0.0188013  0.02001467 0.02172104
#  0.02344932 0.02525551 0.02672985 0.02829983 0.03003692 0.03175025
#  0.03340262 0.03511537 0.0367672  0.03840565 0.04012271 0.04177671
#  0.04347891 0.04518704 0.04681914 0.04860806 0.05023846 0.05185708
#  0.05350815 0.0551702  0.05685636 0.05856681 0.06019415 0.0619082
#  0.0635709  0.06530336 0.06687618 0.06857058 0.07023412 0.07189628
#  0.07357782 0.07522096 0.0769083  0.07857421 0.08026781 0.08192716
#  0.08357589 0.08524657 0.08693124 0.08859587 0.09026112 0.09194101
#  0.0936495  0.0953276  0.09702059 0.09868415 0.10035763 0.10201719
#  0.10370308 0.10536117 0.1070284  0.10869977 0.11037371 0.11204206
#  0.11371438 0.1154001  0.11706873 0.1187317  0.12041065 0.12210788
#  0.12377453 0.12544255 0.12711287 0.12878843 0.13045686 0.13213408
#  0.13378961 0.13544268 0.13712591 0.13879858 0.14048518 0.14215657
#  0.14383184 0.14550981 0.14717056 0.14884362 0.15051208 0.15218442
#  0.15385792 0.15554064 0.15721287 0.1588861  0.16054772 0.16222386
#  0.16389113 0.16556433 0.16723749 0.16891413 0.17058258 0.17225091
#  0.17392582 0.17560144 0.17726988 0.178945   0.18061337 0.18230042
#  0.18396564 0.18563388 0.18730738 0.18897803 0.19064854 0.1923253
#  0.19399252 0.19566109 0.19733659 0.19900804 0.20068269 0.20235285
#  0.20402422 0.20569558 0.20737061 0.20903264 0.21071714 0.21238932
#  0.21405773 0.22743104 0.23411838 0.24081273 0.25419091 0.25586164
#  0.25753858 0.26088155 0.26255012 0.26422461 0.26756991 0.26924492
#  0.27091777 0.27259136 0.27426044 0.28095026 0.29432845 0.29600066
#  0.29767245 0.30101788 0.30269306 0.30436411 0.3060391  0.30770568
#  0.3143979  0.32108706 0.3344619  0.34784171 0.36122015 0.37460203
#  0.38129278 0.38296495 0.384637   0.38630907 0.38798271 0.39132412
#  0.39467103 0.40136098 0.40804929 0.41473867 0.42811616 0.44149507
#  0.45487367 0.48163105 0.49501021 0.50838906 0.5217675  0.5351451
#  0.56190265 0.58865958 0.60203738 0.61541663 0.64217481 0.69568408
#  0.74920383]
#     band                           magnitude_endpoints unique_magnitudes  \
# 0      1                                    (0.0, 0.0)                 1
# 1      2  (0.004464285714285714, 0.004464285714285714)                 1
# 2      3                            (0.00625, 0.00625)                 1
# 3      4  (0.007680647559859488, 0.007680647559859488)                 1
# 4      5   (0.008838834764831846, 0.00990226473786555)                 3
# ..   ...                                           ...               ...
# 176  177       (0.588660382494327, 0.6020360331442642)              6237
# 177  178      (0.6020386814645649, 0.6154143752922308)              6060
# 178  179      (0.6154182614121813, 0.6421728749141544)             11160
# 179  180       (0.6421753577108206, 0.695682980008473)             17806
# 180  181      (0.6956869907009993, 0.7491928054205256)              9709
#
#                                                   data  number_of_coefficents
# 0    [47779933484.0, 47779933484.0, 47779933484.0, ...                    1.0
# 1    [-16214758521.574413, -16214758521.574413, -16...                    1.0
# 2    [-9879205199.709785, -9879205199.709785, -9879...                    2.0
# 3    [2829991022.1984396, 2829991022.1984396, 28299...                    2.0
# 4    [3513628056.67588, 3513628056.67588, 351362805...                    3.0
# ..                                                 ...                    ...
# 176  [925462.3097729231, 925462.3097729231, 925462....                21719.0
# 177  [1010516.5748960951, 1010516.5748960951, 10105...                20236.0
# 178  [-492288.67960672657, -492288.67960672657, -49...                35646.0
# 179  [-584576.5780511233, -584576.5780511233, -5845...                49514.0
# 180  [-288305.1917897236, -288305.1917897236, -2883...                21000.0
#
# [181 rows x 5 columns]

# %%
converted = convert_to_fourier_basis_3d(data_dir, threshold =0.03, max_depth = 9)
converted["number_of_coefficents"] = converted["data"].apply(lambda x:len(x))/(2 *n)
converted
# Out:
# Both Endpoints Are The Same 0.0 and 0.0 Recursion Depth of 8
# Both Endpoints Are The Same 0.004464285714285714 and 0.004464285714285714 Recursion Depth of 9
# Both Endpoints Are The Same 0.00625 and 0.00625 Recursion Depth of 9
# Both Endpoints Are The Same 0.007680647559859488 and 0.007680647559859488 Recursion Depth of 9
# Recursion Depth Exceeded Endpoints are 0.008838834764831846 and 0.00990226473786555
# Both Endpoints Are The Same 0.010898710371190806 and 0.010898710371190806 Recursion Depth of 9
# Recursion Depth Exceeded Endpoints are 0.0125 and 0.013273275667248667
# Recursion Depth Exceeded Endpoints are 0.013392857142857142 and 0.01477941549754183
# Recursion Depth Exceeded Endpoints are 0.015361295119718977 and 0.01658408537589885
# Recursion Depth Exceeded Endpoints are 0.01767766952966369 and 0.018750000000000003
# Recursion Depth Exceeded Endpoints are 0.018919303661086687 and 0.019924922861090533
# Recursion Depth Exceeded Endpoints are 0.02026215306769682 and 0.021687424645519857
# Recursion Depth Exceeded Endpoints are 0.021797420742381612 and 0.023179919617405658
# Recursion Depth Exceeded Endpoints are 0.023874539209144535 and 0.02512722728476837
# Recursion Depth Exceeded Endpoints are 0.02539546902379981 and 0.02663648908960053
# Recursion Depth Exceeded Endpoints are 0.026785714285714284 and 0.028206373212377348
# Recursion Depth Exceeded Endpoints are 0.028305120507406 and 0.0298139426019
# Recursion Depth Exceeded Endpoints are 0.030212364849443982 and 0.03171842797916359
# Recursion Depth Exceeded Endpoints are 0.03186887195995491 and 0.03328812836126294
# Recursion Depth Exceeded Endpoints are 0.033514864962720464 and 0.035004099614129744
# Recursion Depth Exceeded Endpoints are 0.03535533905932738 and 0.036715866419557305
# Recursion Depth Exceeded Endpoints are 0.03679178174649378 and 0.03840323779929744
# Recursion Depth Exceeded Endpoints are 0.0385275875185561 and 0.040019526483955306
# Recursion Depth Exceeded Endpoints are 0.040178571428571425 and 0.041735699616143734
# Recursion Depth Exceeded Endpoints are 0.041812033835600344 and 0.04337484929103971
# Recursion Depth Exceeded Endpoints are 0.043594841484763225 and 0.045087075617687856
# Recursion Depth Exceeded Endpoints are 0.04522830407826407 and 0.04677923891939191
# Recursion Depth Exceeded Endpoints are 0.047017216234577094 and 0.048478114144636535
# Recursion Depth Exceeded Endpoints are 0.048814060474416596 and 0.050198902845966425
# Recursion Depth Exceeded Endpoints are 0.05025445456953674 and 0.05178571428571429
# Recursion Depth Exceeded Endpoints are 0.051924076244816826 and 0.053459704928295375
# Recursion Depth Exceeded Endpoints are 0.053519319895163245 and 0.05511178343575345
# Recursion Depth Exceeded Endpoints are 0.05519850541454905 and 0.05682108063106186
# Recursion Depth Exceeded Endpoints are 0.05694020986965187 and 0.05854174988494824
# Recursion Depth Exceeded Endpoints are 0.058636995095908105 and 0.06019340639529706
# Recursion Depth Exceeded Endpoints are 0.06027281725620597 and 0.06187184335382292
# Recursion Depth Exceeded Endpoints are 0.061923360301427505 and 0.0635435833880646
# Recursion Depth Exceeded Endpoints are 0.06373774391990981 and 0.06530076608295196
# Recursion Depth Exceeded Endpoints are 0.065349579968358 and 0.06686897979768851
# Recursion Depth Exceeded Endpoints are 0.06692260607658396 and 0.06852933045530987
# Recursion Depth Exceeded Endpoints are 0.06863394657492004 and 0.07021854550368486
# Recursion Depth Exceeded Endpoints are 0.07024692236703908 and 0.07181813411496503
# Recursion Depth Exceeded Endpoints are 0.07196783046923799 and 0.07354563521503961
# Recursion Depth Exceeded Endpoints are 0.07358356349298756 and 0.0751327481657551
# Recursion Depth Exceeded Endpoints are 0.07525996611745185 and 0.0768583543452048
# Recursion Depth Exceeded Endpoints are 0.07691538055100633 and 0.07856128181235335
# Recursion Depth Exceeded Endpoints are 0.07861707278100007 and 0.08023303908755103
# Recursion Depth Exceeded Endpoints are 0.08028270361665706 and 0.0818755355178
# Recursion Depth Exceeded Endpoints are 0.08196798155377501 and 0.08357161935265159
# Recursion Depth Exceeded Endpoints are 0.08362406767120069 and 0.08518250215548608
# Recursion Depth Exceeded Endpoints are 0.08527603737874086 and 0.08686908106396635
# Recursion Depth Exceeded Endpoints are 0.08694246572842743 and 0.08851902971931505
# Recursion Depth Exceeded Endpoints are 0.0886090429922364 and 0.09024926507700093
# Recursion Depth Exceeded Endpoints are 0.09030224899452609 and 0.09190358607069184
# Recursion Depth Exceeded Endpoints are 0.09198162111231233 and 0.09357977743560816
# Recursion Depth Exceeded Endpoints are 0.09369896570117191 and 0.09530178302077447
# Recursion Depth Exceeded Endpoints are 0.09533105582170813 and 0.09695622828927307
# Recursion Depth Exceeded Endpoints are 0.10038986502630631 and 0.10199696123924877
# Recursion Depth Exceeded Endpoints are 0.1020243130787151 and 0.10364452469860624
# Recursion Depth Exceeded Endpoints are 0.10370603937110323 and 0.10536092608219595
# Recursion Depth Exceeded Endpoints are 0.10541009565172646 and 0.10701629429623302
# Recursion Depth Exceeded Endpoints are 0.10703863979032649 and 0.10869779417809579
# Recursion Depth Exceeded Endpoints are 0.10871979406919874 and 0.11036089915012695
# Recursion Depth Exceeded Endpoints are 0.11037534523948132 and 0.11200998725514595
# Recursion Depth Exceeded Endpoints are 0.1120811363363567 and 0.11370878374162657
# Recursion Depth Exceeded Endpoints are 0.11374733681565061 and 0.11537911665992459
# Recursion Depth Exceeded Endpoints are 0.11541365820387117 and 0.11705285632341225
# Recursion Depth Exceeded Endpoints are 0.11707328617893449 and 0.11869292398488476
# Recursion Depth Exceeded Endpoints are 0.11873321578485206 and 0.12039012371351357
# Recursion Depth Exceeded Endpoints are 0.1204430861020919 and 0.1220996425223335
# Recursion Depth Exceeded Endpoints are 0.12211269991115518 and 0.12377267365981055
# Recursion Depth Exceeded Endpoints are 0.12377911428287512 and 0.12543610150680104
# Recursion Depth Exceeded Endpoints are 0.12544881161945973 and 0.12710598381842209
# Recursion Depth Exceeded Endpoints are 0.12713106887566622 and 0.12877278379742663
# Recursion Depth Exceeded Endpoints are 0.12879444943040688 and 0.13044578688607206
# Recursion Depth Exceeded Endpoints are 0.13048550431651285 and 0.1321307909548995
# Recursion Depth Exceeded Endpoints are 0.13214587351769674 and 0.13378265861051633
# Recursion Depth Exceeded Endpoints are 0.1338005340354188 and 0.13537905024374325
# Recursion Depth Exceeded Endpoints are 0.13546146564048903 and 0.13708483240501193
# Recursion Depth Exceeded Endpoints are 0.13714587980299944 and 0.13879836902823448
# Recursion Depth Exceeded Endpoints are 0.1388155985765406 and 0.14045128158902645
# Recursion Depth Exceeded Endpoints are 0.14049384473407817 and 0.14213545386320037
# Recursion Depth Exceeded Endpoints are 0.1421719056821921 and 0.14381930450026095
# Recursion Depth Exceeded Endpoints are 0.14384978790249167 and 0.14550558408528522
# Recursion Depth Exceeded Endpoints are 0.14551654124363386 and 0.1471698354255507
# Recursion Depth Exceeded Endpoints are 0.16055795968548972 and 0.162217670751622
# Recursion Depth Exceeded Endpoints are 0.16222749914731424 and 0.16388975964448338
# Recursion Depth Exceeded Endpoints are 0.16390435161883846 and 0.16556422161684525
# Recursion Depth Exceeded Endpoints are 0.16556662910583578 and 0.16722430097547036
# Recursion Depth Exceeded Endpoints are 0.17728330046129268 and 0.17893044267627164
# Recursion Depth Exceeded Endpoints are 0.17897276329095443 and 0.18060670499113568
# [0.003125   0.00535714 0.00663664 0.00879146 0.01047696 0.01208599
#  0.01331824 0.01498847 0.01665889 0.0188013  0.02001467 0.02172104
#  0.02344932 0.02525551 0.02672985 0.02829983 0.03003692 0.03175025
#  0.03340262 0.03511537 0.0367672  0.03840565 0.04012271 0.04177671
#  0.04347891 0.04518704 0.04681914 0.04860806 0.05023846 0.05185708
#  0.05350815 0.0551702  0.05685636 0.05856681 0.06019415 0.0619082
#  0.0635709  0.06530336 0.06687618 0.06857058 0.07023412 0.07189628
#  0.07357782 0.07522096 0.0769083  0.07857421 0.08026781 0.08192716
#  0.08357589 0.08524657 0.08693124 0.08859587 0.09026112 0.09194101
#  0.0936495  0.0953276  0.09702059 0.10035763 0.10201719 0.10370308
#  0.10536117 0.1070284  0.10869977 0.11037371 0.11204206 0.11371438
#  0.1154001  0.11706873 0.1187317  0.12041065 0.12210788 0.12377453
#  0.12544255 0.12711287 0.12878843 0.13045686 0.13213408 0.13378961
#  0.13544268 0.13712591 0.13879858 0.14048518 0.14215657 0.14383184
#  0.14550981 0.14717056 0.15385792 0.16054772 0.16222386 0.16389113
#  0.16556433 0.16723749 0.17392582 0.17726988 0.178945   0.18061337
#  0.18730738 0.21405773 0.24081273 0.25419091 0.26756991 0.28095026
#  0.29432845 0.30770568 0.32108706 0.34784171 0.37460203 0.40136098
#  0.42811616 0.45487367 0.48163105 0.50838906 0.5351451  0.56190265
#  0.58865958 0.61541663 0.64217481]
#     band                           magnitude_endpoints unique_magnitudes  \
# 0      1                                    (0.0, 0.0)                 1
# 1      2  (0.004464285714285714, 0.004464285714285714)                 1
# 2      3                            (0.00625, 0.00625)                 1
# 3      4  (0.007680647559859488, 0.007680647559859488)                 1
# 4      5   (0.008838834764831846, 0.00990226473786555)                 3
# ..   ...                                           ...               ...
# 112  113      (0.5083902227840824, 0.5351447865783996)             13779
# 113  114      (0.5351462762551897, 0.5619023185227344)             13520
# 114  115      (0.5619051559976422, 0.5886590282418271)             12962
# 115  116       (0.588660382494327, 0.6154143752922308)             12297
# 116  117      (0.6154182614121813, 0.6421728749141544)             11160
#
#                                                   data  number_of_coefficents
# 0    [47779933484.0, 47779933484.0, 47779933484.0, ...                    1.0
# 1    [-16214758521.574413, -16214758521.574413, -16...                    1.0
# 2    [-9879205199.709785, -9879205199.709785, -9879...                    2.0
# 3    [2829991022.1984396, 2829991022.1984396, 28299...                    2.0
# 4    [3513628056.67588, 3513628056.67588, 351362805...                    3.0
# ..                                                 ...                    ...
# 112  [538567.8376235683, 538567.8376235683, 538567....                56962.0
# 113  [-792366.9147590024, -792366.9147590024, -7923...                52586.0
# 114  [1463718.9726669993, 1463718.9726669993, 14637...                47640.0
# 115  [925462.3097729231, 925462.3097729231, 925462....                41955.0
# 116  [-492288.67960672657, -492288.67960672657, -49...                35646.0
#
# [117 rows x 5 columns]

# %%
converted["magnitude_length"] = converted["magnitude_endpoints"].apply(lambda x: x[1] - x[0])
x = np.asfarray(converted["band"][4:].to_numpy())
y = np.asfarray(converted["magnitude_endpoints"].apply(lambda x: x[1])[4:].to_numpy())
logy = np.log(y)
plt.plot(x, logy)
print(np.poly1d(np.polyfit(x, logy, 1)))
plt.plot(x, np.poly1d(np.polyfit(x, logy, 1))(x))
np.exp(np.polyfit(x, logy, 1)[0])
# Out:
#
# 0.02726 x - 3.988
# 1.0276344954831453

# %% [markdown]
# # Unique Magnitude

# %%
def uniqueMags(folder_dir, start = None, end = None, dim="2d"):
    file_list = [os.path.join(folder_dir, filename) for filename in os.listdir(folder_dir)]
    image = np.array(Image.open(file_list[0]).convert('L'))
    if dim == "2d":
        coord_df = getIndexDF(image, no_zero =False).sort_values(["magnitude"])
    if dim == "3d":
        coord_df = getIndexDF_3d(image, no_zero =False).sort_values(["magnitude"])
    magnitudes = np.unique(coord_df["magnitude"])
    if start != None:
        start_idx = np.argmax(magnitudes >= start)
        magnitudes = magnitudes[start_idx:]
    if end != None:
        end_idx = np.argmax(magnitudes > end)
        magnitudes = magnitudes[:end_idx]
    return magnitudes.tolist()

# %%
unique_splits = uniqueMags(data_dir,0, 0.008052940675034493 )[1:]
unique_splits
# Out:
# [0.001953125,
#  0.0027621358640099515,
#  0.00390625,
#  0.004367320268554277,
#  0.005524271728019903,
#  0.005859375,
#  0.006176323555016366,
#  0.007042092334890604,
#  0.0078125,
#  0.008052940675034493]

# %% [markdown]
# # New Dataset Stuff

# %%
def getSplits(minfreq, maxfreq, mult):
    arr = []
    next_freq = minfreq
    while next_freq < maxfreq:
        arr.append(next_freq)
        next_freq *= mult
    return arr
splits = getSplits(0.008052940675034493,0.5282291467669505, 1.35)
splits
# Out:
# [0.008052940675034493,
#  0.010871469911296566,
#  0.014676484380250364,
#  0.01981325391333799,
#  0.02674789278300629,
#  0.0361096552570585,
#  0.04874803459702898,
#  0.06580984670598912,
#  0.08884329305308532,
#  0.11993844562166518,
#  0.161916901589248,
#  0.21858781714548484,
#  0.29509355314640456,
#  0.3983762967476462]
