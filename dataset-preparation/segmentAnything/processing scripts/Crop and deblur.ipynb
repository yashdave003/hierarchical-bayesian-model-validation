# %%
import os
import random
import glob
import cv2

def boxes_intersect(boxA, boxB):
    """
    Check if two boxes intersect.
    Each box is represented as (x1, y1, x2, y2).
    Returns True if the boxes overlap, False otherwise.
    """
    ax1, ay1, ax2, ay2 = boxA
    bx1, by1, bx2, by2 = boxB

    # If one rectangle is on the left side of the other
    if ax2 <= bx1 or bx2 <= ax1:
        return False
    # If one rectangle is above the other
    if ay2 <= by1 or by2 <= ay1:
        return False
    return True

def crop_images_without_blurred_faces(input_dir, output_dir,
                                      crop_size=(512, 512),
                                      seed=42,
                                      blur_threshold=500.0,
                                      max_attempts=50):
    """
    For each image in input_dir, detect blurred faces and then take a random crop
    of size crop_size that does not include any part of any blurred face.
    
    Parameters:
      - input_dir: Path to the directory containing the input images.
      - output_dir: Path to the directory where cropped images will be saved.
      - crop_size: Tuple indicating the (width, height) of the crop.
      - seed: Seed for the random number generator (for reproducibility).
      - blur_threshold: Variance threshold below which a face is considered blurred.
      - max_attempts: Maximum attempts to find a valid crop.
    """
    # Set seed for reproducibility
    random.seed(seed)

    # Create output directory if needed
    os.makedirs(output_dir, exist_ok=True)

    # Gather image files from the input directory (adjust extensions as needed)
    image_extensions = ('*.jpg')
    image_files = []
    for ext in image_extensions:
        image_files.extend(glob.glob(os.path.join(input_dir, ext)))
    image_files = sorted(image_files)

    # Load Haar cascade for face detection
    cascade_path = cv2.data.haarcascades + "haarcascade_frontalface_default.xml"
    face_cascade = cv2.CascadeClassifier(cascade_path)
    if face_cascade.empty():
        print("Error loading Haar cascade. Check the path:", cascade_path)
        return

    for image_path in image_files:
        # Read the image
        img = cv2.imread(image_path)
        if img is None:
            print(f"Could not load image {image_path}. Skipping.")
            continue

        height, width = img.shape[:2]
        crop_w, crop_h = crop_size

        # Ensure image is large enough for the desired crop
        if width < crop_w or height < crop_h:
            print(f"Skipping {os.path.basename(image_path)}: image too small ({width}x{height}).")
            continue

        # Convert to grayscale for face detection and blur evaluation
        gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

        # Detect faces in the full image
        faces = face_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5)
        print(f"Detected {len(faces)} faces in {os.path.basename(image_path)}.")
        blurred_faces = []

        for (fx, fy, fw, fh) in faces:
            face_roi = gray[fy:fy+fh, fx:fx+fw]
            # Compute the variance of the Laplacian (a measure of sharpness)
            variance = cv2.Laplacian(face_roi, cv2.CV_64F).var()
            if variance < blur_threshold:
                blurred_faces.append((fx, fy, fw, fh))
                # Debug: print(f"Detected blurred face at {(fx,fy,fw,fh)} with variance {variance:.2f}")

        # Attempt to find a valid random crop that does not include any blurred face
        valid_crop_found = False
        for attempt in range(max_attempts):
            crop_x = random.randint(0, width - crop_w)
            crop_y = random.randint(0, height - crop_h)
            crop_box = (crop_x, crop_y, crop_x + crop_w, crop_y + crop_h)

            valid = True  # Assume the crop is valid until proven otherwise

            # Check each blurred face bounding box for any intersection with the crop box.
            for (fx, fy, fw, fh) in blurred_faces:
                face_box = (fx, fy, fx + fw, fy + fh)
                if boxes_intersect(crop_box, face_box):
                    valid = False
                    # Debug: print(f"Crop at {(crop_x, crop_y)} intersects blurred face at {(fx,fy,fw,fh)}")
                    break

            if valid:
                valid_crop_found = True
                break  # Exit the loop if a valid crop is found

        if not valid_crop_found:
            print(f"No valid crop found for {os.path.basename(image_path)} after {max_attempts} attempts. Skipping.")
            continue

        # Crop the image using the valid coordinates
        cropped_img = img[crop_y:crop_y+crop_h, crop_x:crop_x+crop_w]

        # Save the cropped image with the same base filename
        base_name = os.path.basename(image_path)
        output_path = os.path.join(output_dir, base_name)
        cv2.imwrite(output_path, cropped_img)
        print(f"Cropped {base_name} at ({crop_x}, {crop_y}) and saved to {output_path}")

if __name__ == "__main__":
    # Replace with your actual paths. Use raw strings (r"...") or double backslashes on Windows.
    input_folder = r"D:\Download\meta\test for deblurring"    # Folder containing the original images.
    output_folder = r"D:\Download\meta\Cropped and Deblurred"     # Folder to save the cropped images.

    crop_images_without_blurred_faces(input_folder, output_folder)
# Out:
# Could not load image D:\Download\meta\test for deblurring\.. Skipping.
# Detected 5 faces in sa_66.jpg.
# Cropped sa_66.jpg at (456, 25) and saved to D:\Download\meta\Cropped and Deblurred\sa_66.jpg
# Detected 3 faces in sa_7.jpg.
# Cropped sa_7.jpg at (759, 563) and saved to D:\Download\meta\Cropped and Deblurred\sa_7.jpg
# Detected 3 faces in sa_70.jpg.
# Cropped sa_70.jpg at (1003, 228) and saved to D:\Download\meta\Cropped and Deblurred\sa_70.jpg
# Detected 5 faces in sa_71.jpg.
# Cropped sa_71.jpg at (142, 1508) and saved to D:\Download\meta\Cropped and Deblurred\sa_71.jpg
# Detected 8 faces in sa_8.jpg.
# Cropped sa_8.jpg at (209, 692) and saved to D:\Download\meta\Cropped and Deblurred\sa_8.jpg
# Detected 1 faces in sa_9.jpg.
# Cropped sa_9.jpg at (1516, 913) and saved to D:\Download\meta\Cropped and Deblurred\sa_9.jpg

# %%
import os
import random
import glob
import cv2

def boxes_intersect(boxA, boxB):
    """
    Check if two boxes intersect.
    Each box is represented as (x1, y1, x2, y2).
    Returns True if the boxes overlap, False otherwise.
    """
    ax1, ay1, ax2, ay2 = boxA
    bx1, by1, bx2, by2 = boxB

    # If one rectangle is completely to the left or above the other, they don't intersect.
    if ax2 <= bx1 or bx2 <= ax1:
        return False
    if ay2 <= by1 or by2 <= ay1:
        return False
    return True

def detect_blurred_regions(gray, block_size = 64, blur_threshold = 100):
    """
    Divide the grayscale image into non-overlapping blocks.
    For each block, compute the variance of the Laplacian.
    Blocks with variance below the blur_threshold are considered blurred.
    
    Returns:
        A list of bounding boxes for blurred blocks, each in the form (x1, y1, x2, y2).
    """
    height, width = gray.shape
    blurred_regions = []
    for y in range(0, height, block_size):
        for x in range(0, width, block_size):
            # Make sure the block does not exceed the image boundaries.
            x_end = min(x + block_size, width)
            y_end = min(y + block_size, height)
            block = gray[y:y_end, x:x_end]
            # Compute the variance of the Laplacian (a measure of sharpness).
            var = cv2.Laplacian(block, cv2.CV_64F).var()
            if var < blur_threshold:
                blurred_regions.append((x, y, x_end, y_end))
    return blurred_regions

def crop_images_avoiding_blur(input_dir, output_dir,
                              crop_size=(512, 512),
                              seed=42,
                              blur_threshold = 100,
                              block_size=64,
                              max_attempts=100):
    """
    For each image in input_dir:
      1. Convert it to grayscale.
      2. Divide it into blocks and detect blurred regions.
      3. Attempt to pick a random crop of size crop_size that does not include any blurred block.
      4. Save the crop in output_dir if found.
    
    Parameters:
      - input_dir: Folder containing the original images.
      - output_dir: Folder where cropped images will be saved.
      - crop_size: Tuple (width, height) of the desired crop.
      - seed: Seed for the random number generator (for reproducibility).
      - blur_threshold: Variance threshold below which a block is considered blurred.
      - block_size: Size of the non-overlapping block used to detect blur.
      - max_attempts: Maximum number of random crop attempts per image.
    """
    # Set the random seed for reproducibility.
    random.seed(seed)
    os.makedirs(output_dir, exist_ok=True)
    
    # Collect image files from the input directory.
    image_extensions = ('*.jpg', '*.jpeg', '*.png', '*.bmp', '*.tiff')
    image_files = []
    for ext in image_extensions:
        image_files.extend(glob.glob(os.path.join(input_dir, ext)))
    image_files = sorted(image_files)
    
    for image_path in image_files:
        img = cv2.imread(image_path)
        if img is None:
            print(f"Could not load image {image_path}. Skipping.")
            continue
        
        height, width = img.shape[:2]
        crop_w, crop_h = crop_size
        
        # Skip images that are too small.
        if width < crop_w or height < crop_h:
            print(f"Skipping {os.path.basename(image_path)}: image too small ({width}x{height}).")
            continue
        
        # Convert the image to grayscale for blur detection.
        gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        
        # Detect blurred regions.
        blurred_regions = detect_blurred_regions(gray, block_size=block_size, blur_threshold=blur_threshold)
        
        valid_crop_found = False
        for attempt in range(max_attempts):
            # Choose a random crop position.
            crop_x = random.randint(0, width - crop_w)
            crop_y = random.randint(0, height - crop_h)
            crop_box = (crop_x, crop_y, crop_x + crop_w, crop_y + crop_h)
            
            valid = True  # Assume this crop is valid until proven otherwise.
            # Check if the candidate crop intersects any blurred block.
            for region in blurred_regions:
                if boxes_intersect(crop_box, region):
                    valid = False
                    break
            
            if valid:
                valid_crop_found = True
                break  # Accept this crop.
        
        if not valid_crop_found:
            print(f"No valid crop found for {os.path.basename(image_path)} after {max_attempts} attempts. Skipping.")
            continue
        
        # Crop and save the image.
        cropped_img = img[crop_y:crop_y+crop_h, crop_x:crop_x+crop_w]
        base_name = os.path.basename(image_path)
        output_path = os.path.join(output_dir, base_name)
        cv2.imwrite(output_path, cropped_img)
        print(f"Cropped {base_name} at ({crop_x}, {crop_y}) and saved to {output_path}")

if __name__ == "__main__":
    # Use raw strings for Windows paths to avoid escape sequence issues.
    input_folder = r"D:\Download\meta\Meta Images"    # Folder containing the original images.
    output_folder = r"D:\Download\meta\Cropped and Deblurred"     # Folder to save the cropped images.
    
    crop_images_avoiding_blur(input_folder, output_folder)
# Out:
# Cropped sa_1.jpg at (654, 228) and saved to D:\Download\meta\Cropped and Deblurred\sa_1.jpg
# No valid crop found for sa_10.jpg after 100 attempts. Skipping.
# No valid crop found for sa_100.jpg after 100 attempts. Skipping.
# Cropped sa_1000.jpg at (252, 1185) and saved to D:\Download\meta\Cropped and Deblurred\sa_1000.jpg
# No valid crop found for sa_10000.jpg after 100 attempts. Skipping.
# No valid crop found for sa_10001.jpg after 100 attempts. Skipping.
# Cropped sa_10002.jpg at (556, 343) and saved to D:\Download\meta\Cropped and Deblurred\sa_10002.jpg
# No valid crop found for sa_10003.jpg after 100 attempts. Skipping.
# No valid crop found for sa_10004.jpg after 100 attempts. Skipping.
# No valid crop found for sa_10005.jpg after 100 attempts. Skipping.
# Cropped sa_10006.jpg at (1187, 675) and saved to D:\Download\meta\Cropped and Deblurred\sa_10006.jpg
# Cropped sa_10007.jpg at (1002, 886) and saved to D:\Download\meta\Cropped and Deblurred\sa_10007.jpg
# No valid crop found for sa_10008.jpg after 100 attempts. Skipping.
# No valid crop found for sa_10009.jpg after 100 attempts. Skipping.
# No valid crop found for sa_1001.jpg after 100 attempts. Skipping.
# Cropped sa_10010.jpg at (770, 429) and saved to D:\Download\meta\Cropped and Deblurred\sa_10010.jpg
# Cropped sa_10011.jpg at (638, 738) and saved to D:\Download\meta\Cropped and Deblurred\sa_10011.jpg
# Cropped sa_10012.jpg at (1355, 434) and saved to D:\Download\meta\Cropped and Deblurred\sa_10012.jpg
# No valid crop found for sa_10013.jpg after 100 attempts. Skipping.
# Cropped sa_10014.jpg at (507, 724) and saved to D:\Download\meta\Cropped and Deblurred\sa_10014.jpg
# No valid crop found for sa_10015.jpg after 100 attempts. Skipping.
# No valid crop found for sa_10016.jpg after 100 attempts. Skipping.
# Cropped sa_10017.jpg at (913, 219) and saved to D:\Download\meta\Cropped and Deblurred\sa_10017.jpg
# Cropped sa_10018.jpg at (251, 138) and saved to D:\Download\meta\Cropped and Deblurred\sa_10018.jpg
# No valid crop found for sa_10019.jpg after 100 attempts. Skipping.
# No valid crop found for sa_1002.jpg after 100 attempts. Skipping.
# Cropped sa_10020.jpg at (977, 1583) and saved to D:\Download\meta\Cropped and Deblurred\sa_10020.jpg
# Cropped sa_10021.jpg at (1647, 149) and saved to D:\Download\meta\Cropped and Deblurred\sa_10021.jpg
# Cropped sa_10022.jpg at (589, 978) and saved to D:\Download\meta\Cropped and Deblurred\sa_10022.jpg
# Cropped sa_10023.jpg at (1151, 712) and saved to D:\Download\meta\Cropped and Deblurred\sa_10023.jpg
# No valid crop found for sa_10024.jpg after 100 attempts. Skipping.
# Cropped sa_10025.jpg at (1121, 924) and saved to D:\Download\meta\Cropped and Deblurred\sa_10025.jpg
# Cropped sa_10026.jpg at (1035, 207) and saved to D:\Download\meta\Cropped and Deblurred\sa_10026.jpg
# Cropped sa_10027.jpg at (772, 1589) and saved to D:\Download\meta\Cropped and Deblurred\sa_10027.jpg
# Cropped sa_10028.jpg at (1096, 741) and saved to D:\Download\meta\Cropped and Deblurred\sa_10028.jpg
# Cropped sa_10029.jpg at (1698, 195) and saved to D:\Download\meta\Cropped and Deblurred\sa_10029.jpg
# Cropped sa_1003.jpg at (1544, 689) and saved to D:\Download\meta\Cropped and Deblurred\sa_1003.jpg
# No valid crop found for sa_10030.jpg after 100 attempts. Skipping.
# No valid crop found for sa_10031.jpg after 100 attempts. Skipping.
# No valid crop found for sa_10032.jpg after 100 attempts. Skipping.
# Cropped sa_10033.jpg at (1637, 892) and saved to D:\Download\meta\Cropped and Deblurred\sa_10033.jpg
# Cropped sa_10034.jpg at (749, 333) and saved to D:\Download\meta\Cropped and Deblurred\sa_10034.jpg
# No valid crop found for sa_10035.jpg after 100 attempts. Skipping.
# Cropped sa_10036.jpg at (1397, 780) and saved to D:\Download\meta\Cropped and Deblurred\sa_10036.jpg
# No valid crop found for sa_10037.jpg after 100 attempts. Skipping.
# Cropped sa_10038.jpg at (1437, 411) and saved to D:\Download\meta\Cropped and Deblurred\sa_10038.jpg
# Cropped sa_10039.jpg at (635, 715) and saved to D:\Download\meta\Cropped and Deblurred\sa_10039.jpg
# No valid crop found for sa_1004.jpg after 100 attempts. Skipping.
# Cropped sa_10040.jpg at (807, 76) and saved to D:\Download\meta\Cropped and Deblurred\sa_10040.jpg
# Cropped sa_10041.jpg at (1212, 581) and saved to D:\Download\meta\Cropped and Deblurred\sa_10041.jpg
# Cropped sa_10042.jpg at (127, 445) and saved to D:\Download\meta\Cropped and Deblurred\sa_10042.jpg
# Cropped sa_10043.jpg at (1427, 617) and saved to D:\Download\meta\Cropped and Deblurred\sa_10043.jpg
# No valid crop found for sa_10044.jpg after 100 attempts. Skipping.
# No valid crop found for sa_10045.jpg after 100 attempts. Skipping.
# Cropped sa_10046.jpg at (969, 864) and saved to D:\Download\meta\Cropped and Deblurred\sa_10046.jpg
# Cropped sa_10047.jpg at (2003, 916) and saved to D:\Download\meta\Cropped and Deblurred\sa_10047.jpg
# No valid crop found for sa_10048.jpg after 100 attempts. Skipping.
# No valid crop found for sa_10049.jpg after 100 attempts. Skipping.
# Cropped sa_1005.jpg at (490, 888) and saved to D:\Download\meta\Cropped and Deblurred\sa_1005.jpg
# Cropped sa_10050.jpg at (647, 883) and saved to D:\Download\meta\Cropped and Deblurred\sa_10050.jpg
# Cropped sa_10051.jpg at (1465, 184) and saved to D:\Download\meta\Cropped and Deblurred\sa_10051.jpg
# Cropped sa_10052.jpg at (331, 499) and saved to D:\Download\meta\Cropped and Deblurred\sa_10052.jpg
# Cropped sa_10053.jpg at (1002, 804) and saved to D:\Download\meta\Cropped and Deblurred\sa_10053.jpg
# Cropped sa_10054.jpg at (132, 1258) and saved to D:\Download\meta\Cropped and Deblurred\sa_10054.jpg
# Cropped sa_10055.jpg at (913, 659) and saved to D:\Download\meta\Cropped and Deblurred\sa_10055.jpg
# No valid crop found for sa_10056.jpg after 100 attempts. Skipping.
# Cropped sa_10057.jpg at (116, 820) and saved to D:\Download\meta\Cropped and Deblurred\sa_10057.jpg
# Cropped sa_10058.jpg at (999, 115) and saved to D:\Download\meta\Cropped and Deblurred\sa_10058.jpg
# Cropped sa_10059.jpg at (1388, 537) and saved to D:\Download\meta\Cropped and Deblurred\sa_10059.jpg
# Cropped sa_1006.jpg at (1571, 761) and saved to D:\Download\meta\Cropped and Deblurred\sa_1006.jpg
# Cropped sa_10060.jpg at (1371, 894) and saved to D:\Download\meta\Cropped and Deblurred\sa_10060.jpg
# Cropped sa_10061.jpg at (692, 531) and saved to D:\Download\meta\Cropped and Deblurred\sa_10061.jpg
# Cropped sa_10062.jpg at (788, 152) and saved to D:\Download\meta\Cropped and Deblurred\sa_10062.jpg
# Cropped sa_10063.jpg at (1718, 846) and saved to D:\Download\meta\Cropped and Deblurred\sa_10063.jpg
# No valid crop found for sa_10064.jpg after 100 attempts. Skipping.
# Cropped sa_10065.jpg at (429, 639) and saved to D:\Download\meta\Cropped and Deblurred\sa_10065.jpg
# Cropped sa_10066.jpg at (943, 1377) and saved to D:\Download\meta\Cropped and Deblurred\sa_10066.jpg
# No valid crop found for sa_10067.jpg after 100 attempts. Skipping.
# Cropped sa_10068.jpg at (1475, 633) and saved to D:\Download\meta\Cropped and Deblurred\sa_10068.jpg
# Cropped sa_10069.jpg at (129, 774) and saved to D:\Download\meta\Cropped and Deblurred\sa_10069.jpg
# No valid crop found for sa_1007.jpg after 100 attempts. Skipping.
# No valid crop found for sa_10070.jpg after 100 attempts. Skipping.
# No valid crop found for sa_10071.jpg after 100 attempts. Skipping.
# No valid crop found for sa_10072.jpg after 100 attempts. Skipping.
# No valid crop found for sa_10073.jpg after 100 attempts. Skipping.
# No valid crop found for sa_10074.jpg after 100 attempts. Skipping.
# Cropped sa_10075.jpg at (213, 968) and saved to D:\Download\meta\Cropped and Deblurred\sa_10075.jpg
# Cropped sa_10076.jpg at (1616, 248) and saved to D:\Download\meta\Cropped and Deblurred\sa_10076.jpg
# Cropped sa_10077.jpg at (973, 704) and saved to D:\Download\meta\Cropped and Deblurred\sa_10077.jpg
# No valid crop found for sa_10078.jpg after 100 attempts. Skipping.
# Cropped sa_10079.jpg at (1307, 590) and saved to D:\Download\meta\Cropped and Deblurred\sa_10079.jpg
# Cropped sa_1008.jpg at (1565, 648) and saved to D:\Download\meta\Cropped and Deblurred\sa_1008.jpg
# Cropped sa_10080.jpg at (0, 1487) and saved to D:\Download\meta\Cropped and Deblurred\sa_10080.jpg
# Cropped sa_10081.jpg at (70, 291) and saved to D:\Download\meta\Cropped and Deblurred\sa_10081.jpg
# Cropped sa_10082.jpg at (1165, 939) and saved to D:\Download\meta\Cropped and Deblurred\sa_10082.jpg
# No valid crop found for sa_10083.jpg after 100 attempts. Skipping.
# Cropped sa_10084.jpg at (1616, 713) and saved to D:\Download\meta\Cropped and Deblurred\sa_10084.jpg
# Cropped sa_10085.jpg at (1265, 277) and saved to D:\Download\meta\Cropped and Deblurred\sa_10085.jpg
# Cropped sa_10086.jpg at (1340, 967) and saved to D:\Download\meta\Cropped and Deblurred\sa_10086.jpg
# No valid crop found for sa_10087.jpg after 100 attempts. Skipping.
# No valid crop found for sa_10088.jpg after 100 attempts. Skipping.
# Cropped sa_10089.jpg at (1337, 357) and saved to D:\Download\meta\Cropped and Deblurred\sa_10089.jpg
# No valid crop found for sa_1009.jpg after 100 attempts. Skipping.
# Cropped sa_10090.jpg at (925, 849) and saved to D:\Download\meta\Cropped and Deblurred\sa_10090.jpg
# No valid crop found for sa_10091.jpg after 100 attempts. Skipping.
# Cropped sa_10092.jpg at (1012, 660) and saved to D:\Download\meta\Cropped and Deblurred\sa_10092.jpg
# Cropped sa_10093.jpg at (251, 92) and saved to D:\Download\meta\Cropped and Deblurred\sa_10093.jpg
# Cropped sa_10094.jpg at (927, 544) and saved to D:\Download\meta\Cropped and Deblurred\sa_10094.jpg
# Cropped sa_10095.jpg at (596, 399) and saved to D:\Download\meta\Cropped and Deblurred\sa_10095.jpg
# Cropped sa_10096.jpg at (890, 735) and saved to D:\Download\meta\Cropped and Deblurred\sa_10096.jpg
# No valid crop found for sa_10097.jpg after 100 attempts. Skipping.
# No valid crop found for sa_10098.jpg after 100 attempts. Skipping.
# No valid crop found for sa_10099.jpg after 100 attempts. Skipping.
# Cropped sa_101.jpg at (1018, 609) and saved to D:\Download\meta\Cropped and Deblurred\sa_101.jpg
# Cropped sa_1010.jpg at (950, 788) and saved to D:\Download\meta\Cropped and Deblurred\sa_1010.jpg
# Cropped sa_10100.jpg at (115, 1631) and saved to D:\Download\meta\Cropped and Deblurred\sa_10100.jpg
# Cropped sa_10101.jpg at (1728, 933) and saved to D:\Download\meta\Cropped and Deblurred\sa_10101.jpg
# Cropped sa_10102.jpg at (361, 163) and saved to D:\Download\meta\Cropped and Deblurred\sa_10102.jpg
# Cropped sa_10103.jpg at (1372, 944) and saved to D:\Download\meta\Cropped and Deblurred\sa_10103.jpg
# No valid crop found for sa_10104.jpg after 100 attempts. Skipping.
# Cropped sa_10105.jpg at (1429, 968) and saved to D:\Download\meta\Cropped and Deblurred\sa_10105.jpg
# Cropped sa_10106.jpg at (589, 1627) and saved to D:\Download\meta\Cropped and Deblurred\sa_10106.jpg
# Cropped sa_10107.jpg at (424, 806) and saved to D:\Download\meta\Cropped and Deblurred\sa_10107.jpg
# No valid crop found for sa_10108.jpg after 100 attempts. Skipping.
# No valid crop found for sa_10109.jpg after 100 attempts. Skipping.
# Cropped sa_1011.jpg at (710, 1675) and saved to D:\Download\meta\Cropped and Deblurred\sa_1011.jpg
# No valid crop found for sa_10110.jpg after 100 attempts. Skipping.
# Cropped sa_10111.jpg at (750, 714) and saved to D:\Download\meta\Cropped and Deblurred\sa_10111.jpg
# Cropped sa_10112.jpg at (595, 875) and saved to D:\Download\meta\Cropped and Deblurred\sa_10112.jpg
# Cropped sa_10113.jpg at (1752, 193) and saved to D:\Download\meta\Cropped and Deblurred\sa_10113.jpg
# Cropped sa_10114.jpg at (205, 1218) and saved to D:\Download\meta\Cropped and Deblurred\sa_10114.jpg
# No valid crop found for sa_10115.jpg after 100 attempts. Skipping.
# Cropped sa_10116.jpg at (369, 902) and saved to D:\Download\meta\Cropped and Deblurred\sa_10116.jpg
# Cropped sa_10117.jpg at (38, 642) and saved to D:\Download\meta\Cropped and Deblurred\sa_10117.jpg
# Cropped sa_10118.jpg at (1353, 985) and saved to D:\Download\meta\Cropped and Deblurred\sa_10118.jpg
# No valid crop found for sa_10119.jpg after 100 attempts. Skipping.
# No valid crop found for sa_1012.jpg after 100 attempts. Skipping.
# Cropped sa_10120.jpg at (175, 10) and saved to D:\Download\meta\Cropped and Deblurred\sa_10120.jpg
# No valid crop found for sa_10121.jpg after 100 attempts. Skipping.
# Cropped sa_10122.jpg at (491, 988) and saved to D:\Download\meta\Cropped and Deblurred\sa_10122.jpg
# No valid crop found for sa_10123.jpg after 100 attempts. Skipping.
# No valid crop found for sa_10124.jpg after 100 attempts. Skipping.
# Cropped sa_10125.jpg at (1020, 750) and saved to D:\Download\meta\Cropped and Deblurred\sa_10125.jpg
# Cropped sa_10126.jpg at (1325, 372) and saved to D:\Download\meta\Cropped and Deblurred\sa_10126.jpg
# No valid crop found for sa_10127.jpg after 100 attempts. Skipping.
# Cropped sa_10128.jpg at (1192, 197) and saved to D:\Download\meta\Cropped and Deblurred\sa_10128.jpg
# Cropped sa_10129.jpg at (842, 1594) and saved to D:\Download\meta\Cropped and Deblurred\sa_10129.jpg
# No valid crop found for sa_1013.jpg after 100 attempts. Skipping.
# No valid crop found for sa_10130.jpg after 100 attempts. Skipping.
# Cropped sa_10131.jpg at (473, 758) and saved to D:\Download\meta\Cropped and Deblurred\sa_10131.jpg
# No valid crop found for sa_10132.jpg after 100 attempts. Skipping.
# Cropped sa_10133.jpg at (111, 432) and saved to D:\Download\meta\Cropped and Deblurred\sa_10133.jpg
# No valid crop found for sa_10134.jpg after 100 attempts. Skipping.
# Cropped sa_10135.jpg at (447, 313) and saved to D:\Download\meta\Cropped and Deblurred\sa_10135.jpg
# Cropped sa_10136.jpg at (435, 772) and saved to D:\Download\meta\Cropped and Deblurred\sa_10136.jpg
# No valid crop found for sa_10137.jpg after 100 attempts. Skipping.
# No valid crop found for sa_10138.jpg after 100 attempts. Skipping.
# Cropped sa_10139.jpg at (22, 693) and saved to D:\Download\meta\Cropped and Deblurred\sa_10139.jpg
# Cropped sa_1014.jpg at (1382, 545) and saved to D:\Download\meta\Cropped and Deblurred\sa_1014.jpg
# No valid crop found for sa_10140.jpg after 100 attempts. Skipping.
# Cropped sa_10141.jpg at (1407, 712) and saved to D:\Download\meta\Cropped and Deblurred\sa_10141.jpg
# No valid crop found for sa_10142.jpg after 100 attempts. Skipping.
# Cropped sa_10143.jpg at (1161, 833) and saved to D:\Download\meta\Cropped and Deblurred\sa_10143.jpg
# Cropped sa_10144.jpg at (435, 190) and saved to D:\Download\meta\Cropped and Deblurred\sa_10144.jpg
# No valid crop found for sa_10145.jpg after 100 attempts. Skipping.
# Cropped sa_10146.jpg at (778, 590) and saved to D:\Download\meta\Cropped and Deblurred\sa_10146.jpg
# Cropped sa_10147.jpg at (388, 867) and saved to D:\Download\meta\Cropped and Deblurred\sa_10147.jpg
# Cropped sa_10148.jpg at (794, 433) and saved to D:\Download\meta\Cropped and Deblurred\sa_10148.jpg
# Cropped sa_10149.jpg at (532, 1359) and saved to D:\Download\meta\Cropped and Deblurred\sa_10149.jpg
# No valid crop found for sa_1015.jpg after 100 attempts. Skipping.
# Cropped sa_10150.jpg at (193, 813) and saved to D:\Download\meta\Cropped and Deblurred\sa_10150.jpg
# No valid crop found for sa_10151.jpg after 100 attempts. Skipping.
# Cropped sa_10152.jpg at (651, 969) and saved to D:\Download\meta\Cropped and Deblurred\sa_10152.jpg
# Cropped sa_10153.jpg at (1088, 564) and saved to D:\Download\meta\Cropped and Deblurred\sa_10153.jpg
# Cropped sa_10154.jpg at (937, 187) and saved to D:\Download\meta\Cropped and Deblurred\sa_10154.jpg
# Cropped sa_10155.jpg at (514, 1174) and saved to D:\Download\meta\Cropped and Deblurred\sa_10155.jpg
# Cropped sa_10156.jpg at (178, 970) and saved to D:\Download\meta\Cropped and Deblurred\sa_10156.jpg
# Cropped sa_10157.jpg at (253, 935) and saved to D:\Download\meta\Cropped and Deblurred\sa_10157.jpg
# Cropped sa_10158.jpg at (318, 787) and saved to D:\Download\meta\Cropped and Deblurred\sa_10158.jpg
# No valid crop found for sa_10159.jpg after 100 attempts. Skipping.
# Cropped sa_1016.jpg at (266, 339) and saved to D:\Download\meta\Cropped and Deblurred\sa_1016.jpg
# No valid crop found for sa_10160.jpg after 100 attempts. Skipping.
# No valid crop found for sa_10161.jpg after 100 attempts. Skipping.
# No valid crop found for sa_10162.jpg after 100 attempts. Skipping.
# No valid crop found for sa_10163.jpg after 100 attempts. Skipping.
# No valid crop found for sa_10164.jpg after 100 attempts. Skipping.
# Cropped sa_10165.jpg at (1330, 16) and saved to D:\Download\meta\Cropped and Deblurred\sa_10165.jpg
# No valid crop found for sa_10166.jpg after 100 attempts. Skipping.
# Cropped sa_10167.jpg at (430, 703) and saved to D:\Download\meta\Cropped and Deblurred\sa_10167.jpg
# Cropped sa_10168.jpg at (859, 384) and saved to D:\Download\meta\Cropped and Deblurred\sa_10168.jpg
# No valid crop found for sa_10169.jpg after 100 attempts. Skipping.
# Cropped sa_1017.jpg at (1318, 802) and saved to D:\Download\meta\Cropped and Deblurred\sa_1017.jpg
# Cropped sa_10170.jpg at (268, 861) and saved to D:\Download\meta\Cropped and Deblurred\sa_10170.jpg
# Cropped sa_10171.jpg at (1092, 940) and saved to D:\Download\meta\Cropped and Deblurred\sa_10171.jpg
# No valid crop found for sa_10172.jpg after 100 attempts. Skipping.
# No valid crop found for sa_10173.jpg after 100 attempts. Skipping.
# No valid crop found for sa_10174.jpg after 100 attempts. Skipping.
# Cropped sa_10175.jpg at (1699, 665) and saved to D:\Download\meta\Cropped and Deblurred\sa_10175.jpg
# No valid crop found for sa_10176.jpg after 100 attempts. Skipping.
# Cropped sa_10177.jpg at (92, 30) and saved to D:\Download\meta\Cropped and Deblurred\sa_10177.jpg
# Cropped sa_10178.jpg at (872, 1500) and saved to D:\Download\meta\Cropped and Deblurred\sa_10178.jpg
# Cropped sa_10179.jpg at (325, 237) and saved to D:\Download\meta\Cropped and Deblurred\sa_10179.jpg
# No valid crop found for sa_1018.jpg after 100 attempts. Skipping.
# Cropped sa_10180.jpg at (1017, 519) and saved to D:\Download\meta\Cropped and Deblurred\sa_10180.jpg
# No valid crop found for sa_10181.jpg after 100 attempts. Skipping.
# Cropped sa_10182.jpg at (743, 1698) and saved to D:\Download\meta\Cropped and Deblurred\sa_10182.jpg
# Cropped sa_10183.jpg at (1272, 444) and saved to D:\Download\meta\Cropped and Deblurred\sa_10183.jpg
# Cropped sa_10184.jpg at (116, 826) and saved to D:\Download\meta\Cropped and Deblurred\sa_10184.jpg
# No valid crop found for sa_10185.jpg after 100 attempts. Skipping.
# Cropped sa_10186.jpg at (52, 621) and saved to D:\Download\meta\Cropped and Deblurred\sa_10186.jpg
# No valid crop found for sa_10187.jpg after 100 attempts. Skipping.
# Cropped sa_10188.jpg at (1282, 36) and saved to D:\Download\meta\Cropped and Deblurred\sa_10188.jpg
# Cropped sa_10189.jpg at (1300, 896) and saved to D:\Download\meta\Cropped and Deblurred\sa_10189.jpg
# No valid crop found for sa_1019.jpg after 100 attempts. Skipping.
# No valid crop found for sa_10190.jpg after 100 attempts. Skipping.
# Cropped sa_10191.jpg at (277, 168) and saved to D:\Download\meta\Cropped and Deblurred\sa_10191.jpg
# No valid crop found for sa_10192.jpg after 100 attempts. Skipping.
# Cropped sa_10193.jpg at (62, 883) and saved to D:\Download\meta\Cropped and Deblurred\sa_10193.jpg
# No valid crop found for sa_10194.jpg after 100 attempts. Skipping.
# Cropped sa_10195.jpg at (762, 577) and saved to D:\Download\meta\Cropped and Deblurred\sa_10195.jpg
# No valid crop found for sa_10196.jpg after 100 attempts. Skipping.
# No valid crop found for sa_10197.jpg after 100 attempts. Skipping.
# No valid crop found for sa_10198.jpg after 100 attempts. Skipping.
# No valid crop found for sa_10199.jpg after 100 attempts. Skipping.
# No valid crop found for sa_102.jpg after 100 attempts. Skipping.
# Cropped sa_1020.jpg at (778, 884) and saved to D:\Download\meta\Cropped and Deblurred\sa_1020.jpg
# No valid crop found for sa_10200.jpg after 100 attempts. Skipping.
# Cropped sa_10201.jpg at (996, 817) and saved to D:\Download\meta\Cropped and Deblurred\sa_10201.jpg
# No valid crop found for sa_10202.jpg after 100 attempts. Skipping.
# No valid crop found for sa_10203.jpg after 100 attempts. Skipping.
# Cropped sa_10204.jpg at (69, 855) and saved to D:\Download\meta\Cropped and Deblurred\sa_10204.jpg
# No valid crop found for sa_10205.jpg after 100 attempts. Skipping.
# Cropped sa_10206.jpg at (1580, 643) and saved to D:\Download\meta\Cropped and Deblurred\sa_10206.jpg
# Cropped sa_10207.jpg at (144, 901) and saved to D:\Download\meta\Cropped and Deblurred\sa_10207.jpg
# Cropped sa_10208.jpg at (1102, 757) and saved to D:\Download\meta\Cropped and Deblurred\sa_10208.jpg
# Cropped sa_10209.jpg at (1648, 856) and saved to D:\Download\meta\Cropped and Deblurred\sa_10209.jpg
# Cropped sa_1021.jpg at (932, 324) and saved to D:\Download\meta\Cropped and Deblurred\sa_1021.jpg
# Cropped sa_10210.jpg at (1018, 654) and saved to D:\Download\meta\Cropped and Deblurred\sa_10210.jpg
# Cropped sa_10211.jpg at (788, 106) and saved to D:\Download\meta\Cropped and Deblurred\sa_10211.jpg
# No valid crop found for sa_10212.jpg after 100 attempts. Skipping.
# Cropped sa_10213.jpg at (1581, 181) and saved to D:\Download\meta\Cropped and Deblurred\sa_10213.jpg
# Cropped sa_10214.jpg at (1625, 963) and saved to D:\Download\meta\Cropped and Deblurred\sa_10214.jpg
# Cropped sa_10215.jpg at (246, 826) and saved to D:\Download\meta\Cropped and Deblurred\sa_10215.jpg
# Cropped sa_10216.jpg at (596, 110) and saved to D:\Download\meta\Cropped and Deblurred\sa_10216.jpg
# No valid crop found for sa_10217.jpg after 100 attempts. Skipping.
# No valid crop found for sa_10218.jpg after 100 attempts. Skipping.
# No valid crop found for sa_10219.jpg after 100 attempts. Skipping.
# Cropped sa_1022.jpg at (311, 167) and saved to D:\Download\meta\Cropped and Deblurred\sa_1022.jpg
# Cropped sa_10220.jpg at (425, 242) and saved to D:\Download\meta\Cropped and Deblurred\sa_10220.jpg
# No valid crop found for sa_10221.jpg after 100 attempts. Skipping.
# Cropped sa_10222.jpg at (1527, 948) and saved to D:\Download\meta\Cropped and Deblurred\sa_10222.jpg
# Cropped sa_10223.jpg at (187, 735) and saved to D:\Download\meta\Cropped and Deblurred\sa_10223.jpg
# Cropped sa_10224.jpg at (187, 3) and saved to D:\Download\meta\Cropped and Deblurred\sa_10224.jpg
# No valid crop found for sa_10225.jpg after 100 attempts. Skipping.
# Cropped sa_10226.jpg at (1484, 382) and saved to D:\Download\meta\Cropped and Deblurred\sa_10226.jpg
# No valid crop found for sa_10227.jpg after 100 attempts. Skipping.
# No valid crop found for sa_10228.jpg after 100 attempts. Skipping.
# No valid crop found for sa_10229.jpg after 100 attempts. Skipping.
# Cropped sa_1023.jpg at (858, 901) and saved to D:\Download\meta\Cropped and Deblurred\sa_1023.jpg
# Cropped sa_10230.jpg at (229, 513) and saved to D:\Download\meta\Cropped and Deblurred\sa_10230.jpg
# Cropped sa_10231.jpg at (337, 757) and saved to D:\Download\meta\Cropped and Deblurred\sa_10231.jpg
# No valid crop found for sa_10232.jpg after 100 attempts. Skipping.
# No valid crop found for sa_10233.jpg after 100 attempts. Skipping.
# Cropped sa_10234.jpg at (2036, 791) and saved to D:\Download\meta\Cropped and Deblurred\sa_10234.jpg
# Cropped sa_10235.jpg at (153, 443) and saved to D:\Download\meta\Cropped and Deblurred\sa_10235.jpg
# No valid crop found for sa_10236.jpg after 100 attempts. Skipping.
# No valid crop found for sa_10237.jpg after 100 attempts. Skipping.
# Cropped sa_10238.jpg at (1075, 954) and saved to D:\Download\meta\Cropped and Deblurred\sa_10238.jpg
# Cropped sa_10239.jpg at (261, 927) and saved to D:\Download\meta\Cropped and Deblurred\sa_10239.jpg
# Cropped sa_1024.jpg at (351, 784) and saved to D:\Download\meta\Cropped and Deblurred\sa_1024.jpg
# Cropped sa_10240.jpg at (278, 1051) and saved to D:\Download\meta\Cropped and Deblurred\sa_10240.jpg
# No valid crop found for sa_10241.jpg after 100 attempts. Skipping.
# Cropped sa_10242.jpg at (448, 479) and saved to D:\Download\meta\Cropped and Deblurred\sa_10242.jpg
# Cropped sa_10243.jpg at (163, 685) and saved to D:\Download\meta\Cropped and Deblurred\sa_10243.jpg
# No valid crop found for sa_10244.jpg after 100 attempts. Skipping.
# Cropped sa_10245.jpg at (1042, 313) and saved to D:\Download\meta\Cropped and Deblurred\sa_10245.jpg
# Cropped sa_10246.jpg at (1445, 834) and saved to D:\Download\meta\Cropped and Deblurred\sa_10246.jpg
# No valid crop found for sa_10247.jpg after 100 attempts. Skipping.
# Cropped sa_10248.jpg at (469, 41) and saved to D:\Download\meta\Cropped and Deblurred\sa_10248.jpg
# Cropped sa_10249.jpg at (227, 1682) and saved to D:\Download\meta\Cropped and Deblurred\sa_10249.jpg
# Cropped sa_1025.jpg at (155, 821) and saved to D:\Download\meta\Cropped and Deblurred\sa_1025.jpg
# Cropped sa_10250.jpg at (762, 664) and saved to D:\Download\meta\Cropped and Deblurred\sa_10250.jpg
# No valid crop found for sa_10251.jpg after 100 attempts. Skipping.
# Cropped sa_10252.jpg at (828, 604) and saved to D:\Download\meta\Cropped and Deblurred\sa_10252.jpg
# Cropped sa_10253.jpg at (147, 700) and saved to D:\Download\meta\Cropped and Deblurred\sa_10253.jpg
# No valid crop found for sa_10254.jpg after 100 attempts. Skipping.
# No valid crop found for sa_10255.jpg after 100 attempts. Skipping.
# No valid crop found for sa_10256.jpg after 100 attempts. Skipping.
# Cropped sa_10257.jpg at (192, 950) and saved to D:\Download\meta\Cropped and Deblurred\sa_10257.jpg
# No valid crop found for sa_10258.jpg after 100 attempts. Skipping.
# Cropped sa_10259.jpg at (1409, 386) and saved to D:\Download\meta\Cropped and Deblurred\sa_10259.jpg
# Cropped sa_1026.jpg at (1304, 719) and saved to D:\Download\meta\Cropped and Deblurred\sa_1026.jpg
# Cropped sa_10260.jpg at (2037, 270) and saved to D:\Download\meta\Cropped and Deblurred\sa_10260.jpg
# No valid crop found for sa_10261.jpg after 100 attempts. Skipping.
# Cropped sa_10262.jpg at (815, 655) and saved to D:\Download\meta\Cropped and Deblurred\sa_10262.jpg
# No valid crop found for sa_10263.jpg after 100 attempts. Skipping.
# Cropped sa_10264.jpg at (332, 59) and saved to D:\Download\meta\Cropped and Deblurred\sa_10264.jpg
# Cropped sa_10265.jpg at (1232, 68) and saved to D:\Download\meta\Cropped and Deblurred\sa_10265.jpg
# No valid crop found for sa_10266.jpg after 100 attempts. Skipping.
# Cropped sa_10267.jpg at (1349, 860) and saved to D:\Download\meta\Cropped and Deblurred\sa_10267.jpg
# No valid crop found for sa_10268.jpg after 100 attempts. Skipping.
# No valid crop found for sa_10269.jpg after 100 attempts. Skipping.
# Cropped sa_1027.jpg at (1009, 723) and saved to D:\Download\meta\Cropped and Deblurred\sa_1027.jpg
# Cropped sa_10270.jpg at (1381, 758) and saved to D:\Download\meta\Cropped and Deblurred\sa_10270.jpg
# Cropped sa_10271.jpg at (914, 1370) and saved to D:\Download\meta\Cropped and Deblurred\sa_10271.jpg
# Cropped sa_10272.jpg at (572, 554) and saved to D:\Download\meta\Cropped and Deblurred\sa_10272.jpg
# Cropped sa_10273.jpg at (1728, 987) and saved to D:\Download\meta\Cropped and Deblurred\sa_10273.jpg
# No valid crop found for sa_10274.jpg after 100 attempts. Skipping.
# Cropped sa_10275.jpg at (960, 179) and saved to D:\Download\meta\Cropped and Deblurred\sa_10275.jpg
# Cropped sa_10276.jpg at (1612, 734) and saved to D:\Download\meta\Cropped and Deblurred\sa_10276.jpg
# Cropped sa_10277.jpg at (745, 444) and saved to D:\Download\meta\Cropped and Deblurred\sa_10277.jpg
# No valid crop found for sa_10278.jpg after 100 attempts. Skipping.
# No valid crop found for sa_10279.jpg after 100 attempts. Skipping.
# Cropped sa_1028.jpg at (1477, 987) and saved to D:\Download\meta\Cropped and Deblurred\sa_1028.jpg
# No valid crop found for sa_10280.jpg after 100 attempts. Skipping.
# No valid crop found for sa_10281.jpg after 100 attempts. Skipping.
# Cropped sa_10282.jpg at (300, 918) and saved to D:\Download\meta\Cropped and Deblurred\sa_10282.jpg
# No valid crop found for sa_10283.jpg after 100 attempts. Skipping.
# No valid crop found for sa_10284.jpg after 100 attempts. Skipping.
# Cropped sa_10285.jpg at (57, 776) and saved to D:\Download\meta\Cropped and Deblurred\sa_10285.jpg
# No valid crop found for sa_10286.jpg after 100 attempts. Skipping.
# Cropped sa_10287.jpg at (708, 713) and saved to D:\Download\meta\Cropped and Deblurred\sa_10287.jpg
# No valid crop found for sa_10288.jpg after 100 attempts. Skipping.
# Cropped sa_10289.jpg at (790, 823) and saved to D:\Download\meta\Cropped and Deblurred\sa_10289.jpg
# No valid crop found for sa_1029.jpg after 100 attempts. Skipping.
# No valid crop found for sa_10290.jpg after 100 attempts. Skipping.
# Cropped sa_10291.jpg at (0, 1454) and saved to D:\Download\meta\Cropped and Deblurred\sa_10291.jpg
# Cropped sa_10292.jpg at (129, 647) and saved to D:\Download\meta\Cropped and Deblurred\sa_10292.jpg
# Cropped sa_10293.jpg at (947, 1442) and saved to D:\Download\meta\Cropped and Deblurred\sa_10293.jpg
# Cropped sa_10294.jpg at (1440, 793) and saved to D:\Download\meta\Cropped and Deblurred\sa_10294.jpg
# No valid crop found for sa_10295.jpg after 100 attempts. Skipping.
# Cropped sa_10296.jpg at (474, 1218) and saved to D:\Download\meta\Cropped and Deblurred\sa_10296.jpg
# Cropped sa_10297.jpg at (442, 311) and saved to D:\Download\meta\Cropped and Deblurred\sa_10297.jpg
# Cropped sa_10298.jpg at (1582, 738) and saved to D:\Download\meta\Cropped and Deblurred\sa_10298.jpg
# No valid crop found for sa_10299.jpg after 100 attempts. Skipping.
# Cropped sa_103.jpg at (89, 350) and saved to D:\Download\meta\Cropped and Deblurred\sa_103.jpg
# Cropped sa_1030.jpg at (1215, 754) and saved to D:\Download\meta\Cropped and Deblurred\sa_1030.jpg
# Cropped sa_10300.jpg at (1215, 789) and saved to D:\Download\meta\Cropped and Deblurred\sa_10300.jpg
# No valid crop found for sa_10301.jpg after 100 attempts. Skipping.
# Cropped sa_10302.jpg at (415, 961) and saved to D:\Download\meta\Cropped and Deblurred\sa_10302.jpg
# Cropped sa_10303.jpg at (1542, 898) and saved to D:\Download\meta\Cropped and Deblurred\sa_10303.jpg
# Cropped sa_10304.jpg at (478, 717) and saved to D:\Download\meta\Cropped and Deblurred\sa_10304.jpg
# No valid crop found for sa_10305.jpg after 100 attempts. Skipping.
# Cropped sa_10306.jpg at (1399, 189) and saved to D:\Download\meta\Cropped and Deblurred\sa_10306.jpg
# No valid crop found for sa_10307.jpg after 100 attempts. Skipping.
# No valid crop found for sa_10308.jpg after 100 attempts. Skipping.
# Cropped sa_10309.jpg at (1635, 250) and saved to D:\Download\meta\Cropped and Deblurred\sa_10309.jpg
# No valid crop found for sa_1031.jpg after 100 attempts. Skipping.
# Cropped sa_10310.jpg at (579, 1331) and saved to D:\Download\meta\Cropped and Deblurred\sa_10310.jpg
# Cropped sa_10311.jpg at (101, 711) and saved to D:\Download\meta\Cropped and Deblurred\sa_10311.jpg
# Cropped sa_10312.jpg at (759, 607) and saved to D:\Download\meta\Cropped and Deblurred\sa_10312.jpg
# Cropped sa_10313.jpg at (1167, 781) and saved to D:\Download\meta\Cropped and Deblurred\sa_10313.jpg
# No valid crop found for sa_10314.jpg after 100 attempts. Skipping.
# No valid crop found for sa_10315.jpg after 100 attempts. Skipping.
# Cropped sa_10316.jpg at (669, 677) and saved to D:\Download\meta\Cropped and Deblurred\sa_10316.jpg
# Cropped sa_10317.jpg at (1494, 794) and saved to D:\Download\meta\Cropped and Deblurred\sa_10317.jpg
# Cropped sa_10318.jpg at (1274, 805) and saved to D:\Download\meta\Cropped and Deblurred\sa_10318.jpg
# No valid crop found for sa_10319.jpg after 100 attempts. Skipping.
# Cropped sa_1032.jpg at (648, 424) and saved to D:\Download\meta\Cropped and Deblurred\sa_1032.jpg
# Cropped sa_10320.jpg at (734, 580) and saved to D:\Download\meta\Cropped and Deblurred\sa_10320.jpg
# No valid crop found for sa_10321.jpg after 100 attempts. Skipping.
# No valid crop found for sa_10322.jpg after 100 attempts. Skipping.
# No valid crop found for sa_10323.jpg after 100 attempts. Skipping.
# Cropped sa_10324.jpg at (909, 251) and saved to D:\Download\meta\Cropped and Deblurred\sa_10324.jpg
# Cropped sa_10325.jpg at (605, 310) and saved to D:\Download\meta\Cropped and Deblurred\sa_10325.jpg
# Cropped sa_10326.jpg at (972, 516) and saved to D:\Download\meta\Cropped and Deblurred\sa_10326.jpg
# No valid crop found for sa_10327.jpg after 100 attempts. Skipping.
# Cropped sa_10328.jpg at (584, 940) and saved to D:\Download\meta\Cropped and Deblurred\sa_10328.jpg
# No valid crop found for sa_10329.jpg after 100 attempts. Skipping.
# No valid crop found for sa_1033.jpg after 100 attempts. Skipping.
# No valid crop found for sa_10330.jpg after 100 attempts. Skipping.
# No valid crop found for sa_10331.jpg after 100 attempts. Skipping.
# No valid crop found for sa_10332.jpg after 100 attempts. Skipping.
# Cropped sa_10333.jpg at (1463, 876) and saved to D:\Download\meta\Cropped and Deblurred\sa_10333.jpg
# Cropped sa_10334.jpg at (457, 658) and saved to D:\Download\meta\Cropped and Deblurred\sa_10334.jpg
# Cropped sa_10335.jpg at (705, 2076) and saved to D:\Download\meta\Cropped and Deblurred\sa_10335.jpg
# Cropped sa_10336.jpg at (857, 960) and saved to D:\Download\meta\Cropped and Deblurred\sa_10336.jpg
# No valid crop found for sa_10337.jpg after 100 attempts. Skipping.
# Cropped sa_10338.jpg at (312, 970) and saved to D:\Download\meta\Cropped and Deblurred\sa_10338.jpg
# Cropped sa_10339.jpg at (1511, 769) and saved to D:\Download\meta\Cropped and Deblurred\sa_10339.jpg
# Cropped sa_1034.jpg at (180, 784) and saved to D:\Download\meta\Cropped and Deblurred\sa_1034.jpg
# Cropped sa_10340.jpg at (1373, 727) and saved to D:\Download\meta\Cropped and Deblurred\sa_10340.jpg
# Cropped sa_10341.jpg at (1254, 504) and saved to D:\Download\meta\Cropped and Deblurred\sa_10341.jpg
# No valid crop found for sa_10342.jpg after 100 attempts. Skipping.
# Cropped sa_10343.jpg at (227, 797) and saved to D:\Download\meta\Cropped and Deblurred\sa_10343.jpg
# No valid crop found for sa_10344.jpg after 100 attempts. Skipping.
# No valid crop found for sa_10345.jpg after 100 attempts. Skipping.
# Cropped sa_10346.jpg at (59, 1940) and saved to D:\Download\meta\Cropped and Deblurred\sa_10346.jpg
# Cropped sa_10347.jpg at (603, 161) and saved to D:\Download\meta\Cropped and Deblurred\sa_10347.jpg
# No valid crop found for sa_10348.jpg after 100 attempts. Skipping.
# Cropped sa_10349.jpg at (95, 169) and saved to D:\Download\meta\Cropped and Deblurred\sa_10349.jpg
# Cropped sa_1035.jpg at (1266, 905) and saved to D:\Download\meta\Cropped and Deblurred\sa_1035.jpg
# No valid crop found for sa_10350.jpg after 100 attempts. Skipping.
# Cropped sa_10351.jpg at (1305, 895) and saved to D:\Download\meta\Cropped and Deblurred\sa_10351.jpg
# Cropped sa_10352.jpg at (300, 877) and saved to D:\Download\meta\Cropped and Deblurred\sa_10352.jpg
# Cropped sa_10353.jpg at (840, 117) and saved to D:\Download\meta\Cropped and Deblurred\sa_10353.jpg
# Cropped sa_10354.jpg at (12, 1316) and saved to D:\Download\meta\Cropped and Deblurred\sa_10354.jpg
# Cropped sa_10355.jpg at (1782, 306) and saved to D:\Download\meta\Cropped and Deblurred\sa_10355.jpg
# No valid crop found for sa_10356.jpg after 100 attempts. Skipping.
# Cropped sa_10357.jpg at (1528, 623) and saved to D:\Download\meta\Cropped and Deblurred\sa_10357.jpg
# Cropped sa_10358.jpg at (45, 837) and saved to D:\Download\meta\Cropped and Deblurred\sa_10358.jpg
# Cropped sa_10359.jpg at (392, 966) and saved to D:\Download\meta\Cropped and Deblurred\sa_10359.jpg
# Cropped sa_1036.jpg at (829, 1188) and saved to D:\Download\meta\Cropped and Deblurred\sa_1036.jpg
# Cropped sa_10360.jpg at (1190, 181) and saved to D:\Download\meta\Cropped and Deblurred\sa_10360.jpg
# Cropped sa_10361.jpg at (1042, 859) and saved to D:\Download\meta\Cropped and Deblurred\sa_10361.jpg
# No valid crop found for sa_10362.jpg after 100 attempts. Skipping.
# Cropped sa_10363.jpg at (731, 11) and saved to D:\Download\meta\Cropped and Deblurred\sa_10363.jpg
# No valid crop found for sa_10364.jpg after 100 attempts. Skipping.
# Cropped sa_10365.jpg at (877, 757) and saved to D:\Download\meta\Cropped and Deblurred\sa_10365.jpg
# No valid crop found for sa_10366.jpg after 100 attempts. Skipping.
# Cropped sa_10367.jpg at (5, 51) and saved to D:\Download\meta\Cropped and Deblurred\sa_10367.jpg
# Cropped sa_10368.jpg at (583, 11) and saved to D:\Download\meta\Cropped and Deblurred\sa_10368.jpg
# Cropped sa_10369.jpg at (403, 1574) and saved to D:\Download\meta\Cropped and Deblurred\sa_10369.jpg
# No valid crop found for sa_1037.jpg after 100 attempts. Skipping.
# Cropped sa_10370.jpg at (22, 880) and saved to D:\Download\meta\Cropped and Deblurred\sa_10370.jpg
# Cropped sa_10371.jpg at (1223, 375) and saved to D:\Download\meta\Cropped and Deblurred\sa_10371.jpg
# Cropped sa_10372.jpg at (236, 229) and saved to D:\Download\meta\Cropped and Deblurred\sa_10372.jpg
# Cropped sa_10373.jpg at (50, 1276) and saved to D:\Download\meta\Cropped and Deblurred\sa_10373.jpg
# Cropped sa_10374.jpg at (280, 44) and saved to D:\Download\meta\Cropped and Deblurred\sa_10374.jpg
# Cropped sa_10375.jpg at (717, 542) and saved to D:\Download\meta\Cropped and Deblurred\sa_10375.jpg
# No valid crop found for sa_10376.jpg after 100 attempts. Skipping.
# No valid crop found for sa_10377.jpg after 100 attempts. Skipping.
# Cropped sa_10378.jpg at (1003, 723) and saved to D:\Download\meta\Cropped and Deblurred\sa_10378.jpg
# Cropped sa_10379.jpg at (322, 1218) and saved to D:\Download\meta\Cropped and Deblurred\sa_10379.jpg
# Cropped sa_1038.jpg at (891, 601) and saved to D:\Download\meta\Cropped and Deblurred\sa_1038.jpg
# Cropped sa_10380.jpg at (1431, 788) and saved to D:\Download\meta\Cropped and Deblurred\sa_10380.jpg
# Cropped sa_10381.jpg at (496, 1533) and saved to D:\Download\meta\Cropped and Deblurred\sa_10381.jpg
# Cropped sa_10382.jpg at (103, 321) and saved to D:\Download\meta\Cropped and Deblurred\sa_10382.jpg
# No valid crop found for sa_10383.jpg after 100 attempts. Skipping.
# Cropped sa_10384.jpg at (525, 882) and saved to D:\Download\meta\Cropped and Deblurred\sa_10384.jpg
# Cropped sa_10385.jpg at (140, 788) and saved to D:\Download\meta\Cropped and Deblurred\sa_10385.jpg
# Cropped sa_10386.jpg at (1049, 602) and saved to D:\Download\meta\Cropped and Deblurred\sa_10386.jpg
# Cropped sa_10387.jpg at (1083, 416) and saved to D:\Download\meta\Cropped and Deblurred\sa_10387.jpg
# No valid crop found for sa_10388.jpg after 100 attempts. Skipping.
# Cropped sa_10389.jpg at (1426, 526) and saved to D:\Download\meta\Cropped and Deblurred\sa_10389.jpg
# No valid crop found for sa_1039.jpg after 100 attempts. Skipping.
# No valid crop found for sa_10390.jpg after 100 attempts. Skipping.
# No valid crop found for sa_10391.jpg after 100 attempts. Skipping.
# Cropped sa_10392.jpg at (717, 64) and saved to D:\Download\meta\Cropped and Deblurred\sa_10392.jpg
# No valid crop found for sa_10393.jpg after 100 attempts. Skipping.
# Cropped sa_10394.jpg at (1447, 760) and saved to D:\Download\meta\Cropped and Deblurred\sa_10394.jpg
# No valid crop found for sa_10395.jpg after 100 attempts. Skipping.
# Cropped sa_10396.jpg at (1592, 971) and saved to D:\Download\meta\Cropped and Deblurred\sa_10396.jpg
# Cropped sa_10397.jpg at (1350, 293) and saved to D:\Download\meta\Cropped and Deblurred\sa_10397.jpg
# No valid crop found for sa_10398.jpg after 100 attempts. Skipping.
# No valid crop found for sa_10399.jpg after 100 attempts. Skipping.
# Cropped sa_104.jpg at (776, 125) and saved to D:\Download\meta\Cropped and Deblurred\sa_104.jpg
# Cropped sa_1040.jpg at (1454, 243) and saved to D:\Download\meta\Cropped and Deblurred\sa_1040.jpg
# No valid crop found for sa_10400.jpg after 100 attempts. Skipping.
# No valid crop found for sa_10401.jpg after 100 attempts. Skipping.
# No valid crop found for sa_10402.jpg after 100 attempts. Skipping.
# No valid crop found for sa_10403.jpg after 100 attempts. Skipping.
# Cropped sa_10404.jpg at (911, 886) and saved to D:\Download\meta\Cropped and Deblurred\sa_10404.jpg
# Cropped sa_10405.jpg at (224, 146) and saved to D:\Download\meta\Cropped and Deblurred\sa_10405.jpg
# Cropped sa_10406.jpg at (111, 887) and saved to D:\Download\meta\Cropped and Deblurred\sa_10406.jpg
# No valid crop found for sa_10407.jpg after 100 attempts. Skipping.
# Cropped sa_10408.jpg at (232, 887) and saved to D:\Download\meta\Cropped and Deblurred\sa_10408.jpg
# No valid crop found for sa_10409.jpg after 100 attempts. Skipping.
# No valid crop found for sa_1041.jpg after 100 attempts. Skipping.
# Cropped sa_10410.jpg at (141, 406) and saved to D:\Download\meta\Cropped and Deblurred\sa_10410.jpg
# Cropped sa_10411.jpg at (31, 1032) and saved to D:\Download\meta\Cropped and Deblurred\sa_10411.jpg
# Cropped sa_10412.jpg at (933, 884) and saved to D:\Download\meta\Cropped and Deblurred\sa_10412.jpg
# No valid crop found for sa_10413.jpg after 100 attempts. Skipping.
# Cropped sa_10414.jpg at (1879, 915) and saved to D:\Download\meta\Cropped and Deblurred\sa_10414.jpg
# No valid crop found for sa_10415.jpg after 100 attempts. Skipping.
# No valid crop found for sa_10416.jpg after 100 attempts. Skipping.
# Cropped sa_10417.jpg at (849, 613) and saved to D:\Download\meta\Cropped and Deblurred\sa_10417.jpg
# Cropped sa_10418.jpg at (1060, 320) and saved to D:\Download\meta\Cropped and Deblurred\sa_10418.jpg
# Cropped sa_10419.jpg at (246, 315) and saved to D:\Download\meta\Cropped and Deblurred\sa_10419.jpg
# Cropped sa_1042.jpg at (499, 892) and saved to D:\Download\meta\Cropped and Deblurred\sa_1042.jpg
# Cropped sa_10420.jpg at (1492, 440) and saved to D:\Download\meta\Cropped and Deblurred\sa_10420.jpg
# No valid crop found for sa_10421.jpg after 100 attempts. Skipping.
# Cropped sa_10422.jpg at (1530, 170) and saved to D:\Download\meta\Cropped and Deblurred\sa_10422.jpg
# Cropped sa_10423.jpg at (446, 1525) and saved to D:\Download\meta\Cropped and Deblurred\sa_10423.jpg
# Cropped sa_10424.jpg at (354, 975) and saved to D:\Download\meta\Cropped and Deblurred\sa_10424.jpg
# Cropped sa_10425.jpg at (847, 1087) and saved to D:\Download\meta\Cropped and Deblurred\sa_10425.jpg
# No valid crop found for sa_10426.jpg after 100 attempts. Skipping.
# No valid crop found for sa_10427.jpg after 100 attempts. Skipping.
# Cropped sa_10428.jpg at (1589, 451) and saved to D:\Download\meta\Cropped and Deblurred\sa_10428.jpg
# Cropped sa_10429.jpg at (744, 506) and saved to D:\Download\meta\Cropped and Deblurred\sa_10429.jpg
# Cropped sa_1043.jpg at (1115, 866) and saved to D:\Download\meta\Cropped and Deblurred\sa_1043.jpg
# No valid crop found for sa_10430.jpg after 100 attempts. Skipping.
# Cropped sa_10431.jpg at (208, 963) and saved to D:\Download\meta\Cropped and Deblurred\sa_10431.jpg
# Cropped sa_10432.jpg at (19, 443) and saved to D:\Download\meta\Cropped and Deblurred\sa_10432.jpg
# No valid crop found for sa_10433.jpg after 100 attempts. Skipping.
# No valid crop found for sa_10434.jpg after 100 attempts. Skipping.
# No valid crop found for sa_10435.jpg after 100 attempts. Skipping.
# Cropped sa_10436.jpg at (53, 986) and saved to D:\Download\meta\Cropped and Deblurred\sa_10436.jpg
# No valid crop found for sa_10437.jpg after 100 attempts. Skipping.
# Cropped sa_10438.jpg at (1041, 799) and saved to D:\Download\meta\Cropped and Deblurred\sa_10438.jpg
# Cropped sa_10439.jpg at (1380, 986) and saved to D:\Download\meta\Cropped and Deblurred\sa_10439.jpg
# No valid crop found for sa_1044.jpg after 100 attempts. Skipping.
# Cropped sa_10440.jpg at (873, 78) and saved to D:\Download\meta\Cropped and Deblurred\sa_10440.jpg
# Cropped sa_10441.jpg at (1316, 782) and saved to D:\Download\meta\Cropped and Deblurred\sa_10441.jpg
# Cropped sa_10442.jpg at (663, 836) and saved to D:\Download\meta\Cropped and Deblurred\sa_10442.jpg
# Cropped sa_10443.jpg at (1333, 879) and saved to D:\Download\meta\Cropped and Deblurred\sa_10443.jpg
# No valid crop found for sa_10444.jpg after 100 attempts. Skipping.
# No valid crop found for sa_10445.jpg after 100 attempts. Skipping.
# Cropped sa_10446.jpg at (1016, 586) and saved to D:\Download\meta\Cropped and Deblurred\sa_10446.jpg
# Cropped sa_10447.jpg at (1637, 954) and saved to D:\Download\meta\Cropped and Deblurred\sa_10447.jpg
# Cropped sa_10448.jpg at (1637, 649) and saved to D:\Download\meta\Cropped and Deblurred\sa_10448.jpg
# Cropped sa_10449.jpg at (648, 1440) and saved to D:\Download\meta\Cropped and Deblurred\sa_10449.jpg
# No valid crop found for sa_1045.jpg after 100 attempts. Skipping.
# No valid crop found for sa_10450.jpg after 100 attempts. Skipping.
# Cropped sa_10451.jpg at (124, 855) and saved to D:\Download\meta\Cropped and Deblurred\sa_10451.jpg
# Cropped sa_10452.jpg at (225, 405) and saved to D:\Download\meta\Cropped and Deblurred\sa_10452.jpg
# Cropped sa_10453.jpg at (681, 767) and saved to D:\Download\meta\Cropped and Deblurred\sa_10453.jpg
# Cropped sa_10454.jpg at (947, 612) and saved to D:\Download\meta\Cropped and Deblurred\sa_10454.jpg
# Cropped sa_10455.jpg at (252, 972) and saved to D:\Download\meta\Cropped and Deblurred\sa_10455.jpg
# No valid crop found for sa_10456.jpg after 100 attempts. Skipping.
# Cropped sa_10457.jpg at (729, 720) and saved to D:\Download\meta\Cropped and Deblurred\sa_10457.jpg
# No valid crop found for sa_10458.jpg after 100 attempts. Skipping.
# Cropped sa_10459.jpg at (862, 669) and saved to D:\Download\meta\Cropped and Deblurred\sa_10459.jpg
# Cropped sa_1046.jpg at (651, 852) and saved to D:\Download\meta\Cropped and Deblurred\sa_1046.jpg
# Cropped sa_10460.jpg at (525, 629) and saved to D:\Download\meta\Cropped and Deblurred\sa_10460.jpg
# Cropped sa_10461.jpg at (439, 956) and saved to D:\Download\meta\Cropped and Deblurred\sa_10461.jpg
# Cropped sa_10462.jpg at (611, 111) and saved to D:\Download\meta\Cropped and Deblurred\sa_10462.jpg
# No valid crop found for sa_10463.jpg after 100 attempts. Skipping.
# Cropped sa_10464.jpg at (828, 474) and saved to D:\Download\meta\Cropped and Deblurred\sa_10464.jpg
# Cropped sa_10465.jpg at (664, 964) and saved to D:\Download\meta\Cropped and Deblurred\sa_10465.jpg
# Cropped sa_10466.jpg at (1343, 863) and saved to D:\Download\meta\Cropped and Deblurred\sa_10466.jpg
# No valid crop found for sa_10467.jpg after 100 attempts. Skipping.
# Cropped sa_10468.jpg at (1134, 611) and saved to D:\Download\meta\Cropped and Deblurred\sa_10468.jpg
# Cropped sa_10469.jpg at (383, 676) and saved to D:\Download\meta\Cropped and Deblurred\sa_10469.jpg
# Cropped sa_1047.jpg at (833, 552) and saved to D:\Download\meta\Cropped and Deblurred\sa_1047.jpg
# No valid crop found for sa_10470.jpg after 100 attempts. Skipping.
# No valid crop found for sa_10471.jpg after 100 attempts. Skipping.
# No valid crop found for sa_10472.jpg after 100 attempts. Skipping.
# Cropped sa_10473.jpg at (1080, 754) and saved to D:\Download\meta\Cropped and Deblurred\sa_10473.jpg
# No valid crop found for sa_10474.jpg after 100 attempts. Skipping.
# Cropped sa_10475.jpg at (58, 499) and saved to D:\Download\meta\Cropped and Deblurred\sa_10475.jpg
# Cropped sa_10476.jpg at (332, 1094) and saved to D:\Download\meta\Cropped and Deblurred\sa_10476.jpg
# Cropped sa_10477.jpg at (1098, 672) and saved to D:\Download\meta\Cropped and Deblurred\sa_10477.jpg
# Cropped sa_10478.jpg at (43, 1526) and saved to D:\Download\meta\Cropped and Deblurred\sa_10478.jpg
# Cropped sa_10479.jpg at (582, 783) and saved to D:\Download\meta\Cropped and Deblurred\sa_10479.jpg
# No valid crop found for sa_1048.jpg after 100 attempts. Skipping.
# No valid crop found for sa_10480.jpg after 100 attempts. Skipping.
# Cropped sa_10481.jpg at (1663, 876) and saved to D:\Download\meta\Cropped and Deblurred\sa_10481.jpg
# No valid crop found for sa_10482.jpg after 100 attempts. Skipping.
# No valid crop found for sa_10483.jpg after 100 attempts. Skipping.
# Cropped sa_10484.jpg at (737, 393) and saved to D:\Download\meta\Cropped and Deblurred\sa_10484.jpg
# Cropped sa_10485.jpg at (1514, 628) and saved to D:\Download\meta\Cropped and Deblurred\sa_10485.jpg
# No valid crop found for sa_10486.jpg after 100 attempts. Skipping.
# Cropped sa_10487.jpg at (1173, 639) and saved to D:\Download\meta\Cropped and Deblurred\sa_10487.jpg
# Cropped sa_10488.jpg at (104, 782) and saved to D:\Download\meta\Cropped and Deblurred\sa_10488.jpg
# No valid crop found for sa_10489.jpg after 100 attempts. Skipping.
# No valid crop found for sa_1049.jpg after 100 attempts. Skipping.
# Cropped sa_10490.jpg at (1444, 926) and saved to D:\Download\meta\Cropped and Deblurred\sa_10490.jpg
# Cropped sa_10491.jpg at (2078, 7) and saved to D:\Download\meta\Cropped and Deblurred\sa_10491.jpg
# ...
# No valid crop found for sa_9834.jpg after 100 attempts. Skipping.
# No valid crop found for sa_9835.jpg after 100 attempts. Skipping.
# Cropped sa_9836.jpg at (953, 1377) and saved to D:\Download\meta\Cropped and Deblurred\sa_9836.jpg
# Cropped sa_9837.jpg at (436, 1286) and saved to D:\Download\meta\Cropped and Deblurred\sa_9837.jpg
# No valid crop found for sa_9838.jpg after 100 attempts. Skipping.
# Cropped sa_9839.jpg at (1003, 144) and saved to D:\Download\meta\Cropped and Deblurred\sa_9839.jpg
# Cropped sa_984.jpg at (268, 903) and saved to D:\Download\meta\Cropped and Deblurred\sa_984.jpg
# Cropped sa_9840.jpg at (755, 968) and saved to D:\Download\meta\Cropped and Deblurred\sa_9840.jpg
# Cropped sa_9841.jpg at (427, 152) and saved to D:\Download\meta\Cropped and Deblurred\sa_9841.jpg
# Cropped sa_9842.jpg at (882, 273) and saved to D:\Download\meta\Cropped and Deblurred\sa_9842.jpg
# Cropped sa_9843.jpg at (529, 613) and saved to D:\Download\meta\Cropped and Deblurred\sa_9843.jpg
# Cropped sa_9844.jpg at (752, 806) and saved to D:\Download\meta\Cropped and Deblurred\sa_9844.jpg
# No valid crop found for sa_9845.jpg after 100 attempts. Skipping.
# Cropped sa_9846.jpg at (283, 772) and saved to D:\Download\meta\Cropped and Deblurred\sa_9846.jpg
# Cropped sa_9847.jpg at (1684, 620) and saved to D:\Download\meta\Cropped and Deblurred\sa_9847.jpg
# Cropped sa_9848.jpg at (373, 446) and saved to D:\Download\meta\Cropped and Deblurred\sa_9848.jpg
# No valid crop found for sa_9849.jpg after 100 attempts. Skipping.
# No valid crop found for sa_985.jpg after 100 attempts. Skipping.
# No valid crop found for sa_9850.jpg after 100 attempts. Skipping.
# Cropped sa_9851.jpg at (1482, 687) and saved to D:\Download\meta\Cropped and Deblurred\sa_9851.jpg
# Cropped sa_9852.jpg at (837, 949) and saved to D:\Download\meta\Cropped and Deblurred\sa_9852.jpg
# No valid crop found for sa_9853.jpg after 100 attempts. Skipping.
# Cropped sa_9854.jpg at (819, 608) and saved to D:\Download\meta\Cropped and Deblurred\sa_9854.jpg
# Cropped sa_9855.jpg at (1086, 843) and saved to D:\Download\meta\Cropped and Deblurred\sa_9855.jpg
# No valid crop found for sa_9856.jpg after 100 attempts. Skipping.
# Cropped sa_9857.jpg at (173, 225) and saved to D:\Download\meta\Cropped and Deblurred\sa_9857.jpg
# No valid crop found for sa_9858.jpg after 100 attempts. Skipping.
# Cropped sa_9859.jpg at (1817, 898) and saved to D:\Download\meta\Cropped and Deblurred\sa_9859.jpg
# No valid crop found for sa_986.jpg after 100 attempts. Skipping.
# No valid crop found for sa_9860.jpg after 100 attempts. Skipping.
# Cropped sa_9861.jpg at (4037, 542) and saved to D:\Download\meta\Cropped and Deblurred\sa_9861.jpg
# No valid crop found for sa_9862.jpg after 100 attempts. Skipping.
# Cropped sa_9863.jpg at (1672, 442) and saved to D:\Download\meta\Cropped and Deblurred\sa_9863.jpg
# Cropped sa_9864.jpg at (533, 863) and saved to D:\Download\meta\Cropped and Deblurred\sa_9864.jpg
# No valid crop found for sa_9865.jpg after 100 attempts. Skipping.
# Cropped sa_9866.jpg at (727, 589) and saved to D:\Download\meta\Cropped and Deblurred\sa_9866.jpg
# Cropped sa_9867.jpg at (1037, 34) and saved to D:\Download\meta\Cropped and Deblurred\sa_9867.jpg
# Cropped sa_9868.jpg at (357, 101) and saved to D:\Download\meta\Cropped and Deblurred\sa_9868.jpg
# Cropped sa_9869.jpg at (573, 917) and saved to D:\Download\meta\Cropped and Deblurred\sa_9869.jpg
# No valid crop found for sa_987.jpg after 100 attempts. Skipping.
# No valid crop found for sa_9870.jpg after 100 attempts. Skipping.
# No valid crop found for sa_9871.jpg after 100 attempts. Skipping.
# Cropped sa_9872.jpg at (306, 247) and saved to D:\Download\meta\Cropped and Deblurred\sa_9872.jpg
# Cropped sa_9873.jpg at (660, 182) and saved to D:\Download\meta\Cropped and Deblurred\sa_9873.jpg
# Cropped sa_9874.jpg at (954, 290) and saved to D:\Download\meta\Cropped and Deblurred\sa_9874.jpg
# Cropped sa_9875.jpg at (795, 760) and saved to D:\Download\meta\Cropped and Deblurred\sa_9875.jpg
# Cropped sa_9876.jpg at (528, 972) and saved to D:\Download\meta\Cropped and Deblurred\sa_9876.jpg
# Cropped sa_9877.jpg at (1228, 778) and saved to D:\Download\meta\Cropped and Deblurred\sa_9877.jpg
# No valid crop found for sa_9878.jpg after 100 attempts. Skipping.
# No valid crop found for sa_9879.jpg after 100 attempts. Skipping.
# No valid crop found for sa_988.jpg after 100 attempts. Skipping.
# No valid crop found for sa_9880.jpg after 100 attempts. Skipping.
# No valid crop found for sa_9881.jpg after 100 attempts. Skipping.
# Cropped sa_9882.jpg at (762, 904) and saved to D:\Download\meta\Cropped and Deblurred\sa_9882.jpg
# Cropped sa_9883.jpg at (751, 384) and saved to D:\Download\meta\Cropped and Deblurred\sa_9883.jpg
# Cropped sa_9884.jpg at (1555, 136) and saved to D:\Download\meta\Cropped and Deblurred\sa_9884.jpg
# Cropped sa_9885.jpg at (2138, 942) and saved to D:\Download\meta\Cropped and Deblurred\sa_9885.jpg
# Cropped sa_9886.jpg at (860, 781) and saved to D:\Download\meta\Cropped and Deblurred\sa_9886.jpg
# Cropped sa_9887.jpg at (894, 1670) and saved to D:\Download\meta\Cropped and Deblurred\sa_9887.jpg
# Cropped sa_9888.jpg at (830, 818) and saved to D:\Download\meta\Cropped and Deblurred\sa_9888.jpg
# No valid crop found for sa_9889.jpg after 100 attempts. Skipping.
# Cropped sa_989.jpg at (416, 398) and saved to D:\Download\meta\Cropped and Deblurred\sa_989.jpg
# Cropped sa_9890.jpg at (1498, 283) and saved to D:\Download\meta\Cropped and Deblurred\sa_9890.jpg
# Cropped sa_9891.jpg at (1625, 505) and saved to D:\Download\meta\Cropped and Deblurred\sa_9891.jpg
# Cropped sa_9892.jpg at (35, 866) and saved to D:\Download\meta\Cropped and Deblurred\sa_9892.jpg
# Cropped sa_9893.jpg at (1310, 972) and saved to D:\Download\meta\Cropped and Deblurred\sa_9893.jpg
# No valid crop found for sa_9894.jpg after 100 attempts. Skipping.
# Cropped sa_9895.jpg at (286, 414) and saved to D:\Download\meta\Cropped and Deblurred\sa_9895.jpg
# Cropped sa_9896.jpg at (1211, 805) and saved to D:\Download\meta\Cropped and Deblurred\sa_9896.jpg
# Cropped sa_9897.jpg at (575, 1533) and saved to D:\Download\meta\Cropped and Deblurred\sa_9897.jpg
# Cropped sa_9898.jpg at (1238, 209) and saved to D:\Download\meta\Cropped and Deblurred\sa_9898.jpg
# Cropped sa_9899.jpg at (1670, 842) and saved to D:\Download\meta\Cropped and Deblurred\sa_9899.jpg
# Cropped sa_99.jpg at (798, 553) and saved to D:\Download\meta\Cropped and Deblurred\sa_99.jpg
# No valid crop found for sa_990.jpg after 100 attempts. Skipping.
# Cropped sa_9900.jpg at (1004, 796) and saved to D:\Download\meta\Cropped and Deblurred\sa_9900.jpg
# Cropped sa_9901.jpg at (177, 725) and saved to D:\Download\meta\Cropped and Deblurred\sa_9901.jpg
# No valid crop found for sa_9902.jpg after 100 attempts. Skipping.
# Cropped sa_9903.jpg at (846, 1567) and saved to D:\Download\meta\Cropped and Deblurred\sa_9903.jpg
# Cropped sa_9904.jpg at (1692, 988) and saved to D:\Download\meta\Cropped and Deblurred\sa_9904.jpg
# Cropped sa_9905.jpg at (310, 880) and saved to D:\Download\meta\Cropped and Deblurred\sa_9905.jpg
# Cropped sa_9906.jpg at (705, 1483) and saved to D:\Download\meta\Cropped and Deblurred\sa_9906.jpg
# No valid crop found for sa_9907.jpg after 100 attempts. Skipping.
# Cropped sa_9908.jpg at (1366, 638) and saved to D:\Download\meta\Cropped and Deblurred\sa_9908.jpg
# Cropped sa_9909.jpg at (1134, 571) and saved to D:\Download\meta\Cropped and Deblurred\sa_9909.jpg
# Cropped sa_991.jpg at (1817, 946) and saved to D:\Download\meta\Cropped and Deblurred\sa_991.jpg
# Cropped sa_9910.jpg at (1513, 280) and saved to D:\Download\meta\Cropped and Deblurred\sa_9910.jpg
# Cropped sa_9911.jpg at (575, 967) and saved to D:\Download\meta\Cropped and Deblurred\sa_9911.jpg
# No valid crop found for sa_9912.jpg after 100 attempts. Skipping.
# Cropped sa_9913.jpg at (1382, 885) and saved to D:\Download\meta\Cropped and Deblurred\sa_9913.jpg
# Cropped sa_9914.jpg at (774, 814) and saved to D:\Download\meta\Cropped and Deblurred\sa_9914.jpg
# No valid crop found for sa_9915.jpg after 100 attempts. Skipping.
# No valid crop found for sa_9916.jpg after 100 attempts. Skipping.
# No valid crop found for sa_9917.jpg after 100 attempts. Skipping.
# Cropped sa_9918.jpg at (1215, 833) and saved to D:\Download\meta\Cropped and Deblurred\sa_9918.jpg
# Cropped sa_9919.jpg at (819, 744) and saved to D:\Download\meta\Cropped and Deblurred\sa_9919.jpg
# Cropped sa_992.jpg at (934, 89) and saved to D:\Download\meta\Cropped and Deblurred\sa_992.jpg
# No valid crop found for sa_9920.jpg after 100 attempts. Skipping.
# No valid crop found for sa_9921.jpg after 100 attempts. Skipping.
# No valid crop found for sa_9922.jpg after 100 attempts. Skipping.
# No valid crop found for sa_9923.jpg after 100 attempts. Skipping.
# Cropped sa_9924.jpg at (187, 1060) and saved to D:\Download\meta\Cropped and Deblurred\sa_9924.jpg
# No valid crop found for sa_9925.jpg after 100 attempts. Skipping.
# Cropped sa_9926.jpg at (1051, 245) and saved to D:\Download\meta\Cropped and Deblurred\sa_9926.jpg
# Cropped sa_9927.jpg at (278, 161) and saved to D:\Download\meta\Cropped and Deblurred\sa_9927.jpg
# Cropped sa_9928.jpg at (1253, 961) and saved to D:\Download\meta\Cropped and Deblurred\sa_9928.jpg
# Cropped sa_9929.jpg at (21, 903) and saved to D:\Download\meta\Cropped and Deblurred\sa_9929.jpg
# Cropped sa_993.jpg at (843, 900) and saved to D:\Download\meta\Cropped and Deblurred\sa_993.jpg
# Cropped sa_9930.jpg at (525, 870) and saved to D:\Download\meta\Cropped and Deblurred\sa_9930.jpg
# No valid crop found for sa_9931.jpg after 100 attempts. Skipping.
# Cropped sa_9932.jpg at (1632, 667) and saved to D:\Download\meta\Cropped and Deblurred\sa_9932.jpg
# No valid crop found for sa_9933.jpg after 100 attempts. Skipping.
# Cropped sa_9934.jpg at (1592, 897) and saved to D:\Download\meta\Cropped and Deblurred\sa_9934.jpg
# Cropped sa_9935.jpg at (209, 192) and saved to D:\Download\meta\Cropped and Deblurred\sa_9935.jpg
# Cropped sa_9936.jpg at (416, 1392) and saved to D:\Download\meta\Cropped and Deblurred\sa_9936.jpg
# No valid crop found for sa_9937.jpg after 100 attempts. Skipping.
# No valid crop found for sa_9938.jpg after 100 attempts. Skipping.
# Cropped sa_9939.jpg at (239, 616) and saved to D:\Download\meta\Cropped and Deblurred\sa_9939.jpg
# Cropped sa_994.jpg at (354, 895) and saved to D:\Download\meta\Cropped and Deblurred\sa_994.jpg
# Cropped sa_9940.jpg at (505, 609) and saved to D:\Download\meta\Cropped and Deblurred\sa_9940.jpg
# Cropped sa_9941.jpg at (942, 235) and saved to D:\Download\meta\Cropped and Deblurred\sa_9941.jpg
# No valid crop found for sa_9942.jpg after 100 attempts. Skipping.
# Cropped sa_9943.jpg at (197, 902) and saved to D:\Download\meta\Cropped and Deblurred\sa_9943.jpg
# No valid crop found for sa_9944.jpg after 100 attempts. Skipping.
# Cropped sa_9945.jpg at (633, 636) and saved to D:\Download\meta\Cropped and Deblurred\sa_9945.jpg
# Cropped sa_9946.jpg at (331, 1573) and saved to D:\Download\meta\Cropped and Deblurred\sa_9946.jpg
# Cropped sa_9947.jpg at (1482, 490) and saved to D:\Download\meta\Cropped and Deblurred\sa_9947.jpg
# Cropped sa_9948.jpg at (1705, 790) and saved to D:\Download\meta\Cropped and Deblurred\sa_9948.jpg
# Cropped sa_9949.jpg at (1093, 724) and saved to D:\Download\meta\Cropped and Deblurred\sa_9949.jpg
# No valid crop found for sa_995.jpg after 100 attempts. Skipping.
# Cropped sa_9950.jpg at (378, 438) and saved to D:\Download\meta\Cropped and Deblurred\sa_9950.jpg
# Cropped sa_9951.jpg at (362, 45) and saved to D:\Download\meta\Cropped and Deblurred\sa_9951.jpg
# Cropped sa_9952.jpg at (1147, 550) and saved to D:\Download\meta\Cropped and Deblurred\sa_9952.jpg
# Cropped sa_9953.jpg at (74, 904) and saved to D:\Download\meta\Cropped and Deblurred\sa_9953.jpg
# Cropped sa_9954.jpg at (290, 1626) and saved to D:\Download\meta\Cropped and Deblurred\sa_9954.jpg
# Cropped sa_9955.jpg at (1000, 620) and saved to D:\Download\meta\Cropped and Deblurred\sa_9955.jpg
# Cropped sa_9956.jpg at (347, 11) and saved to D:\Download\meta\Cropped and Deblurred\sa_9956.jpg
# Cropped sa_9957.jpg at (741, 654) and saved to D:\Download\meta\Cropped and Deblurred\sa_9957.jpg
# No valid crop found for sa_9958.jpg after 100 attempts. Skipping.
# No valid crop found for sa_9959.jpg after 100 attempts. Skipping.
# No valid crop found for sa_996.jpg after 100 attempts. Skipping.
# Cropped sa_9960.jpg at (272, 104) and saved to D:\Download\meta\Cropped and Deblurred\sa_9960.jpg
# Cropped sa_9961.jpg at (754, 1605) and saved to D:\Download\meta\Cropped and Deblurred\sa_9961.jpg
# Cropped sa_9962.jpg at (1679, 670) and saved to D:\Download\meta\Cropped and Deblurred\sa_9962.jpg
# Cropped sa_9963.jpg at (452, 128) and saved to D:\Download\meta\Cropped and Deblurred\sa_9963.jpg
# Cropped sa_9964.jpg at (390, 360) and saved to D:\Download\meta\Cropped and Deblurred\sa_9964.jpg
# No valid crop found for sa_9965.jpg after 100 attempts. Skipping.
# Cropped sa_9966.jpg at (150, 689) and saved to D:\Download\meta\Cropped and Deblurred\sa_9966.jpg
# No valid crop found for sa_9967.jpg after 100 attempts. Skipping.
# No valid crop found for sa_9968.jpg after 100 attempts. Skipping.
# Cropped sa_9969.jpg at (60, 510) and saved to D:\Download\meta\Cropped and Deblurred\sa_9969.jpg
# No valid crop found for sa_997.jpg after 100 attempts. Skipping.
# Cropped sa_9970.jpg at (711, 1508) and saved to D:\Download\meta\Cropped and Deblurred\sa_9970.jpg
# No valid crop found for sa_9971.jpg after 100 attempts. Skipping.
# No valid crop found for sa_9972.jpg after 100 attempts. Skipping.
# No valid crop found for sa_9973.jpg after 100 attempts. Skipping.
# Cropped sa_9974.jpg at (120, 186) and saved to D:\Download\meta\Cropped and Deblurred\sa_9974.jpg
# No valid crop found for sa_9975.jpg after 100 attempts. Skipping.
# No valid crop found for sa_9976.jpg after 100 attempts. Skipping.
# No valid crop found for sa_9977.jpg after 100 attempts. Skipping.
# Cropped sa_9978.jpg at (192, 111) and saved to D:\Download\meta\Cropped and Deblurred\sa_9978.jpg
# No valid crop found for sa_9979.jpg after 100 attempts. Skipping.
# No valid crop found for sa_998.jpg after 100 attempts. Skipping.
# Cropped sa_9980.jpg at (1512, 254) and saved to D:\Download\meta\Cropped and Deblurred\sa_9980.jpg
# Cropped sa_9981.jpg at (812, 785) and saved to D:\Download\meta\Cropped and Deblurred\sa_9981.jpg
# No valid crop found for sa_9982.jpg after 100 attempts. Skipping.
# Cropped sa_9983.jpg at (152, 1537) and saved to D:\Download\meta\Cropped and Deblurred\sa_9983.jpg
# Cropped sa_9984.jpg at (348, 586) and saved to D:\Download\meta\Cropped and Deblurred\sa_9984.jpg
# Cropped sa_9985.jpg at (747, 953) and saved to D:\Download\meta\Cropped and Deblurred\sa_9985.jpg
# Cropped sa_9986.jpg at (773, 875) and saved to D:\Download\meta\Cropped and Deblurred\sa_9986.jpg
# No valid crop found for sa_9987.jpg after 100 attempts. Skipping.
# Cropped sa_9988.jpg at (847, 197) and saved to D:\Download\meta\Cropped and Deblurred\sa_9988.jpg
# No valid crop found for sa_9989.jpg after 100 attempts. Skipping.
# Cropped sa_999.jpg at (535, 752) and saved to D:\Download\meta\Cropped and Deblurred\sa_999.jpg
# No valid crop found for sa_9990.jpg after 100 attempts. Skipping.
# Cropped sa_9991.jpg at (1060, 941) and saved to D:\Download\meta\Cropped and Deblurred\sa_9991.jpg
# Cropped sa_9992.jpg at (303, 686) and saved to D:\Download\meta\Cropped and Deblurred\sa_9992.jpg
# Cropped sa_9993.jpg at (814, 314) and saved to D:\Download\meta\Cropped and Deblurred\sa_9993.jpg
# Cropped sa_9994.jpg at (898, 462) and saved to D:\Download\meta\Cropped and Deblurred\sa_9994.jpg
# No valid crop found for sa_9995.jpg after 100 attempts. Skipping.
# Cropped sa_9996.jpg at (818, 978) and saved to D:\Download\meta\Cropped and Deblurred\sa_9996.jpg
# Cropped sa_9997.jpg at (199, 390) and saved to D:\Download\meta\Cropped and Deblurred\sa_9997.jpg
# Cropped sa_9998.jpg at (1704, 812) and saved to D:\Download\meta\Cropped and Deblurred\sa_9998.jpg
# Cropped sa_9999.jpg at (1523, 937) and saved to D:\Download\meta\Cropped and Deblurred\sa_9999.jpg
