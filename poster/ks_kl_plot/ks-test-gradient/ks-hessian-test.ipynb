# %%
import numpy as np
import scipy
from scipy import integrate, stats
import matplotlib.pyplot as plt
import os
import pickle
from scipy.linalg import svd
import matplotlib.patches as patches
from sigfig import round

# Use the generalized gamma CDF from your MATLAB function
def compute_cdf_using_gengamma(r, beta, x):
    gen_gamma_cdf = lambda x: scipy.special.gammainc(beta, x ** r)
    gauss_density = lambda z: (1. / (np.sqrt(2 * np.pi))) * np.exp(-0.5 * (z ** 2))

    integrand = lambda z: gauss_density(z) * (1 - gen_gamma_cdf((x / z) ** 2))
    res, _ = scipy.integrate.quad(integrand, -np.inf, 0)
    if x > 0:
        res = 1 - res
    return res

# Approximate KS statistic as per your previous implementation
def ks_1samp_test(subsample, cdf_func):
    # Use the KS test with a custom callable CDF function
    return stats.ks_1samp(subsample, cdf_func).statistic

# Update the CDF function to handle arrays of inputs
def compute_cdf_using_gengamma(r, beta, x):
    gen_gamma_cdf = lambda x: scipy.special.gammainc(beta, x ** r)
    gauss_density = lambda z: (1. / (np.sqrt(2 * np.pi))) * np.exp(-0.5 * (z ** 2))

    # Define the integrand using array support for z
    def integrand(z, x):
        return gauss_density(z) * (1 - gen_gamma_cdf((x / z) ** 2))

    if isinstance(x, (np.ndarray, list)):
        # Handle array input by vectorizing the integrand
        res = np.array([scipy.integrate.quad(lambda z: integrand(z, xi), -np.inf, 0)[0] for xi in x])
        res[x > 0] = 1 - res[x > 0]  # Apply correction for positive x values
        return res
    else:
        # Handle scalar input
        res, _ = scipy.integrate.quad(lambda z: integrand(z, x), -np.inf, 0)
        if x > 0:
            res = 1 - res
        return res
def generate_points(theta, epsilon=1e-5):
    # Generate scalar values from theta using cosine and sine
    point_x = epsilon * np.cos(theta)
    point_y = epsilon * np.sin(theta)
    return point_x, point_y

# Derivative function for r using the KS test approximation
def derivative_r_ks(r, eta, epsilon=1e-5):
    def derivative_function(theta):
        # Generate scalar points based on theta
        point_x, _ = generate_points(theta, epsilon)
        
        # Generate a sample using r + epsilon (perturbation in r)
        sample_plus_epsilon = np.array([r + epsilon + point_x] * 10)  # Use 10 points as an example
        sample_original = np.array([r + point_x] * 10)

        # Define a CDF function for the KS test (handling arrays of inputs)
        cdf_func = lambda x: compute_cdf_using_gengamma(r, eta, x)

        # Calculate KS statistic difference
        ks_diff = ks_1samp_test(sample_plus_epsilon, cdf_func) - ks_1samp_test(sample_original, cdf_func)
        return ks_diff / epsilon
    return derivative_function

# Derivative function for eta using the KS test approximation
def derivative_eta_ks(r, eta, epsilon=1e-5):
    def derivative_function(theta):
        # Generate scalar points based on theta
        _, point_y = generate_points(theta, epsilon)

        # Generate a sample using eta + epsilon (perturbation in eta)
        sample_plus_epsilon = np.array([eta + epsilon + point_y] * 10)  # Use 10 points as an example
        sample_original = np.array([eta + point_y] * 10)

        # Define a CDF function for the KS test (handling arrays of inputs)
        cdf_func = lambda x: compute_cdf_using_gengamma(r, eta, x)

        # Calculate KS statistic difference
        ks_diff = ks_1samp_test(sample_plus_epsilon, cdf_func) - ks_1samp_test(sample_original, cdf_func)
        return ks_diff / epsilon
    return derivative_function


# Integrate the functions over theta to calculate the Hessian
def integrate_function_ks_r_eta(r, eta, theta_range, epsilon=1e-5):
    dr_func = derivative_r_ks(r, eta, epsilon)
    de_func = derivative_eta_ks(r, eta, epsilon)
    def integrand(theta):
        return dr_func(theta) * de_func(theta)
    result, error = integrate.quad(integrand, 0, 2 * np.pi)
    return result

def integrate_function_ks_r_r(r, eta, theta_range, epsilon=1e-5):
    dr_func = derivative_r_ks(r, eta, epsilon)
    def integrand(theta):
        return dr_func(theta) ** 2
    result, error = integrate.quad(integrand, 0, 2 * np.pi)
    return result

def integrate_function_ks_eta_eta(r, eta, theta_range, epsilon=1e-5):
    de_func = derivative_eta_ks(r, eta, epsilon)
    def integrand(theta):
        return de_func(theta) ** 2
    result, error = integrate.quad(integrand, 0, 2 * np.pi)
    return result

def hessian_ks(r, eta, theta_range, epsilon=1e-5):
    H_ks = np.array([
        [integrate_function_ks_r_r(r, eta, theta_range, epsilon),
         integrate_function_ks_r_eta(r, eta, theta_range, epsilon)],
        [integrate_function_ks_r_eta(r, eta, theta_range, epsilon),
         integrate_function_ks_eta_eta(r, eta, theta_range, epsilon)]
    ])
    return H_ks

# Visualization setup
#r_ellipses = [0.5, 0.75, 1, 1.25, 1.5, 1.75, 2, 2.25, 2.5, 2.75, 3, 3.25, 3.5, 3.75, 4]
#eta_ellipses = [1, 1.5, 2, 2.5, 3, 3.5, 4, 4.5, 5, 5.5, 6, 6.5, 7, 7.5, 8]
r_ellipses = [0.5, 0.75, 1, 1.25, 1.5, 1.75, 2]
eta_ellipses = [1, 1.5, 2, 2.5, 3, 3.5, 4]
R_ellipses, Eta_ellipses = np.meshgrid(r_ellipses, eta_ellipses)

# Define a range of theta values for integration
theta_range = np.linspace(0, 2 * np.pi, 100)

fig, ax = plt.subplots()
ax.set_xlim(np.min(r_ellipses), np.max(r_ellipses))
ax.set_ylim(np.min(eta_ellipses), np.max(eta_ellipses))

scale_factor = 0.0000001
pos_list = []
singular_values = []

# Loop through R_ellipses and Eta_ellipses for the ellipses
for i in range(len(r_ellipses)):
    for j in range(len(eta_ellipses)):
        H = hessian_ks(R_ellipses[i, j], Eta_ellipses[i, j], theta_range)
        
        pos_list.append(np.all(np.linalg.eigvals(H) > 0))  # Check for positive definiteness
        U, s, Vt = svd(H)
        for singular_value in s:
            singular_values.append((singular_value, R_ellipses[i, j], Eta_ellipses[i, j]))
        angle = np.arctan2(U[0, 1], U[0, 0]) * 180 / np.pi
        width, height = scale_factor / np.sqrt(s[0]), scale_factor / np.sqrt(s[1])
        ellipse = patches.Ellipse((R_ellipses[i, j], Eta_ellipses[i, j]), width, height, angle=angle, edgecolor='blue', facecolor='none')
        ax.add_patch(ellipse)

singular_values.sort(key=lambda x: x[0])

for value, r_val, eta_val in singular_values:
    print(f'Singular Value: {value}, r: {r_val}, eta: {eta_val}')

plt.title('Ellipses Representing the SVD of the Hessian with KS Test Approximation')
plt.xlabel('r')
plt.ylabel('eta')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [11], line 143
#     141 for i in range(len(r_ellipses)):
#     142     for j in range(len(eta_ellipses)):
# --> 143         H = hessian_ks(R_ellipses[i, j], Eta_ellipses[i, j], theta_range)
#     145         pos_list.append(np.all(np.linalg.eigvals(H) > 0))  # Check for positive definiteness
#     146         U, s, Vt = svd(H)
#
# Cell In [11], line 118, in hessian_ks(r, eta, theta_range, epsilon)
#     113 def hessian_ks(r, eta, theta_range, epsilon=1e-5):
#     114     H_ks = np.array([
#     115         [integrate_function_ks_r_r(r, eta, theta_range, epsilon),
#     116          integrate_function_ks_r_eta(r, eta, theta_range, epsilon)],
#     117         [integrate_function_ks_r_eta(r, eta, theta_range, epsilon),
# --> 118          integrate_function_ks_eta_eta(r, eta, theta_range, epsilon)]
#     119     ])
#     120     return H_ks
#
# Cell In [11], line 110, in integrate_function_ks_eta_eta(r, eta, theta_range, epsilon)
#     108 def integrand(theta):
#     109     return de_func(theta) ** 2
# --> 110 result, error = integrate.quad(integrand, 0, 2 * np.pi)
#     111 return result
#
# File c:\Users\24340\AppData\Local\Programs\Python\Python39\lib\site-packages\scipy\integrate\_quadpack_py.py:464, in quad(func, a, b, args, full_output, epsabs, epsrel, limit, points, weight, wvar, wopts, maxp1, limlst, complex_func)
#     461     return retval
#     463 if weight is None:
# --> 464     retval = _quad(func, a, b, args, full_output, epsabs, epsrel, limit,
#     465                    points)
#     466 else:
#     467     if points is not None:
#
# File c:\Users\24340\AppData\Local\Programs\Python\Python39\lib\site-packages\scipy\integrate\_quadpack_py.py:611, in _quad(func, a, b, args, full_output, epsabs, epsrel, limit, points)
#     609 if points is None:
#     610     if infbounds == 0:
# --> 611         return _quadpack._qagse(func,a,b,args,full_output,epsabs,epsrel,limit)
#     612     else:
#     613         return _quadpack._qagie(func, bound, infbounds, args, full_output,
#     614                                 epsabs, epsrel, limit)
#
# Cell In [11], line 109, in integrate_function_ks_eta_eta.<locals>.integrand(theta)
#     108 def integrand(theta):
# --> 109     return de_func(theta) ** 2
#
# Cell In [11], line 85, in derivative_eta_ks.<locals>.derivative_function(theta)
#      82 cdf_func = lambda x: compute_cdf_using_gengamma(r, eta, x)
#      84 # Calculate KS statistic difference
# ---> 85 ks_diff = ks_1samp_test(sample_plus_epsilon, cdf_func) - ks_1samp_test(sample_original, cdf_func)
#      86 return ks_diff / epsilon
#
# Cell In [11], line 25, in ks_1samp_test(subsample, cdf_func)
#      23 def ks_1samp_test(subsample, cdf_func):
#      24     # Use the KS test with a custom callable CDF function
# ---> 25     return stats.ks_1samp(subsample, cdf_func).statistic
#
# File c:\Users\24340\AppData\Local\Programs\Python\Python39\lib\site-packages\scipy\stats\_axis_nan_policy.py:531, in _axis_nan_policy_factory.<locals>.axis_nan_policy_decorator.<locals>.axis_nan_policy_wrapper(***failed resolving arguments***)
#     529 if sentinel:
#     530     samples = _remove_sentinel(samples, paired, sentinel)
# --> 531 res = hypotest_fun_out(*samples, **kwds)
#     532 res = result_to_tuple(res)
#     533 res = _add_reduced_axes(res, reduced_axes, keepdims)
#
# File c:\Users\24340\AppData\Local\Programs\Python\Python39\lib\site-packages\scipy\_lib\_util.py:794, in _rename_parameter.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     792         raise TypeError(message)
#     793     kwargs[new_name] = kwargs.pop(old_name)
# --> 794 return fun(*args, **kwargs)
#
# File c:\Users\24340\AppData\Local\Programs\Python\Python39\lib\site-packages\scipy\stats\_stats_py.py:8371, in ks_1samp(x, cdf, args, alternative, method)
#    8368     raise ValueError("Unexpected alternative %s" % alternative)
#    8370 N = len(x)
# -> 8371 x = np.sort(x)
#    8372 cdfvals = cdf(x, *args)
#    8373 np_one = np.int8(1)
#
# File c:\Users\24340\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\_core\fromnumeric.py:1077, in sort(a, axis, kind, order, stable)
#    1075 else:
#    1076     a = asanyarray(a).copy(order="K")
# -> 1077 a.sort(axis=axis, kind=kind, order=order, stable=stable)
#    1078 return a
#
# KeyboardInterrupt:

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [3], line 18
#      16 USE_MATLAB= True
#      17 if USE_MATLAB:
# ---> 18     import matlab.engine
#      19     eng = matlab.engine.connect_matlab()
#      20 else:
#
# ModuleNotFoundError: No module named 'matlab'

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats
from tqdm import tqdm
from utilities.testing import * 

# Assuming the utility functions are defined or imported as provided
# E.g., compute_prior_cdf, etc.

# Set reference parameters
r0 = 0.8
eta0 = 3.0

# Compute reference CDF
cdf_p0 = compute_prior_cdf(
    r=r0,
    eta=eta0,
    method='gamma_cdf',
    n_samples=1000,
    tail_bound=0.001,
    tail_percent=0.1,
    scale=1,
    use_matlab=False,
    eng=None,
    debug=False,
    enforce_assert=True,
    return_assert=False,
    return_xs=False
)

# Define ε
epsilon = 0.01

# Define θ values from 0 to 2π
theta_values = np.linspace(0, 2 * np.pi, num=100)

# Initialize array to store derivatives
KS_derivatives = np.zeros_like(theta_values)

# Define x values for CDF evaluation
xs = np.linspace(-10, 10, 1000)

# Evaluate reference CDF at xs
cdf_p0_values = cdf_p0(xs)

# Loop over θ values and compute derivatives
for idx, theta in tqdm(enumerate(theta_values), total=len(theta_values), desc='Computing derivatives'):
    delta_r = epsilon * np.cos(theta)
    delta_eta = epsilon * np.sin(theta)
    r_prime = r0 + delta_r
    eta_prime = eta0 + delta_eta
    # Compute CDF for (r', η')
    try:
        cdf_p_prime = compute_prior_cdf(
            r=r_prime,
            eta=eta_prime,
            method='gamma_cdf',
            n_samples=1000,
            tail_bound=0.001,
            tail_percent=0.1,
            scale=1,
            use_matlab=False,
            eng=None,
            debug=False,
            enforce_assert=True,
            return_assert=False,
            return_xs=False
        )
        # Evaluate CDF at xs
        cdf_p_prime_values = cdf_p_prime(xs)
        # Compute KS statistic
        ks_stat = np.max(np.abs(cdf_p_prime_values - cdf_p0_values))
        # Approximate derivative as ks_stat / epsilon
        ks_derivative = ks_stat / epsilon
        # Store derivative
        KS_derivatives[idx] = ks_derivative
    except Exception as e:
        print(f"Error computing CDF for r={r_prime}, eta={eta_prime}: {e}")
        KS_derivatives[idx] = np.nan

# Plot derivative as a function of θ
plt.figure(figsize=(10, 6))
plt.plot(theta_values, KS_derivatives, label='KS Derivative')
plt.xlabel('θ (radians)')
plt.ylabel('Derivative of KS Statistic')
plt.title('Derivative of KS Statistic with respect to ε at (r₀, η₀)')
plt.legend()
plt.grid(True)
plt.show()

# Visualize KS statistics over a grid of (r, η)
# Define ranges for r and η around the reference point
r_values = np.linspace(r0 - 0.05, r0 + 0.05, num=50)
eta_values = np.linspace(eta0 - 0.05, eta0 + 0.05, num=50)

# Create a grid of (r, η)
R, ETA = np.meshgrid(r_values, eta_values)

# Initialize array to store KS statistics
KS_values = np.zeros_like(R)

# Loop over grid points and compute KS statistic
for i in tqdm(range(R.shape[0]), desc='Computing KS statistics over grid'):
    for j in range(R.shape[1]):
        r = R[i, j]
        eta = ETA[i, j]
        # Compute CDF for (r, η)
        try:
            cdf_p = compute_prior_cdf(
                r=r,
                eta=eta,
                method='gamma_cdf',
                n_samples=1000,
                tail_bound=0.001,
                tail_percent=0.1,
                scale=1,
                use_matlab=False,
                eng=None,
                debug=False,
                enforce_assert=True,
                return_assert=False,
                return_xs=False
            )
            # Evaluate CDF at xs
            cdf_p_values = cdf_p(xs)
            # Compute KS statistic
            ks_stat = np.max(np.abs(cdf_p_values - cdf_p0_values))
            # Store KS statistic
            KS_values[i, j] = ks_stat
        except Exception as e:
            print(f"Error computing CDF for r={r}, eta={eta}: {e}")
            KS_values[i, j] = np.nan

# Plot the contour of KS statistics
plt.figure(figsize=(10, 8))
contour = plt.contourf(R, ETA, KS_values, levels=50, cmap='viridis')
plt.colorbar(contour, label='KS Statistic')
plt.xlabel('r')
plt.ylabel('η')
plt.title('KS Statistic between p(r, η) and p(r₀, η₀)')
plt.grid(True)
plt.show()
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.0.2 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "c:\Users\24340\AppData\Local\Programs\Python\Python39\lib\runpy.py", line 197, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "c:\Users\24340\AppData\Local\Programs\Python\Python39\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\24340\AppData\Roaming\Python\Python39\site-packages\ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "C:\Users\24340\AppData\Roaming\Python\Python39\site-packages\traitlets\config\application.py", line 976, in launch_instance
#     app.start()
#   File "C:\Users\24340\AppData\Roaming\Python\Python39\site-packages\ipykernel\kernelapp.py", line 712, in start
#     self.io_loop.start()
#   File "C:\Users\24340\AppData\Roaming\Python\Python39\site-packages\tornado\platform\asyncio.py", line 215, in start
#     self.asyncio_loop.run_forever()
#   File "c:\Users\24340\AppData\Local\Programs\Python\Python39\lib\asyncio\base_events.py", line 596, in run_forever
#     self._run_once()
#   File "c:\Users\24340\AppData\Local\Programs\Python\Python39\lib\asyncio\base_events.py", line 1890, in _run_once
#     handle._run()
#   File "c:\Users\24340\AppData\Local\Programs\Python\Python39\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\24340\AppData\Roaming\Python\Python39\site-packages\ipykernel\kernelbase.py", line 510, in dispatch_queue
#     await self.process_one()
#   File "C:\Users\24340\AppData\Roaming\Python\Python39\site-packages\ipykernel\kernelbase.py", line 499, in process_one
#     await dispatch(*args)
#   File "C:\Users\24340\AppData\Roaming\Python\Python39\site-packages\ipykernel\kernelbase.py", line 406, in dispatch_shell
#     await result
#   File "C:\Users\24340\AppData\Roaming\Python\Python39\site-packages\ipykernel\kernelbase.py", line 730, in execute_request
#     reply_content = await reply_content
#   File "C:\Users\24340\AppData\Roaming\Python\Python39\site-packages\ipykernel\ipkernel.py", line 383, in do_execute
#     res = shell.run_cell(
#   File "C:\Users\24340\AppData\Roaming\Python\Python39\site-packages\ipykernel\zmqshell.py", line 528, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "C:\Users\24340\AppData\Roaming\Python\Python39\site-packages\IPython\core\interactiveshell.py", line 2885, in run_cell
#     result = self._run_cell(
#   File "C:\Users\24340\AppData\Roaming\Python\Python39\site-packages\IPython\core\interactiveshell.py", line 2940, in _run_cell
#     return runner(coro)
#   File "C:\Users\24340\AppData\Roaming\Python\Python39\site-packages\IPython\core\async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\24340\AppData\Roaming\Python\Python39\site-packages\IPython\core\interactiveshell.py", line 3139, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\24340\AppData\Roaming\Python\Python39\site-packages\IPython\core\interactiveshell.py", line 3318, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "C:\Users\24340\AppData\Roaming\Python\Python39\site-packages\IPython\core\interactiveshell.py", line 3378, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\24340\AppData\Local\Temp\ipykernel_14456\4130928498.py", line 3, in <module>
#     import matplotlib.pyplot as plt
#   File "c:\Users\24340\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\__init__.py", line 174, in <module>
#     _check_versions()
#   File "c:\Users\24340\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\__init__.py", line 159, in _check_versions
#     from . import ft2font
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: _ARRAY_API not found
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In [2], line 3
#       1 import numpy as np
#       2 import pandas as pd
# ----> 3 import matplotlib.pyplot as plt
#       4 from scipy import stats
#       5 from tqdm import tqdm
#
# File c:\Users\24340\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\__init__.py:174
#     169         if LooseVersion(module.__version__) < minver:
#     170             raise ImportError("Matplotlib requires {}>={}; you have {}"
#     171                               .format(modname, minver, module.__version__))
# --> 174 _check_versions()
#     177 # The decorator ensures this always returns the same handler (and it is only
#     178 # attached once).
#     179 @functools.lru_cache()
#     180 def _ensure_handler():
#
# File c:\Users\24340\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\__init__.py:159, in _check_versions()
#     155 def _check_versions():
#     156
#     157     # Quickfix to ensure Microsoft Visual C++ redistributable
#     158     # DLLs are loaded before importing kiwisolver
# --> 159     from . import ft2font
#     161     for modname, minver in [
#     162             ("cycler", "0.10"),
#     163             ("dateutil", "2.1"),
#    (...)
#     166             ("pyparsing", "2.0.1"),
#     167     ]:
#     168         module = importlib.import_module(modname)
#
# ImportError: numpy.core.multiarray failed to import

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import integrate, interpolate, stats, special
from tqdm import tqdm

# Utility Functions (Corrected)

def compute_cdf_vals(r, beta, xs, scale=1, debug=False):
    prior_cdf = np.zeros_like(xs)
    
    def integrand(theta, x):
        # Gaussian density with variance theta
        gauss = (1.0 / np.sqrt(2 * np.pi * theta)) * np.exp(-0.5 * x ** 2 / theta)
        # Generalized Gamma density for theta
        gen_gamma = (r / special.gamma(beta)) * (1.0 / scale) * (theta / scale) ** (r * beta - 1) * np.exp(-(theta / scale) ** r)
        return gauss * gen_gamma

    for idx, x in enumerate(xs):
        # Integrate over theta from 0 to infinity
        result, _ = integrate.quad(integrand, 0, np.inf, args=(x,))
        prior_cdf[idx] = result
        if debug and idx % 100 == 0:
            print(f"x={x:.2f}, CDF={prior_cdf[idx]:.5f}")

    # Ensure CDF is cumulative
    prior_cdf = np.cumsum(prior_cdf)
    # Normalize CDF to range [0, 1]
    prior_cdf /= prior_cdf[-1]

    return prior_cdf

def compute_prior_cdf_using_gamma_cdf(r, eta, n_samples=1000, tail_bound=0.001, tail_percent=0.1,
                                      scale=1, use_matlab=False, eng=None, enforce_assert=True,
                                      return_assert=False, return_xs=False, debug=False):
    beta = (eta + 1.5) / r
    # Check if beta is positive
    if beta <= 0:
        raise ValueError(f"Invalid beta value: beta={beta}. Ensure that (eta + 1.5) / r > 0.")
    var_prior = scale * special.gamma(beta + 1 / r) / special.gamma(beta)
    cheby = np.sqrt(var_prior / (tail_bound))
    if np.isnan(var_prior) or np.isinf(var_prior):
        cheby = 1e100
    x_max = min(99, cheby)
    n_tail = int(n_samples * tail_percent) if cheby >= 120 else 0

    if debug:
        print(f"Params: r={r}, eta={eta}")
        print(f"Chebyshev bound: {cheby}")
        print(f"{'No tail' if n_tail == 0 else f'Tail samples: {n_tail}'}")

    # Generate xs for negative and positive sides
    xs_minus = np.concatenate((
        -np.logspace(np.log10(cheby), 2, n_tail),
        np.linspace(-x_max, 0, n_samples // 2 - n_tail)
    ))
    xs_plus = -np.flip(xs_minus[:-1])

    xs = np.concatenate((xs_minus, xs_plus))

    # Compute prior CDF values at xs
    prior_cdf = compute_cdf_vals(r, beta, xs, scale=scale, debug=debug)

    if debug:
        print(f"First CDF value: {prior_cdf[0]}")
        print(f"Last CDF value: {prior_cdf[-1]}")

    # Check if CDF starts near 0 and ends near 1
    if enforce_assert:
        eps = tail_bound
        if not (-eps < prior_cdf[0] < eps):
            raise AssertionError(f"CDF at start not within tolerance: {prior_cdf[0]}")
        if not (1 - eps < prior_cdf[-1] < 1 + eps):
            raise AssertionError(f"CDF at end not within tolerance: {prior_cdf[-1]}")

    # Create spline for interpolation
    cdf_spline = interpolate.InterpolatedUnivariateSpline(xs, prior_cdf, k=3, ext='const')

    # Optional: Perform a KS test to validate the CDF
    if enforce_assert or return_assert:
        x_samples = np.sort(sample_prior(r, eta, size=10000))
        ks_stat, p_value = stats.kstest(x_samples, cdf_spline)
        if debug:
            print(f"KS test statistic: {ks_stat}, p-value: {p_value}")
        if ks_stat > 0.1:
            if enforce_assert:
                raise AssertionError(f"KS test failed with statistic: {ks_stat}")
            if return_assert:
                return (xs, None) if return_xs else None

    return (xs, cdf_spline) if return_xs else cdf_spline

def compute_prior_cdf(r, eta, method='gamma_cdf', n_samples=1000, tail_bound=0.001,
                      tail_percent=0.1, scale=1, use_matlab=False, eng=None,
                      debug=False, enforce_assert=True, return_assert=False,
                      return_xs=False):
    if method == 'gamma_cdf':
        return compute_prior_cdf_using_gamma_cdf(
            r=r, eta=eta, n_samples=n_samples, tail_bound=tail_bound,
            tail_percent=tail_percent, scale=scale, use_matlab=use_matlab,
            eng=eng, enforce_assert=enforce_assert, return_assert=return_assert,
            return_xs=return_xs, debug=debug
        )
    else:
        raise ValueError("Invalid method. Valid options are: 'gamma_cdf'.")

def sample_prior(r, eta, size=1):
    beta = (eta + 1.5) / r
    assert beta > 0
    vars = stats.gengamma.rvs(a=beta, c=r, size=size)
    x = np.random.normal(scale=np.sqrt(vars), size=size)
    return x

# Main Script

# Set reference parameters
r0 = 0.8
eta0 = 3.0

# Compute reference CDF
cdf_p0 = compute_prior_cdf(
    r=r0,
    eta=eta0,
    method='gamma_cdf',
    n_samples=1000,
    tail_bound=0.001,
    tail_percent=0.1,
    scale=1,
    use_matlab=False,
    eng=None,
    debug=True,  # Set to True for debugging
    enforce_assert=True,
    return_assert=False,
    return_xs=False
)

# Define ε
epsilon = 0.01

# Define θ values from 0 to 2π
theta_values = np.linspace(0, 2 * np.pi, num=100)

# Initialize array to store derivatives
KS_derivatives = np.zeros_like(theta_values)

# Define x values for CDF evaluation
xs = np.linspace(-10, 10, 1000)

# Evaluate reference CDF at xs
cdf_p0_values = cdf_p0(xs)

# Loop over θ values and compute derivatives
for idx, theta in tqdm(enumerate(theta_values), total=len(theta_values), desc='Computing derivatives'):
    delta_r = epsilon * np.cos(theta)
    delta_eta = epsilon * np.sin(theta)
    r_prime = r0 + delta_r
    eta_prime = eta0 + delta_eta
    # Compute CDF for (r', η')
    try:
        cdf_p_prime = compute_prior_cdf(
            r=r_prime,
            eta=eta_prime,
            method='gamma_cdf',
            n_samples=1000,
            tail_bound=0.001,
            tail_percent=0.1,
            scale=1,
            use_matlab=False,
            eng=None,
            debug=False,
            enforce_assert=True,
            return_assert=False,
            return_xs=False
        )
        # Evaluate CDF at xs
        cdf_p_prime_values = cdf_p_prime(xs)
        # Compute KS statistic
        ks_stat = np.max(np.abs(cdf_p_prime_values - cdf_p0_values))
        # Approximate derivative as ks_stat / epsilon
        ks_derivative = ks_stat / epsilon
        # Store derivative
        KS_derivatives[idx] = ks_derivative
    except Exception as e:
        print(f"Error computing CDF for r={r_prime}, eta={eta_prime}: {e}")
        KS_derivatives[idx] = np.nan

# Plot derivative as a function of θ
plt.figure(figsize=(10, 6))
plt.plot(theta_values, KS_derivatives, label='KS Derivative')
plt.xlabel('θ (radians)')
plt.ylabel('Derivative of KS Statistic')
plt.title('Derivative of KS Statistic with respect to ε at (r₀, η₀)')
plt.legend()
plt.grid(True)
plt.show()

# Visualize KS statistics over a grid of (r, η)
# Define ranges for r and η around the reference point
r_values = np.linspace(r0 - 0.05, r0 + 0.05, num=50)
eta_values = np.linspace(eta0 - 0.05, eta0 + 0.05, num=50)

# Create a grid of (r, η)
R, ETA = np.meshgrid(r_values, eta_values)

# Initialize array to store KS statistics
KS_values = np.zeros_like(R)

# Loop over grid points and compute KS statistic
for i in tqdm(range(R.shape[0]), desc='Computing KS statistics over grid'):
    for j in range(R.shape[1]):
        r = R[i, j]
        eta = ETA[i, j]
        # Compute CDF for (r, η)
        try:
            cdf_p = compute_prior_cdf(
                r=r,
                eta=eta,
                method='gamma_cdf',
                n_samples=1000,
                tail_bound=0.001,
                tail_percent=0.1,
                scale=1,
                use_matlab=False,
                eng=None,
                debug=False,
                enforce_assert=True,
                return_assert=False,
                return_xs=False
            )
            # Evaluate CDF at xs
            cdf_p_values = cdf_p(xs)
            # Compute KS statistic
            ks_stat = np.max(np.abs(cdf_p_values - cdf_p0_values))
            # Store KS statistic
            KS_values[i, j] = ks_stat
        except Exception as e:
            print(f"Error computing CDF for r={r}, eta={eta}: {e}")
            KS_values[i, j] = np.nan

# Plot the contour of KS statistics
plt.figure(figsize=(10, 8))
contour = plt.contourf(R, ETA, KS_values, levels=50, cmap='viridis')
plt.colorbar(contour, label='KS Statistic')
plt.xlabel('r')
plt.ylabel('η')
plt.title('KS Statistic between p(r, η) and p(r₀, η₀)')
plt.grid(True)
plt.show()
# Out:
# Params: r=0.8, eta=3.0
# Chebyshev bound: 94.31924566666
# No tail
# x=-94.32, CDF=0.00000
# x=-75.42, CDF=0.00000
# x=-56.52, CDF=0.00000
# x=-37.61, CDF=0.00000
# x=-18.71, CDF=0.00000
# x=0.19, CDF=0.14883
# x=19.09, CDF=0.00000
# x=37.99, CDF=0.00000
# x=56.89, CDF=0.00000
# x=75.80, CDF=0.00000
# First CDF value: 4.1947114789640103e-35
# Last CDF value: 1.0
# KS test statistic: 0.018763961954059383, p-value: 0.0017268034442502569
# Computing derivatives: 100%|██████████| 100/100 [00:42<00:00,  2.33it/s]
# Computing KS statistics over grid: 100%|██████████| 50/50 [17:47<00:00, 21.36s/it]

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import integrate, interpolate, stats, special
from tqdm import tqdm

# Utility Functions (Corrected)

def compute_cdf_vals(r, beta, xs, scale=1, debug=False):
    prior_cdf = np.zeros_like(xs)
    
    def gen_gamma_density(theta):
        return (r / special.gamma(beta)) * (theta / scale) ** (r * beta - 1) * np.exp(-(theta / scale) ** r) / scale

    for idx, x in enumerate(xs):
        def integrand(theta):
            cdf_normal = stats.norm.cdf(x / np.sqrt(theta))
            return cdf_normal * gen_gamma_density(theta)
        
        # Integrate over theta from 0 to infinity
        result, _ = integrate.quad(integrand, 0, np.inf, limit=100)
        prior_cdf[idx] = result
        if debug and idx % 100 == 0:
            print(f"x={x:.2f}, CDF={prior_cdf[idx]:.5f}")
    return prior_cdf

def compute_prior_cdf_using_gamma_cdf(r, eta, n_samples=1000, tail_bound=0.001, scale=1, enforce_assert=True, return_xs=False, debug=False):
    beta = (eta + 1.5) / r
    # Check if beta is positive
    if beta <= 0:
        raise ValueError(f"Invalid beta value: beta={beta}. Ensure that (eta + 1.5) / r > 0.")
    
    # Generate xs over a suitable range
    xs = np.linspace(-10, 10, n_samples)
    
    # Compute prior CDF values at xs
    prior_cdf = compute_cdf_vals(r, beta, xs, scale=scale, debug=debug)
    
    # Ensure the CDF is properly normalized
    cdf_min = prior_cdf[0]
    cdf_max = prior_cdf[-1]
    prior_cdf = (prior_cdf - cdf_min) / (cdf_max - cdf_min)
    
    if enforce_assert:
        eps = tail_bound
        if not (-eps < prior_cdf[0] < eps):
            raise AssertionError(f"CDF at start not within tolerance: {prior_cdf[0]}")
        if not (1 - eps < prior_cdf[-1] < 1 + eps):
            raise AssertionError(f"CDF at end not within tolerance: {prior_cdf[-1]}")
    
    # Create spline for interpolation
    cdf_spline = interpolate.InterpolatedUnivariateSpline(xs, prior_cdf, k=3, ext='const')
    
    return (xs, cdf_spline) if return_xs else cdf_spline

def compute_prior_cdf(r, eta, n_samples=1000, debug=False):
    return compute_prior_cdf_using_gamma_cdf(r, eta, n_samples=n_samples, debug=debug)

def sample_prior(r, eta, size=1):
    beta = (eta + 1.5) / r
    assert beta > 0
    vars = stats.gengamma.rvs(a=beta, c=r, size=size)
    x = np.random.normal(scale=np.sqrt(vars), size=size)
    return x

# Main Script

# Define the lists of r and eta values
r_ellipses = [0.5, 0.75, 1]
eta_ellipses = [1, 1.5, 2]

# Use the midpoints of the ranges as the reference parameters
r0 = np.mean(r_ellipses)
eta0 = np.mean(eta_ellipses)

# Compute reference CDF
cdf_p0 = compute_prior_cdf(r=r0, eta=eta0, n_samples=1000, debug=False)

# Define ranges for r and η covering r_ellipses and eta_ellipses with some padding
r_min, r_max = min(r_ellipses) - 0.1, max(r_ellipses) + 0.1
eta_min, eta_max = min(eta_ellipses) - 0.1, max(eta_ellipses) + 0.1

r_values = np.linspace(r_min, r_max, num=10)
eta_values = np.linspace(eta_min, eta_max, num=10)

# Create a grid of (r, η)
R, ETA = np.meshgrid(r_values, eta_values)

# Initialize array to store KS statistics
KS_values = np.zeros_like(R)

# Define x values for CDF evaluation
xs = np.linspace(-10, 10, 500)

# Evaluate reference CDF at xs
cdf_p0_values = cdf_p0(xs)

# Loop over grid points and compute KS statistic
for i in tqdm(range(R.shape[0]), desc='Computing KS statistics over grid'):
    for j in range(R.shape[1]):
        r = R[i, j]
        eta = ETA[i, j]
        # Compute CDF for (r, η)
        try:
            cdf_p = compute_prior_cdf(r=r, eta=eta, n_samples=500, debug=False)
            # Evaluate CDF at xs
            cdf_p_values = cdf_p(xs)
            # Compute KS statistic
            ks_stat = np.max(np.abs(cdf_p_values - cdf_p0_values))
            # Store KS statistic
            KS_values[i, j] = ks_stat
        except Exception:
            # Handle exceptions (e.g., invalid parameter combinations)
            KS_values[i, j] = np.nan

# Determine levels for the KS statistic contours
# For example, use quantiles of the KS statistic
valid_KS_values = KS_values[np.isfinite(KS_values)]
levels = np.quantile(valid_KS_values, [0.2, 0.4, 0.6, 0.8])

# Plot the contour of KS statistics using level sets
plt.figure(figsize=(12, 8))
contour = plt.contour(R, ETA, KS_values, levels=levels, colors='k', linewidths=1)
plt.clabel(contour, inline=True, fontsize=8, fmt='KS = %.3f')

# Overlay the specified r_ellipses and eta_ellipses
plt.scatter(r_ellipses, [eta0]*len(r_ellipses), color='blue', marker='o', label='r values')
plt.scatter([r0]*len(eta_ellipses), eta_ellipses, color='red', marker='x', label='η values')
plt.xlabel('r')
plt.ylabel('η')
plt.title(f'Level Sets of KS Statistic between p(r, η) and p({r0:.2f}, {eta0:.2f})')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Computing KS statistics over grid: 100%|██████████| 10/10 [12:10<00:00, 73.05s/it]

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import integrate, interpolate, stats, special
from tqdm import tqdm
import pickle
import os

# Utility Functions (Corrected)

def compute_cdf_vals(r, beta, xs, scale=1, debug=False):
    prior_cdf = np.zeros_like(xs)
    
    def gen_gamma_density(theta):
        return (r / special.gamma(beta)) * (theta / scale) ** (r * beta - 1) * np.exp(-(theta / scale) ** r) / scale

    for idx, x in enumerate(xs):
        def integrand(theta):
            cdf_normal = stats.norm.cdf(x / np.sqrt(theta))
            return cdf_normal * gen_gamma_density(theta)
        
        # Integrate over theta from 0 to infinity
        result, _ = integrate.quad(integrand, 0, np.inf, limit=100)
        prior_cdf[idx] = result
        if debug and idx % 100 == 0:
            print(f"x={x:.2f}, CDF={prior_cdf[idx]:.5f}")
    return prior_cdf

def compute_prior_cdf_using_gamma_cdf(r, eta, n_samples=1000, tail_bound=0.001, scale=1, enforce_assert=True, return_xs=False, debug=False):
    beta = (eta + 1.5) / r
    # Check if beta is positive
    if beta <= 0:
        raise ValueError(f"Invalid beta value: beta={beta}. Ensure that (eta + 1.5) / r > 0.")
    
    # Generate xs over a suitable range
    xs = np.linspace(-10, 10, n_samples)
    
    # Compute prior CDF values at xs
    prior_cdf = compute_cdf_vals(r, beta, xs, scale=scale, debug=debug)
    
    # Ensure the CDF is properly normalized
    cdf_min = prior_cdf[0]
    cdf_max = prior_cdf[-1]
    prior_cdf = (prior_cdf - cdf_min) / (cdf_max - cdf_min)
    
    if enforce_assert:
        eps = tail_bound
        if not (-eps < prior_cdf[0] < eps):
            raise AssertionError(f"CDF at start not within tolerance: {prior_cdf[0]}")
        if not (1 - eps < prior_cdf[-1] < 1 + eps):
            raise AssertionError(f"CDF at end not within tolerance: {prior_cdf[-1]}")
    
    # Create spline for interpolation
    cdf_spline = interpolate.InterpolatedUnivariateSpline(xs, prior_cdf, k=3, ext='const')
    
    return (xs, cdf_spline) if return_xs else cdf_spline

def compute_prior_cdf(r, eta, n_samples=1000, debug=False):
    return compute_prior_cdf_using_gamma_cdf(r, eta, n_samples=n_samples, debug=debug)

def sample_prior(r, eta, size=1):
    beta = (eta + 1.5) / r
    assert beta > 0
    vars = stats.gengamma.rvs(a=beta, c=r, size=size)
    x = np.random.normal(scale=np.sqrt(vars), size=size)
    return x

# Main Script

# Lists of r and η values
r_ellipses = [0.5, 0.75, 1, 1.25]
eta_ellipses = [1, 1.5, 2, 2.5]

# Define ε
epsilon = 0.0001

# Define θ values from 0 to 2π
theta_values = np.linspace(0, 2 * np.pi, num=50)

# Define x values for CDF evaluation
xs = np.linspace(-10, 10, 1000)

# KS statistic level for level set
KS_level = 0.001 #You can change this value to adjust the level set

# Directory to save gradient data
gradient_data_dir = 'gradient_data'

# Create directory if it doesn't exist
if not os.path.exists(gradient_data_dir):
    os.makedirs(gradient_data_dir)

# Loop over all (r0, η0) pairs
for r0 in r_ellipses:
    for eta0 in eta_ellipses:
        print(f"Processing r0={r0}, eta0={eta0}")
        
        # File name for gradient data
        gradient_file = os.path.join(gradient_data_dir, f'gradient_data_r{r0}_eta{eta0}.pkl')
        
        # Try to load existing gradient data
        if os.path.exists(gradient_file):
            print(f"Loading existing gradient data from {gradient_file}")
            with open(gradient_file, 'rb') as f:
                gradient_data = pickle.load(f)
            theta_values = gradient_data['theta_values']
            KS_derivatives = gradient_data['KS_derivatives']
        else:
            print(f"Computing gradient data for r0={r0}, eta0={eta0}")
            # Compute reference CDF at (r0, η0)
            try:
                cdf_p0 = compute_prior_cdf(r=r0, eta=eta0, n_samples=1000)
                cdf_p0_values = cdf_p0(xs)
            except Exception as e:
                print(f"Error computing reference CDF for r={r0}, eta={eta0}: {e}")
                continue  # Skip this pair if there's an error

            # Initialize array to store derivatives
            KS_derivatives = np.zeros_like(theta_values)
            
            # Loop over θ values and compute derivatives
            for idx, theta in tqdm(enumerate(theta_values), total=len(theta_values), desc='Computing derivatives'):
                delta_r = epsilon * np.cos(theta)
                delta_eta = epsilon * np.sin(theta)
                r_prime = r0 + delta_r
                eta_prime = eta0 + delta_eta
                # Compute CDF for (r', η')
                try:
                    cdf_p_prime = compute_prior_cdf(r=r_prime, eta=eta_prime, n_samples=1000)
                    cdf_p_prime_values = cdf_p_prime(xs)
                    # Compute KS statistic
                    ks_stat = np.max(np.abs(cdf_p_prime_values - cdf_p0_values))
                    # Approximate derivative as ks_stat / epsilon
                    ks_derivative = ks_stat / epsilon
                    # Store derivative
                    KS_derivatives[idx] = ks_derivative
                except Exception as e:
                    print(f"Error computing CDF for r={r_prime}, eta={eta_prime}: {e}")
                    KS_derivatives[idx] = np.nan
            
            # Save gradient data
            gradient_data = {'theta_values': theta_values, 'KS_derivatives': KS_derivatives}
            with open(gradient_file, 'wb') as f:
                pickle.dump(gradient_data, f)
        
        # Now, use the gradient data to draw a level set
        # For each θ, compute the distance s where KS_statistic equals KS_level
        # Approximate s = KS_level / KS_derivative
        s_values = KS_level / KS_derivatives  # s = KS_level / derivative
        print(min(KS_derivatives),max(KS_derivatives))
        # Handle division by zero or NaN
        s_values = np.nan_to_num(s_values, nan=np.inf, posinf=np.inf, neginf=-np.inf)
        
        # Limit s_values to a reasonable range to avoid plotting extreme values
        # max_s = 0.5  # Maximum allowed perturbation
        # s_values = np.clip(s_values, -max_s, max_s)
        
        # Compute the points on the level set
        r_values = r0 + s_values * np.cos(theta_values)
        eta_values = eta0 + s_values * np.sin(theta_values)
        
        # Remove points where s_values are infinite or NaN
        valid_indices = np.isfinite(s_values)
        r_values = r_values[valid_indices]
        eta_values = eta_values[valid_indices]
        
        # Plot the level set
        plt.plot(r_values, eta_values, label=f'r0={r0}, η0={eta0}')
        plt.scatter(r0, eta0, marker='o', color='black')  # Mark the center point

# Plot formatting
plt.xlabel('r')
plt.ylabel('η')
plt.title(f'Level Sets of KS Statistic at Level {KS_level}')
plt.grid(True)
plt.show()
# Out:
# Processing r0=0.5, eta0=1
# Loading existing gradient data from gradient_data\gradient_data_r0.5_eta1.pkl
# 0.005891601376162292 0.7550188979481703
# Processing r0=0.5, eta0=1.5
# Loading existing gradient data from gradient_data\gradient_data_r0.5_eta1.5.pkl
# 0.016213460213032604 0.7182976523292028
# Processing r0=0.5, eta0=2
# Loading existing gradient data from gradient_data\gradient_data_r0.5_eta2.pkl
# 0.01945002981682542 0.6669148895859428
# Processing r0=0.5, eta0=2.5
# Loading existing gradient data from gradient_data\gradient_data_r0.5_eta2.5.pkl
# 0.011660173993291445 0.6069331137467354
# Processing r0=0.75, eta0=1
# Loading existing gradient data from gradient_data\gradient_data_r0.75_eta1.pkl
# 0.009966536106242874 0.42161836352738735
# Processing r0=0.75, eta0=1.5
# Loading existing gradient data from gradient_data\gradient_data_r0.75_eta1.5.pkl
# 0.01167455928255956 0.45854045174850144
# Processing r0=0.75, eta0=2
# Loading existing gradient data from gradient_data\gradient_data_r0.75_eta2.pkl
# 0.004884300028729083 0.48809879007360446
# Processing r0=0.75, eta0=2.5
# Loading existing gradient data from gradient_data\gradient_data_r0.75_eta2.5.pkl
# 0.010578437187547252 0.5104213687957104
# Processing r0=1, eta0=1
# Loading existing gradient data from gradient_data\gradient_data_r1_eta1.pkl
# 0.00808260315308118 0.2182897844956483
# Processing r0=1, eta0=1.5
# Loading existing gradient data from gradient_data\gradient_data_r1_eta1.5.pkl
# 0.00728305717032085 0.2397511183588108
# Processing r0=1, eta0=2
# Loading existing gradient data from gradient_data\gradient_data_r1_eta2.pkl
# 0.007091489164644249 0.2582491701474593
# Processing r0=1, eta0=2.5
# Loading existing gradient data from gradient_data\gradient_data_r1_eta2.5.pkl
# 0.006514872104157465 0.27490535953764994
# Processing r0=1.25, eta0=1
# Loading existing gradient data from gradient_data\gradient_data_r1.25_eta1.pkl
# 0.007057372523378014 0.12995216640947216
# Processing r0=1.25, eta0=1.5
# Loading existing gradient data from gradient_data\gradient_data_r1.25_eta1.5.pkl
# 0.007055795728971859 0.14147065974367268
# Processing r0=1.25, eta0=2
# Loading existing gradient data from gradient_data\gradient_data_r1.25_eta2.pkl
# 0.0057420592203372145 0.15272892646715774
# Processing r0=1.25, eta0=2.5
# Loading existing gradient data from gradient_data\gradient_data_r1.25_eta2.5.pkl
# 0.0022989187873766193 0.16267963278029374

# %%
import matlab.engine

# %%
eng.quit()
eng = matlab.engine.start_matlab()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import integrate, interpolate, stats, special
from tqdm import tqdm
import pickle
import os

# Import MATLAB Engine API for Python
import matlab.engine

# Start MATLAB engine
eng = matlab.engine.start_matlab()

# Utility Functions (Updated)

def compute_cdf_vals(r, beta, xs, use_matlab=False, debug=False):
    prior_cdf = np.zeros_like(xs)
    if use_matlab:
        if debug:
            for j in tqdm(range(len(xs)), desc="Computing CDF with MATLAB"):
                prior_cdf[j] = eng.compute_cdf_using_gengamma(float(r), float(beta), float(xs[j]), nargout=1)
        else:
            for j, x in enumerate(xs):
                prior_cdf[j] = eng.compute_cdf_using_gengamma(float(r), float(beta), float(x), nargout=1)
    else:
        def gen_gamma_density(theta):
            return (np.abs(r) / special.gamma(beta)) * (theta) ** (r * beta - 1) * np.exp(-(theta) ** r)

        for idx, x in enumerate(xs):
            def integrand(theta):
                cdf_normal = stats.norm.cdf(x / np.sqrt(theta))
                return cdf_normal * gen_gamma_density(theta)
            # Integrate over theta from 0 to infinity
            result, _ = integrate.quad(integrand, 0, np.inf, limit=100)
            prior_cdf[idx] = result
            if debug and idx % 100 == 0:
                print(f"x={x:.2f}, CDF={prior_cdf[idx]:.5f}")
    return prior_cdf

def sample_prior(r, eta, size=1):
    beta = (eta + 1.5)/r 
    assert beta > 0
    vars = stats.gengamma.rvs(a=beta, c=r, size=size)
    x = np.random.normal(scale=np.sqrt(vars), size=size)
    return x

def compute_prior_cdf_using_gamma_cdf(r, eta, n_samples=1000, tail_bound=0.001, tail_percent=0.1, scale=1, use_matlab=True, eng=None, enforce_assert=True, return_assert=False, return_xs=False, debug=False):
    beta = (eta + 1.5) / r
    var_prior = scale * special.gamma(beta + 1/r) / special.gamma(beta)
    
    cheby = np.sqrt(var_prior / tail_bound)
    if np.isnan(var_prior) or np.isinf(var_prior):
        cheby = 1e100
    x_max = min(99, cheby)
    n_tail = int(n_samples * tail_percent) if cheby >= 120 else 0

    if debug:
        print(f"Params: r={r}, eta={eta}")
        print(f"Chebyshev bound: {cheby}")
        print(f"{'No tail' if n_tail == 0 else f'Tail samples: {n_tail}'}")

    xs_minus = np.concatenate((-np.logspace(np.log10(cheby), 2, n_tail),
                               np.linspace(-x_max, 0, n_samples//2-n_tail)))

    prior_cdf_minus = compute_cdf_vals(r, beta, xs_minus, use_matlab=use_matlab, debug=debug)

    xs_plus = -np.flip(xs_minus[:-1])
    prior_cdf_plus = 1 - np.flip(prior_cdf_minus[:-1])

    xs = np.concatenate((xs_minus, xs_plus))
    prior_cdf = np.concatenate((prior_cdf_minus, prior_cdf_plus))

    if debug:
        print(f"First CDF value: {prior_cdf[0]}")
        print(f"Last CDF value: {prior_cdf[-1]}")
        print(f"Tail bound: {tail_bound}")

    if return_assert or enforce_assert:
        eps = tail_bound
        if not (-eps < prior_cdf[0] < eps and 1 - eps < prior_cdf[-1] < 1 + eps):
            if return_assert:
                return (xs, None) if return_xs else None
            elif enforce_assert:
                raise AssertionError("CDF bounds not satisfied")
        
    xs = np.concatenate(([1.01 * xs[0]], xs, [1.01 * xs[-1]]))
    prior_cdf = np.concatenate(([0], prior_cdf, [1]))
    cdf_spline = interpolate.InterpolatedUnivariateSpline(x=xs, y=prior_cdf, k=3, ext='const')

    if return_assert or enforce_assert:
        x = np.sort(sample_prior(r, eta, 10000))
        res = stats.kstest(x, cdf_spline)
        if debug:
            print(res)
        if not 0 <= res.statistic <= 0.2:
            if return_assert:
                return (xs, None) if return_xs else None
            elif enforce_assert:
                raise AssertionError("KS test failed")

    return (xs, cdf_spline) if return_xs else cdf_spline

def compute_prior_cdf(r, eta, method='gamma_cdf', n_samples=1000, tail_bound=0.001, tail_percent=0.1, scale=1, use_matlab=True, eng=None, debug=False, enforce_assert=True, return_assert=False, return_xs=False):
    if method == 'gamma_cdf':
        return compute_prior_cdf_using_gamma_cdf(r=r, eta=eta, n_samples=n_samples, tail_bound=tail_bound, tail_percent=tail_percent, scale=scale, use_matlab=use_matlab, eng=eng, enforce_assert=enforce_assert, return_assert=return_assert, return_xs=return_xs, debug=debug)
    else:
        raise ValueError("Invalid method specified.")

# Main Script

# Lists of r and η values
r_ellipses = [0.5, 0.75]
eta_ellipses = [1, 1.5]

# Define ε
epsilon = 0.00001

# Define θ values from 0 to 2π
theta_values = np.linspace(0, 2 * np.pi, num=100)

# Define x values for CDF evaluation
xs = np.linspace(-10, 10, 1000)

# KS statistic level for level set
KS_level = 0.001  # You can change this value to adjust the level set

# Directory to save gradient data
gradient_data_dir = 'gradient_data'

# Create directory if it doesn't exist
if not os.path.exists(gradient_data_dir):
    os.makedirs(gradient_data_dir)

# Function to format numbers for filenames
def format_number(x, multiplier):
    return int(np.round(x * multiplier))

# Loop over all (r0, η0) pairs
for r0 in r_ellipses:
    for eta0 in eta_ellipses:
        print(f"Processing r0={r0}, eta0={eta0}")
        
        # Format numbers for filenames
        r0_int = format_number(r0, 100)
        eta0_int = format_number(eta0, 100)
        epsilon_int = format_number(epsilon, 1e6)
        theta_num = len(theta_values)
        
        # File name for gradient data
        gradient_file = os.path.join(
            gradient_data_dir,
            f'gradient_data_r{r0_int}_eta{eta0_int}_eps{epsilon_int}_theta{theta_num}.pkl'
        )
        
        # Try to load existing gradient data
        if os.path.exists(gradient_file):
            print(f"Loading existing gradient data from {gradient_file}")
            with open(gradient_file, 'rb') as f:
                gradient_data = pickle.load(f)
            theta_values = gradient_data['theta_values']
            KS_derivatives = gradient_data['KS_derivatives']
        else:
            print(f"Computing gradient data for r0={r0}, eta0={eta0}")
            # Compute reference CDF at (r0, η0)
            try:
                cdf_p0 = compute_prior_cdf(r=r0, eta=eta0, n_samples=1000, use_matlab=True, eng=eng, debug=False)
                cdf_p0_values = cdf_p0(xs)
            except Exception as e:
                print(f"Error computing reference CDF for r={r0}, eta={eta0}: {e}")
                continue  # Skip this pair if there's an error

            # Initialize array to store derivatives
            KS_derivatives = np.zeros_like(theta_values)
            
            # Loop over θ values and compute derivatives
            for idx, theta in tqdm(enumerate(theta_values), total=len(theta_values), desc='Computing derivatives'):
                delta_r = epsilon * np.cos(theta)
                delta_eta = epsilon * np.sin(theta)
                r_prime = r0 + delta_r
                eta_prime = eta0 + delta_eta
                # Compute CDF for (r', η')
                try:
                    cdf_p_prime = compute_prior_cdf(r=r_prime, eta=eta_prime, n_samples=1000, use_matlab=True, eng=eng, debug=False)
                    cdf_p_prime_values = cdf_p_prime(xs)
                    # Compute KS statistic
                    ks_stat = np.max(np.abs(cdf_p_prime_values - cdf_p0_values))
                    # Approximate derivative as ks_stat / epsilon
                    ks_derivative = ks_stat / epsilon
                    # Store derivative
                    KS_derivatives[idx] = ks_derivative
                except Exception as e:
                    print(f"Error computing CDF for r={r_prime}, eta={eta_prime}: {e}")
                    KS_derivatives[idx] = np.nan
            
            # Save gradient data
            gradient_data = {
                'theta_values': theta_values,
                'KS_derivatives': KS_derivatives,
                'epsilon': epsilon,
                'theta_num': theta_num,
                'r0': r0,
                'eta0': eta0
            }
            with open(gradient_file, 'wb') as f:
                pickle.dump(gradient_data, f)
        
        # Now, use the gradient data to draw a level set
        # For each θ, compute the distance s where KS_statistic equals KS_level
        # Approximate s = KS_level / KS_derivative
        s_values = KS_level / KS_derivatives  # s = KS_level / derivative
        print(f"KS Derivatives range: {np.nanmin(KS_derivatives)}, {np.nanmax(KS_derivatives)}")
        # Handle division by zero or NaN
        s_values = np.nan_to_num(s_values, nan=np.inf, posinf=np.inf, neginf=-np.inf)
        
        # Remove infinite or NaN s_values
        valid_indices = np.isfinite(s_values)
        s_values = s_values[valid_indices]
        theta_values_valid = theta_values[valid_indices]
        
        # Compute the points on the level set
        r_values = r0 + s_values * np.cos(theta_values_valid)
        eta_values = eta0 + s_values * np.sin(theta_values_valid)
        
        # Plot the level set
        plt.plot(r_values, eta_values, label=f'r0={r0}, η0={eta0}')
        plt.scatter(r0, eta0, marker='o', color='black')  # Mark the center point

# Plot formatting
plt.xlabel('r')
plt.ylabel('η')
plt.title(f'Level Sets of KS Statistic at Level {KS_level}')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Processing r0=0.5, eta0=1
# Computing gradient data for r0=0.5, eta0=1
# Computing derivatives: 100%|██████████| 50/50 [00:54<00:00,  1.10s/it]
# KS Derivatives range: 0.020537166312145638, 1.0605946442121539
# Processing r0=0.5, eta0=1.5
# Computing gradient data for r0=0.5, eta0=1.5
# Computing derivatives: 100%|██████████| 50/50 [00:54<00:00,  1.08s/it]
# KS Derivatives range: 0.03782040190913882, 1.1624961355904961
# Processing r0=0.75, eta0=1
# Computing gradient data for r0=0.75, eta0=1
# Computing derivatives: 100%|██████████| 50/50 [00:56<00:00,  1.14s/it]
# KS Derivatives range: 0.010603436049680393, 0.42137924512131164
# Processing r0=0.75, eta0=1.5
# Computing gradient data for r0=0.75, eta0=1.5
# Computing derivatives: 100%|██████████| 50/50 [00:53<00:00,  1.08s/it]
# KS Derivatives range: 0.011337000294653343, 0.46295000311641354

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import integrate, interpolate, stats, special
from tqdm import tqdm
import pickle
import os
from sigfig import round

# Import MATLAB Engine API for Python
import matlab.engine

# Start MATLAB engine
eng = matlab.engine.start_matlab()

# Utility Functions (Updated)

def compute_cdf_vals(r, beta, xs, use_matlab=False, debug=False):
    prior_cdf = np.zeros_like(xs)
    if use_matlab:
        if debug:
            for j in tqdm(range(len(xs)), desc="Computing CDF with MATLAB"):
                prior_cdf[j] = eng.compute_cdf_using_gengamma(float(r), float(beta), float(xs[j]), nargout=1)
        else:
            for j, x in enumerate(xs):
                prior_cdf[j] = eng.compute_cdf_using_gengamma(float(r), float(beta), float(x), nargout=1)
    else:
        def gen_gamma_density(theta):
            return (np.abs(r) / special.gamma(beta)) * (theta) ** (r * beta - 1) * np.exp(-(theta) ** r)

        for idx, x in enumerate(xs):
            def integrand(theta):
                cdf_normal = stats.norm.cdf(x / np.sqrt(theta))
                return cdf_normal * gen_gamma_density(theta)
            # Integrate over theta from 0 to infinity
            result, _ = integrate.quad(integrand, 0, np.inf, limit=100)
            prior_cdf[idx] = result
            if debug and idx % 100 == 0:
                print(f"x={x:.2f}, CDF={prior_cdf[idx]:.5f}")
    return prior_cdf

def sample_prior(r, eta, size=1):
    beta = (eta + 1.5)/r 
    assert beta > 0
    vars = stats.gengamma.rvs(a=beta, c=r, size=size)
    x = np.random.normal(scale=np.sqrt(vars), size=size)
    return x

def compute_prior_cdf_using_gamma_cdf(r, eta, n_samples=1000, tail_bound=0.001, tail_percent=0.1, scale=1, use_matlab=True, eng=None, enforce_assert=True, return_assert=False, return_xs=False, debug=False):
    beta = (eta + 1.5) / r
    var_prior = scale * special.gamma(beta + 1/r) / special.gamma(beta)
    
    cheby = np.sqrt(var_prior / tail_bound)
    if np.isnan(var_prior) or np.isinf(var_prior):
        cheby = 1e100
    x_max = min(99, cheby)
    n_tail = int(n_samples * tail_percent) if cheby >= 120 else 0

    if debug:
        print(f"Params: r={r}, eta={eta}")
        print(f"Chebyshev bound: {cheby}")
        print(f"{'No tail' if n_tail == 0 else f'Tail samples: {n_tail}'}")

    xs_minus = np.concatenate((-np.logspace(np.log10(cheby), 2, n_tail),
                               np.linspace(-x_max, 0, n_samples//2-n_tail)))

    prior_cdf_minus = compute_cdf_vals(r, beta, xs_minus, use_matlab=use_matlab, debug=debug)

    xs_plus = -np.flip(xs_minus[:-1])
    prior_cdf_plus = 1 - np.flip(prior_cdf_minus[:-1])

    xs = np.concatenate((xs_minus, xs_plus))
    prior_cdf = np.concatenate((prior_cdf_minus, prior_cdf_plus))

    if debug:
        print(f"First CDF value: {prior_cdf[0]}")
        print(f"Last CDF value: {prior_cdf[-1]}")
        print(f"Tail bound: {tail_bound}")

    if return_assert or enforce_assert:
        eps = tail_bound
        if not (-eps < prior_cdf[0] < eps and 1 - eps < prior_cdf[-1] < 1 + eps):
            if return_assert:
                return (xs, None) if return_xs else None
            elif enforce_assert:
                raise AssertionError("CDF bounds not satisfied")
        
    xs = np.concatenate(([1.01 * xs[0]], xs, [1.01 * xs[-1]]))
    prior_cdf = np.concatenate(([0], prior_cdf, [1]))
    cdf_spline = interpolate.InterpolatedUnivariateSpline(x=xs, y=prior_cdf, k=3, ext='const')

    if return_assert or enforce_assert:
        x = np.sort(sample_prior(r, eta, 10000))
        res = stats.kstest(x, cdf_spline)
        if debug:
            print(res)
        if not 0 <= res.statistic <= 0.2:
            if return_assert:
                return (xs, None) if return_xs else None
            elif enforce_assert:
                raise AssertionError("KS test failed")

    return (xs, cdf_spline) if return_xs else cdf_spline

def compute_prior_cdf(r, eta, method='gamma_cdf', n_samples=1000, tail_bound=0.001, tail_percent=0.1, scale=1, use_matlab=True, eng=None, debug=False, enforce_assert=True, return_assert=False, return_xs=False):
    if method == 'gamma_cdf':
        return compute_prior_cdf_using_gamma_cdf(r=r, eta=eta, n_samples=n_samples, tail_bound=tail_bound, tail_percent=tail_percent, scale=scale, use_matlab=use_matlab, eng=eng, enforce_assert=enforce_assert, return_assert=return_assert, return_xs=return_xs, debug=debug)
    else:
        raise ValueError("Invalid method specified.")

def variance_prior(r, eta, scale=1):
    beta = (eta + 1.5)/r 
    var_prior = scale * special.gamma(beta + 1 / r) / special.gamma(beta)
    return var_prior

# Main Script

# Lists of r and η values for level sets
r_ellipses = [0.5, 0.75, 1, 1.25, 1.5, 1.75, 2, 2.25, 2.5, 2.75, 3, 3.25, 3.5, 3.75, 4]
eta_ellipses = [0, 0.5, 1, 1.5, 2, 2.5, 3, 3.5, 4, 4.5, 5, 5.5, 6, 6.5, 7, 7.5, 8]

# Define ε
epsilon = 0.00001

# Define θ values from 0 to 2π
theta_values = np.linspace(0, 2 * np.pi, num=100)  # Granularity specified here

# Define x values for CDF evaluation
xs = np.linspace(-10, 10, 1000)

# KS statistic level for level set
KS_level = 0.0001  # You can change this value to adjust the level set

# Directory to save gradient data
gradient_data_dir = 'hierarchical-bayesian-model-validation/gradient_data'
os.makedirs(gradient_data_dir, exist_ok=True)

# Function to format numbers for filenames
def format_number(x, multiplier):
    return int(np.round(x * multiplier))

# Initialize lists for plotting level sets
all_r_values = []
all_eta_values = []

# Grid values for contour plot
r_contour = [round(i*0.01 + 0.5, sigfigs=2) for i in range(-10, 360)]
eta_contour = [round(j*0.02 + 1, sigfigs=2) for j in range(-50, 400)]
R_contour, Eta_contour = np.meshgrid(r_contour, eta_contour)

# Compute variance_prior values for the contour plot
var_prior_values = variance_prior(R_contour, Eta_contour)

# Loop over all (r0, η0) pairs
for r0 in r_ellipses:
    for eta0 in eta_ellipses:
        print(f"Processing r0={r0}, eta0={eta0}")
        
        # Format numbers for filenames
        r0_int = format_number(r0, 100)
        eta0_int = format_number(eta0, 100)
        epsilon_int = format_number(epsilon, 1e6)
        theta_num = len(theta_values)
        
        # File name for gradient data
        gradient_file = os.path.join(
            gradient_data_dir,
            f'gradient_data_r{r0_int}_eta{eta0_int}_eps{epsilon_int}_theta{theta_num}.pkl'
        )
        
        # Try to load existing gradient data
        if os.path.exists(gradient_file):
            print(f"Loading existing gradient data from {gradient_file}")
            with open(gradient_file, 'rb') as f:
                gradient_data = pickle.load(f)
            theta_values = gradient_data['theta_values']
            KS_derivatives = gradient_data['KS_derivatives']
        else:
            print(f"Computing gradient data for r0={r0}, eta0={eta0}")
            # Compute reference CDF at (r0, η0)
            try:
                cdf_p0 = compute_prior_cdf(r=r0, eta=eta0, n_samples=1000, use_matlab=True, eng=eng, debug=False)
                cdf_p0_values = cdf_p0(xs)
            except Exception as e:
                print(f"Error computing reference CDF for r={r0}, eta={eta0}: {e}")
                continue  # Skip this pair if there's an error

            # Initialize array to store derivatives
            KS_derivatives = np.zeros_like(theta_values)
            
            # Loop over θ values and compute derivatives
            for idx, theta in tqdm(enumerate(theta_values), total=len(theta_values), desc='Computing derivatives'):
                delta_r = epsilon * np.cos(theta)
                delta_eta = epsilon * np.sin(theta)
                r_prime = r0 + delta_r
                eta_prime = eta0 + delta_eta
                # Compute CDF for (r', η')
                try:
                    cdf_p_prime = compute_prior_cdf(r=r_prime, eta=eta_prime, n_samples=1000, use_matlab=True, eng=eng, debug=False)
                    cdf_p_prime_values = cdf_p_prime(xs)
                    # Compute KS statistic
                    ks_stat = np.max(np.abs(cdf_p_prime_values - cdf_p0_values))
                    # Approximate derivative as ks_stat / epsilon
                    ks_derivative = ks_stat / epsilon
                    # Store derivative
                    KS_derivatives[idx] = ks_derivative
                except Exception as e:
                    print(f"Error computing CDF for r={r_prime}, eta={eta_prime}: {e}")
                    KS_derivatives[idx] = np.nan
            
            # Save gradient data
            gradient_data = {
                'theta_values': theta_values,
                'KS_derivatives': KS_derivatives,
                'epsilon': epsilon,
                'theta_num': theta_num,
                'r0': r0,
                'eta0': eta0
            }
            with open(gradient_file, 'wb') as f:
                pickle.dump(gradient_data, f)
        
        # Now, use the gradient data to draw a level set
        # For each θ, compute the distance s where KS_statistic equals KS_level
        # Approximate s = KS_level / KS_derivative
        s_values = KS_level / KS_derivatives  # s = KS_level / derivative
        print(f"KS Derivatives range: {np.nanmin(KS_derivatives)}, {np.nanmax(KS_derivatives)}")
        # Handle division by zero or NaN
        s_values = np.nan_to_num(s_values, nan=np.inf, posinf=np.inf, neginf=-np.inf)
        
        # Remove infinite or NaN s_values
        valid_indices = np.isfinite(s_values)
        s_values = s_values[valid_indices]
        theta_values_valid = theta_values[valid_indices]
        
        # Compute the points on the level set
        r_values = r0 + s_values * np.cos(theta_values_valid)
        eta_values = eta0 + s_values * np.sin(theta_values_valid)
        
        # Store the level set points for plotting
        all_r_values.append(r_values)
        all_eta_values.append(eta_values)

# Plotting
fig, ax = plt.subplots(figsize=(10, 8))
ax.set_xlabel('r (shape parameter)', fontsize=18)
ax.set_ylabel('η (scale parameter)', fontsize=18)
# ax.set_title(f'Level Sets of KS Statistic at Level {KS_level}\nε={epsilon}, θ samples={len(theta_values)}')
ax.set_title('KS Statistic', fontsize=20)

ax.set_xlim(0, 4)  # Set x-axis to start from 0, while keeping the upper limit automatic
ax.set_ylim(0, 8)  # Set y-axis to start from 0, while keeping the upper limit automatic


# Plot the variance prior contour
log_levels = np.logspace(np.log10(np.min(var_prior_values)), np.log10(np.max(var_prior_values)), 150)
contour = ax.contour(R_contour, Eta_contour, np.log10(var_prior_values), levels=np.log10(log_levels), cmap='cividis', alpha=0.7, linewidths=0.8)
cbar = fig.colorbar(contour, ax=ax)
cbar.set_label('Log(Variance)', fontsize=18)
cbar.ax.tick_params(labelsize=12)

# Plot level sets
for r_values, eta_values, r0, eta0 in zip(all_r_values, all_eta_values, r_ellipses * len(eta_ellipses), np.repeat(eta_ellipses, len(r_ellipses))):
    ax.plot(r_values, eta_values, color='red', label=f'r0={r0}, η0={eta0}')


ax.tick_params(axis='both', which='major', labelsize=16)

plt.show()
# Out:
# Processing r0=0.5, eta0=0
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r50_eta0_eps10_theta100.pkl
# KS Derivatives range: 0.02207575909990433, 0.7914887269477865
# Processing r0=0.5, eta0=0.5
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r50_eta50_eps10_theta100.pkl
# KS Derivatives range: 0.01387023181864677, 0.9391626459631651
# Processing r0=0.5, eta0=1
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r50_eta100_eps10_theta100.pkl
# KS Derivatives range: 0.010009018203138709, 1.0604514940504295
# Processing r0=0.5, eta0=1.5
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r50_eta150_eps10_theta100.pkl
# KS Derivatives range: 0.020745471407401794, 1.1622111349529618
# Processing r0=0.5, eta0=2
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r50_eta200_eps10_theta100.pkl
# KS Derivatives range: 0.0074110076409006345, 1.249205444120438
# Processing r0=0.5, eta0=2.5
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r50_eta250_eps10_theta100.pkl
# KS Derivatives range: 0.008797402961668865, 1.325138856811403
# Processing r0=0.5, eta0=3
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r50_eta300_eps10_theta100.pkl
# KS Derivatives range: 0.016547286929569083, 1.392222129581455
# Processing r0=0.5, eta0=3.5
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r50_eta350_eps10_theta100.pkl
# KS Derivatives range: 0.02311530303833464, 1.4521449978488474
# Processing r0=0.5, eta0=4
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r50_eta400_eps10_theta100.pkl
# KS Derivatives range: 0.018259665346409548, 1.5062144187227842
# Processing r0=0.5, eta0=4.5
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r50_eta450_eps10_theta100.pkl
# KS Derivatives range: 0.014126591063590153, 1.5465495806887828
# Processing r0=0.5, eta0=5
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r50_eta500_eps10_theta100.pkl
# KS Derivatives range: 0.01056254109732535, 1.5648450699290437
# Processing r0=0.5, eta0=5.5
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r50_eta550_eps10_theta100.pkl
# KS Derivatives range: 0.007439774055151282, 1.5666282873527668
# Processing r0=0.5, eta0=6
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r50_eta600_eps10_theta100.pkl
# KS Derivatives range: 0.00472068607537679, 1.5564677963708637
# Processing r0=0.5, eta0=6.5
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r50_eta650_eps10_theta100.pkl
# KS Derivatives range: 0.0023834620610507784, 1.5379129376658083
# Processing r0=0.5, eta0=7
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r50_eta700_eps10_theta100.pkl
# KS Derivatives range: 0.00048277359332438147, 1.5136415421501679
# Processing r0=0.5, eta0=7.5
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r50_eta750_eps10_theta100.pkl
# KS Derivatives range: 0.0012975366725509474, 1.4856795308659796
# Processing r0=0.5, eta0=8
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r50_eta800_eps10_theta100.pkl
# KS Derivatives range: 0.0027241436606484366, 1.4554312899095476
# Processing r0=0.75, eta0=0
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r75_eta0_eps10_theta100.pkl
# KS Derivatives range: 0.01891184076008301, 0.3172571225396048
# Processing r0=0.75, eta0=0.5
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r75_eta50_eps10_theta100.pkl
# KS Derivatives range: 0.012182355579870572, 0.37307923008711436
# Processing r0=0.75, eta0=1
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r75_eta100_eps10_theta100.pkl
# KS Derivatives range: 0.009097301745253361, 0.42154016937079314
# Processing r0=0.75, eta0=1.5
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r75_eta150_eps10_theta100.pkl
# KS Derivatives range: 0.005770551203543305, 0.4630216228596051
# Processing r0=0.75, eta0=2
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r75_eta200_eps10_theta100.pkl
# KS Derivatives range: 0.008101146642403023, 0.49896328700171905
# Processing r0=0.75, eta0=2.5
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r75_eta250_eps10_theta100.pkl
# KS Derivatives range: 0.0047174747781764115, 0.530358706041234
# Processing r0=0.75, eta0=3
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r75_eta300_eps10_theta100.pkl
# KS Derivatives range: 0.009518935639718507, 0.5582830655326276
# Processing r0=0.75, eta0=3.5
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r75_eta350_eps10_theta100.pkl
# KS Derivatives range: 0.005157138596723065, 0.5832545885681162
# Processing r0=0.75, eta0=4
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r75_eta400_eps10_theta100.pkl
# KS Derivatives range: 0.001673152109221698, 0.6058228687932932
# Processing r0=0.75, eta0=4.5
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r75_eta450_eps10_theta100.pkl
# KS Derivatives range: 0.003742360582537074, 0.6264886100559863
# Processing r0=0.75, eta0=5
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r75_eta500_eps10_theta100.pkl
# KS Derivatives range: 0.0062392487842899405, 0.645458175141389
# Processing r0=0.75, eta0=5.5
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r75_eta550_eps10_theta100.pkl
# KS Derivatives range: 0.008673796048075388, 0.6629750706754756
# Processing r0=0.75, eta0=6
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r75_eta600_eps10_theta100.pkl
# KS Derivatives range: 0.010825637797307051, 0.679244581619498
# Processing r0=0.75, eta0=6.5
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r75_eta650_eps10_theta100.pkl
# KS Derivatives range: 0.009235689768516409, 0.6944208881864976
# Processing r0=0.75, eta0=7
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r75_eta700_eps10_theta100.pkl
# KS Derivatives range: 0.007819939895625794, 0.7086434153397158
# Processing r0=0.75, eta0=7.5
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r75_eta750_eps10_theta100.pkl
# KS Derivatives range: 0.006550285835960067, 0.722020973339954
# Processing r0=0.75, eta0=8
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r75_eta800_eps10_theta100.pkl
# KS Derivatives range: 0.005404600317282514, 0.7346486118275929
# Processing r0=1, eta0=0
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r100_eta0_eps10_theta100.pkl
# KS Derivatives range: 0.017056575901674975, 0.1702062258385206
# Processing r0=1, eta0=0.5
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r100_eta50_eps10_theta100.pkl
# KS Derivatives range: 0.010167938757632555, 0.19274937669289113
# Processing r0=1, eta0=1
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r100_eta100_eps10_theta100.pkl
# KS Derivatives range: 0.006978673239288468, 0.21600334688398612
# Processing r0=1, eta0=1.5
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r100_eta150_eps10_theta100.pkl
# KS Derivatives range: 0.004721096041881978, 0.23710646640529018
# Processing r0=1, eta0=2
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r100_eta200_eps10_theta100.pkl
# KS Derivatives range: 0.003957359980683028, 0.2558253949458411
# Processing r0=1, eta0=2.5
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r100_eta250_eps10_theta100.pkl
# KS Derivatives range: 0.0030146247942397504, 0.27247009877218176
# Processing r0=1, eta0=3
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r100_eta300_eps10_theta100.pkl
# KS Derivatives range: 0.005162263250202415, 0.28737748394291884
# Processing r0=1, eta0=3.5
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r100_eta350_eps10_theta100.pkl
# KS Derivatives range: 0.002180142566476917, 0.3007741887328663
# Processing r0=1, eta0=4
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r100_eta400_eps10_theta100.pkl
# KS Derivatives range: 0.0029974390650111533, 0.312960613513269
# Processing r0=1, eta0=4.5
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r100_eta450_eps10_theta100.pkl
# KS Derivatives range: 0.005246648504542151, 0.3241305611023648
# Processing r0=1, eta0=5
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r100_eta500_eps10_theta100.pkl
# KS Derivatives range: 0.003540046544792119, 0.33439373885724155
# Processing r0=1, eta0=5.5
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r100_eta550_eps10_theta100.pkl
# KS Derivatives range: 0.0017446858652236938, 0.34388725627110256
# Processing r0=1, eta0=6
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r100_eta600_eps10_theta100.pkl
# KS Derivatives range: 0.0009967150944867331, 0.35273039463434847
# Processing r0=1, eta0=6.5
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r100_eta650_eps10_theta100.pkl
# KS Derivatives range: 0.0019719428978604014, 0.36102185945463544
# Processing r0=1, eta0=7
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r100_eta700_eps10_theta100.pkl
# KS Derivatives range: 0.003103734229348287, 0.3688010096924987
# Processing r0=1, eta0=7.5
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r100_eta750_eps10_theta100.pkl
# KS Derivatives range: 0.0042138229905397395, 0.3761214205921792
# Processing r0=1, eta0=8
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r100_eta800_eps10_theta100.pkl
# KS Derivatives range: 0.00525117860306068, 0.3830403795507253
# Processing r0=1.25, eta0=0
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r125_eta0_eps10_theta100.pkl
# KS Derivatives range: 0.013885688887604884, 0.11207002382773722
# Processing r0=1.25, eta0=0.5
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r125_eta50_eps10_theta100.pkl
# KS Derivatives range: 0.00945157040410649, 0.11762972740303466
# Processing r0=1.25, eta0=1
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r125_eta100_eps10_theta100.pkl
# KS Derivatives range: 0.006187786105726899, 0.12881597333813666
# Processing r0=1.25, eta0=1.5
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r125_eta150_eps10_theta100.pkl
# KS Derivatives range: 0.005468587255252898, 0.1404293970885817
# Processing r0=1.25, eta0=2
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r125_eta200_eps10_theta100.pkl
# KS Derivatives range: 0.003826691552522021, 0.15129519894685473
# Processing r0=1.25, eta0=2.5
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r125_eta250_eps10_theta100.pkl
# KS Derivatives range: 0.0037449061823791037, 0.1612285976115846
# Processing r0=1.25, eta0=3
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r125_eta300_eps10_theta100.pkl
# KS Derivatives range: 0.0027302965333042546, 0.1702361094202409
# Processing r0=1.25, eta0=3.5
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r125_eta350_eps10_theta100.pkl
# KS Derivatives range: 0.0018124718392797943, 0.17844027490332423
# Processing r0=1.25, eta0=4
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r125_eta400_eps10_theta100.pkl
# KS Derivatives range: 0.0026542767428416876, 0.1859568358020258
# Processing r0=1.25, eta0=4.5
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r125_eta450_eps10_theta100.pkl
# KS Derivatives range: 0.0022380702902058403, 0.19285793729229003
# Processing r0=1.25, eta0=5
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r125_eta500_eps10_theta100.pkl
# KS Derivatives range: 0.0010186986434956857, 0.1992161326180852
# Processing r0=1.25, eta0=5.5
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r125_eta550_eps10_theta100.pkl
# KS Derivatives range: 0.0020617467288985836, 0.20515469518755933
# Processing r0=1.25, eta0=6
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r125_eta600_eps10_theta100.pkl
# KS Derivatives range: 0.0032995344359521, 0.2106853543071274
# Processing r0=1.25, eta0=6.5
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r125_eta650_eps10_theta100.pkl
# KS Derivatives range: 0.00253328785726481, 0.21585659942258137
# Processing r0=1.25, eta0=7
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r125_eta700_eps10_theta100.pkl
# KS Derivatives range: 0.001540608951522415, 0.22070917320426983
# Processing r0=1.25, eta0=7.5
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r125_eta750_eps10_theta100.pkl
# KS Derivatives range: 0.0006805473462545563, 0.22528975073266008
# Processing r0=1.25, eta0=8
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r125_eta800_eps10_theta100.pkl
# KS Derivatives range: 0.0006562933640985591, 0.22962860739550447
# Processing r0=1.5, eta0=0
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r150_eta0_eps10_theta100.pkl
# KS Derivatives range: 0.010927111926406495, 0.08610771965456009
# Processing r0=1.5, eta0=0.5
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r150_eta50_eps10_theta100.pkl
# KS Derivatives range: 0.008068588741583227, 0.08150532729289672
# Processing r0=1.5, eta0=1
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r150_eta100_eps10_theta100.pkl
# KS Derivatives range: 0.005501628819182257, 0.08558571959194071
# Processing r0=1.5, eta0=1.5
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r150_eta150_eps10_theta100.pkl
# KS Derivatives range: 0.004089362531933816, 0.09184700789366394
# Processing r0=1.5, eta0=2
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r150_eta200_eps10_theta100.pkl
# KS Derivatives range: 0.003000795201213435, 0.09838292334141129
# Processing r0=1.5, eta0=2.5
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r150_eta250_eps10_theta100.pkl
# KS Derivatives range: 0.0026344895265317803, 0.10466178081147691
# Processing r0=1.5, eta0=3
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r150_eta300_eps10_theta100.pkl
# KS Derivatives range: 0.0018413432778530134, 0.11050937707701712
# Processing r0=1.5, eta0=3.5
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r150_eta350_eps10_theta100.pkl
# KS Derivatives range: 0.002021544848185286, 0.11592271587090862
# Processing r0=1.5, eta0=4
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r150_eta400_eps10_theta100.pkl
# KS Derivatives range: 0.0019824016664338195, 0.12092323531387449
# Processing r0=1.5, eta0=4.5
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r150_eta450_eps10_theta100.pkl
# KS Derivatives range: 0.0011972097480050792, 0.12554717361279444
# Processing r0=1.5, eta0=5
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r150_eta500_eps10_theta100.pkl
# KS Derivatives range: 0.0015093457039760947, 0.12985295393397323
# Processing r0=1.5, eta0=5.5
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r150_eta550_eps10_theta100.pkl
# KS Derivatives range: 0.002010999755608367, 0.1338650614857162
# Processing r0=1.5, eta0=6
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r150_eta600_eps10_theta100.pkl
# KS Derivatives range: 0.0008821095132116595, 0.13760572360466128
# Processing r0=1.5, eta0=6.5
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r150_eta650_eps10_theta100.pkl
# KS Derivatives range: 0.000828784585404918, 0.14111993001664214
# Processing r0=1.5, eta0=7
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r150_eta700_eps10_theta100.pkl
# KS Derivatives range: 0.0015105972986373393, 0.1444442541909119
# Processing r0=1.5, eta0=7.5
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r150_eta750_eps10_theta100.pkl
# KS Derivatives range: 0.0022628939611024634, 0.14757878434024096
# Processing r0=1.5, eta0=8
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r150_eta800_eps10_theta100.pkl
# KS Derivatives range: 0.0018891036956958371, 0.1505422574932247
# Processing r0=1.75, eta0=0
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r175_eta0_eps10_theta100.pkl
# KS Derivatives range: 0.008538452809375707, 0.07330570383767832
# Processing r0=1.75, eta0=0.5
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r175_eta50_eps10_theta100.pkl
# KS Derivatives range: 0.006872165314586453, 0.0625844098323114
# Processing r0=1.75, eta0=1
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r175_eta100_eps10_theta100.pkl
# KS Derivatives range: 0.004867536092245661, 0.06200294949687545
# Processing r0=1.75, eta0=1.5
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r175_eta150_eps10_theta100.pkl
# KS Derivatives range: 0.0037955246501297775, 0.06480587269042104
# Processing r0=1.75, eta0=2
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r175_eta200_eps10_theta100.pkl
# KS Derivatives range: 0.002871922999414522, 0.06864121726568584
# Processing r0=1.75, eta0=2.5
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r175_eta250_eps10_theta100.pkl
# KS Derivatives range: 0.0021436443620181933, 0.07266678626050016
# Processing r0=1.75, eta0=3
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r175_eta300_eps10_theta100.pkl
# KS Derivatives range: 0.001939084826041437, 0.0765855424633699
# Processing r0=1.75, eta0=3.5
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r175_eta350_eps10_theta100.pkl
# KS Derivatives range: 0.001836973806401687, 0.08031083797988003
# Processing r0=1.75, eta0=4
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r175_eta400_eps10_theta100.pkl
# KS Derivatives range: 0.0013772647772247735, 0.08380104261629384
# Processing r0=1.75, eta0=4.5
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r175_eta450_eps10_theta100.pkl
# KS Derivatives range: 0.0009330012984420931, 0.08706939820246616
# Processing r0=1.75, eta0=5
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r175_eta500_eps10_theta100.pkl
# KS Derivatives range: 0.0015055201085800716, 0.09012803007246716
# Processing r0=1.75, eta0=5.5
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r175_eta550_eps10_theta100.pkl
# KS Derivatives range: 0.0008451494504235767, 0.0929856360354364
# Processing r0=1.75, eta0=6
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r175_eta600_eps10_theta100.pkl
# KS Derivatives range: 0.0009220291259659507, 0.09567767944584914
# Processing r0=1.75, eta0=6.5
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r175_eta650_eps10_theta100.pkl
# KS Derivatives range: 0.0016419568815706496, 0.09821466283310708
# Processing r0=1.75, eta0=7
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r175_eta700_eps10_theta100.pkl
# KS Derivatives range: 0.0009706113857088637, 0.1006030683647907
# Processing r0=1.75, eta0=7.5
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r175_eta750_eps10_theta100.pkl
# KS Derivatives range: 0.0003345798794268661, 0.10285473683868672
# Processing r0=1.75, eta0=8
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r175_eta800_eps10_theta100.pkl
# KS Derivatives range: 0.0006910575056640055, 0.10500653548628501
# Processing r0=2, eta0=0
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r200_eta0_eps10_theta100.pkl
# KS Derivatives range: 0.006810298026904692, 0.0662277499535735
# Processing r0=2, eta0=0.5
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r200_eta50_eps10_theta100.pkl
# KS Derivatives range: 0.005651013240681734, 0.0520391243874485
# Processing r0=2, eta0=1
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r200_eta100_eps10_theta100.pkl
# KS Derivatives range: 0.004213316573409287, 0.0482971782789221
# Processing r0=2, eta0=1.5
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r200_eta150_eps10_theta100.pkl
# KS Derivatives range: 0.003419377105073895, 0.04869227606674186
# Processing r0=2, eta0=2
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r200_eta200_eps10_theta100.pkl
# KS Derivatives range: 0.0023836679297062346, 0.0506557455870471
# Processing r0=2, eta0=2.5
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r200_eta250_eps10_theta100.pkl
# KS Derivatives range: 0.002112978947366173, 0.05316263628207806
# Processing r0=2, eta0=3
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r200_eta300_eps10_theta100.pkl
# KS Derivatives range: 0.0019363917469483736, 0.05580899910262448
# Processing r0=2, eta0=3.5
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r200_eta350_eps10_theta100.pkl
# KS Derivatives range: 0.0011090604989938413, 0.05841625917990533
# Processing r0=2, eta0=4
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r200_eta400_eps10_theta100.pkl
# KS Derivatives range: 0.0009196471150579865, 0.06091965158439016
# Processing r0=2, eta0=4.5
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r200_eta450_eps10_theta100.pkl
# KS Derivatives range: 0.000944409850323069, 0.0633043032771674
# Processing r0=2, eta0=5
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r200_eta500_eps10_theta100.pkl
# KS Derivatives range: 0.0013008957196192217, 0.06555469516111856
# Processing r0=2, eta0=5.5
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r200_eta550_eps10_theta100.pkl
# KS Derivatives range: 0.0005891291929988052, 0.06767192727852311
# Processing r0=2, eta0=6
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r200_eta600_eps10_theta100.pkl
# KS Derivatives range: 0.0011863226623276546, 0.06967955234193912
# Processing r0=2, eta0=6.5
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r200_eta650_eps10_theta100.pkl
# KS Derivatives range: 0.0006267960372952075, 0.07157152150938373
# Processing r0=2, eta0=7
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r200_eta700_eps10_theta100.pkl
# KS Derivatives range: 0.0005943263436947177, 0.07336530438717404
# Processing r0=2, eta0=7.5
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r200_eta750_eps10_theta100.pkl
# KS Derivatives range: 0.0010755374035831267, 0.0750721766640261
# Processing r0=2, eta0=8
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r200_eta800_eps10_theta100.pkl
# KS Derivatives range: 0.0009488117513889448, 0.07668927516357726
# Processing r0=2.25, eta0=0
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r225_eta0_eps10_theta100.pkl
# KS Derivatives range: 0.005493375489218354, 0.0618687244990923
# Processing r0=2.25, eta0=0.5
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r225_eta50_eps10_theta100.pkl
# KS Derivatives range: 0.004462347757971941, 0.04579081193945011
# Processing r0=2.25, eta0=1
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r225_eta100_eps10_theta100.pkl
# KS Derivatives range: 0.003724487129819209, 0.039962840786555986
# Processing r0=2.25, eta0=1.5
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r225_eta150_eps10_theta100.pkl
# KS Derivatives range: 0.002781833574605485, 0.03861331266952206
# Processing r0=2.25, eta0=2
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r225_eta200_eps10_theta100.pkl
# KS Derivatives range: 0.0022970091828611316, 0.03920864420914327
# Processing r0=2.25, eta0=2.5
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r225_eta250_eps10_theta100.pkl
# KS Derivatives range: 0.001904183583728569, 0.0406170152733587
# Processing r0=2.25, eta0=3
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r225_eta300_eps10_theta100.pkl
# KS Derivatives range: 0.0016125171087288945, 0.042353279333662286
# Processing r0=2.25, eta0=3.5
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r225_eta350_eps10_theta100.pkl
# KS Derivatives range: 0.001308368723779152, 0.0441765914960257
# Processing r0=2.25, eta0=4
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r225_eta400_eps10_theta100.pkl
# KS Derivatives range: 0.0012050126452223253, 0.045996575759321694
# Processing r0=2.25, eta0=4.5
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r225_eta450_eps10_theta100.pkl
# KS Derivatives range: 0.0010613926404445806, 0.04776407791784453
# Processing r0=2.25, eta0=5
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r225_eta500_eps10_theta100.pkl
# KS Derivatives range: 0.0010469100586441016, 0.049455328193781505
# Processing r0=2.25, eta0=5.5
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r225_eta550_eps10_theta100.pkl
# KS Derivatives range: 0.0006246031469814284, 0.05106221576955949
# Processing r0=2.25, eta0=6
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r225_eta600_eps10_theta100.pkl
# KS Derivatives range: 0.000838633384958598, 0.05259979659888447
# Processing r0=2.25, eta0=6.5
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r225_eta650_eps10_theta100.pkl
# KS Derivatives range: 0.0005056649654555656, 0.05405035776728794
# Processing r0=2.25, eta0=7
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r225_eta700_eps10_theta100.pkl
# KS Derivatives range: 0.0009626861641187644, 0.0554407269426349
# Processing r0=2.25, eta0=7.5
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r225_eta750_eps10_theta100.pkl
# KS Derivatives range: 0.0004825954635911955, 0.05675704123353497
# Processing r0=2.25, eta0=8
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r225_eta800_eps10_theta100.pkl
# KS Derivatives range: 0.0003993649300149115, 0.05801184528864133
# Processing r0=2.5, eta0=0
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r250_eta0_eps10_theta100.pkl
# KS Derivatives range: 0.004319100739558213, 0.058918207423985784
# Processing r0=2.5, eta0=0.5
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r250_eta50_eps10_theta100.pkl
# KS Derivatives range: 0.0037760643445405857, 0.04185324935512824
# Processing r0=2.5, eta0=1
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r250_eta100_eps10_theta100.pkl
# KS Derivatives range: 0.003418091687468205, 0.03468360176839269
# Processing r0=2.5, eta0=1.5
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r250_eta150_eps10_theta100.pkl
# KS Derivatives range: 0.002781440699983761, 0.032071508532238724
# Processing r0=2.5, eta0=2
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r250_eta200_eps10_theta100.pkl
# KS Derivatives range: 0.002118430664221904, 0.031637485375934915
# Processing r0=2.5, eta0=2.5
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r250_eta250_eps10_theta100.pkl
# KS Derivatives range: 0.0015578728529419548, 0.03221935976072121
# Processing r0=2.5, eta0=3
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r250_eta300_eps10_theta100.pkl
# KS Derivatives range: 0.0015115572793433783, 0.03326530267078187
# Processing r0=2.5, eta0=3.5
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r250_eta350_eps10_theta100.pkl
# KS Derivatives range: 0.0012671701965505378, 0.034510270774390506
# Processing r0=2.5, eta0=4
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r250_eta400_eps10_theta100.pkl
# KS Derivatives range: 0.0008927762751298473, 0.0358220258789288
# Processing r0=2.5, eta0=4.5
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r250_eta450_eps10_theta100.pkl
# KS Derivatives range: 0.0009175344622969205, 0.0371388000741657
# Processing r0=2.5, eta0=5
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r250_eta500_eps10_theta100.pkl
# KS Derivatives range: 0.0008075010021757477, 0.038426533288671294
# Processing r0=2.5, eta0=5.5
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r250_eta550_eps10_theta100.pkl
# KS Derivatives range: 0.0005776696676562665, 0.03966819095424512
# Processing r0=2.5, eta0=6
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r250_eta600_eps10_theta100.pkl
# KS Derivatives range: 0.0005664765989621401, 0.040865833833558796
# Processing r0=2.5, eta0=6.5
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r250_eta650_eps10_theta100.pkl
# KS Derivatives range: 0.000636769827838668, 0.042007907863350624
# Processing r0=2.5, eta0=7
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r250_eta700_eps10_theta100.pkl
# KS Derivatives range: 0.0004828389355004958, 0.04310123652428998
# Processing r0=2.5, eta0=7.5
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r250_eta750_eps10_theta100.pkl
# KS Derivatives range: 0.00044141400534769554, 0.04414348411252433
# Processing r0=2.5, eta0=8
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r250_eta800_eps10_theta100.pkl
# KS Derivatives range: 0.0007909429111663256, 0.0451439631010686
# Processing r0=2.75, eta0=0
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r275_eta0_eps10_theta100.pkl
# KS Derivatives range: 0.003092975375817985, 0.0567896353581565
# Processing r0=2.75, eta0=0.5
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r275_eta50_eps10_theta100.pkl
# KS Derivatives range: 0.0031851786763681385, 0.03919527242768339
# Processing r0=2.75, eta0=1
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r275_eta100_eps10_theta100.pkl
# KS Derivatives range: 0.0028819389430445592, 0.031198434466417343
# Processing r0=2.75, eta0=1.5
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r275_eta150_eps10_theta100.pkl
# KS Derivatives range: 0.0023713202845776493, 0.0277012757843309
# Processing r0=2.75, eta0=2
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r275_eta200_eps10_theta100.pkl
# KS Derivatives range: 0.0019370317974609639, 0.026477981010519788
# Processing r0=2.75, eta0=2.5
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r275_eta250_eps10_theta100.pkl
# KS Derivatives range: 0.0015599425973178425, 0.0264136857941466
# Processing r0=2.75, eta0=3
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r275_eta300_eps10_theta100.pkl
# KS Derivatives range: 0.0013088237840741535, 0.026924683640960897
# Processing r0=2.75, eta0=3.5
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r275_eta350_eps10_theta100.pkl
# KS Derivatives range: 0.001046816255900751, 0.027724120735261867
# Processing r0=2.75, eta0=4
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r275_eta400_eps10_theta100.pkl
# KS Derivatives range: 0.0010200620903511037, 0.028648980687773214
# Processing r0=2.75, eta0=4.5
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r275_eta450_eps10_theta100.pkl
# KS Derivatives range: 0.0006244687211776068, 0.029622713448862466
# Processing r0=2.75, eta0=5
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r275_eta500_eps10_theta100.pkl
# KS Derivatives range: 0.0006057272239345934, 0.030604084699792363
# Processing r0=2.75, eta0=5.5
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r275_eta550_eps10_theta100.pkl
# KS Derivatives range: 0.0004959485933042629, 0.03157143103338367
# Processing r0=2.75, eta0=6
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r275_eta600_eps10_theta100.pkl
# KS Derivatives range: 0.00045203153442585625, 0.0325150583124767
# Processing r0=2.75, eta0=6.5
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r275_eta650_eps10_theta100.pkl
# KS Derivatives range: 0.0006700470955856018, 0.03342493169744554
# Processing r0=2.75, eta0=7
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r275_eta700_eps10_theta100.pkl
# KS Derivatives range: 0.00032287962303811923, 0.03429584523040319
# Processing r0=2.75, eta0=7.5
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r275_eta750_eps10_theta100.pkl
# KS Derivatives range: 0.0006376022265719428, 0.03513830707513321
# Processing r0=2.75, eta0=8
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r275_eta800_eps10_theta100.pkl
# KS Derivatives range: 0.00027212035957902003, 0.0359405263161694
# Processing r0=3, eta0=0
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r300_eta0_eps10_theta100.pkl
# KS Derivatives range: 0.0025413834259246926, 0.055161737100295476
# Processing r0=3, eta0=0.5
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r300_eta50_eps10_theta100.pkl
# KS Derivatives range: 0.002644585295197288, 0.03730451079153596
# Processing r0=3, eta0=1
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r300_eta100_eps10_theta100.pkl
# KS Derivatives range: 0.0023409491900494572, 0.028805205265491903
# Processing r0=3, eta0=1.5
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r300_eta150_eps10_theta100.pkl
# KS Derivatives range: 0.002102604723663859, 0.024689630870322606
# Processing r0=3, eta0=2
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r300_eta200_eps10_theta100.pkl
# KS Derivatives range: 0.0017921832351497355, 0.02287884666163364
# Processing r0=3, eta0=2.5
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r300_eta250_eps10_theta100.pkl
# KS Derivatives range: 0.0014057958130919699, 0.022301718927142385
# Processing r0=3, eta0=3
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r300_eta300_eps10_theta100.pkl
# KS Derivatives range: 0.001095665548567215, 0.02239122579572594
# Processing r0=3, eta0=3.5
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r300_eta350_eps10_theta100.pkl
# KS Derivatives range: 0.0009429609815203576, 0.02282792722629878
# Processing r0=3, eta0=4
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r300_eta400_eps10_theta100.pkl
# KS Derivatives range: 0.0007387273515124803, 0.023449354957794096
# Processing r0=3, eta0=4.5
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r300_eta450_eps10_theta100.pkl
# KS Derivatives range: 0.0008200428718019291, 0.024156666544872248
# Processing r0=3, eta0=5
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r300_eta500_eps10_theta100.pkl
# KS Derivatives range: 0.000534018479436682, 0.02490154101808528
# Processing r0=3, eta0=5.5
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r300_eta550_eps10_theta100.pkl
# KS Derivatives range: 0.0004068192227535405, 0.02565368990570249
# Processing r0=3, eta0=6
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r300_eta600_eps10_theta100.pkl
# KS Derivatives range: 0.00041897657565570506, 0.026398095198665313
# Processing r0=3, eta0=6.5
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r300_eta650_eps10_theta100.pkl
# KS Derivatives range: 0.000563012744758673, 0.027125179541398477
# Processing r0=3, eta0=7
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r300_eta700_eps10_theta100.pkl
# KS Derivatives range: 0.00039589233835624066, 0.02783115239379796
# Processing r0=3, eta0=7.5
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r300_eta750_eps10_theta100.pkl
# KS Derivatives range: 0.00037557581489267017, 0.02851547273863275
# Processing r0=3, eta0=8
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r300_eta800_eps10_theta100.pkl
# KS Derivatives range: 0.0003474665333236259, 0.02917142581937426
# Processing r0=3.25, eta0=0
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r325_eta0_eps10_theta100.pkl
# KS Derivatives range: 0.0020141087520020307, 0.05390232129531824
# Processing r0=3.25, eta0=0.5
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r325_eta50_eps10_theta100.pkl
# KS Derivatives range: 0.0021750911960438657, 0.03589095416978161
# Processing r0=3.25, eta0=1
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r325_eta100_eps10_theta100.pkl
# KS Derivatives range: 0.0021421001639154724, 0.027088488674387175
# Processing r0=3.25, eta0=1.5
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r325_eta150_eps10_theta100.pkl
# KS Derivatives range: 0.0017664608553680237, 0.022559743328987022
# Processing r0=3.25, eta0=2
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r325_eta200_eps10_theta100.pkl
# KS Derivatives range: 0.0015035419909104062, 0.020307205514380477
# Processing r0=3.25, eta0=2.5
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r325_eta250_eps10_theta100.pkl
# KS Derivatives range: 0.0012457114006991787, 0.019332191902865503
# Processing r0=3.25, eta0=3
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r325_eta300_eps10_theta100.pkl
# KS Derivatives range: 0.001033316032739151, 0.019075748566854678
# Processing r0=3.25, eta0=3.5
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r325_eta350_eps10_theta100.pkl
# KS Derivatives range: 0.0008923259409154837, 0.019222952252206937
# Processing r0=3.25, eta0=4
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r325_eta400_eps10_theta100.pkl
# KS Derivatives range: 0.0006965752360338361, 0.019593430222730746
# Processing r0=3.25, eta0=4.5
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r325_eta450_eps10_theta100.pkl
# KS Derivatives range: 0.0005508426492717433, 0.020085346219556044
# Processing r0=3.25, eta0=5
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r325_eta500_eps10_theta100.pkl
# KS Derivatives range: 0.0006569624289021192, 0.020638297293373853
# Processing r0=3.25, eta0=5.5
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r325_eta550_eps10_theta100.pkl
# KS Derivatives range: 0.000498017682648566, 0.021219335522015822
# Processing r0=3.25, eta0=6
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r325_eta600_eps10_theta100.pkl
# KS Derivatives range: 0.00042936044719610317, 0.021807995509437458
# Processing r0=3.25, eta0=6.5
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r325_eta650_eps10_theta100.pkl
# KS Derivatives range: 0.0004739449499524539, 0.022394069154607617
# Processing r0=3.25, eta0=7
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r325_eta700_eps10_theta100.pkl
# KS Derivatives range: 0.0004218165261526962, 0.022967485691083308
# Processing r0=3.25, eta0=7.5
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r325_eta750_eps10_theta100.pkl
# KS Derivatives range: 0.00023187016751080589, 0.023525688902514826
# Processing r0=3.25, eta0=8
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r325_eta800_eps10_theta100.pkl
# KS Derivatives range: 0.00046529560204788817, 0.02407144485960799
# Processing r0=3.5, eta0=0
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r350_eta0_eps10_theta100.pkl
# KS Derivatives range: 0.0018781589818106512, 0.05287263687425713
# Processing r0=3.5, eta0=0.5
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r350_eta50_eps10_theta100.pkl
# KS Derivatives range: 0.0019496146808073431, 0.03479571037967588
# Processing r0=3.5, eta0=1
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r350_eta100_eps10_theta100.pkl
# KS Derivatives range: 0.0017571063493093673, 0.0258106813005865
# Processing r0=3.5, eta0=1.5
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r350_eta150_eps10_theta100.pkl
# KS Derivatives range: 0.001627897761036223, 0.021005791295269916
# Processing r0=3.5, eta0=2
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r350_eta200_eps10_theta100.pkl
# KS Derivatives range: 0.0013648307595204299, 0.018435475124256584
# Processing r0=3.5, eta0=2.5
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r350_eta250_eps10_theta100.pkl
# KS Derivatives range: 0.001182781533826116, 0.017147169048548072
# Processing r0=3.5, eta0=3
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r350_eta300_eps10_theta100.pkl
# KS Derivatives range: 0.0010461646202108987, 0.016611731595839174
# Processing r0=3.5, eta0=3.5
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r350_eta350_eps10_theta100.pkl
# KS Derivatives range: 0.0008609206569865079, 0.016518953882549425
# Processing r0=3.5, eta0=4
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r350_eta400_eps10_theta100.pkl
# KS Derivatives range: 0.0006986933899499891, 0.016683170211972964
# Processing r0=3.5, eta0=4.5
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r350_eta450_eps10_theta100.pkl
# KS Derivatives range: 0.0006304524367839459, 0.01699479519612357
# Processing r0=3.5, eta0=5
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r350_eta500_eps10_theta100.pkl
# KS Derivatives range: 0.00046762266281419324, 0.017392228468526838
# Processing r0=3.5, eta0=5.5
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r350_eta550_eps10_theta100.pkl
# KS Derivatives range: 0.0005344451090016911, 0.017832586141075524
# Processing r0=3.5, eta0=6
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r350_eta600_eps10_theta100.pkl
# KS Derivatives range: 0.00046301267264681195, 0.018295688875014093
# Processing r0=3.5, eta0=6.5
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r350_eta650_eps10_theta100.pkl
# KS Derivatives range: 0.00043673531457955045, 0.01876580031368036
# Processing r0=3.5, eta0=7
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r350_eta700_eps10_theta100.pkl
# KS Derivatives range: 0.0004147315942060192, 0.019232022305248897
# Processing r0=3.5, eta0=7.5
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r350_eta750_eps10_theta100.pkl
# KS Derivatives range: 0.00027737751817635825, 0.019692130995285773
# Processing r0=3.5, eta0=8
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r350_eta800_eps10_theta100.pkl
# KS Derivatives range: 0.0002877997007377786, 0.02014424764773537
# Processing r0=3.75, eta0=0
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r375_eta0_eps10_theta100.pkl
# KS Derivatives range: 0.0014164700579133436, 0.05202184379382579
# Processing r0=3.75, eta0=0.5
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r375_eta50_eps10_theta100.pkl
# KS Derivatives range: 0.0016709116201774064, 0.03391952887454863
# Processing r0=3.75, eta0=1
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r375_eta100_eps10_theta100.pkl
# KS Derivatives range: 0.0014523883463957164, 0.02482948753823599
# Processing r0=3.75, eta0=1.5
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r375_eta150_eps10_theta100.pkl
# KS Derivatives range: 0.0014271237080976105, 0.01984170356905679
# Processing r0=3.75, eta0=2
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r375_eta200_eps10_theta100.pkl
# KS Derivatives range: 0.0011448182624107517, 0.017040237534904357
# Processing r0=3.75, eta0=2.5
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r375_eta250_eps10_theta100.pkl
# KS Derivatives range: 0.0010725203808403805, 0.015513503548447714
# Processing r0=3.75, eta0=3
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r375_eta300_eps10_theta100.pkl
# KS Derivatives range: 0.0008946265776799133, 0.014754463806276872
# Processing r0=3.75, eta0=3.5
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r375_eta350_eps10_theta100.pkl
# KS Derivatives range: 0.0008301211495975734, 0.014461024600009862
# Processing r0=3.75, eta0=4
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r375_eta400_eps10_theta100.pkl
# KS Derivatives range: 0.0006811403018003314, 0.014453158517224727
# Processing r0=3.75, eta0=4.5
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r375_eta450_eps10_theta100.pkl
# KS Derivatives range: 0.000593270466087148, 0.014616351926011182
# Processing r0=3.75, eta0=5
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r375_eta500_eps10_theta100.pkl
# KS Derivatives range: 0.0005599944896683695, 0.014880650869852905
# Processing r0=3.75, eta0=5.5
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r375_eta550_eps10_theta100.pkl
# KS Derivatives range: 0.0004016342813883966, 0.01520374733610108
# Processing r0=3.75, eta0=6
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r375_eta600_eps10_theta100.pkl
# KS Derivatives range: 0.0004406593069605779, 0.01556095521326739
# Processing r0=3.75, eta0=6.5
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r375_eta650_eps10_theta100.pkl
# KS Derivatives range: 0.00042984453219041535, 0.015935998176619393
# Processing r0=3.75, eta0=7
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r375_eta700_eps10_theta100.pkl
# KS Derivatives range: 0.0003878609031171542, 0.01631521124867419
# Processing r0=3.75, eta0=7.5
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r375_eta750_eps10_theta100.pkl
# KS Derivatives range: 0.0002970098167409674, 0.016694624205282338
# Processing r0=3.75, eta0=8
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r375_eta800_eps10_theta100.pkl
# KS Derivatives range: 0.00018272532688323737, 0.017069198568475663
# Processing r0=4, eta0=0
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r400_eta0_eps10_theta100.pkl
# KS Derivatives range: 0.0014316017371562848, 0.05130038063516639
# Processing r0=4, eta0=0.5
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r400_eta50_eps10_theta100.pkl
# KS Derivatives range: 0.0013585568892082731, 0.0331970704703366
# Processing r0=4, eta0=1
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r400_eta100_eps10_theta100.pkl
# KS Derivatives range: 0.0011815682765536906, 0.024048696592449122
# Processing r0=4, eta0=1.5
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r400_eta150_eps10_theta100.pkl
# KS Derivatives range: 0.001181571362973699, 0.018943738155918766
# Processing r0=4, eta0=2
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r400_eta200_eps10_theta100.pkl
# KS Derivatives range: 0.001009391770168122, 0.015979737766347313
# Processing r0=4, eta0=2.5
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r400_eta250_eps10_theta100.pkl
# KS Derivatives range: 0.0009294638794732356, 0.014270731535370727
# Processing r0=4, eta0=3
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r400_eta300_eps10_theta100.pkl
# KS Derivatives range: 0.0007837953910905248, 0.013332804948973374
# Processing r0=4, eta0=3.5
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r400_eta350_eps10_theta100.pkl
# KS Derivatives range: 0.0007650389086122366, 0.01287477319200647
# Processing r0=4, eta0=4
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r400_eta400_eps10_theta100.pkl
# KS Derivatives range: 0.000655781677572076, 0.012721730746623193
# Processing r0=4, eta0=4.5
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r400_eta450_eps10_theta100.pkl
# KS Derivatives range: 0.0004642257311199271, 0.012757791917339388
# Processing r0=4, eta0=5
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r400_eta500_eps10_theta100.pkl
# KS Derivatives range: 0.0004103869910565549, 0.01291038120854182
# Processing r0=4, eta0=5.5
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r400_eta550_eps10_theta100.pkl
# KS Derivatives range: 0.0004012447041290556, 0.013135449733470137
# Processing r0=4, eta0=6
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r400_eta600_eps10_theta100.pkl
# KS Derivatives range: 0.00034856656935811076, 0.013401871468143865
# Processing r0=4, eta0=6.5
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r400_eta650_eps10_theta100.pkl
# KS Derivatives range: 0.00036773681877377834, 0.01369651948246453
# Processing r0=4, eta0=7
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r400_eta700_eps10_theta100.pkl
# KS Derivatives range: 0.0003508571877475219, 0.014003325077283078
# Processing r0=4, eta0=7.5
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r400_eta750_eps10_theta100.pkl
# KS Derivatives range: 0.00029711909599328123, 0.0143147113496056
# Processing r0=4, eta0=8
# Loading existing gradient data from hierarchical-bayesian-model-validation/gradient_data\gradient_data_r400_eta800_eps10_theta100.pkl
# KS Derivatives range: 0.0002141127421195765, 0.014625998856487852
