# %%
import numpy as np
import pandas as pd
import scipy
import seaborn as sns
from scipy import integrate, interpolate, special
from scipy.special import psi
from scipy.stats import gengamma, laplace, norm, kstwo, ks_1samp
import matplotlib.pyplot as plt
import pickle
import os
import math
from scipy.linalg import svd
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from sigfig import round

# %%
def derivative_r(r, eta, scale=1):
    beta = (eta + 1.5) / r

    def gauss_density(theta, x):
        return (1. / (np.sqrt(2 * np.pi) * theta)) * np.exp(-0.5 * (x / theta) ** 2)

    def gen_gamma_density(theta):
        return (r / scipy.special.gamma(beta)) * (1 / scale) * (theta / scale) ** (r * beta - 1) * np.exp(-(theta / scale) ** r)

    def integrand_up(theta, x):
        return gauss_density(theta, x) * gen_gamma_density(theta) * math.log(theta) * theta ** r

    def integrand_down(theta, x):
        return gauss_density(theta, x) * gen_gamma_density(theta)

    def integral_up(x):
        result, error = scipy.integrate.quad(lambda theta: integrand_up(theta, x), 0, np.inf)
        return result

    def integral_down(x):
        result, error = scipy.integrate.quad(lambda theta: integrand_down(theta, x), 0, np.inf)
        return result

    def integral_ratio(x):
        up = integral_up(x)
        down = integral_down(x)
        return up / down if down != 0 else float('inf')  # Avoid division by zero

    psi_value = scipy.special.psi((eta + 0.5) / r) * ((eta + 0.5) / r**2)

    return lambda x: r**-1 + psi_value - integral_ratio(x)

# %%
def derivative_eta(r, eta, scale=1):
    beta = (eta + 1.5) / r

    def gauss_density(theta, x):
        return (1. / (np.sqrt(2 * np.pi) * theta)) * np.exp(-0.5 * (x / theta) ** 2)

    def gen_gamma_density(theta):
        return (r / scipy.special.gamma(beta)) * (1 / scale) * (theta / scale) ** (r * beta - 1) * np.exp(-(theta / scale) ** r)

    def integrand_up(theta, x):
        return gauss_density(theta, x) * gen_gamma_density(theta) * math.log(theta)

    def integrand_down(theta, x):
        return gauss_density(theta, x) * gen_gamma_density(theta)

    def integral_up(x):
        result, error = scipy.integrate.quad(lambda theta: integrand_up(theta, x), 0, np.inf)
        return result

    def integral_down(x):
        result, error = scipy.integrate.quad(lambda theta: integrand_down(theta, x), 0, np.inf)
        return result

    def integral_ratio(x):
        up = integral_up(x)
        down = integral_down(x)
        return up / down if down != 0 else float('inf')  # Avoid division by zero

    psi_value = - scipy.special.psi((eta + 0.5) / r) * (1 / r)

    return lambda x: psi_value + integral_ratio(x)

# %%
def integrate_function_r_eta(r, eta, scale=1):
    # Create instances of the functions that depend on x
    dr_func = derivative_r(r, eta, scale)
    de_func = derivative_eta(r, eta, scale)
    
    # Define the function for integrate_with_respect_to_theta_down from derivative_r
    # (Should ideally be the same in both derivative_r and derivative_eta to avoid duplication)
    def integral_down(x):
        beta = (eta + 1.5) / r
        def gauss_density(theta, x):
            return (1. / (np.sqrt(2 * np.pi) * theta)) * np.exp(-0.5 * (x / theta) ** 2)
        def gen_gamma_density(theta):
            return (r / scipy.special.gamma(beta)) * (1 / scale) * (theta / scale) ** (r * beta - 1) * np.exp(-(theta / scale) ** r)
        def integrand_down(theta, x):
            return gauss_density(theta, x) * gen_gamma_density(theta)
        result, error = scipy.integrate.quad(lambda theta: integrand_down(theta, x), 0, np.inf)
        return result
    
    # Define the function to be integrated over x
    def integrand(x):
        dr_val = dr_func(x)
        de_val = de_func(x)
        down_val = integral_down(x)
        if down_val != 0:
            return (dr_val * de_val) * down_val
        else:
            return 0  # Handle division by zero if necessary

    # Perform the integration from -inf to inf
    result, error = scipy.integrate.quad(integrand, -np.inf, np.inf)
    return result

# %%
def integrate_function_r_r(r, eta, scale=1):
    # Create instances of the functions that depend on x
    dr_func = derivative_r(r, eta, scale)
    de_func = derivative_eta(r, eta, scale)
    
    # Define the function for integrate_with_respect_to_theta_down from derivative_r
    # (Should ideally be the same in both derivative_r and derivative_eta to avoid duplication)
    def integral_down(x):
        beta = (eta + 1.5) / r
        def gauss_density(theta, x):
            return (1. / (np.sqrt(2 * np.pi) * theta)) * np.exp(-0.5 * (x / theta) ** 2)
        def gen_gamma_density(theta):
            return (r / scipy.special.gamma(beta)) * (1 / scale) * (theta / scale) ** (r * beta - 1) * np.exp(-(theta / scale) ** r)
        def integrand_down(theta, x):
            return gauss_density(theta, x) * gen_gamma_density(theta)
        result, error = scipy.integrate.quad(lambda theta: integrand_down(theta, x), 0, np.inf)
        return result
    
    # Define the function to be integrated over x
    def integrand(x):
        dr_val = dr_func(x)
        down_val = integral_down(x)
        if down_val != 0:
            return (dr_val * dr_val) * down_val
        else:
            return 0  # Handle division by zero if necessary

    # Perform the integration from -inf to inf
    result, error = scipy.integrate.quad(integrand, -np.inf, np.inf)
    return result

# %%
def integrate_function_eta_eta(r, eta, scale=1):
    # Create instances of the functions that depend on x
    dr_func = derivative_r(r, eta, scale)
    de_func = derivative_eta(r, eta, scale)
    
    # Define the function for integrate_with_respect_to_theta_down from derivative_r
    # (Should ideally be the same in both derivative_r and derivative_eta to avoid duplication)
    def integral_down(x):
        beta = (eta + 1.5) / r
        def gauss_density(theta, x):
            return (1. / (np.sqrt(2 * np.pi) * theta)) * np.exp(-0.5 * (x / theta) ** 2)
        def gen_gamma_density(theta):
            return (r / scipy.special.gamma(beta)) * (1 / scale) * (theta / scale) ** (r * beta - 1) * np.exp(-(theta / scale) ** r)
        def integrand_down(theta, x):
            return gauss_density(theta, x) * gen_gamma_density(theta)
        result, error = scipy.integrate.quad(lambda theta: integrand_down(theta, x), 0, np.inf)
        return result
    
    # Define the function to be integrated over x
    def integrand(x):
        de_val = de_func(x)
        down_val = integral_down(x)
        if down_val != 0:
            return (de_val * de_val) * down_val
        else:
            return 0  # Handle division by zero if necessary

    # Perform the integration from -inf to inf
    result, error = scipy.integrate.quad(integrand, -np.inf, np.inf)
    return result

# %%
#r = np.linspace(0.1, 2, 20)
#eta = np.linspace(0.1, 2, 20)
#r = [0.25, 0.5, 0.75, 1, 1.25, 1.5, 1.75, 2, 2.25, 2.5, 2.75, 3, 3.25, 3.5, 3.75, 4]
#eta = [0.5, 1, 1.5, 2, 2.5, 3, 3.5, 4, 4.5, 5, 5.5, 6, 6.5, 7, 7.5, 8]
#R, Eta = np.meshgrid(r, eta)


# Grid values for ellipses
r_ellipses = [0.5, 0.75, 1, 1.25, 1.5, 1.75, 2, 2.25, 2.5, 2.75, 3, 3.25, 3.5, 3.75, 4]
eta_ellipses = [1, 1.5, 2, 2.5, 3, 3.5, 4, 4.5, 5, 5.5, 6, 6.5, 7, 7.5, 8]
R_ellipses, Eta_ellipses = np.meshgrid(r_ellipses, eta_ellipses)

# Finer grid values for the contour plot
r_contour = [round(i*0.01 + 0.5, sigfigs=2) for i in range(0, 360)]
eta_contour = [round(j*0.02 + 1, sigfigs=2) for j in range(0, 360)]
R_contour, Eta_contour = np.meshgrid(r_contour, eta_contour)

#0.25 r=3 0.5 eta=8
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 14
#      11 R_ellipses, Eta_ellipses = np.meshgrid(r_ellipses, eta_ellipses)
#      13 # Finer grid values for the contour plot
# ---> 14 r_contour = [round(i*0.01 + 0.5, sigfigs=2) for i in range(0, 360)]
#      15 eta_contour = [round(j*0.02 + 1, sigfigs=2) for j in range(0, 360)]
#      16 R_contour, Eta_contour = np.meshgrid(r_contour, eta_contour)
#
# Cell In[8], line 14, in <listcomp>(.0)
#      11 R_ellipses, Eta_ellipses = np.meshgrid(r_ellipses, eta_ellipses)
#      13 # Finer grid values for the contour plot
# ---> 14 r_contour = [round(i*0.01 + 0.5, sigfigs=2) for i in range(0, 360)]
#      15 eta_contour = [round(j*0.02 + 1, sigfigs=2) for j in range(0, 360)]
#      16 R_contour, Eta_contour = np.meshgrid(r_contour, eta_contour)
#
# TypeError: 'sigfigs' is an invalid keyword argument for round()

# %%
def hessian(r, eta):
        # Hessian matrix
    H = np.array([[integrate_function_r_r(r, eta), integrate_function_r_eta(r, eta)],
                  [integrate_function_r_eta(r, eta), integrate_function_eta_eta(r, eta)]])
    return H

# %%
def is_pos_def(x):
    return np.all(np.linalg.eigvals(x) > 0)

# %%
# Grid values for ellipses
r_ellipses = [0.5, 0.75, 1, 1.25, 1.5, 1.75, 2, 2.25, 2.5, 2.75, 3, 3.25, 3.5, 3.75, 4]
eta_ellipses = [1, 1.5, 2, 2.5, 3, 3.5, 4, 4.5, 5, 5.5, 6, 6.5, 7, 7.5, 8]
R_ellipses, Eta_ellipses = np.meshgrid(r_ellipses, eta_ellipses)

# Finer grid values for the contour plot
r_contour = [round(i*0.01 + 0.5, sigfigs=2) for i in range(-10, 360)]
eta_contour = [round(j*0.02 + 1, sigfigs=2) for j in range(-30, 380)]
R_contour, Eta_contour = np.meshgrid(r_contour, eta_contour)

# Initialize the plot
fig, ax = plt.subplots()
ax.set_xlim(np.min(r_ellipses), np.max(r_ellipses))
ax.set_ylim(np.min(eta_ellipses), np.max(eta_ellipses))

scale_factor = 0.01
pos_list = []
singular_values = []

# Directory for storing Hessian matrices
hessian_dir = 'hessian_matrices'
os.makedirs(hessian_dir, exist_ok=True)

# Function to generate a file path for a given (r, eta) pair
def get_hessian_path(r_val, eta_val):
    return os.path.join(hessian_dir, f'hessian_R{r_val}_Eta{eta_val}.pkl')

# Function to calculate variance_prior
def variance_prior(r, eta, scale=1):
    beta = (eta + 1.5) / r
    var_prior = scale * scipy.special.gamma(beta + 1 / r) / scipy.special.gamma(beta)
    return var_prior

# Initialize grid for var_prior values for the contour plot
var_prior_values = variance_prior(R_contour, Eta_contour)

# Loop through R_ellipses and Eta_ellipses for the ellipses
for i in range(len(r_ellipses)):
    for j in range(len(eta_ellipses)):
        hessian_path = get_hessian_path(R_ellipses[i, j], Eta_ellipses[i, j])
        
        # Check if the Hessian matrix is already stored
        if os.path.exists(hessian_path):
            with open(hessian_path, 'rb') as f:
                H = pickle.load(f)
        else:
            # Calculate the Hessian matrix if not already stored
            H = hessian(R_ellipses[i, j], Eta_ellipses[i, j])
            # Store the Hessian matrix in a pickle file
            with open(hessian_path, 'wb') as f:
                pickle.dump(H, f)
        
        pos_list.append(is_pos_def(H))
        U, s, Vt = np.linalg.svd(H)
        for singular_value in s:
            if R_ellipses[i, j] != 0.25:
                singular_values.append((singular_value, R_ellipses[i, j], Eta_ellipses[i, j]))
        angle = np.arctan2(U[0, 1], U[0, 0]) * 180 / np.pi  # Convert radian to degree
        width, height = scale_factor / np.sqrt(s[0]), scale_factor / np.sqrt(s[1])  # Axis lengths
        ellipse = patches.Ellipse((R_ellipses[i, j], Eta_ellipses[i, j]), width, height, angle=angle, edgecolor='red', facecolor='none')
        ax.add_patch(ellipse)

# Sort the singular values in ascending order
singular_values.sort(key=lambda x: x[0])

# Print the sorted singular values and corresponding r, eta pairs
for value, r_val, eta_val in singular_values:
    print(f'Singular Value: {value}, r: {r_val}, eta: {eta_val}')

print(pos_list)

# Set upper bound for variance
upper_bound = 5

# Define contour levels using var_prior_values from the original grid
exp_levels = np.logspace(np.log10(np.min(var_prior_values)), np.log10(np.max(var_prior_values)), 150)

# Overlay contour plot with reduced opacity and no labels
contour = plt.contour(R_contour, Eta_contour, np.log10(var_prior_values), levels=np.log10(exp_levels), cmap='cividis', alpha=0.7, linewidths=0.8)
plt.colorbar(contour)

# Title and labels
plt.title('Ellipses Representing the SVD of the Hessian with Variance Prior Contour')
plt.xlabel('r')
plt.ylabel('eta')
plt.show()
# Out:
# c:\Users\24340\AppData\Local\Programs\Python\Python39\lib\site-packages\sigfig\sigfig.py:586: UserWarning: warning: 2 significant figures requested from number with only 1 significant figures
#   warn("warning: %d significant figures requested from number with only %d significant figures" % (given['sigfigs'], len(num.map)))
# Singular Value: 0.00010386688595042408, r: 4.0, eta: 8.0
# Singular Value: 0.0001113006318880988, r: 3.75, eta: 8.0
# Singular Value: 0.00011977126818300338, r: 3.5, eta: 8.0
# Singular Value: 0.00012955828664449777, r: 3.25, eta: 8.0
# Singular Value: 0.000129695058504761, r: 4.0, eta: 7.5
# Singular Value: 0.00013897558298822546, r: 3.75, eta: 7.5
# Singular Value: 0.0001410508677727813, r: 3.0, eta: 8.0
# Singular Value: 0.00014947277521371987, r: 3.5, eta: 7.5
# Singular Value: 0.00015480312396015493, r: 2.75, eta: 8.0
# Singular Value: 0.00016153945212856512, r: 3.25, eta: 7.5
# Singular Value: 0.0001637894931522884, r: 4.0, eta: 7.0
# Singular Value: 0.0001715602620449371, r: 2.5, eta: 8.0
# Singular Value: 0.00017559098221174395, r: 3.75, eta: 7.0
# Singular Value: 0.00017563192309265048, r: 3.0, eta: 7.5
# Singular Value: 0.00018883437202813578, r: 3.5, eta: 7.0
# Singular Value: 0.0001924186260879491, r: 2.75, eta: 7.5
# Singular Value: 0.0001924498817607383, r: 2.25, eta: 8.0
# Singular Value: 0.00020394162119789344, r: 3.25, eta: 7.0
# Singular Value: 0.00020934413540155868, r: 4.0, eta: 6.5
# Singular Value: 0.00021280252200104303, r: 2.5, eta: 7.5
# Singular Value: 0.00021913573058397246, r: 2.0, eta: 8.0
# Singular Value: 0.0002214733271765577, r: 3.0, eta: 7.0
# Singular Value: 0.00022470271313999567, r: 3.75, eta: 6.5
# Singular Value: 0.00023812472745949454, r: 2.25, eta: 7.5
# Singular Value: 0.00024175975291487785, r: 3.5, eta: 6.5
# Singular Value: 0.0002422376342558705, r: 2.75, eta: 7.0
# Singular Value: 0.00025432579449014063, r: 1.75, eta: 8.0
# Singular Value: 0.0002610391458718235, r: 3.25, eta: 6.5
# Singular Value: 0.0002673399570662565, r: 2.5, eta: 7.0
# Singular Value: 0.00027038995202356887, r: 2.0, eta: 7.5
# Singular Value: 0.00027095301006618524, r: 4.0, eta: 6.0
# Singular Value: 0.0002832298118117365, r: 3.0, eta: 6.5
# Singular Value: 0.00029149437818639187, r: 3.75, eta: 6.0
# Singular Value: 0.0002983945062066733, r: 2.25, eta: 7.0
# Singular Value: 0.00030257174438987755, r: 1.5, eta: 8.0
# Singular Value: 0.00030932253200148394, r: 2.75, eta: 6.5
# Singular Value: 0.00031284398274006314, r: 1.75, eta: 7.5
# Singular Value: 0.0003140360650498172, r: 3.5, eta: 6.0
# Singular Value: 0.00033784475292029996, r: 2.0, eta: 7.0
# Singular Value: 0.0003392242779893812, r: 3.25, eta: 6.0
# Singular Value: 0.00034068535663747045, r: 2.5, eta: 6.5
# Singular Value: 0.0003551816748534915, r: 4.0, eta: 5.5
# Singular Value: 0.0003679108308290648, r: 3.0, eta: 6.0
# Singular Value: 0.00037085952029653515, r: 1.5, eta: 7.5
# Singular Value: 0.00037140498025056885, r: 1.25, eta: 8.0
# Singular Value: 0.0003792872143202891, r: 2.25, eta: 6.5
# Singular Value: 0.0003835836959198943, r: 3.75, eta: 5.5
# Singular Value: 0.00038958089253881417, r: 1.75, eta: 7.0
# Singular Value: 0.0004013346946286742, r: 2.75, eta: 6.0
# Singular Value: 0.00041432801498886437, r: 3.5, eta: 5.5
# Singular Value: 0.0004281348867611401, r: 2.0, eta: 6.5
# Singular Value: 0.00044120494672654715, r: 2.5, eta: 6.0
# Singular Value: 0.00044820719842519126, r: 3.25, eta: 5.5
# Singular Value: 0.0004542683668650544, r: 1.25, eta: 7.5
# Singular Value: 0.0004600941762642777, r: 1.5, eta: 7.0
# Singular Value: 0.00047129372998052315, r: 4.0, eta: 5.0
# Singular Value: 0.00047832426542101445, r: 1.0, eta: 8.0
# Singular Value: 0.0004862968545855467, r: 3.0, eta: 5.5
# Singular Value: 0.0004899599156020848, r: 2.25, eta: 6.0
# Singular Value: 0.0004919784993772472, r: 1.75, eta: 6.5
# Singular Value: 0.0005121241692855776, r: 3.75, eta: 5.0
# Singular Value: 0.0005301388165567816, r: 2.75, eta: 5.5
# Singular Value: 0.000551346867452095, r: 2.0, eta: 6.0
# Singular Value: 0.0005557017402649158, r: 3.5, eta: 5.0
# Singular Value: 0.0005612127704729127, r: 1.25, eta: 7.0
# Singular Value: 0.0005786497090437449, r: 1.5, eta: 6.5
# Singular Value: 0.0005814622979459703, r: 1.0, eta: 7.5
# Singular Value: 0.0005819096980811158, r: 2.5, eta: 5.5
# Singular Value: 0.0006029781464783019, r: 3.25, eta: 5.0
# Singular Value: 0.0006312376014822719, r: 1.75, eta: 6.0
# Singular Value: 0.0006318100890122279, r: 4.0, eta: 4.5
# Singular Value: 0.0006446852620471363, r: 2.25, eta: 5.5
# Singular Value: 0.0006552799315348819, r: 3.0, eta: 5.0
# Singular Value: 0.0006931375730709633, r: 3.75, eta: 4.5
# Singular Value: 0.0007026182634158573, r: 1.25, eta: 6.5
# Singular Value: 0.0007145616113550878, r: 2.75, eta: 5.0
# Singular Value: 0.0007232030796397286, r: 2.0, eta: 5.5
# Singular Value: 0.0007258706228920671, r: 1.0, eta: 7.0
# Singular Value: 0.0007392979485581761, r: 1.5, eta: 6.0
# Singular Value: 0.0007578177068725286, r: 3.5, eta: 4.5
# Singular Value: 0.0007836118371868464, r: 2.5, eta: 5.0
# Singular Value: 0.0008248183751338949, r: 1.75, eta: 5.5
# Singular Value: 0.0008268508325355851, r: 3.25, eta: 4.5
# Singular Value: 0.0008520283046992367, r: 4.0, eta: 4.0
# Singular Value: 0.00086640679367889, r: 2.25, eta: 5.0
# Singular Value: 0.0008931651699481185, r: 1.25, eta: 6.0
# Singular Value: 0.0008943900911226603, r: 1.0, eta: 6.5
# Singular Value: 0.0009018291547828624, r: 3.0, eta: 4.5
# Singular Value: 0.0009483861945232872, r: 3.75, eta: 4.0
# Singular Value: 0.0009616234680570391, r: 1.5, eta: 5.5
# Singular Value: 0.0009690002087844114, r: 2.0, eta: 5.0
# Singular Value: 0.0009732662879006824, r: 0.75, eta: 7.5
# Singular Value: 0.0009757283483803317, r: 0.75, eta: 8.0
# Singular Value: 0.0009851956692197622, r: 2.75, eta: 4.5
# Singular Value: 0.0010103032055501187, r: 0.75, eta: 7.0
# Singular Value: 0.0010494532316344225, r: 3.5, eta: 4.0
# Singular Value: 0.001080568822682197, r: 2.5, eta: 4.5
# Singular Value: 0.0011008199443040187, r: 1.75, eta: 5.0
# Singular Value: 0.0011253357342591661, r: 1.0, eta: 6.0
# Singular Value: 0.001146148302936005, r: 4.0, eta: 3.5
# Singular Value: 0.0011556343484467788, r: 1.25, eta: 5.5
# Singular Value: 0.0011559290579685705, r: 3.25, eta: 4.0
# Singular Value: 0.0011931354899019783, r: 2.25, eta: 4.5
# Singular Value: 0.0012227972183721449, r: 0.75, eta: 6.5
# Singular Value: 0.0012694399439784918, r: 3.0, eta: 4.0
# Singular Value: 0.001277295545790413, r: 1.5, eta: 5.0
# Singular Value: 0.0013034229998486076, r: 3.75, eta: 3.5
# Singular Value: 0.00133088512013835, r: 2.0, eta: 4.5
# Singular Value: 0.0013928775238983427, r: 2.75, eta: 4.0
# Singular Value: 0.0014516466668488257, r: 1.0, eta: 5.5
# Singular Value: 0.0014696568598585437, r: 3.5, eta: 3.5
# Singular Value: 0.001506064557277766, r: 1.75, eta: 4.5
# Singular Value: 0.001515790432529103, r: 4.0, eta: 3.0
# Singular Value: 0.0015240525553845018, r: 0.75, eta: 6.0
# Singular Value: 0.0015263329885552355, r: 1.25, eta: 5.0
# Singular Value: 0.0015308766339994632, r: 2.5, eta: 4.0
# Singular Value: 0.0016442343135776227, r: 3.25, eta: 3.5
# Singular Value: 0.0016903124050959921, r: 2.25, eta: 4.0
# Singular Value: 0.0017388920962570378, r: 1.5, eta: 4.5
# Singular Value: 0.0017767708113780691, r: 3.75, eta: 3.0
# Singular Value: 0.0018278612689644998, r: 3.0, eta: 3.5
# Singular Value: 0.0018818945123123163, r: 2.0, eta: 4.0
# Singular Value: 0.001906799052420205, r: 1.0, eta: 5.0
# Singular Value: 0.0019287436152503525, r: 4.0, eta: 2.5
# Singular Value: 0.0019436073410228545, r: 0.75, eta: 5.5
# Singular Value: 0.0020232341862760125, r: 2.75, eta: 3.5
# Singular Value: 0.002060793112960596, r: 3.5, eta: 3.0
# Singular Value: 0.0020654839364456453, r: 1.25, eta: 4.5
# Singular Value: 0.002122039452868691, r: 1.75, eta: 4.0
# Singular Value: 0.002235845584582142, r: 2.5, eta: 3.5
# Singular Value: 0.002302439797924116, r: 4.0, eta: 2.0
# Singular Value: 0.002350888857945069, r: 3.75, eta: 2.5
# Singular Value: 0.0023640361264767873, r: 3.25, eta: 3.0
# Singular Value: 0.002437853093513216, r: 1.5, eta: 4.0
# Singular Value: 0.0024746910499263064, r: 2.25, eta: 3.5
# Singular Value: 0.0025117857033376202, r: 4.0, eta: 1.0
# Singular Value: 0.002525810738632526, r: 4.0, eta: 1.5
# Singular Value: 0.002529966717225967, r: 0.75, eta: 5.0
# Singular Value: 0.0025615771373790857, r: 1.0, eta: 4.5
# Singular Value: 0.002683596748925858, r: 3.0, eta: 3.0
# Singular Value: 0.0027543390029345443, r: 2.0, eta: 3.5
# Singular Value: 0.0028370884679224887, r: 3.5, eta: 2.5
# Singular Value: 0.0028773919652735533, r: 1.25, eta: 4.0
# Singular Value: 0.0029302303822846725, r: 3.75, eta: 2.0
# Singular Value: 0.003019226140754438, r: 2.75, eta: 3.0
# Singular Value: 0.00309743130181302, r: 1.75, eta: 3.5
# Singular Value: 0.0033416891757424416, r: 3.75, eta: 1.5
# Singular Value: 0.0033719986055100867, r: 0.75, eta: 4.5
# Singular Value: 0.003375303697285046, r: 2.5, eta: 3.0
# Singular Value: 0.003381333763651593, r: 3.25, eta: 2.5
# Singular Value: 0.003421885869329548, r: 3.75, eta: 1.0
# Singular Value: 0.0035388802023849433, r: 1.0, eta: 4.0
# Singular Value: 0.003541525250836244, r: 1.5, eta: 3.5
# Singular Value: 0.0037122676525122595, r: 3.5, eta: 2.0
# Singular Value: 0.003762288453762117, r: 2.25, eta: 3.0
# Singular Value: 0.003973462864335776, r: 3.0, eta: 2.5
# Singular Value: 0.004152544839306638, r: 1.25, eta: 3.5
# Singular Value: 0.004199655080694014, r: 2.0, eta: 3.0
# Singular Value: 0.004440331259740593, r: 3.5, eta: 1.5
# Singular Value: 0.0046028600872881084, r: 2.75, eta: 2.5
# Singular Value: 0.004620598702824205, r: 0.75, eta: 4.0
# Singular Value: 0.00466151696918492, r: 3.25, eta: 2.0
# Singular Value: 0.0047180174621174525, r: 3.5, eta: 1.0
# Singular Value: 0.0047193941743296376, r: 1.75, eta: 3.0
# Singular Value: 0.00506199219932453, r: 1.0, eta: 3.5
# Singular Value: 0.0052641018326182515, r: 2.5, eta: 2.5
# Singular Value: 0.005375386406304338, r: 1.5, eta: 3.0
# Singular Value: 0.0057749945503182245, r: 3.0, eta: 2.0
# Singular Value: 0.005906232099961722, r: 3.25, eta: 1.5
# Singular Value: 0.005962263024531, r: 2.25, eta: 2.5
# Singular Value: 0.0062620319158415766, r: 1.25, eta: 3.0
# Singular Value: 0.006549668948878956, r: 0.75, eta: 3.5
# Singular Value: 0.006581263752423871, r: 3.25, eta: 1.0
# Singular Value: 0.006718968259789195, r: 2.0, eta: 2.5
# Singular Value: 0.007030406262542176, r: 2.75, eta: 2.0
# Singular Value: 0.007563794410981695, r: 1.0, eta: 3.0
# Singular Value: 0.007578327165887639, r: 1.75, eta: 2.5
# Singular Value: 0.007824121196732604, r: 3.0, eta: 1.5
# Singular Value: 0.008392857280267677, r: 2.5, eta: 2.0
# Singular Value: 0.008620041049393968, r: 1.5, eta: 2.5
# Singular Value: 0.009273500673285608, r: 3.0, eta: 1.0
# Singular Value: 0.0096917176507024, r: 0.75, eta: 3.0
# Singular Value: 0.009831649754140383, r: 2.25, eta: 2.0
# Singular Value: 0.00998615947810029, r: 1.25, eta: 2.5
# Singular Value: 0.010250512950642937, r: 2.75, eta: 1.5
# Singular Value: 0.011342961248673514, r: 2.0, eta: 2.0
# Singular Value: 0.011951647125235049, r: 1.0, eta: 2.5
# Singular Value: 0.012969944700987033, r: 1.75, eta: 2.0
# Singular Value: 0.013151110861741354, r: 2.75, eta: 1.0
# Singular Value: 0.013176277730774124, r: 2.5, eta: 1.5
# Singular Value: 0.014389755968152602, r: 0.5, eta: 3.0
# Singular Value: 0.014826004346908879, r: 1.5, eta: 2.0
# Singular Value: 0.015190641613534422, r: 0.75, eta: 2.5
# Singular Value: 0.016506159361191885, r: 2.25, eta: 1.5
# Singular Value: 0.017134889227729343, r: 1.25, eta: 2.0
# Singular Value: 0.018636905956472324, r: 2.5, eta: 1.0
# Singular Value: 0.020098465582568902, r: 2.0, eta: 1.5
# Singular Value: 0.020336940413110235, r: 1.0, eta: 2.0
# Singular Value: 0.023862813164957582, r: 1.75, eta: 1.5
# Singular Value: 0.02568171930784616, r: 0.75, eta: 2.0
# Singular Value: 0.026085010424049947, r: 2.25, eta: 1.0
# Singular Value: 0.02683039517861819, r: 0.5, eta: 2.5
# Singular Value: 0.027869082649484157, r: 1.5, eta: 1.5
# Singular Value: 0.03021134545967982, r: 4.0, eta: 4.0
# Singular Value: 0.03062888738434299, r: 4.0, eta: 3.5
# Singular Value: 0.0307087914834459, r: 4.0, eta: 4.5
# Singular Value: 0.031748069830225295, r: 4.0, eta: 5.0
# Singular Value: 0.03244485953894476, r: 1.25, eta: 1.5
# Singular Value: 0.03267634836698669, r: 4.0, eta: 3.0
# Singular Value: 0.0331210471105911, r: 4.0, eta: 5.5
# Singular Value: 0.03470457539555622, r: 4.0, eta: 6.0
# Singular Value: 0.035511129099942654, r: 2.0, eta: 1.0
# Singular Value: 0.036422106205136875, r: 4.0, eta: 6.5
# Singular Value: 0.037827032363461806, r: 4.0, eta: 2.5
# Singular Value: 0.03822412425641653, r: 4.0, eta: 7.0
# Singular Value: 0.03834774006479077, r: 1.0, eta: 1.5
# Singular Value: 0.03866433537877532, r: 3.75, eta: 3.5
# Singular Value: 0.03902870442368562, r: 3.75, eta: 4.0
# Singular Value: 0.03995445037863836, r: 3.75, eta: 3.0
# Singular Value: 0.040077508643030654, r: 4.0, eta: 7.5
# Singular Value: 0.04031726620155931, r: 3.75, eta: 4.5
# Singular Value: 0.04195962260938467, r: 4.0, eta: 8.0
# Singular Value: 0.04214926024188042, r: 3.75, eta: 5.0
# Singular Value: 0.04431148337803757, r: 3.75, eta: 5.5
# Singular Value: 0.044415376518607684, r: 3.75, eta: 2.5
# Singular Value: 0.04448853859599847, r: 0.5, eta: 3.5
# Singular Value: 0.04640153612557318, r: 1.75, eta: 1.0
# Singular Value: 0.046677111766843964, r: 3.75, eta: 6.0
# Singular Value: 0.0475725951152713, r: 0.75, eta: 1.5
# Singular Value: 0.04916697993209625, r: 3.75, eta: 6.5
# Singular Value: 0.04940104361437003, r: 4.0, eta: 2.0
# Singular Value: 0.050443289897073314, r: 3.5, eta: 3.5
# Singular Value: 0.05057712482099512, r: 3.5, eta: 3.0
# Singular Value: 0.05172975838825146, r: 3.75, eta: 7.0
# Singular Value: 0.05198279264040104, r: 3.5, eta: 4.0
# Singular Value: 0.05393773462919932, r: 3.5, eta: 2.5
# Singular Value: 0.05433119350148968, r: 3.75, eta: 7.5
# Singular Value: 0.05445096202192576, r: 3.5, eta: 4.5
# Singular Value: 0.05486374184796597, r: 0.5, eta: 5.0
# Singular Value: 0.05549108144633999, r: 3.75, eta: 2.0
# Singular Value: 0.056947966483889736, r: 3.75, eta: 8.0
# Singular Value: 0.05745829433921949, r: 3.5, eta: 5.0
# Singular Value: 0.05802340790943201, r: 1.5, eta: 1.0
# Singular Value: 0.060785267323107774, r: 3.5, eta: 5.5
# Singular Value: 0.06409273124186342, r: 3.5, eta: 2.0
# Singular Value: 0.06430057931362693, r: 3.5, eta: 6.0
# Singular Value: 0.06655345153584658, r: 3.25, eta: 3.0
# Singular Value: 0.06792200859187668, r: 3.5, eta: 6.5
# Singular Value: 0.06816367723915033, r: 3.25, eta: 2.5
# Singular Value: 0.06821229202402215, r: 3.25, eta: 3.5
# Singular Value: 0.07018925010975136, r: 1.25, eta: 1.0
# Singular Value: 0.07155555602457989, r: 3.25, eta: 4.0
# Singular Value: 0.07159631610097678, r: 3.5, eta: 7.0
# Singular Value: 0.07528813043415183, r: 3.5, eta: 7.5
# Singular Value: 0.07582287519085812, r: 3.25, eta: 4.5
# Singular Value: 0.07598278396424607, r: 4.0, eta: 1.5
# Singular Value: 0.07672001753416706, r: 3.25, eta: 2.0
# Singular Value: 0.07897369870571136, r: 3.5, eta: 8.0
# Singular Value: 0.08061357709265374, r: 3.25, eta: 5.0
# Singular Value: 0.08206415507871503, r: 3.75, eta: 1.5
# Singular Value: 0.08357472554469127, r: 0.5, eta: 4.0
# Singular Value: 0.08398559112985382, r: 1.0, eta: 1.0
# Singular Value: 0.08570014411705212, r: 3.25, eta: 5.5
# Singular Value: 0.09018783846286861, r: 3.0, eta: 2.5
# Singular Value: 0.09028128327509906, r: 3.5, eta: 1.5
# Singular Value: 0.09094586576508948, r: 3.25, eta: 6.0
# Singular Value: 0.09139602145710787, r: 3.0, eta: 3.0
# Singular Value: 0.09590021521168113, r: 3.0, eta: 3.5
# Singular Value: 0.0960382942853173, r: 3.0, eta: 2.0
# Singular Value: 0.09626519380772244, r: 3.25, eta: 6.5
# Singular Value: 0.10160300024839271, r: 3.25, eta: 7.0
# Singular Value: 0.10185910975699074, r: 3.25, eta: 1.5
# Singular Value: 0.10208570163646995, r: 3.0, eta: 4.0
# Singular Value: 0.10295006665621212, r: 0.75, eta: 1.0
# Singular Value: 0.10692314783049565, r: 3.25, eta: 7.5
# Singular Value: 0.10917172302177511, r: 3.0, eta: 4.5
# Singular Value: 0.11220166737489713, r: 3.25, eta: 8.0
# Singular Value: 0.11674265702958794, r: 3.0, eta: 5.0
# Singular Value: 0.11897550112358554, r: 3.0, eta: 1.5
# Singular Value: 0.12456098064742922, r: 3.0, eta: 5.5
# Singular Value: 0.12565569382539743, r: 2.75, eta: 2.5
# Singular Value: 0.1269240776024288, r: 2.75, eta: 2.0
# Singular Value: 0.13151687198005868, r: 2.75, eta: 3.0
# Singular Value: 0.13248390381421613, r: 3.0, eta: 6.0
# Singular Value: 0.1404226155930091, r: 3.0, eta: 6.5
# Singular Value: 0.14067797268636006, r: 2.75, eta: 3.5
# Singular Value: 0.1454116144353937, r: 4.0, eta: 1.0
# Singular Value: 0.145670645535985, r: 2.75, eta: 1.5
# Singular Value: 0.14832068709041593, r: 3.0, eta: 7.0
# Singular Value: 0.1514857847353867, r: 2.75, eta: 4.0
# Singular Value: 0.15263770790180026, r: 3.75, eta: 1.0
# Singular Value: 0.15614193992392994, r: 3.0, eta: 7.5
# Singular Value: 0.16185277094938538, r: 3.5, eta: 1.0
# Singular Value: 0.16313042581867174, r: 2.75, eta: 4.5
# Singular Value: 0.16386324060305127, r: 3.0, eta: 8.0
# Singular Value: 0.17402172271669894, r: 3.25, eta: 1.0
# Singular Value: 0.17517667407615004, r: 2.75, eta: 5.0
# Singular Value: 0.17873307329667987, r: 2.5, eta: 2.0
# Singular Value: 0.18469930231073328, r: 0.5, eta: 4.5
# Singular Value: 0.1854015896598368, r: 2.5, eta: 2.5
# Singular Value: 0.18737525542490038, r: 2.75, eta: 5.5
# Singular Value: 0.18978284265636958, r: 2.5, eta: 1.5
# Singular Value: 0.1908168267929742, r: 3.0, eta: 1.0
# Singular Value: 0.19503406686693536, r: 0.5, eta: 1.0
# Singular Value: 0.19922615148077708, r: 2.5, eta: 3.0
# Singular Value: 0.19957734020094745, r: 2.75, eta: 6.0
# Singular Value: 0.2116918818263378, r: 2.75, eta: 6.5
# Singular Value: 0.2153151800918198, r: 2.75, eta: 1.0
# Singular Value: 0.21630217002704052, r: 2.5, eta: 3.5
# Singular Value: 0.22366268477852128, r: 2.75, eta: 7.0
# Singular Value: 0.23491691392433742, r: 2.5, eta: 4.0
# Singular Value: 0.23545534354783265, r: 2.75, eta: 7.5
# Singular Value: 0.24704942756493953, r: 2.75, eta: 8.0
# Singular Value: 0.2535510021934366, r: 2.5, eta: 1.0
# Singular Value: 0.2542194141957037, r: 2.5, eta: 4.5
# Singular Value: 0.2673333212706957, r: 2.25, eta: 1.5
# Singular Value: 0.2705101591792542, r: 2.25, eta: 2.0
# Singular Value: 0.273750295133602, r: 2.5, eta: 5.0
# Singular Value: 0.29029233117759295, r: 0.5, eta: 1.5
# Singular Value: 0.2915065530364906, r: 2.25, eta: 2.5
# Singular Value: 0.2932483474043852, r: 2.5, eta: 5.5
# Singular Value: 0.31191700428196534, r: 0.5, eta: 2.0
# Singular Value: 0.31256079058843383, r: 2.5, eta: 6.0
# Singular Value: 0.3181483129062559, r: 2.25, eta: 1.0
# Singular Value: 0.3195992658279527, r: 2.25, eta: 3.0
# Singular Value: 0.3315974985336778, r: 2.5, eta: 6.5
# Singular Value: 0.3503063075169339, r: 2.5, eta: 7.0
# Singular Value: 0.3507569678607273, r: 2.25, eta: 3.5
# Singular Value: 0.35251336728461025, r: 0.5, eta: 5.5
# Singular Value: 0.36607058984117613, r: 0.5, eta: 7.0
# Singular Value: 0.36865846564873883, r: 2.5, eta: 7.5
# Singular Value: 0.38317428900038303, r: 2.25, eta: 4.0
# Singular Value: 0.3866401578486004, r: 2.5, eta: 8.0
# Singular Value: 0.41336534256251456, r: 2.0, eta: 1.5
# Singular Value: 0.41594668790194883, r: 2.25, eta: 4.5
# Singular Value: 0.4372996041377764, r: 2.0, eta: 1.0
# Singular Value: 0.44397045867505464, r: 2.0, eta: 2.0
# Singular Value: 0.4485896296197222, r: 2.25, eta: 5.0
# Singular Value: 0.4808337533587091, r: 2.25, eta: 5.5
# Singular Value: 0.4923446738951116, r: 2.0, eta: 2.5
# Singular Value: 0.5125301401164236, r: 2.25, eta: 6.0
# Singular Value: 0.5435977252124901, r: 2.25, eta: 6.5
# Singular Value: 0.5474915944662757, r: 2.0, eta: 3.0
# Singular Value: 0.547837137290399, r: 0.5, eta: 6.0
# Singular Value: 0.5739968295301026, r: 2.25, eta: 7.0
# Singular Value: 0.603712862707816, r: 2.25, eta: 7.5
# Singular Value: 0.6051526746000873, r: 2.0, eta: 3.5
# Singular Value: 0.623102398183161, r: 0.5, eta: 7.5
# Singular Value: 0.629234748023471, r: 0.5, eta: 6.5
# Singular Value: 0.6327467605915292, r: 2.25, eta: 8.0
# Singular Value: 0.6633915996133254, r: 2.0, eta: 4.0
# Singular Value: 0.6789009623266562, r: 1.75, eta: 1.0
# Singular Value: 0.7117176190425605, r: 1.75, eta: 1.5
# Singular Value: 0.7212448856759307, r: 2.0, eta: 4.5
# Singular Value: 0.7782128644476, r: 2.0, eta: 5.0
# Singular Value: 0.7990864444273685, r: 1.75, eta: 2.0
# Singular Value: 0.8340366717925541, r: 2.0, eta: 5.5
# Singular Value: 0.8885896006600651, r: 2.0, eta: 6.0
# Singular Value: 0.9036793800638969, r: 1.75, eta: 2.5
# Singular Value: 0.9418203915115485, r: 2.0, eta: 6.5
# Singular Value: 0.99372176152605, r: 2.0, eta: 7.0
# Singular Value: 1.0138890927046502, r: 1.75, eta: 3.0
# Singular Value: 1.0443121412255425, r: 2.0, eta: 7.5
# Singular Value: 1.0936249025174634, r: 2.0, eta: 8.0
# Singular Value: 1.1250989109770926, r: 1.75, eta: 3.5
# Singular Value: 1.2247218425813076, r: 1.5, eta: 1.0
# Singular Value: 1.2352216404967873, r: 1.75, eta: 4.0
# Singular Value: 1.343262352463245, r: 1.75, eta: 4.5
# Singular Value: 1.3875704633503545, r: 1.5, eta: 1.5
# Singular Value: 1.4487521293521153, r: 1.75, eta: 5.0
# Singular Value: 1.551493659093504, r: 1.75, eta: 5.5
# Singular Value: 1.5848033819891783, r: 0.5, eta: 8.0
# Singular Value: 1.6041304814098263, r: 1.5, eta: 2.0
# Singular Value: 1.6514357844632015, r: 1.75, eta: 6.0
# Singular Value: 1.7486070276157202, r: 1.75, eta: 6.5
# Singular Value: 1.8353051526574327, r: 1.5, eta: 2.5
# Singular Value: 1.843080253711184, r: 1.75, eta: 7.0
# Singular Value: 1.9349511457788773, r: 1.75, eta: 7.5
# Singular Value: 2.0243263531950983, r: 1.75, eta: 8.0
# Singular Value: 2.068357828168677, r: 1.5, eta: 3.0
# Singular Value: 2.2982330882282054, r: 1.5, eta: 3.5
# Singular Value: 2.5227762740588293, r: 1.5, eta: 4.0
# Singular Value: 2.641478824551604, r: 1.25, eta: 1.0
# Singular Value: 2.7411018152438005, r: 1.5, eta: 4.5
# Singular Value: 2.952928612314166, r: 1.5, eta: 5.0
# Singular Value: 3.143954055364362, r: 1.25, eta: 1.5
# Singular Value: 3.1582767589099006, r: 1.5, eta: 5.5
# Singular Value: 3.3573185312254896, r: 1.5, eta: 6.0
# Singular Value: 3.550298989431057, r: 1.5, eta: 6.5
# Singular Value: 3.693716372560106, r: 1.25, eta: 2.0
# Singular Value: 3.737495365189148, r: 1.5, eta: 7.0
# Singular Value: 3.9191932037545136, r: 1.5, eta: 7.5
# Singular Value: 4.095674590205329, r: 1.5, eta: 8.0
# Singular Value: 4.2474015496487, r: 1.25, eta: 2.5
# Singular Value: 4.790791933226293, r: 1.25, eta: 3.0
# Singular Value: 5.3187233120375605, r: 1.25, eta: 3.5
# Singular Value: 5.829510503809026, r: 1.25, eta: 4.0
# Singular Value: 6.322903727910248, r: 1.25, eta: 4.5
# Singular Value: 6.799382847579227, r: 1.25, eta: 5.0
# Singular Value: 7.1139533918280415, r: 1.0, eta: 1.0
# Singular Value: 7.2596760841991825, r: 1.25, eta: 5.5
# Singular Value: 7.7046295765725965, r: 1.25, eta: 6.0
# Singular Value: 8.13510944895122, r: 1.25, eta: 6.5
# Singular Value: 8.551949165534209, r: 1.25, eta: 7.0
# Singular Value: 8.679337580946465, r: 1.0, eta: 1.5
# Singular Value: 8.955936835316853, r: 1.25, eta: 7.5
# Singular Value: 9.34779725799834, r: 1.25, eta: 8.0
# Singular Value: 10.25381787086017, r: 1.0, eta: 2.0
# Singular Value: 11.788075390033578, r: 1.0, eta: 2.5
# Singular Value: 13.268333016128388, r: 1.0, eta: 3.0
# Singular Value: 14.692009166688072, r: 1.0, eta: 3.5
# Singular Value: 16.060537158624026, r: 1.0, eta: 4.0
# Singular Value: 17.3766257267449, r: 1.0, eta: 4.5
# Singular Value: 18.643444624428515, r: 1.0, eta: 5.0
# Singular Value: 19.86380750224338, r: 1.0, eta: 5.5
# Singular Value: 21.039812695816895, r: 1.0, eta: 6.0
# Singular Value: 22.174032641926797, r: 1.0, eta: 6.5
# Singular Value: 23.27428183276108, r: 1.0, eta: 7.0
# Singular Value: 24.334750717790158, r: 1.0, eta: 7.5
# Singular Value: 25.365791192639758, r: 1.0, eta: 8.0
# Singular Value: 26.16546123117308, r: 0.75, eta: 1.0
# Singular Value: 32.11383097786346, r: 0.75, eta: 1.5
# Singular Value: 37.85493730934153, r: 0.75, eta: 2.0
# Singular Value: 43.339760005411726, r: 0.75, eta: 2.5
# Singular Value: 48.50287593077206, r: 0.75, eta: 3.0
# Singular Value: 53.44159691770789, r: 0.75, eta: 3.5
# Singular Value: 58.19568207506925, r: 0.75, eta: 4.0
# Singular Value: 62.752903398984735, r: 0.75, eta: 4.5
# Singular Value: 67.12914609008313, r: 0.75, eta: 5.0
# Singular Value: 71.34032984524673, r: 0.75, eta: 5.5
# Singular Value: 75.40073137542456, r: 0.75, eta: 6.0
# Singular Value: 79.32955351195719, r: 0.75, eta: 6.5
# Singular Value: 83.15627664972752, r: 0.75, eta: 7.0
# Singular Value: 86.92857929080155, r: 0.75, eta: 7.5
# Singular Value: 90.91460861980497, r: 0.75, eta: 8.0
# Singular Value: 168.83745202339327, r: 0.5, eta: 1.0
# Singular Value: 252.50922186116375, r: 0.5, eta: 1.5
# Singular Value: 294.83327938172437, r: 0.5, eta: 3.0
# Singular Value: 344.9215583086088, r: 0.5, eta: 3.5
# Singular Value: 369.67666593685703, r: 0.5, eta: 2.0
# Singular Value: 471.3236598508317, r: 0.5, eta: 4.0
# Singular Value: 514.9972454099924, r: 0.5, eta: 2.5
# Singular Value: 1456.5629308031916, r: 0.5, eta: 4.5
# Singular Value: 2110.9968541475328, r: 0.5, eta: 7.0
# Singular Value: 2619.019136025932, r: 0.5, eta: 5.0
# Singular Value: 4404.546505777711, r: 0.5, eta: 5.5
# Singular Value: 4841.768375412775, r: 0.5, eta: 7.5
# Singular Value: 6701.92502027815, r: 0.5, eta: 6.0
# Singular Value: 8444.805033540018, r: 0.5, eta: 6.5
# Singular Value: 12987.912909869086, r: 0.5, eta: 8.0
# [np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.False_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_, np.True_]

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import scipy.special
import os
import pickle
from sigfig import round

# Grid values for ellipses
r_ellipses = [0.5, 0.75, 1, 1.25, 1.5, 1.75, 2, 2.25, 2.5, 2.75, 3, 3.25, 3.5, 3.75, 4]
eta_ellipses = [0, 0.5, 1, 1.5, 2, 2.5, 3, 3.5, 4, 4.5, 5, 5.5, 6, 6.5, 7, 7.5, 8]
R_ellipses, Eta_ellipses = np.meshgrid(r_ellipses, eta_ellipses)

# Finer grid values for the contour plot
r_contour = [round(i*0.01 + 0.5, sigfigs=2) for i in range(-10, 360)]
eta_contour = [round(j*0.02 + 1, sigfigs=2) for j in range(-50, 400)]
R_contour, Eta_contour = np.meshgrid(r_contour, eta_contour)

# Directory for storing Hessian matrices
hessian_dir = 'hessian_matrices'
os.makedirs(hessian_dir, exist_ok=True)

# Function to generate a file path for a given (r, eta) pair
def get_hessian_path(r_val, eta_val):
    return os.path.join(hessian_dir, f'hessian_R{r_val}_Eta{eta_val}.pkl')

# Function to calculate variance_prior
def variance_prior(r, eta, scale=1):
    beta = (eta + 1.5) / r
    var_prior = scale * scipy.special.gamma(beta + 1 / r) / scipy.special.gamma(beta)
    return var_prior

# Hessian function
def hessian(r, eta):
    return np.array([[r, 0], [0, eta]])

# Example function to check if a matrix is positive definite
def is_pos_def(matrix):
    return np.all(np.linalg.eigvals(matrix) > 0)

# Initialize grid for var_prior values for the contour plot
var_prior_values = variance_prior(R_contour, Eta_contour)

# Plotting
fig, ax = plt.subplots(figsize=(10, 8))
ax.set_xlabel('r (shape parameter)', fontsize=18)
ax.set_ylabel('η (scale parameter)', fontsize=18)
ax.set_title('Figure 2: KL Statistics Sensitivity', fontsize=20)

# Set x and y axis limits
ax.set_xlim(0, 4)
ax.set_ylim(0, 8)

# Overlay contour plot with reduced opacity and no labels
log_levels = np.logspace(np.log10(np.min(var_prior_values)), np.log10(np.max(var_prior_values)), 150)
contour = ax.contour(R_contour, Eta_contour, np.log10(var_prior_values), levels=np.log10(log_levels), cmap='cividis', alpha=0.7, linewidths=0.8)

# Add colorbar
cbar = fig.colorbar(contour, ax=ax)
cbar.set_label('Log(Variance)', fontsize=18)
cbar.ax.tick_params(labelsize=12)

# Plot ellipses
scale_factor = 0.01
rows, cols = R_ellipses.shape  # Get correct dimensions of the meshgrid

for i in range(rows):  # Loop over rows
    for j in range(cols):  # Loop over columns
        hessian_path = get_hessian_path(R_ellipses[i, j], Eta_ellipses[i, j])
        
        # Check if the Hessian matrix is already stored
        if os.path.exists(hessian_path):
            with open(hessian_path, 'rb') as f:
                H = pickle.load(f)
        else:
            print(i, j)
            # Calculate the Hessian matrix if not already stored
            H = hessian(R_ellipses[i, j], Eta_ellipses[i, j])
            # Store the Hessian matrix in a pickle file
            with open(hessian_path, 'wb') as f:
                pickle.dump(H, f)
        
        U, s, Vt = np.linalg.svd(H)
        angle = np.arctan2(U[0, 1], U[0, 0]) * 180 / np.pi  # Convert radian to degree
        width, height = scale_factor / np.sqrt(s[0]), scale_factor / np.sqrt(s[1])  # Axis lengths
        ellipse = patches.Ellipse((R_ellipses[i, j], Eta_ellipses[i, j]), width, height, angle=angle, edgecolor='red', facecolor='none')
        ax.add_patch(ellipse)

# Customize tick parameters
ax.tick_params(axis='both', which='major', labelsize=16)

# Show the plot
plt.show()
# Out:
# C:\Users\24340\AppData\Local\Temp\ipykernel_24316\2027700233.py:15: UserWarning: 2 significant figures requested from number with only 1 significant figures
#   r_contour = [round(i*0.01 + 0.5, sigfigs=2) for i in range(-10, 360)]
# C:\Users\24340\AppData\Local\Temp\ipykernel_24316\2027700233.py:16: UserWarning: 2 significant figures requested from number with only 1 significant figures
#   eta_contour = [round(j*0.02 + 1, sigfigs=2) for j in range(-50, 400)]
# C:\Users\24340\AppData\Local\Temp\ipykernel_24316\2027700233.py:85: RuntimeWarning: divide by zero encountered in scalar divide
#   width, height = scale_factor / np.sqrt(s[0]), scale_factor / np.sqrt(s[1])  # Axis lengths
# c:\Users\24340\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\transforms.py:2057: RuntimeWarning: invalid value encountered in scalar multiply
#   self._mtx[1, 0] *= sy
# c:\Users\24340\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\transforms.py:2059: RuntimeWarning: invalid value encountered in scalar multiply
#   self._mtx[1, 2] *= sy
