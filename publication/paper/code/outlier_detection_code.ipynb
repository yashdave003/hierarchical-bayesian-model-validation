# %%
import os
import git
from pathlib import Path

ROOT_DIR =  Path(git.Repo('.', search_parent_directories=True).working_tree_dir)
SAVE_FIGS = False

os.chdir(os.path.join(ROOT_DIR, "utilities"))
from testing import * # If MATLAB is not installed, open utilities and set to False
from plotting import *
from reporting import *
plots_path = os.path.join(ROOT_DIR, "publication", "paper", "draft_plots")
save_path_with_hull = Path(os.path.join(ROOT_DIR, 'publication', 'paper', 'CSVs', 'final_results_with_hull.pickle'))
main_df = pd.read_pickle(save_path_with_hull)
RERUN=False
np.random.seed(0)

# %%
files_in_transformed_data = os.listdir(os.path.join(ROOT_DIR, "transformed-data"))
files_in_transformed_data = [f for f in files_in_transformed_data if not (f.endswith('-size.pickle') or f.endswith('.csv'))]
files_in_transformed_data = [f for f in files_in_transformed_data if 'standardTesting' not in f]
print(files_in_transformed_data)
# Out:
# ['coco-outdoor-wavelet-diagonal-red.pickle', 'syntheticMRI2D-sagittal-wavelet-vertical.pickle', 'pastis-full-wavelet-diagonal-gray.pickle', 'syntheticMRI3D-full-wavelet-add.pickle', 'coco-outdoor-wavelet-vertical-red.pickle', 'syntheticMRI2D-coronal-wavelet-horizontal.pickle', 'coco-indoor-wavelet-horizontal-red.pickle', 'pastis-full-fourier-blue.pickle', 'segmentAnything-full-wavelet-horizontal-green.pickle', 'agriVision-full-fourier-green.pickle', 'coco-indoor-wavelet-diagonal-green.pickle', 'syntheticMRI2D-sagittal-wavelet-diagonal.pickle', 'agriVision-full-wavelet-horizVert-green.pickle', 'syntheticMRI3D-full-wavelet-dad.pickle', 'syntheticMRI2D-axial-wavelet-diagonal.pickle', 'spaceNet-full-wavelet-horizVert-gray.pickle', 'coco-indoor-wavelet-horizontal-blue.pickle', 'coco-indoor-wavelet-vertical-gray.pickle', 'coco-outdoor-wavelet-diagonal-gray.pickle', 'syntheticMRI3D-full-wavelet-dda.pickle', 'coco-outdoor-wavelet-horizontal-blue.pickle', 'agriVision-full-wavelet-diagonal-red.pickle', 'segmentAnything-full-wavelet-diagonal-gray.pickle', 'syntheticMRI2D-axial-wavelet-vertical.pickle', 'spaceNet-full-wavelet-diagonal-green.pickle', 'spaceNet-full-fourier-blue.pickle', 'agriVision-full-wavelet-diagonal-green.pickle', 'agriVision-full-fourier-blue.pickle', 'segmentAnything-full-wavelet-diagonal-green.pickle', 'agriVision-full-fourier-red.pickle', 'coco-indoor-learned.pickle', 'segmentAnything-full-wavelet-vertical-gray.pickle', 'segmentAnything-full-wavelet-horizontal-red.pickle', 'segmentAnything-full-wavelet-horizontal-gray.pickle', 'coco-outdoor-wavelet-vertical-gray.pickle', 'agriVision-full-wavelet-horizVert-gray.pickle', 'spaceNet-full-wavelet-diagonal-blue.pickle', 'coco-indoor-wavelet-diagonal-gray.pickle', 'pastis-full-wavelet-horizVert-red.pickle', 'spaceNet-full-fourier-green.pickle', 'coco-outdoor-wavelet-diagonal-green.pickle', 'coco-outdoor-wavelet-horizontal-red.pickle', 'agriVision-full-wavelet-diagonal-blue.pickle', 'pastis-full-wavelet-horizVert-blue.pickle', 'coco-indoor.pickle', 'pastis-full-fourier-green.pickle', 'coco-indoor-wavelet-learned.pickle', 'spaceNet-full-learned.pickle', 'coco-outdoor-wavelet-vertical-green.pickle', 'pastis-full-wavelet-diagonal-blue.pickle', 'pastis-full-learned.pickle', 'spaceNet-full-wavelet-diagonal-red.pickle', 'pastis-full-fourier-red.pickle', 'agriVision-full-wavelet-horizVert-red.pickle', 'pastis-full-fourier-gray.pickle', 'coco-outdoor-wavelet-diagonal-blue.pickle', 'coco-outdoor-wavelet-horizontal-gray.pickle', 'coco-indoor-wavelet-horizontal-gray.pickle', 'spaceNet-full-wavelet-horizVert-blue.pickle', 'segmentAnything-full-wavelet-vertical-green.pickle', 'coco-indoor-wavelet-vertical-blue.pickle', 'segmentAnything-full-learned.pickle', 'coco-indoor-wavelet-diagonal-red.pickle', 'spaceNet-full-wavelet-horizVert-red.pickle', 'spaceNet-full-fourier-gray.pickle', 'segmentAnything-full-wavelet-diagonal-blue.pickle', 'coco-indoor-wavelet-vertical-red.pickle', 'segmentAnything-full-wavelet-vertical-blue.pickle', 'spaceNet-full-fourier-red.pickle', 'agriVision-full-fourier-gray.pickle', 'pastis-full-wavelet-horizVert-green.pickle', 'coco-outdoor-wavelet-horizontal-green.pickle', 'agriVision-full-learned.pickle', 'coco-outdoor-learned.pickle', 'agriVision-full-wavelet-horizVert-blue.pickle', 'spaceNet-full-wavelet-diagonal-gray.pickle', 'coco-indoor-wavelet-diagonal-blue.pickle', 'syntheticMRI3D-full-wavelet-daa.pickle', 'syntheticMRI3D-full-wavelet-ddd.pickle', 'segmentAnything-full-wavelet-horizontal-blue.pickle', 'coco-outdoor-wavelet-vertical-blue.pickle', 'pastis-full-wavelet-diagonal-red.pickle', 'pastis-full-wavelet-diagonal-green.pickle', 'syntheticMRI2D-coronal-wavelet-vertical.pickle', 'syntheticMRI2D-sagittal-wavelet-horizontal.pickle', 'spaceNet-full-wavelet-horizVert-green.pickle', 'segmentAnything-full-wavelet-vertical-red.pickle', 'coco-indoor-wavelet-horizontal-green.pickle', 'syntheticMRI3D-full-wavelet-aad.pickle', 'coco-indoor-wavelet-vertical-green.pick ...

# %%
bad_files = ["coco-indoor.pickle", "coco-indoor-wavelet-learned.pickle"]

# %%
results = []
for file in files_in_transformed_data:
    name = file[:-7]
    name_parts = name.split('-')
    if file in bad_files:
        continue
    dataset, subset, transform,  = name.split('-')[:3]
    if dataset == "syntheticMRI2D":
        orientation = name_parts[3]
        channel = np.nan
    elif dataset == "syntheticMRI3D":
        orientation = name_parts[3]
        channel = np.nan
    elif transform == "fourier":
        orientation = "fourier"
        channel = name_parts[3]
    elif transform == "learned":
        orientation = "learned"
        channel = "learned"
    else:
        orientation = name_parts[3]
        channel = name_parts[4]
    data_dict = pd.read_pickle(os.path.join(ROOT_DIR, "transformed-data", file))
    for group in data_dict.keys():
        data = np.sort(data_dict[group])
        if len(data) == 0:
            continue
        result_df = pd.DataFrame({
            'dataset': [dataset],
            'subset': [subset],
            'transform': [transform],
            'orientation': [orientation],
            'channel': [channel],
            'largest': [data[-1]],
            '5th_largest': [data[-5] if len(data) >= 5 else np.nan],
            '10th_largest': [data[-10] if len(data) >= 10 else np.nan],
            'smallest': [data[0]],
            '5th_smallest': [data[4] if len(data) >= 5 else np.nan],
            '10th_smallest': [data[9] if len(data) >= 10 else np.nan]
        })
        results.append(result_df)
big_df = pd.concat(results, ignore_index=True)
# Out:
#        dataset subset transform orientation  channel      largest  \
# 0   agriVision   full   fourier     fourier     blue   879.080903
# 1   agriVision   full   fourier     fourier     gray   765.249209
# 2   agriVision   full   fourier     fourier    green   917.181420
# 3   agriVision   full   fourier     fourier      red  1174.376641
# 4   agriVision   full   learned     learned  learned   753.729710
# ..         ...    ...       ...         ...      ...          ...
# 73    spaceNet   full   wavelet    diagonal      red   268.866453
# 74    spaceNet   full   wavelet   horizVert     blue   478.770991
# 75    spaceNet   full   wavelet   horizVert     gray   436.208920
# 76    spaceNet   full   wavelet   horizVert    green   466.449742
# 77    spaceNet   full   wavelet   horizVert      red   421.991972
#
#     5th_largest  10th_largest     smallest  5th_smallest  10th_smallest  \
# 0    277.383149    214.957980  -960.251741   -273.939473    -206.767568
# 1    234.990690    183.808504  -856.438866   -249.705479    -191.983160
# 2    254.866586    196.725627 -1013.762157   -299.996352    -206.670328
# 3    333.328066    236.752563 -1347.064706   -341.205097    -232.859068
# 4    246.595823    188.386164  -767.669439   -252.524204    -190.501899
# ..          ...           ...          ...           ...            ...
# 73   167.152909    144.581975  -213.637369   -165.565024    -149.697336
# 74   300.394093    260.467443  -452.628271   -303.774332    -250.979607
# 75   303.079782    262.380964  -481.099241   -304.339677    -262.242167
# 76   315.608535    273.440251  -515.947244   -320.506719    -281.928197
# 77   287.529461    244.852913  -447.048669   -284.788663    -242.447798
#
#     largest_ratio_5  largest_ratio_10  smallest_ratio_5  smallest_ratio_10
# 0          6.423387          8.763420          6.467639           8.932063
# 1          6.457287          8.609113          6.387079           8.734236
# 2          6.585265          8.792938          6.513617           9.066858
# 3          6.032936          9.033726          6.421487           9.635047
# 4          3.368549          4.413428          3.400447           4.479953
# ..              ...               ...               ...                ...
# 73         2.027077          2.363626          1.794632           2.075392
# 74         2.183963          2.546405          2.168279           2.570690
# 75         1.877307          2.158416          1.999221           2.299987
# 76         1.894506          2.170119          2.048480           2.332926
# 77         1.898958          2.194895          1.972575           2.278712
#
# [78 rows x 15 columns]

# %%
pd.set_option('display.max_rows', None)

# %%
big_df["largest_ratio_5"] = big_df["largest"] / big_df["5th_largest"]
big_df["largest_ratio_10"] = big_df["largest"] / big_df["10th_largest"]
big_df["smallest_ratio_5"] =  big_df["smallest"] / big_df["5th_smallest"]
big_df["smallest_ratio_10"] = big_df["smallest"]/big_df["10th_smallest"]
big_df.groupby(['dataset', 'subset', 'transform', 'orientation', 'channel']).mean().reset_index()
# Out:
#             dataset   subset transform orientation  channel      largest  \
# 0        agriVision     full   fourier     fourier     blue   879.080903
# 1        agriVision     full   fourier     fourier     gray   765.249209
# 2        agriVision     full   fourier     fourier    green   917.181420
# 3        agriVision     full   fourier     fourier      red  1174.376641
# 4        agriVision     full   learned     learned  learned   753.729710
# 5        agriVision     full   wavelet    diagonal     blue  1753.880606
# 6        agriVision     full   wavelet    diagonal     gray  1350.232354
# 7        agriVision     full   wavelet    diagonal    green  1338.255876
# 8        agriVision     full   wavelet    diagonal      red  2021.722946
# 9        agriVision     full   wavelet   horizVert     blue  4433.894446
# 10       agriVision     full   wavelet   horizVert     gray  3595.577834
# 11       agriVision     full   wavelet   horizVert    green  4050.354129
# 12       agriVision     full   wavelet   horizVert      red  5858.775408
# 13             coco   indoor   learned     learned  learned    53.265982
# 14             coco   indoor   wavelet    diagonal     blue    50.060523
# 15             coco   indoor   wavelet    diagonal     gray    45.530041
# 16             coco   indoor   wavelet    diagonal    green    44.837051
# 17             coco   indoor   wavelet    diagonal      red    51.381352
# 18             coco   indoor   wavelet  horizontal     blue    83.291636
# 19             coco   indoor   wavelet  horizontal     gray    76.694991
# 20             coco   indoor   wavelet  horizontal    green    77.484311
# 21             coco   indoor   wavelet  horizontal      red    86.968315
# 22             coco   indoor   wavelet    vertical     blue    80.071571
# 23             coco   indoor   wavelet    vertical     gray    75.549228
# 24             coco   indoor   wavelet    vertical    green    74.821247
# 25             coco   indoor   wavelet    vertical      red    80.877841
# 26             coco  outdoor   learned     learned  learned    69.835588
# 27             coco  outdoor   wavelet    diagonal     blue    55.354183
# 28             coco  outdoor   wavelet    diagonal     gray    52.929403
# 29             coco  outdoor   wavelet    diagonal    green    55.215775
# 30             coco  outdoor   wavelet    diagonal      red    53.753911
# 31             coco  outdoor   wavelet  horizontal     blue    94.542727
# 32             coco  outdoor   wavelet  horizontal     gray    80.575070
# 33             coco  outdoor   wavelet  horizontal    green    82.348179
# 34             coco  outdoor   wavelet  horizontal      red    89.338710
# 35             coco  outdoor   wavelet    vertical     blue    89.392745
# 36             coco  outdoor   wavelet    vertical     gray    83.519292
# 37             coco  outdoor   wavelet    vertical    green    85.615640
# 38             coco  outdoor   wavelet    vertical      red    83.436142
# 39           pastis     full   fourier     fourier     blue     8.853631
# 40           pastis     full   fourier     fourier     gray     7.922263
# 41           pastis     full   fourier     fourier    green     7.662757
# 42           pastis     full   fourier     fourier      red     8.464455
# 43           pastis     full   learned     learned  learned    36.134686
# 44           pastis     full   wavelet    diagonal     blue    66.574170
# 45           pastis     full   wavelet    diagonal     gray    58.398484
# 46           pastis     full   wavelet    diagonal    green    57.222718
# 47           pastis     full   wavelet    diagonal      red    59.168075
# 48           pastis     full   wavelet   horizVert     blue   105.659800
# 49           pastis     full   wavelet   horizVert     gray   100.548902
# 50           pastis     full   wavelet   horizVert    green   101.745558
# 51           pastis     full   wavelet   horizVert      red    99.477359
# 52  segmentAnything     full   learned     learned  learned    51.661543
# 53  segmentAnything     full   wavelet    diagonal     blue    84.642058
# 54  segmentAnything     full   wavelet    diagonal     gray    85.695033
# 55  segmentAnything     full   wavelet    diagonal    green    85.425306
# 56  segmentAnything     full   wavelet    diagonal      red    94.297995
# 57  segmentAnything     full   wavelet  horizontal     blue   170.904339
# 58  segmentAnything     full   wavelet  horizontal     gray   155.072014
# 59  segmentAnything     full   wavelet  horizontal    green   155.181097
# 60  segmentAnything     full   wavelet  horizontal      red   170.764438
# 61  segmentAnything     full   wavelet    vertical     blue   141.883284
# 62  segmentAnything     full   wavelet    vertical     gray   145.527545
# 63  segmentAnything     full   wavelet    vertical    green   148.320899
# 64  segmentAnything     full   wavelet    vertical      red   169.271965
# 65         spaceNet     full   fourier     fourier     blue   156.512927
# 66         spaceNet     full   fourier     fourier     gray   128.873092
# 67         spaceNet     full   fourier     fourier    green   138.345975
# 68         spaceNet     full   fourier     fourier      red   117.759907
# 69         spaceNet     full   learned     learned  learned   188.161616
# 70         spaceNet     full   wavelet    diagonal     blue   279.965333
# 71         spaceNet     full   wavelet    diagonal     gray   277.750512
# 72         spaceNet     full   wavelet    diagonal    green   299.828386
# 73         spaceNet     full   wavelet    diagonal      red   268.866453
# 74         spaceNet     full   wavelet   horizVert     blue   478.770991
# 75         spaceNet     full   wavelet   horizVert     gray   436.208920
# 76         spaceNet     full   wavelet   horizVert    green   466.449742
# 77         spaceNet     full   wavelet   horizVert      red   421.991972
#
#     5th_largest  10th_largest     smallest  5th_smallest  10th_smallest  \
# 0    277.383149    214.957980  -960.251741   -273.939473    -206.767568
# 1    234.990690    183.808504  -856.438866   -249.705479    -191.983160
# 2    254.866586    196.725627 -1013.762157   -299.996352    -206.670328
# 3    333.328066    236.752563 -1347.064706   -341.205097    -232.859068
# 4    246.595823    188.386164  -767.669439   -252.524204    -190.501899
# 5    733.943328    533.779981 -1760.608279   -755.781451    -537.754254
# 6    724.066624    451.700028 -1895.726074   -725.272489    -464.217368
# 7    719.020343    496.676381 -2025.388487   -802.415318    -468.999043
# 8    798.718124    521.769140 -2445.577499   -736.991483    -511.259328
# 9   2188.696108   1575.229341 -3950.164978  -1748.204492   -1241.957928
# 10  1859.076010   1411.737055 -3484.297626  -1442.715486   -1004.503548
# 11  2303.780352   1484.176964 -3498.102863  -1665.048560   -1103.720329
# 12  2035.454547   1428.924339 -4859.363642  -1681.836629   -1233.634863
# 13    19.536110     17.063471   -53.069847    -19.495997     -17.007452
# 14    39.099581     33.533391   -48.810783    -35.265252     -32.774171
# 15    36.753030     31.939737   -44.436369    -33.991145     -32.036430
# 16    36.959869     32.747113   -45.327187    -36.045292     -32.238154
# 17    39.301016     33.757611   -46.048614    -36.716876     -34.262996
# 18    70.231760     63.332906   -86.055289    -65.588155     -60.505909
# 19    64.171516     59.102147   -81.200944    -60.840052     -58.050509
# 20    64.399322     59.731024   -85.074576    -63.577637     -58.788156
# 47         1.426532          1.639003          1.523911           1.721222
# 48         1.363188          1.505494          1.333971           1.451475
# 49         1.339341          1.559119          1.353331           1.521537
# 50         1.374069          1.558056          1.353652           1.497402
# 51         1.311531          1.563943          1.347470           1.542301
# 52         2.641316          2.984926          2.600144           2.940406
# 53         1.998516          2.259610          2.229171           2.498770
# 54         2.201233          2.449515          2.281304           2.535842
# 55         2.173518          2.435302          2.279307           2.539018
# 56         2.203092          2.467911          2.629890           2.939079
# 57         1.823300          2.001893          1.729733           1.900109
# 58         1.899817          2.093292          1.787095           1.956856
# 59         1.887179          2.089250          1.762761           1.948819
# 60         2.002363          2.211408          2.574178           2.828605
# 61         1.854034          2.039197          1.917998           2.120696
# 62         2.016931          2.216478          2.024806           2.224226
# 63         2.018965          2.220938          2.068587           2.290038
# 64         2.343438          2.600197          2.099419           2.308156
# 65         2.724642          3.223263          2.679227           3.183794
# 66         2.400998          2.763133          2.361162           2.739195
# 67         2.372170          2.728548          2.295699           2.648991
# 68         2.377836          2.752468          2.412729           2.795434
# 69         2.615657          3.043571          2.709583           3.156863
# 70         2.072311          2.471074          2.135377           2.509621
# 71         1.977177          2.325797          1.806355           2.091215
# 72         1.995605          2.333179          1.822706           2.100672
# 73         2.027077          2.363626          1.794632           2.075392
# 74         2.183963          2.546405          2.168279           2.570690
# 75         1.877307          2.158416          1.999221           2.299987
# 76         1.894506          2.170119          2.048480           2.332926
# 77         1.898958          2.194895          1.972575           2.278712

# %%
big_df.groupby(['dataset', 'subset', 'transform', 'orientation', 'channel']).median().reset_index()
# Out:
#             dataset   subset transform orientation  channel      largest  \
# 0        agriVision     full   fourier     fourier     blue   797.941162
# 1        agriVision     full   fourier     fourier     gray   671.636383
# 2        agriVision     full   fourier     fourier    green   772.398041
# 3        agriVision     full   fourier     fourier      red   849.578827
# 4        agriVision     full   learned     learned  learned   750.845712
# 5        agriVision     full   wavelet    diagonal     blue   906.662354
# 6        agriVision     full   wavelet    diagonal     gray   823.057373
# 7        agriVision     full   wavelet    diagonal    green  1044.875366
# 8        agriVision     full   wavelet    diagonal      red  1548.329590
# 9        agriVision     full   wavelet   horizVert     blue  1755.130493
# 10       agriVision     full   wavelet   horizVert     gray  1996.648193
# 11       agriVision     full   wavelet   horizVert    green  1828.234985
# 12       agriVision     full   wavelet   horizVert      red  6049.545898
# 13             coco   indoor   learned     learned  learned    56.511479
# 14             coco   indoor   wavelet    diagonal     blue    26.382990
# 15             coco   indoor   wavelet    diagonal     gray    22.892862
# 16             coco   indoor   wavelet    diagonal    green    23.299333
# 17             coco   indoor   wavelet    diagonal      red    25.668771
# 18             coco   indoor   wavelet  horizontal     blue    52.746712
# 19             coco   indoor   wavelet  horizontal     gray    49.579960
# 20             coco   indoor   wavelet  horizontal    green    49.651432
# 21             coco   indoor   wavelet  horizontal      red    53.507612
# 22             coco   indoor   wavelet    vertical     blue    53.970314
# 23             coco   indoor   wavelet    vertical     gray    52.044744
# 24             coco   indoor   wavelet    vertical    green    51.947462
# 25             coco   indoor   wavelet    vertical      red    54.127325
# 26             coco  outdoor   learned     learned  learned    72.349954
# 27             coco  outdoor   wavelet    diagonal     blue    51.770620
# 28             coco  outdoor   wavelet    diagonal     gray    46.790548
# 29             coco  outdoor   wavelet    diagonal    green    47.833040
# 30             coco  outdoor   wavelet    diagonal      red    46.634335
# 31             coco  outdoor   wavelet  horizontal     blue    59.673182
# 32             coco  outdoor   wavelet  horizontal     gray    55.727537
# 33             coco  outdoor   wavelet  horizontal    green    56.142553
# 34             coco  outdoor   wavelet  horizontal      red    54.505569
# 35             coco  outdoor   wavelet    vertical     blue    71.629789
# 36             coco  outdoor   wavelet    vertical     gray    72.378492
# 37             coco  outdoor   wavelet    vertical    green    72.996908
# 38             coco  outdoor   wavelet    vertical      red    75.068153
# 39           pastis     full   fourier     fourier     blue     7.209689
# 40           pastis     full   fourier     fourier     gray     6.519696
# 41           pastis     full   fourier     fourier    green     6.187887
# 42           pastis     full   fourier     fourier      red     7.429936
# 43           pastis     full   learned     learned  learned    34.940015
# 44           pastis     full   wavelet    diagonal     blue    32.452785
# 45           pastis     full   wavelet    diagonal     gray    31.427387
# 46           pastis     full   wavelet    diagonal    green    32.332722
# 47           pastis     full   wavelet    diagonal      red    31.775148
# 48           pastis     full   wavelet   horizVert     blue    68.473244
# 49           pastis     full   wavelet   horizVert     gray    60.562031
# 50           pastis     full   wavelet   horizVert    green    60.615288
# 51           pastis     full   wavelet   horizVert      red    57.460346
# 52  segmentAnything     full   learned     learned  learned    50.203212
# 53  segmentAnything     full   wavelet    diagonal     blue    57.662136
# 54  segmentAnything     full   wavelet    diagonal     gray    51.890823
# 55  segmentAnything     full   wavelet    diagonal    green    51.401821
# 56  segmentAnything     full   wavelet    diagonal      red    51.158951
# 57  segmentAnything     full   wavelet  horizontal     blue    99.774925
# 58  segmentAnything     full   wavelet  horizontal     gray    77.639854
# 59  segmentAnything     full   wavelet  horizontal    green    79.608299
# 60  segmentAnything     full   wavelet  horizontal      red    88.329041
# 61  segmentAnything     full   wavelet    vertical     blue    76.897133
# 62  segmentAnything     full   wavelet    vertical     gray    96.303635
# 63  segmentAnything     full   wavelet    vertical    green    93.048676
# 64  segmentAnything     full   wavelet    vertical      red   119.061684
# 65         spaceNet     full   fourier     fourier     blue    81.781754
# 66         spaceNet     full   fourier     fourier     gray    91.274429
# 67         spaceNet     full   fourier     fourier    green    93.860649
# 68         spaceNet     full   fourier     fourier      red    84.904068
# 69         spaceNet     full   learned     learned  learned   188.437962
# 70         spaceNet     full   wavelet    diagonal     blue   127.032032
# 71         spaceNet     full   wavelet    diagonal     gray   118.185204
# 72         spaceNet     full   wavelet    diagonal    green   129.119850
# 73         spaceNet     full   wavelet    diagonal      red   115.040237
# 74         spaceNet     full   wavelet   horizVert     blue   337.209251
# 75         spaceNet     full   wavelet   horizVert     gray   294.421654
# 76         spaceNet     full   wavelet   horizVert    green   305.255531
