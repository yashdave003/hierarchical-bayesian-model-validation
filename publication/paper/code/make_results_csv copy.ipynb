# %%
import os
import git
from pathlib import Path
from typing import List
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D
import plotly.express as px
import ipywidgets as widgets
from IPython.display import display
import numpy as np
import plotly.graph_objects as go
from IPython.display import clear_output
import scipy
from scipy import stats
from scipy.spatial import ConvexHull
import pylustrator
from scipy.spatial import Delaunay
from scipy.spatial import distance
from sklearn.decomposition import PCA
from tqdm import tqdm
import warnings

warnings.simplefilter("ignore", RuntimeWarning)
ROOT_DIR =  Path(git.Repo('.', search_parent_directories=True).working_tree_dir)
save_path_with_hull = Path(os.path.join(ROOT_DIR, 'publication', 'paper', 'CSVs', 'final_results_with_hull.pickle'))
save_path_without_hull = Path(os.path.join(ROOT_DIR, 'publication', 'paper', 'CSVs', 'final_results.csv'))
plots_path = os.path.join(ROOT_DIR, "publication", "paper", "draft_plots")

# %%
def variance_prior(r, eta, scale=1):
    beta = (eta+1.5)/r
    var_prior = scale * scipy.special.gamma(beta + 1/r)/scipy.special.gamma(beta)
    return var_prior

def kurtosis_prior(r, eta, scale=1, fisher=True):
    beta = (eta+1.5)/r
    kurtosis = scale*3*scipy.special.gamma(beta + 2/r)*scipy.special.gamma(beta)/scipy.special.gamma(beta+1/r)**2 # DOUBLE CHECK
    if fisher:
        return kurtosis - 3
    else:
        return kurtosis 

def find_master_dfs(root_dir: str) -> List[str]:
    root_path = Path(root_dir)
    if not root_path.exists():
        raise FileNotFoundError(f"Directory not found: {root_dir}")

    master_df_paths = []
    for current_dir, _, files in os.walk(root_path):
        if 'master_df.csv' in files:
            master_df_path = Path(os.path.join(current_dir, 'master_df.csv'))
            master_df_paths.append(str(master_df_path.absolute()))
    return master_df_paths

# %%
def add_hull(master_df, rEtaKsstats_dict, GROUP='group', debug=False):

    master_df_copy = master_df.copy()
    master_df_copy = master_df.set_index(GROUP)
    groups = master_df_copy.index
    master_df_copy["hull"] = ""

    for group in groups:
        if master_df_copy.loc[group, "total_samples"] < 10:
            master_df_copy.loc[group, "hull"] = np.nan
           
        else:
            drop_keys =list(rEtaKsstats_dict[group].keys())[-3:]
            if debug:
                print(drop_keys)
            pre_optimization = pd.DataFrame(rEtaKsstats_dict[group]).drop(drop_keys, axis = 1 )
            optimization = pd.DataFrame(rEtaKsstats_dict[group])[drop_keys]
            optimization = optimization.rename(columns = {"r_optimize": "r", "eta_optimize": "eta", drop_keys[-1]: "ksstat"})
            optimization = optimization.dropna()
            full_df = pre_optimization.merge(optimization, on=["r", "eta"], how="outer")
            full_df = full_df.set_index(["r", "eta"])
            full_df["ksstat"] = full_df.min(axis=1)
            full_df = full_df.reset_index()
            full_df = full_df[["r", "eta", "ksstat"]]
            full_df["1/beta"] = full_df["r"]/(full_df["eta"] + 1.5)
            full_df["log_beta"] = np.log10((full_df["eta"] + 1.5) / full_df["r"])
            MULT = 1.2
            cutoff = max(min(full_df["ksstat"]) * MULT, 0.01)
            filtered_df = full_df[full_df["ksstat"] < cutoff]
            points = np.column_stack((filtered_df["r"], filtered_df["1/beta"])) + stats.norm.rvs(size=(len(filtered_df), 2)) * 0.001  # Adding small noise for convex hull computation
            #points = np.column_stack((np.log10(filtered_df["r"]), filtered_df["log_beta"])) + stats.norm.rvs(size=(len(filtered_df), 2)) * 0.001  # Adding small noise for convex hull computation
            if len(points) < 3:
                hull=np.nan
                master_df_copy.loc[group, "intersect_roi"] = -1
            else:
                hull = ConvexHull(points)

                #x_vals = np.logspace(0, 20, 1000)
                #eta_vals = 1.5 + np.zeros_like(x_vals)
                #roi = (eta_vals) / x_vals
                
                #line_points = np.column_stack((x_vals, roi))
                #line_points = np.column_stack((np.log10(x_vals), np.log10(roi)))

                #intersect_roi = int(np.any(in_hull(line_points, hull)))
                if np.any(filtered_df["eta"] > 0) and np.any(filtered_df["eta"] < 0):
                    intersect_roi = 1
                else:
                    intersect_roi = 0
                master_df_copy.loc[group, "intersect_roi"] = intersect_roi
            master_df_copy.loc[group, "hull"] = hull

    return master_df_copy.reset_index()

# %%
def process_rEtaKsstats_dict(master_df_original, rEtaKsstats_dict, GROUP='group', debug=False):

    master_df = master_df_original.copy()
    master_df = master_df_original.set_index(GROUP)
    groups = master_df.index
    master_df["hull"] = ""

    for group in groups:
        if master_df.loc[group, "total_samples"] < 10:
            master_df.loc[group, "hull"] = np.nan
           
        else:
            drop_keys =list(rEtaKsstats_dict[group].keys())[-3:]
            if debug:
                print(drop_keys)
            pre_optimization = pd.DataFrame(rEtaKsstats_dict[group]).drop(drop_keys, axis = 1 )
            optimization = pd.DataFrame(rEtaKsstats_dict[group])[drop_keys]
            optimization = optimization.rename(columns = {"r_optimize": "r", "eta_optimize": "eta", drop_keys[-1]: "ksstat"})
            optimization = optimization.dropna()

            full_df = pre_optimization.merge(optimization, on=["r", "eta"], how="outer")
            full_df = full_df.set_index(["r", "eta"])
            full_df["ksstat"] = full_df.min(axis=1)
            full_df = full_df.reset_index()
            full_df = full_df[["r", "eta", "ksstat"]]
            full_df["1/beta"] = full_df["r"]/(full_df["eta"] + 1.5)
            
            MULT = 1.2
            cutoff = max(min(full_df["ksstat"]) * MULT, 0.01)
            filtered_df = full_df[full_df["ksstat"] < cutoff]
            points = np.column_stack((filtered_df["r"], filtered_df["1/beta"])) + stats.norm.rvs(size=(len(filtered_df), 2)) * 0.001  # Adding small noise for convex hull computation
            
            if len(points) < 3:
                hull=np.nan
                hull_area = 0
                intersect_roi = -1
            else:
                hull = ConvexHull(points)
                hull_area = hull.volume

                if np.any(filtered_df["eta"] > 0) and np.any(filtered_df["eta"] < 0):
                    intersect_roi = 1
                else:
                    intersect_roi = 0

            master_df.loc[group, "hull"] = hull    
            master_df.loc[group, "hull_area"] = hull_area
            master_df.loc[group, "intersect_roi"] = intersect_roi

            kurt_lower, kurt_upper = master_df.loc[group, "kurt_lower"], master_df.loc[group, "kurt_upper"]
            best_scale = master_df.loc[group, "best_scale"]

            kurt_df = full_df.copy()
            kurt_df['kurt'] = kurt_df.apply(lambda row : kurtosis_prior(r=row['r'], eta=row['eta'], scale=best_scale), axis=1)
            kurt_df['pass_kurt'] = (kurt_df['kurt'] > kurt_lower) & (kurt_df['kurt'] < kurt_upper)

            pass_kurt_anywhere = np.sum(kurt_df['pass_kurt'] > 0)
            if pass_kurt_anywhere >= 3:
                temp = kurt_df[kurt_df['pass_kurt'] == 1]
                points_kurt = np.column_stack((temp["r"], temp["1/beta"])) + stats.norm.rvs(size=(len(temp), 2)) * 0.001
                hull_kurt = ConvexHull(points_kurt)
                hull_kurt_area = hull_kurt.volume
            else:
                hull_kurt = np.nan
                hull_kurt_area = 0

            master_df.loc[group, "hull_kurt"] = hull_kurt
            master_df.loc[group, "hull_kurt_area"] = hull_kurt_area
            master_df.loc[group, "num_pass_kurt_anywhere"] = pass_kurt_anywhere
            master_df.loc[group, "pass_kurt_anywhere"] = int(pass_kurt_anywhere > 0)
            master_df.loc[group, "num_pass_kurt_intersect_hull"] = np.sum((kurt_df['pass_kurt'] == 1) & (kurt_df['ksstat'] < cutoff))
            master_df.loc[group, "pass_kurt_intersect_hull"] = int(master_df.loc[group, "num_pass_kurt_intersect_hull"] > 0)

    return master_df.reset_index()

# %%
all_paths = find_master_dfs(os.path.join(ROOT_DIR, "results", "case-studies"))
all_paths[:10]
# Out:
# ['c:\\Users\\yashd\\Desktop\\hierarchical-bayesian-model-validation\\results\\case-studies\\agriVision\\full\\fourier\\blue\\CSVs\\master_df.csv',
#  'c:\\Users\\yashd\\Desktop\\hierarchical-bayesian-model-validation\\results\\case-studies\\agriVision\\full\\fourier\\gray\\CSVs\\master_df.csv',
#  'c:\\Users\\yashd\\Desktop\\hierarchical-bayesian-model-validation\\results\\case-studies\\agriVision\\full\\fourier\\green\\CSVs\\master_df.csv',
#  'c:\\Users\\yashd\\Desktop\\hierarchical-bayesian-model-validation\\results\\case-studies\\agriVision\\full\\fourier\\red\\CSVs\\master_df.csv',
#  'c:\\Users\\yashd\\Desktop\\hierarchical-bayesian-model-validation\\results\\case-studies\\agriVision\\full\\learned\\CSVs\\master_df.csv',
#  'c:\\Users\\yashd\\Desktop\\hierarchical-bayesian-model-validation\\results\\case-studies\\agriVision\\full\\wavelet\\diagonal\\blue\\CSVs\\master_df.csv',
#  'c:\\Users\\yashd\\Desktop\\hierarchical-bayesian-model-validation\\results\\case-studies\\agriVision\\full\\wavelet\\diagonal\\gray\\CSVs\\master_df.csv',
#  'c:\\Users\\yashd\\Desktop\\hierarchical-bayesian-model-validation\\results\\case-studies\\agriVision\\full\\wavelet\\diagonal\\green\\CSVs\\master_df.csv',
#  'c:\\Users\\yashd\\Desktop\\hierarchical-bayesian-model-validation\\results\\case-studies\\agriVision\\full\\wavelet\\diagonal\\red\\CSVs\\master_df.csv',
#  'c:\\Users\\yashd\\Desktop\\hierarchical-bayesian-model-validation\\results\\case-studies\\agriVision\\full\\wavelet\\horizVert\\blue\\CSVs\\master_df.csv']

# %%
relevant_cols = [
        'group', 'dataset', 'subset', 'transform', 'orientation', 'channel', 'dataset_type', 
        'obs_var', 'var_lower', 'var_upper', 
        'total_samples', 'initial_r', 'initial_eta',  'best_r', 'best_eta', 'best_scale',
        'kstest_stat_initial', 'kstest_stat_cutoff_0.05', 'kstest_stat_best',
        'obs_kurt', 'kurt_lower', 'kurt_upper', 
        'intersect_roi', 'hull', 'hull_area',
        'num_pass_kurt_anywhere', 'pass_kurt_anywhere', 'num_pass_kurt_intersect_hull', 'pass_kurt_intersect_hull', 'hull_kurt', 'hull_kurt_area',
        'param_gaussian', 'kstest_stat_gaussian', 'kstest_pval_gaussian', 
        'param_laplace', 'kstest_stat_laplace', 'kstest_pval_laplace', 
        'param_t', 'kstest_stat_t', 'kstest_pval_t', 'kstest_pval_gengamma', 
        'github_plot']

all_paths = find_master_dfs(os.path.join(ROOT_DIR, "results", "case-studies"))
all_master_dfs = []
github_plots_path = "https://github.com/yashdave003/hierarchical-bayesian-model-validation/blob/main/results/case-studies/"

for i in tqdm(range(len(all_paths))):
    path = all_paths[i]
    if 'scaleTesting' in path:
        continue
    master_df = pd.read_csv(path)
    master_df = master_df.rename(columns={master_df.columns[0]: 'group'})
    parts = Path(path).parts[-7:]
    if parts[0] == 'case-studies':
        parts = parts[1:]
    elif parts[0] == 'results':
        parts = parts[2:]
    if "MRI" in path:
        dataset, slice, transform, orientation, _, _ = parts
        master_df['dataset'] = dataset
        master_df['transform'] = transform
        master_df['subset'] = slice
        master_df['channel'] = np.nan
        master_df['orientation'] = orientation
        master_df['github_plot'] = [github_plots_path+'/'.join([dataset, slice, transform, orientation, 'plots', f'compare_cdf_pdf_layer_{group}.jpg']) for group in master_df['group']]
    elif len(parts) > 6:
        dataset, subset, transform, orientation, channel, _, _ = parts
        master_df['dataset'] = dataset
        master_df['transform'] = transform
        master_df['subset'] = subset
        master_df['channel'] = channel
        master_df['orientation'] = orientation
        master_df['github_plot'] = [github_plots_path+'/'.join([dataset, subset, transform, orientation, channel, 'plots', f'compare_cdf_pdf_layer_{group}.jpg']) for group in master_df['group']]
    elif "learned" in path:
        dataset, subset, transform, _, _ = parts
        master_df['dataset'] = dataset
        master_df['transform'] = transform
        master_df['subset'] = subset
        master_df = master_df.rename(columns={'filter_group' : 'orientation'})
        master_df['channel'] = np.nan
        master_df['github_plot'] = [github_plots_path+'/'.join([dataset, subset, transform, 'plots', f'compare_cdf_pdf_layer_{group}.jpg']) for group in master_df['group']]

    else:
        dataset, size, transform, channel, _, _ = parts
        master_df['dataset'] = dataset
        master_df['transform'] = transform
        master_df['subset'] = size
        master_df['channel'] = channel
        master_df['orientation'] = np.nan
        master_df['github_plot'] = [github_plots_path+'/'.join([dataset, size, transform, channel, 'plots', f'compare_cdf_pdf_layer_{group}.jpg']) for group in master_df['group']]
    
    if dataset in ['pastis', 'agriVision', 'spaceNet']:
        master_df['dataset_type'] = 'remote sensing'
    elif dataset in ['syntheticMRI2D', 'syntheticMRI3D']:
        master_df['dataset_type'] = 'medical'
    elif dataset in ['coco', 'segmentAnything', 'standardTesting']:
        master_df['dataset_type'] = 'natural'
    elif dataset in ['standardTesting']:
        master_df['dataset_type'] = 'classical'

    GROUP = 'layer' if transform.split("-")[0] == 'wavelet' else ('band' if transform.split("-")[0] == 'fourier' else 'filter_idx')
    rEtaKsstatsDict = pd.read_pickle(path[:-18] + "cache" + os.sep + "rEtaKsstats_dict.pickle")
    
    master_df = process_rEtaKsstats_dict(master_df, rEtaKsstatsDict)
    all_master_dfs.append(master_df[relevant_cols])
    
main_df = pd.concat(all_master_dfs)

main_df['best_beta'] = (main_df['best_eta'] + 1.5)/main_df['best_r'] 
main_df['best_1/beta'] = 1/main_df['best_beta']
main_df['beat_all_priors'] = (main_df['kstest_stat_best'] < np.minimum.reduce([main_df['kstest_stat_gaussian'], main_df['kstest_stat_laplace'], main_df['kstest_stat_t']])).astype(int)
main_df["best_prior"] = np.array(["GenGamma", "Gaussian", "Laplace", "Student-T", np.nan])[
                                np.nanargmin(np.array([main_df['kstest_stat_best'], 
                                                        main_df['kstest_stat_gaussian'], 
                                                        main_df['kstest_stat_laplace'], 
                                                        main_df['kstest_stat_t'], 
                                                        0.99*np.ones_like(main_df['kstest_stat_t'])]
                                                        ).T, axis=1)]

print("Main DF (before frequency):", main_df.shape)
frequency_map = pd.read_csv(os.path.join(ROOT_DIR, "transformed-data", "master-frequency-map.csv")).set_index(['dataset', 'transform', 'group'])
main_df = main_df.set_index(['dataset', 'subset', 'transform', 'group']).merge(frequency_map, left_index = True, right_index=True, how='left').reset_index()

print("Main DF (after frequency):", main_df.shape)
old_fail_cat_df_path = os.path.join(ROOT_DIR, "publication", "paper", "CSVs", 'result_categorization_sheet - combined_categories.csv')
old_fail_cat_df = pd.read_csv(old_fail_cat_df_path)
main_df = main_df.merge(old_fail_cat_df[['github_plot', 'failure_category', 'failure_type', 'which_ones']], on='github_plot', how='left')
print("Main DF (after result categorization):", main_df.shape)
# Out:
#   4%|▍         | 4/101 [00:08<03:35,  2.22s/it]C:\Users\yashd\AppData\Local\Temp\ipykernel_98108\580829178.py:67: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '<scipy.spatial._qhull.ConvexHull object at 0x0000022EC6CC2E50>' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   master_df.loc[group, "hull_kurt"] = hull_kurt
#  13%|█▎        | 13/101 [00:32<02:58,  2.03s/it]C:\Users\yashd\AppData\Local\Temp\ipykernel_98108\580829178.py:67: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '<scipy.spatial._qhull.ConvexHull object at 0x0000022EC3769310>' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   master_df.loc[group, "hull_kurt"] = hull_kurt
#  14%|█▍        | 14/101 [00:42<06:25,  4.43s/it]C:\Users\yashd\AppData\Local\Temp\ipykernel_98108\580829178.py:67: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '<scipy.spatial._qhull.ConvexHull object at 0x0000022EC6CC11D0>' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   master_df.loc[group, "hull_kurt"] = hull_kurt
#  15%|█▍        | 15/101 [00:44<05:20,  3.73s/it]C:\Users\yashd\AppData\Local\Temp\ipykernel_98108\580829178.py:67: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '<scipy.spatial._qhull.ConvexHull object at 0x0000022EC422FF10>' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   master_df.loc[group, "hull_kurt"] = hull_kurt
#  16%|█▌        | 16/101 [00:46<04:22,  3.08s/it]C:\Users\yashd\AppData\Local\Temp\ipykernel_98108\580829178.py:67: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '<scipy.spatial._qhull.ConvexHull object at 0x0000022EC5610410>' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   master_df.loc[group, "hull_kurt"] = hull_kurt
#  17%|█▋        | 17/101 [00:47<03:31,  2.51s/it]C:\Users\yashd\AppData\Local\Temp\ipykernel_98108\580829178.py:67: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '<scipy.spatial._qhull.ConvexHull object at 0x0000022EC3F7B950>' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   master_df.loc[group, "hull_kurt"] = hull_kurt
#  18%|█▊        | 18/101 [00:48<02:56,  2.13s/it]C:\Users\yashd\AppData\Local\Temp\ipykernel_98108\580829178.py:67: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '<scipy.spatial._qhull.ConvexHull object at 0x0000022E9C43B690>' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   master_df.loc[group, "hull_kurt"] = hull_kurt
#  19%|█▉        | 19/101 [00:50<02:53,  2.12s/it]C:\Users\yashd\AppData\Local\Temp\ipykernel_98108\580829178.py:67: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '<scipy.spatial._qhull.ConvexHull object at 0x0000022EC556A490>' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   master_df.loc[group, "hull_kurt"] = hull_kurt
#  20%|█▉        | 20/101 [00:52<02:40,  1.98s/it]C:\Users\yashd\AppData\Local\Temp\ipykernel_98108\580829178.py:67: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '<scipy.spatial._qhull.ConvexHull object at 0x0000022EC361C750>' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   master_df.loc[group, "hull_kurt"] = hull_kurt
#  21%|██        | 21/101 [00:53<02:20,  1.75s/it]C:\Users\yashd\AppData\Local\Temp\ipykernel_98108\580829178.py:67: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '<scipy.spatial._qhull.ConvexHull object at 0x0000022EC56CE950>' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   master_df.loc[group, "hull_kurt"] = hull_kurt
#  22%|██▏       | 22/101 [00:55<02:08,  1.63s/it]C:\Users\yashd\AppData\Local\Temp\ipykernel_98108\580829178.py:67: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '<scipy.spatial._qhull.ConvexHull object at 0x0000022EC3F5B350>' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   master_df.loc[group, "hull_kurt"] = hull_kurt
#  23%|██▎       | 23/101 [00:57<02:21,  1.81s/it]C:\Users\yashd\AppData\Local\Temp\ipykernel_98108\580829178.py:67: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '<scipy.spatial._qhull.ConvexHull object at 0x0000022EC3BBF550>' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   master_df.loc[group, "hull_kurt"] = hull_kurt
#  24%|██▍       | 24/101 [00:58<02:12,  1.72s/it]C:\Users\yashd\AppData\Local\Temp\ipykernel_98108\580829178.py:67: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '<scipy.spatial._qhull.ConvexHull object at 0x0000022EC376B910>' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   master_df.loc[group, "hull_kurt"] = hull_kurt
#  25%|██▍       | 25/101 [01:00<01:59,  1.58s/it]C:\Users\yashd\AppData\Local\Temp\ipykernel_98108\580829178.py:67: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '<scipy.spatial._qhull.ConvexHull object at 0x0000022EC5AF5FD0>' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   master_df.loc[group, "hull_kurt"] = hull_kurt
#  27%|██▋       | 27/101 [01:14<06:13,  5.04s/it]C:\Users\yashd\AppData\Local\Temp\ipykernel_98108\580829178.py:67: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '<scipy.spatial._qhull.ConvexHull object at 0x0000022EC5749650>' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   master_df.loc[group, "hull_kurt"] = hull_kurt
#  28%|██▊       | 28/101 [01:16<04:52,  4.01s/it]C:\Users\yashd\AppData\Local\Temp\ipykernel_98108\580829178.py:67: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '<scipy.spatial._qhull.ConvexHull object at 0x0000022EC5575C90>' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   master_df.loc[group, "hull_kurt"] = hull_kurt
#  29%|██▊       | 29/101 [01:18<03:58,  3.31s/it]C:\Users\yashd\AppData\Local\Temp\ipykernel_98108\580829178.py:67: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '<scipy.spatial._qhull.ConvexHull object at 0x0000022EC60514D0>' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   master_df.loc[group, "hull_kurt"] = hull_kurt
#  30%|██▉       | 30/101 [01:19<03:12,  2.71s/it]C:\Users\yashd\AppData\Local\Temp\ipykernel_98108\580829178.py:67: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '<scipy.spatial._qhull.ConvexHull object at 0x0000022EC5749550>' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   master_df.loc[group, "hull_kurt"] = hull_kurt
#  31%|███       | 31/101 [01:21<02:47,  2.40s/it]C:\Users\yashd\AppData\Local\Temp\ipykernel_98108\580829178.py:67: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '<scipy.spatial._qhull.ConvexHull object at 0x0000022EC574BED0>' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   master_df.loc[group, "hull_kurt"] = hull_kurt
#  32%|███▏      | 32/101 [01:22<02:33,  2.22s/it]C:\Users\yashd\AppData\Local\Temp\ipykernel_98108\580829178.py:67: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '<scipy.spatial._qhull.ConvexHull object at 0x0000022EC574BC10>' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   master_df.loc[group, "hull_kurt"] = hull_kurt
#  33%|███▎      | 33/101 [01:24<02:18,  2.04s/it]C:\Users\yashd\AppData\Local\Temp\ipykernel_98108\580829178.py:67: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '<scipy.spatial._qhull.ConvexHull object at 0x0000022EC5AD1A50>' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   master_df.loc[group, "hull_kurt"] = hull_kurt
#  34%|███▎      | 34/101 [01:25<02:00,  1.79s/it]C:\Users\yashd\AppData\Local\Temp\ipykernel_98108\580829178.py:67: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '<scipy.spatial._qhull.ConvexHull object at 0x0000022EC5E12C10>' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   master_df.loc[group, "hull_kurt"] = hull_kurt
#  35%|███▍      | 35/101 [01:26<01:47,  1.62s/it]C:\Users\yashd\AppData\Local\Temp\ipykernel_98108\580829178.py:67: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '<scipy.spatial._qhull.ConvexHull object at 0x0000022EC335BB90>' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   master_df.loc[group, "hull_kurt"] = hull_kurt
#  36%|███▌      | 36/101 [01:28<01:39,  1.53s/it]C:\Users\yashd\AppData\Local\Temp\ipykernel_98108\580829178.py:67: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '<scipy.spatial._qhull.ConvexHull object at 0x0000022EC574AA90>' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   master_df.loc[group, "hull_kurt"] = hull_kurt
#  37%|███▋      | 37/101 [01:30<01:48,  1.70s/it]C:\Users\yashd\AppData\Local\Temp\ipykernel_98108\580829178.py:67: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '<scipy.spatial._qhull.ConvexHull object at 0x0000022EC5E126D0>' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   master_df.loc[group, "hull_kurt"] = hull_kurt
#  38%|███▊      | 38/101 [01:31<01:44,  1.65s/it]C:\Users\yashd\AppData\Local\Temp\ipykernel_98108\580829178.py:67: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '<scipy.spatial._qhull.ConvexHull object at 0x0000022EC5B85550>' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   master_df.loc[group, "hull_kurt"] = hull_kurt
#  39%|███▊      | 39/101 [01:33<01:33,  1.51s/it]C:\Users\yashd\AppData\Local\Temp\ipykernel_98108\580829178.py:67: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '<scipy.spatial._qhull.ConvexHull object at 0x0000022EC5778890>' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   master_df.loc[group, "hull_kurt"] = hull_kurt
#  41%|████      | 41/101 [01:35<01:16,  1.27s/it]C:\Users\yashd\AppData\Local\Temp\ipykernel_98108\580829178.py:67: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '<scipy.spatial._qhull.ConvexHull object at 0x0000022EC6051ED0>' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   master_df.loc[group, "hull_kurt"] = hull_kurt
#  42%|████▏     | 42/101 [01:37<01:33,  1.58s/it]C:\Users\yashd\AppData\Local\Temp\ipykernel_98108\580829178.py:67: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '<scipy.spatial._qhull.ConvexHull object at 0x0000022EC6052CD0>' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   master_df.loc[group, "hull_kurt"] = hull_kurt
#  43%|████▎     | 43/101 [01:39<01:31,  1.58s/it]C:\Users\yashd\AppData\Local\Temp\ipykernel_98108\580829178.py:67: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '<scipy.spatial._qhull.ConvexHull object at 0x0000022EC556E590>' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   master_df.loc[group, "hull_kurt"] = hull_kurt
#  44%|████▎     | 44/101 [01:41<01:35,  1.68s/it]C:\Users\yashd\AppData\Local\Temp\ipykernel_98108\580829178.py:67: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '<scipy.spatial._qhull.ConvexHull object at 0x0000022EC56982D0>' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   master_df.loc[group, "hull_kurt"] = hull_kurt
#  45%|████▍     | 45/101 [01:48<03:01,  3.23s/it]C:\Users\yashd\AppData\Local\Temp\ipykernel_98108\580829178.py:67: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '<scipy.spatial._qhull.ConvexHull object at 0x0000022EC5605190>' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   master_df.loc[group, "hull_kurt"] = hull_kurt
#  46%|████▌     | 46/101 [01:50<02:37,  2.86s/it]C:\Users\yashd\AppData\Local\Temp\ipykernel_98108\580829178.py:67: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '<scipy.spatial._qhull.ConvexHull object at 0x0000022EC34DD190>' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   master_df.loc[group, "hull_kurt"] = hull_kurt
#  47%|████▋     | 47/101 [01:52<02:17,  2.55s/it]C:\Users\yashd\AppData\Local\Temp\ipykernel_98108\580829178.py:67: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '<scipy.spatial._qhull.ConvexHull object at 0x0000022EC60538D0>' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   master_df.loc[group, "hull_kurt"] = hull_kurt
#  48%|████▊     | 48/101 [01:53<01:52,  2.13s/it]C:\Users\yashd\AppData\Local\Temp\ipykernel_98108\580829178.py:67: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '<scipy.spatial._qhull.ConvexHull object at 0x0000022EA4FC0050>' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   master_df.loc[group, "hull_kurt"] = hull_kurt
#  49%|████▊     | 49/101 [01:54<01:37,  1.88s/it]C:\Users\yashd\AppData\Local\Temp\ipykernel_98108\580829178.py:67: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '<scipy.spatial._qhull.ConvexHull object at 0x0000022EC33021D0>' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   master_df.loc[group, "hull_kurt"] = hull_kurt
#  50%|████▉     | 50/101 [01:55<01:21,  1.60s/it]C:\Users\yashd\AppData\Local\Temp\ipykernel_98108\580829178.py:67: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '<scipy.spatial._qhull.ConvexHull object at 0x0000022EC5778DD0>' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   master_df.loc[group, "hull_kurt"] = hull_kurt
#  50%|█████     | 51/101 [01:56<01:16,  1.54s/it]C:\Users\yashd\AppData\Local\Temp\ipykernel_98108\580829178.py:67: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '<scipy.spatial._qhull.ConvexHull object at 0x0000022EC33570D0>' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   master_df.loc[group, "hull_kurt"] = hull_kurt
#  51%|█████▏    | 52/101 [01:58<01:12,  1.48s/it]C:\Users\yashd\AppData\Local\Temp\ipykernel_98108\580829178.py:67: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '<scipy.spatial._qhull.ConvexHull object at 0x0000022EC577A090>' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   master_df.loc[group, "hull_kurt"] = hull_kurt
#  55%|█████▌    | 56/101 [02:10<02:01,  2.69s/it]C:\Users\yashd\AppData\Local\Temp\ipykernel_98108\580829178.py:67: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '<scipy.spatial._qhull.ConvexHull object at 0x0000022EC60414D0>' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   master_df.loc[group, "hull_kurt"] = hull_kurt
#  56%|█████▋    | 57/101 [02:12<01:54,  2.60s/it]C:\Users\yashd\AppData\Local\Temp\ipykernel_98108\580829178.py:67: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '<scipy.spatial._qhull.ConvexHull object at 0x0000022EC31A8110>' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   master_df.loc[group, "hull_kurt"] = hull_kurt
#  57%|█████▋    | 58/101 [02:14<01:39,  2.32s/it]C:\Users\yashd\AppData\Local\Temp\ipykernel_98108\580829178.py:67: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '<scipy.spatial._qhull.ConvexHull object at 0x0000022EC5AD0A90>' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   master_df.loc[group, "hull_kurt"] = hull_kurt
#  58%|█████▊    | 59/101 [02:15<01:27,  2.09s/it]C:\Users\yashd\AppData\Local\Temp\ipykernel_98108\580829178.py:67: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '<scipy.spatial._qhull.ConvexHull object at 0x0000022EC5576FD0>' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   master_df.loc[group, "hull_kurt"] = hull_kurt
#  59%|█████▉    | 60/101 [02:17<01:21,  1.99s/it]C:\Users\yashd\AppData\Local\Temp\ipykernel_98108\580829178.py:67: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '<scipy.spatial._qhull.ConvexHull object at 0x0000022EAE90C3D0>' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   master_df.loc[group, "hull_kurt"] = hull_kurt
#  60%|██████    | 61/101 [02:19<01:24,  2.10s/it]C:\Users\yashd\AppData\Local\Temp\ipykernel_98108\580829178.py:67: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '<scipy.spatial._qhull.ConvexHull object at 0x0000022EC5AD05D0>' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   master_df.loc[group, "hull_kurt"] = hull_kurt
#  61%|██████▏   | 62/101 [02:21<01:19,  2.03s/it]C:\Users\yashd\AppData\Local\Temp\ipykernel_98108\580829178.py:67: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '<scipy.spatial._qhull.ConvexHull object at 0x0000022EC32F3850>' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   master_df.loc[group, "hull_kurt"] = hull_kurt
#  62%|██████▏   | 63/101 [02:22<01:09,  1.84s/it]C:\Users\yashd\AppData\Local\Temp\ipykernel_98108\580829178.py:67: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '<scipy.spatial._qhull.ConvexHull object at 0x0000022EC32F1A90>' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   master_df.loc[group, "hull_kurt"] = hull_kurt
#  63%|██████▎   | 64/101 [02:24<01:03,  1.71s/it]C:\Users\yashd\AppData\Local\Temp\ipykernel_98108\580829178.py:67: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '<scipy.spatial._qhull.ConvexHull object at 0x0000022EC56CD850>' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   master_df.loc[group, "hull_kurt"] = hull_kurt
#  64%|██████▍   | 65/101 [02:26<01:03,  1.78s/it]C:\Users\yashd\AppData\Local\Temp\ipykernel_98108\580829178.py:67: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '<scipy.spatial._qhull.ConvexHull object at 0x0000022EC572EDD0>' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   master_df.loc[group, "hull_kurt"] = hull_kurt
#  65%|██████▌   | 66/101 [02:28<01:04,  1.84s/it]C:\Users\yashd\AppData\Local\Temp\ipykernel_98108\580829178.py:67: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '<scipy.spatial._qhull.ConvexHull object at 0x0000022EC3371910>' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   master_df.loc[group, "hull_kurt"] = hull_kurt
#  66%|██████▋   | 67/101 [02:29<00:58,  1.73s/it]C:\Users\yashd\AppData\Local\Temp\ipykernel_98108\580829178.py:67: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '<scipy.spatial._qhull.ConvexHull object at 0x0000022EC33707D0>' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   master_df.loc[group, "hull_kurt"] = hull_kurt
#  67%|██████▋   | 68/101 [02:31<00:55,  1.69s/it]C:\Users\yashd\AppData\Local\Temp\ipykernel_98108\580829178.py:67: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '<scipy.spatial._qhull.ConvexHull object at 0x0000022EC5699B50>' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   master_df.loc[group, "hull_kurt"] = hull_kurt
#  68%|██████▊   | 69/101 [02:33<00:57,  1.79s/it]C:\Users\yashd\AppData\Local\Temp\ipykernel_98108\580829178.py:67: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '<scipy.spatial._qhull.ConvexHull object at 0x0000022EAE823590>' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   master_df.loc[group, "hull_kurt"] = hull_kurt
#  69%|██████▉   | 70/101 [02:34<00:52,  1.69s/it]C:\Users\yashd\AppData\Local\Temp\ipykernel_98108\580829178.py:67: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '<scipy.spatial._qhull.ConvexHull object at 0x0000022EC331A490>' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   master_df.loc[group, "hull_kurt"] = hull_kurt
#  70%|███████   | 71/101 [02:35<00:46,  1.55s/it]C:\Users\yashd\AppData\Local\Temp\ipykernel_98108\580829178.py:67: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '<scipy.spatial._qhull.ConvexHull object at 0x0000022EC3373C90>' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   master_df.loc[group, "hull_kurt"] = hull_kurt
#  72%|███████▏  | 73/101 [02:47<01:51,  3.97s/it]C:\Users\yashd\AppData\Local\Temp\ipykernel_98108\580829178.py:67: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '<scipy.spatial._qhull.ConvexHull object at 0x0000022EC6050210>' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   master_df.loc[group, "hull_kurt"] = hull_kurt
#  73%|███████▎  | 74/101 [02:48<01:28,  3.26s/it]C:\Users\yashd\AppData\Local\Temp\ipykernel_98108\580829178.py:67: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '<scipy.spatial._qhull.ConvexHull object at 0x0000022EC32D8090>' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   master_df.loc[group, "hull_kurt"] = hull_kurt
#  74%|███████▍  | 75/101 [02:49<01:09,  2.65s/it]C:\Users\yashd\AppData\Local\Temp\ipykernel_98108\580829178.py:67: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '<scipy.spatial._qhull.ConvexHull object at 0x0000022EC57A3850>' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   master_df.loc[group, "hull_kurt"] = hull_kurt
#  75%|███████▌  | 76/101 [02:51<00:56,  2.26s/it]C:\Users\yashd\AppData\Local\Temp\ipykernel_98108\580829178.py:67: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '<scipy.spatial._qhull.ConvexHull object at 0x0000022EC32D8210>' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   master_df.loc[group, "hull_kurt"] = hull_kurt
#  76%|███████▌  | 77/101 [02:53<00:53,  2.22s/it]C:\Users\yashd\AppData\Local\Temp\ipykernel_98108\580829178.py:67: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '<scipy.spatial._qhull.ConvexHull object at 0x0000022EC6053B10>' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   master_df.loc[group, "hull_kurt"] = hull_kurt
#  77%|███████▋  | 78/101 [02:54<00:43,  1.88s/it]C:\Users\yashd\AppData\Local\Temp\ipykernel_98108\580829178.py:67: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '<scipy.spatial._qhull.ConvexHull object at 0x0000022EAE7EE7D0>' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   master_df.loc[group, "hull_kurt"] = hull_kurt
#  78%|███████▊  | 79/101 [02:55<00:33,  1.54s/it]C:\Users\yashd\AppData\Local\Temp\ipykernel_98108\580829178.py:67: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '<scipy.spatial._qhull.ConvexHull object at 0x0000022EC331F8D0>' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   master_df.loc[group, "hull_kurt"] = hull_kurt
#  79%|███████▉  | 80/101 [02:55<00:27,  1.31s/it]C:\Users\yashd\AppData\Local\Temp\ipykernel_98108\580829178.py:67: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '<scipy.spatial._qhull.ConvexHull object at 0x0000022EC331DFD0>' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   master_df.loc[group, "hull_kurt"] = hull_kurt
#  80%|████████  | 81/101 [02:56<00:22,  1.15s/it]C:\Users\yashd\AppData\Local\Temp\ipykernel_98108\580829178.py:67: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '<scipy.spatial._qhull.ConvexHull object at 0x0000022EC606D6D0>' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   master_df.loc[group, "hull_kurt"] = hull_kurt
#  81%|████████  | 82/101 [03:06<01:12,  3.80s/it]C:\Users\yashd\AppData\Local\Temp\ipykernel_98108\580829178.py:67: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '<scipy.spatial._qhull.ConvexHull object at 0x0000022EC5B47910>' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   master_df.loc[group, "hull_kurt"] = hull_kurt
#  82%|████████▏ | 83/101 [03:07<00:54,  3.01s/it]C:\Users\yashd\AppData\Local\Temp\ipykernel_98108\580829178.py:67: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '<scipy.spatial._qhull.ConvexHull object at 0x0000022EC3135CD0>' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   master_df.loc[group, "hull_kurt"] = hull_kurt
#  83%|████████▎ | 84/101 [03:09<00:42,  2.48s/it]C:\Users\yashd\AppData\Local\Temp\ipykernel_98108\580829178.py:67: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '<scipy.spatial._qhull.ConvexHull object at 0x0000022EC3359050>' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   master_df.loc[group, "hull_kurt"] = hull_kurt
#  84%|████████▍ | 85/101 [03:11<00:37,  2.34s/it]C:\Users\yashd\AppData\Local\Temp\ipykernel_98108\580829178.py:67: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '<scipy.spatial._qhull.ConvexHull object at 0x0000022EC3372E10>' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   master_df.loc[group, "hull_kurt"] = hull_kurt
#  85%|████████▌ | 86/101 [03:12<00:31,  2.10s/it]C:\Users\yashd\AppData\Local\Temp\ipykernel_98108\580829178.py:67: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '<scipy.spatial._qhull.ConvexHull object at 0x0000022EC5B46B50>' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   master_df.loc[group, "hull_kurt"] = hull_kurt
#  86%|████████▌ | 87/101 [03:13<00:25,  1.79s/it]C:\Users\yashd\AppData\Local\Temp\ipykernel_98108\580829178.py:67: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '<scipy.spatial._qhull.ConvexHull object at 0x0000022EC3371F90>' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   master_df.loc[group, "hull_kurt"] = hull_kurt
#  87%|████████▋ | 88/101 [03:14<00:20,  1.57s/it]C:\Users\yashd\AppData\Local\Temp\ipykernel_98108\580829178.py:67: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '<scipy.spatial._qhull.ConvexHull object at 0x0000022EAE823B10>' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   master_df.loc[group, "hull_kurt"] = hull_kurt
#  88%|████████▊ | 89/101 [03:16<00:18,  1.53s/it]C:\Users\yashd\AppData\Local\Temp\ipykernel_98108\580829178.py:67: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '<scipy.spatial._qhull.ConvexHull object at 0x0000022EC31364D0>' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   master_df.loc[group, "hull_kurt"] = hull_kurt
#  89%|████████▉ | 90/101 [03:18<00:17,  1.63s/it]C:\Users\yashd\AppData\Local\Temp\ipykernel_98108\580829178.py:67: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '<scipy.spatial._qhull.ConvexHull object at 0x0000022EAEACAD50>' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   master_df.loc[group, "hull_kurt"] = hull_kurt
#  90%|█████████ | 91/101 [03:19<00:16,  1.70s/it]C:\Users\yashd\AppData\Local\Temp\ipykernel_98108\580829178.py:67: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '<scipy.spatial._qhull.ConvexHull object at 0x0000022EC3134210>' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   master_df.loc[group, "hull_kurt"] = hull_kurt
#  91%|█████████ | 92/101 [03:21<00:14,  1.62s/it]C:\Users\yashd\AppData\Local\Temp\ipykernel_98108\580829178.py:67: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '<scipy.spatial._qhull.ConvexHull object at 0x0000022EC3311950>' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   master_df.loc[group, "hull_kurt"] = hull_kurt
#  93%|█████████▎| 94/101 [03:32<00:26,  3.75s/it]C:\Users\yashd\AppData\Local\Temp\ipykernel_98108\580829178.py:67: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '<scipy.spatial._qhull.ConvexHull object at 0x0000022EAE964810>' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   master_df.loc[group, "hull_kurt"] = hull_kurt
#  94%|█████████▍| 95/101 [03:38<00:26,  4.41s/it]C:\Users\yashd\AppData\Local\Temp\ipykernel_98108\580829178.py:67: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '<scipy.spatial._qhull.ConvexHull object at 0x0000022EAE9B2D10>' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   master_df.loc[group, "hull_kurt"] = hull_kurt
#  98%|█████████▊| 99/101 [03:52<00:07,  3.59s/it]C:\Users\yashd\AppData\Local\Temp\ipykernel_98108\580829178.py:67: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '<scipy.spatial._qhull.ConvexHull object at 0x0000022EC6040C90>' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   master_df.loc[group, "hull_kurt"] = hull_kurt
# 100%|██████████| 101/101 [03:58<00:00,  2.36s/it]
# Main DF (before frequency): (1155, 46)
# Main DF (after frequency): (1155, 47)
# Main DF (after result categorization): (1155, 50)

# %%
main_df['hull_area'].sort_values(ascending=False)
main_df['hull_kurt_area'].sort_values(ascending=False)
# Out:
# 393     2089.857009
# 838     2070.166597
# 762     2041.607282
# 862     2024.710025
# 386     1990.983568
#            ...
# 1120            NaN
# 1127            NaN
# 1134            NaN
# 1141            NaN
# 1148            NaN
# Name: hull_kurt_area, Length: 1155, dtype: float64

# %%
main_df['intersect_roi'].value_counts()
# Out:
# intersect_roi
#  1.0    600
#  0.0    535
# -1.0      1
# Name: count, dtype: int64

# %%
save_cols = (relevant_cols +
        ['total_samples', 'beat_all_priors', 'best_prior', 'failure_category', 'failure_type', 'which_ones'])

# %%
main_df[save_cols].drop(['hull', 'hull_kurt'], axis=1).to_csv(save_path_without_hull)
pd.to_pickle(main_df[save_cols], save_path_with_hull)

# %%
main_df['total_samples']
# Out:
# 0           45000.0
# 1          117000.0
# 2          189000.0
# 3          495000.0
# 4         1134000.0
#            ...
# 1150        22538.0
# 1151       296776.0
# 1152      2880648.0
# 1153     25362406.0
# 1154    213093688.0
# Name: total_samples, Length: 1155, dtype: float64

# %%
main_df[(main_df["dataset"] == "pastis") & (main_df["transform"] == "fourier")]
# Out:
#     dataset subset transform  group orientation channel    dataset_type  \
# 494  pastis   full   fourier      2         NaN    blue  remote sensing
# 495  pastis   full   fourier      5         NaN    blue  remote sensing
# 496  pastis   full   fourier      8         NaN    blue  remote sensing
# 497  pastis   full   fourier     11         NaN    blue  remote sensing
# 498  pastis   full   fourier     14         NaN    blue  remote sensing
# 499  pastis   full   fourier     17         NaN    blue  remote sensing
# 500  pastis   full   fourier     20         NaN    blue  remote sensing
# 501  pastis   full   fourier     23         NaN    blue  remote sensing
# 502  pastis   full   fourier     26         NaN    blue  remote sensing
# 503  pastis   full   fourier     29         NaN    blue  remote sensing
# 504  pastis   full   fourier     32         NaN    blue  remote sensing
# 505  pastis   full   fourier      2         NaN    gray  remote sensing
# 506  pastis   full   fourier      5         NaN    gray  remote sensing
# 507  pastis   full   fourier      8         NaN    gray  remote sensing
# 508  pastis   full   fourier     11         NaN    gray  remote sensing
# 509  pastis   full   fourier     14         NaN    gray  remote sensing
# 510  pastis   full   fourier     17         NaN    gray  remote sensing
# 511  pastis   full   fourier     20         NaN    gray  remote sensing
# 512  pastis   full   fourier     23         NaN    gray  remote sensing
# 513  pastis   full   fourier     26         NaN    gray  remote sensing
# 514  pastis   full   fourier     29         NaN    gray  remote sensing
# 515  pastis   full   fourier     32         NaN    gray  remote sensing
# 516  pastis   full   fourier      2         NaN   green  remote sensing
# 517  pastis   full   fourier      5         NaN   green  remote sensing
# 518  pastis   full   fourier      8         NaN   green  remote sensing
# 519  pastis   full   fourier     11         NaN   green  remote sensing
# 520  pastis   full   fourier     14         NaN   green  remote sensing
# 521  pastis   full   fourier     17         NaN   green  remote sensing
# 522  pastis   full   fourier     20         NaN   green  remote sensing
# 523  pastis   full   fourier     23         NaN   green  remote sensing
# 524  pastis   full   fourier     26         NaN   green  remote sensing
# 525  pastis   full   fourier     29         NaN   green  remote sensing
# 526  pastis   full   fourier     32         NaN   green  remote sensing
# 527  pastis   full   fourier      2         NaN     red  remote sensing
# 528  pastis   full   fourier      5         NaN     red  remote sensing
# 529  pastis   full   fourier      8         NaN     red  remote sensing
# 530  pastis   full   fourier     11         NaN     red  remote sensing
# 531  pastis   full   fourier     14         NaN     red  remote sensing
# 532  pastis   full   fourier     17         NaN     red  remote sensing
# 533  pastis   full   fourier     20         NaN     red  remote sensing
# 534  pastis   full   fourier     23         NaN     red  remote sensing
# 535  pastis   full   fourier     26         NaN     red  remote sensing
# 536  pastis   full   fourier     29         NaN     red  remote sensing
# 537  pastis   full   fourier     32         NaN     red  remote sensing
#
#        obs_var  var_lower  var_upper  ...  kstest_pval_gengamma  \
# 494  14.564291  13.887027  15.268839  ...          7.991423e-01
# 495   7.681994   7.323771   8.055925  ...          9.880109e-01
# 496   4.073018   3.884318   4.267340  ...          5.915339e-01
# 497   2.242928   2.133372   2.357460  ...          9.987676e-01
# 498   1.177406   1.121854   1.236006  ...          6.728699e-02
# 499   0.631009   0.600541   0.662828  ...          7.788281e-01
# 500   0.301410   0.286417   0.317915  ...          9.781336e-01
# 501   0.134888   0.127928   0.142416  ...          1.374041e-01
# 502   0.053216   0.049692   0.057507  ...          9.966101e-02
# 503   0.018185   0.016213   0.021056  ...          7.764493e-08
# 504   0.001581   0.001508   0.001656  ...          7.917162e-01
# 505  10.134422   9.643435  10.646572  ...          8.381319e-01
# 506   5.424390   5.164831   5.694692  ...          9.489054e-01
# 507   2.974848   2.833664   3.120628  ...          5.008786e-01
# 508   1.695055   1.610400   1.784300  ...          9.311981e-01
# 509   0.926228   0.881725   0.973125  ...          2.457773e-01
# 510   0.518186   0.492855   0.544779  ...          9.994724e-01
# 511   0.260627   0.247789   0.274535  ...          9.555180e-01
# 512   0.122159   0.116055   0.128693  ...          1.633382e-01
# 513   0.049178   0.046151   0.053056  ...          6.432158e-01
# 514   0.015548   0.014031   0.017973  ...          1.047391e-03
# 515   0.001337   0.001274   0.001402  ...          3.933182e-01
# 516  10.047775   9.564716  10.551455  ...          8.167974e-01
# 517   5.438562   5.180850   5.707798  ...          8.517701e-01
# 518   3.018795   2.876773   3.165153  ...          6.000704e-01
# 519   1.740533   1.654402   1.830307  ...          6.841823e-01
# 520   0.964945   0.918967   1.013377  ...          3.399267e-01
# 521   0.544932   0.518553   0.572532  ...          9.951664e-01
# 522   0.277552   0.264042   0.291775  ...          9.442287e-01
# 523   0.131865   0.125401   0.138744  ...          2.176355e-01
# 524   0.054975   0.051767   0.058932  ...          2.427087e-01
# 525   0.019339   0.017729   0.021846  ...          2.313727e-02
# 526   0.002200   0.002098   0.002306  ...          4.849388e-01
# 527   9.598991   9.110358  10.110742  ...          8.638231e-01
# 528   5.091696   4.837473   5.358150  ...          9.836984e-01
# 529   2.783870   2.644551   2.927817  ...          4.761106e-01
# 530   1.574336   1.491815   1.662111  ...          9.373761e-01
# 531   0.857636   0.814612   0.903813  ...          2.437458e-01
# 532   0.483346   0.458738   0.509555  ...          9.793756e-01
# 533   0.247357   0.234671   0.261674  ...          8.938913e-01
# 534   0.120827   0.114650   0.127477  ...          4.272685e-01
# 535   0.052979   0.049797   0.057025  ...          6.881393e-01
# 536   0.020105   0.018494   0.022679  ...          4.929220e-02
# 537   0.002715   0.002586   0.002847  ...          2.505330e-01
#
#                                            github_plot  best_beta  \
# 494  https://github.com/yashdave003/hierarchical-ba...  29.310345
# 495  https://github.com/yashdave003/hierarchical-ba...  12.653061
# 496  https://github.com/yashdave003/hierarchical-ba...   0.562500
# 497  https://github.com/yashdave003/hierarchical-ba...  10.196078
# 498  https://github.com/yashdave003/hierarchical-ba...   9.000000
# 499  https://github.com/yashdave003/hierarchical-ba...   6.190476
# 500  https://github.com/yashdave003/hierarchical-ba...  53.000000
# 501  https://github.com/yashdave003/hierarchical-ba...   6.166667
# 502  https://github.com/yashdave003/hierarchical-ba...  48.421053
# 503  https://github.com/yashdave003/hierarchical-ba...  42.631579
# 504  https://github.com/yashdave003/hierarchical-ba...  72.500000
# 505  https://github.com/yashdave003/hierarchical-ba...  53.000000
# 506  https://github.com/yashdave003/hierarchical-ba...   3.125000
# 507  https://github.com/yashdave003/hierarchical-ba...  30.333333
# 508  https://github.com/yashdave003/hierarchical-ba...  10.600000
# 509  https://github.com/yashdave003/hierarchical-ba...   1.564626
# 510  https://github.com/yashdave003/hierarchical-ba...   5.454545
# 511  https://github.com/yashdave003/hierarchical-ba...   5.873016
# 512  https://github.com/yashdave003/hierarchical-ba...   2.736842
# 513  https://github.com/yashdave003/hierarchical-ba...  47.000000
# 514  https://github.com/yashdave003/hierarchical-ba...  42.500000
# 515  https://github.com/yashdave003/hierarchical-ba...  10.392157
# 516  https://github.com/yashdave003/hierarchical-ba...   1.027027
# 517  https://github.com/yashdave003/hierarchical-ba...   1.197605
# 518  https://github.com/yashdave003/hierarchical-ba...   3.333333
# 519  https://github.com/yashdave003/hierarchical-ba...  31.000000
# 520  https://github.com/yashdave003/hierarchical-ba...   2.195122
# 521  https://github.com/yashdave003/hierarchical-ba...   5.937500
# 522  https://github.com/yashdave003/hierarchical-ba...  13.750000
# 523  https://github.com/yashdave003/hierarchical-ba...  24.000000
# 524  https://github.com/yashdave003/hierarchical-ba...  51.500000
# 525  https://github.com/yashdave003/hierarchical-ba...  47.500000
# 526  https://github.com/yashdave003/hierarchical-ba...   5.270270
# 527  https://github.com/yashdave003/hierarchical-ba...   2.222222
# 528  https://github.com/yashdave003/hierarchical-ba...  49.500000
# 529  https://github.com/yashdave003/hierarchical-ba...  42.173913
# 530  https://github.com/yashdave003/hierarchical-ba...  54.000000
# 531  https://github.com/yashdave003/hierarchical-ba...   9.200000
# 532  https://github.com/yashdave003/hierarchical-ba...   8.400000
# 533  https://github.com/yashdave003/hierarchical-ba...   7.222222
# 534  https://github.com/yashdave003/hierarchical-ba...  48.500000
# 535  https://github.com/yashdave003/hierarchical-ba...  48.000000
# 536  https://github.com/yashdave003/hierarchical-ba...  45.500000
# 537  https://github.com/yashdave003/hierarchical-ba...   1.796875
#
#      best_1/beta  beat_all_priors  best_prior  frequency  failure_category  \
# 494     0.034118                1    GenGamma   0.061242     actually_pass
# 495     0.079032                1    GenGamma   0.078689     actually_pass
# 496     1.777778                1    GenGamma   0.098453     actually_pass
# 497     0.098077                1    GenGamma   0.123565     actually_pass
# 498     0.111111                1    GenGamma   0.155566     actually_pass
# 499     0.161538                1    GenGamma   0.196261     actually_pass
# 500     0.018868                1    GenGamma   0.247131     actually_pass
# 501     0.162162                1    GenGamma   0.311794     actually_pass
# 502     0.020652                1    GenGamma   0.392401     actually_pass
# 503     0.023457                1    GenGamma   0.493909  practically_pass
# 504     0.013793                1    GenGamma   0.622863     actually_pass
# 505     0.018868                1    GenGamma   0.061242     actually_pass
# 506     0.320000                1    GenGamma   0.078689     actually_pass
# 507     0.032967                1    GenGamma   0.098453     actually_pass
# 508     0.094340                1    GenGamma   0.123565     actually_pass
# 509     0.639130                1    GenGamma   0.155566     actually_pass
# 510     0.183333                1    GenGamma   0.196261     actually_pass
# 511     0.170270                1    GenGamma   0.247131     actually_pass
# 512     0.365385                1    GenGamma   0.311794     actually_pass
# 513     0.021277                1    GenGamma   0.392401     actually_pass
# 514     0.023529                1    GenGamma   0.493909  practically_pass
# 515     0.096226                1    GenGamma   0.622863     actually_pass
# 516     0.973684                1    GenGamma   0.061242     actually_pass
# 517     0.835000                1    GenGamma   0.078689     actually_pass
# 518     0.300000                1    GenGamma   0.098453     actually_pass
# 519     0.032258                1    GenGamma   0.123565     actually_pass
# 520     0.455556                1    GenGamma   0.155566     actually_pass
# 521     0.168421                1    GenGamma   0.196261     actually_pass
# 522     0.072727                1    GenGamma   0.247131     actually_pass
# 523     0.041667                1    GenGamma   0.311794     actually_pass
# 524     0.019417                1    GenGamma   0.392401     actually_pass
# 525     0.021053                1    GenGamma   0.493909  practically_pass
# 526     0.189744                1    GenGamma   0.622863     actually_pass
# 527     0.450000                1    GenGamma   0.061242     actually_pass
# 528     0.020202                1    GenGamma   0.078689     actually_pass
# 529     0.023711                1    GenGamma   0.098453     actually_pass
# 530     0.018519                1    GenGamma   0.123565     actually_pass
# 531     0.108696                1    GenGamma   0.155566     actually_pass
# 532     0.119048                1    GenGamma   0.196261     actually_pass
# 533     0.138462                1    GenGamma   0.247131     actually_pass
# 534     0.020619                1    GenGamma   0.311794     actually_pass
# 535     0.020833                1    GenGamma   0.392401     actually_pass
# 536     0.021978                1    GenGamma   0.493909  practically_pass
# 537     0.556522                1    GenGamma   0.622863     actually_pass
#
#      failure_type  which_ones
# 494          pass         NaN
# 495          pass         NaN
# 496          pass         NaN
# 497          pass         NaN
# 498          pass         NaN
# 499          pass         NaN
# 500          pass         NaN
# 501          pass         NaN
# 502          pass         NaN
# 503          pass         NaN
# 504          pass         NaN
# 505          pass         NaN
# 506          pass         NaN
# 507          pass         NaN
# 508          pass         NaN
# 509          pass         NaN
# 510          pass         NaN
# 511          pass         NaN
# 512          pass         NaN
# 513          pass         NaN
# 514          pass         NaN
# 515          pass         NaN
# 516          pass         NaN
# 517          pass         NaN
# 518          pass         NaN
# 519          pass         NaN
# 520          pass         NaN
# 521          pass         NaN
# 522          pass         NaN
# 523          pass         NaN
# 524          pass         NaN
# 525          pass         NaN
# 526          pass         NaN
# 527          pass         NaN
# 528          pass         NaN
# 529          pass         NaN
# 530          pass         NaN
# 531          pass         NaN
# 532          pass         NaN
# 533          pass         NaN
# 534          pass         NaN
# 535          pass         NaN
# 536          pass         NaN
# 537          pass         NaN
#
# [44 rows x 50 columns]
