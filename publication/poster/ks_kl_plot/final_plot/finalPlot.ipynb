# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import scipy.special
import os
import pickle
from sigfig import round


ROOT_DIR = Path(git.Repo('.', search_parent_directories=True).working_tree_dir)
CWD = os.getcwd()
os.chdir(os.path.join(ROOT_DIR, "utilities"))
from testing import *
from reporting import *
os.chdir(CWD)


SAVE_FIGS = True
plots_path = os.path.join(ROOT_DIR, "publication", "paper", "final_plots")

# %% [markdown]
# # Combo Plot

# %%
fontsize = 20

fig, axes = plt.subplots(ncols=2, figsize=(20, 8), sharey=True)

# KS Statistic plot
ax_ks = axes[0]
ax_ks.set_xlabel(r'$r$', fontsize=fontsize)
ax_ks.set_ylabel(r'$\eta$', fontsize=fontsize)
ax_ks.set_title('KS Statistic', fontsize=fontsize)
ax_ks.set_xlim(0, 4)
ax_ks.set_ylim(0, 8)
log_levels = np.logspace(np.log10(np.min(var_prior_values)), np.log10(np.max(var_prior_values)), 150)
contour_ks = ax_ks.contour(R_contour, Eta_contour, np.log10(var_prior_values), levels=np.log10(log_levels), cmap='cividis', alpha=0.7, linewidths=0.8)
for r_values, eta_values in zip(all_r_values, all_eta_values):
    ax_ks.plot(r_values, eta_values, color='red', linewidth=2, label='KS Level Set')
ax_ks.set_xticks(np.arange(0, 5, 1))
ax_ks.tick_params(axis='both', which='major', labelsize=20)



#cbar_ks = fig.colorbar(contour_ks, ax=ax_ks)
#cbar_ks.set_label('Log(Variance)', fontsize=18)
#cbar_ks.ax.tick_params(labelsize=12)

# KL Divergence plot
ax_kl = axes[1]
ax_kl.set_xlabel(r'$r$', fontsize=fontsize)
#ax_kl.set_ylabel(r'$\eta$', fontsize=18)
ax_kl.set_title('KL Divergence', fontsize=fontsize)
ax_kl.set_xlim(0, 4)
ax_kl.set_ylim(0, 8)
contour_kl = ax_kl.contour(R_contour, Eta_contour, np.log10(var_prior_values), levels=np.log10(log_levels), cmap='cividis', alpha=0.7, linewidths=0.8)
scale_factor = 0.01
rows, cols = R_ellipses.shape
for i in range(rows):
    for j in range(cols):
        hessian_path = get_hessian_path(R_ellipses[i, j], Eta_ellipses[i, j])
        if os.path.exists(hessian_path):
            with open(hessian_path, 'rb') as f:
                H = pickle.load(f)
        else:
            H = hessian(R_ellipses[i, j], Eta_ellipses[i, j])
            with open(hessian_path, 'wb') as f:
                pickle.dump(H, f)
        U, s, Vt = np.linalg.svd(H)
        angle = np.arctan2(U[0, 1], U[0, 0]) * 180 / np.pi
        width, height = scale_factor / np.sqrt(s[0]), scale_factor / np.sqrt(s[1])
        ellipse = patches.Ellipse((R_ellipses[i, j], Eta_ellipses[i, j]), width, height, angle=angle, edgecolor='red', facecolor='none')
        ax_kl.add_patch(ellipse)
ax_kl.tick_params(axis='both', which='major', labelsize=20)
ax_kl.set_xticks(np.arange(0, 5, 1))
cbar_kl = fig.colorbar(contour_kl, ax=ax_kl)
cbar_kl.set_label('Log Variance', fontsize=18)
cbar_kl.ax.tick_params(labelsize=12)

plt.tight_layout()
plt.show()
if SAVE_FIGS:
    fig.savefig(os.path.join(plots_path, "ks_kl_sensitivity.jpg"), bbox_inches='tight', dpi=DPI)
# Out:
# /var/folders/0c/5hhs4r6n7pnc4jcl295d7j_c0000gn/T/ipykernel_26454/2071941775.py:47: RuntimeWarning: divide by zero encountered in scalar divide
#   width, height = scale_factor / np.sqrt(s[0]), scale_factor / np.sqrt(s[1])
# /Users/brandonmarks/opt/anaconda3/envs/HBMV/lib/python3.10/site-packages/matplotlib/transforms.py:2070: RuntimeWarning: invalid value encountered in scalar multiply
#   self._mtx[1, 0] *= sy
# /Users/brandonmarks/opt/anaconda3/envs/HBMV/lib/python3.10/site-packages/matplotlib/transforms.py:2072: RuntimeWarning: invalid value encountered in scalar multiply
#   self._mtx[1, 2] *= sy
# /Users/brandonmarks/opt/anaconda3/envs/HBMV/lib/python3.10/site-packages/matplotlib/transforms.py:2070: RuntimeWarning: invalid value encountered in scalar multiply
#   self._mtx[1, 0] *= sy
# /Users/brandonmarks/opt/anaconda3/envs/HBMV/lib/python3.10/site-packages/matplotlib/transforms.py:2072: RuntimeWarning: invalid value encountered in scalar multiply
#   self._mtx[1, 2] *= sy
# /Users/brandonmarks/opt/anaconda3/envs/HBMV/lib/python3.10/site-packages/matplotlib/transforms.py:2070: RuntimeWarning: invalid value encountered in scalar multiply
#   self._mtx[1, 0] *= sy
# /Users/brandonmarks/opt/anaconda3/envs/HBMV/lib/python3.10/site-packages/matplotlib/transforms.py:2072: RuntimeWarning: invalid value encountered in scalar multiply
#   self._mtx[1, 2] *= sy

# %% [markdown]
# # KS Plot

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import integrate, interpolate, stats, special
from tqdm import tqdm
import pickle
import os
from sigfig import round

import git
from pathlib import Path
import os
import cv2
import numpy as np
from glob import glob

# Import MATLAB Engine API for Python
ROOT_DIR = Path(git.Repo('.', search_parent_directories=True).working_tree_dir)
CWD = os.getcwd()
os.chdir(os.path.join(ROOT_DIR, "utilities"))
from testing import *
os.chdir(CWD)


# Utility Functions (Updated)

def compute_cdf_vals(r, beta, xs, use_matlab=False, debug=False):
    prior_cdf = np.zeros_like(xs)
    if use_matlab:
        if debug:
            for j in tqdm(range(len(xs)), desc="Computing CDF with MATLAB"):
                prior_cdf[j] = eng.compute_cdf_using_gengamma(float(r), float(beta), float(xs[j]), nargout=1)
        else:
            for j, x in enumerate(xs):
                prior_cdf[j] = eng.compute_cdf_using_gengamma(float(r), float(beta), float(x), nargout=1)
    else:
        def gen_gamma_density(theta):
            return (np.abs(r) / special.gamma(beta)) * (theta) ** (r * beta - 1) * np.exp(-(theta) ** r)

        for idx, x in enumerate(xs):
            def integrand(theta):
                cdf_normal = stats.norm.cdf(x / np.sqrt(theta))
                return cdf_normal * gen_gamma_density(theta)
            # Integrate over theta from 0 to infinity
            result, _ = integrate.quad(integrand, 0, np.inf, limit=100)
            prior_cdf[idx] = result
            if debug and idx % 100 == 0:
                print(f"x={x:.2f}, CDF={prior_cdf[idx]:.5f}")
    return prior_cdf

def sample_prior(r, eta, size=1):
    beta = (eta + 1.5)/r 
    assert beta > 0
    vars = stats.gengamma.rvs(a=beta, c=r, size=size)
    x = np.random.normal(scale=np.sqrt(vars), size=size)
    return x

def compute_prior_cdf_using_gamma_cdf(r, eta, n_samples=1000, tail_bound=0.001, tail_percent=0.1, scale=1, use_matlab=True, eng=None, enforce_assert=True, return_assert=False, return_xs=False, debug=False):
    beta = (eta + 1.5) / r
    var_prior = scale * special.gamma(beta + 1/r) / special.gamma(beta)
    
    cheby = np.sqrt(var_prior / tail_bound)
    if np.isnan(var_prior) or np.isinf(var_prior):
        cheby = 1e100
    x_max = min(99, cheby)
    n_tail = int(n_samples * tail_percent) if cheby >= 120 else 0

    if debug:
        print(f"Params: r={r}, eta={eta}")
        print(f"Chebyshev bound: {cheby}")
        print(f"{'No tail' if n_tail == 0 else f'Tail samples: {n_tail}'}")

    xs_minus = np.concatenate((-np.logspace(np.log10(cheby), 2, n_tail),
                               np.linspace(-x_max, 0, n_samples//2-n_tail)))

    prior_cdf_minus = compute_cdf_vals(r, beta, xs_minus, use_matlab=use_matlab, debug=debug)

    xs_plus = -np.flip(xs_minus[:-1])
    prior_cdf_plus = 1 - np.flip(prior_cdf_minus[:-1])

    xs = np.concatenate((xs_minus, xs_plus))
    prior_cdf = np.concatenate((prior_cdf_minus, prior_cdf_plus))

    if debug:
        print(f"First CDF value: {prior_cdf[0]}")
        print(f"Last CDF value: {prior_cdf[-1]}")
        print(f"Tail bound: {tail_bound}")

    if return_assert or enforce_assert:
        eps = tail_bound
        if not (-eps < prior_cdf[0] < eps and 1 - eps < prior_cdf[-1] < 1 + eps):
            if return_assert:
                return (xs, None) if return_xs else None
            elif enforce_assert:
                raise AssertionError("CDF bounds not satisfied")
        
    xs = np.concatenate(([1.01 * xs[0]], xs, [1.01 * xs[-1]]))
    prior_cdf = np.concatenate(([0], prior_cdf, [1]))
    cdf_spline = interpolate.InterpolatedUnivariateSpline(x=xs, y=prior_cdf, k=3, ext='const')

    if return_assert or enforce_assert:
        x = np.sort(sample_prior(r, eta, 10000))
        res = stats.kstest(x, cdf_spline)
        if debug:
            print(res)
        if not 0 <= res.statistic <= 0.2:
            if return_assert:
                return (xs, None) if return_xs else None
            elif enforce_assert:
                raise AssertionError("KS test failed")

    return (xs, cdf_spline) if return_xs else cdf_spline

def compute_prior_cdf(r, eta, method='gamma_cdf', n_samples=1000, tail_bound=0.001, tail_percent=0.1, scale=1, use_matlab=True, eng=None, debug=False, enforce_assert=True, return_assert=False, return_xs=False):
    if method == 'gamma_cdf':
        return compute_prior_cdf_using_gamma_cdf(r=r, eta=eta, n_samples=n_samples, tail_bound=tail_bound, tail_percent=tail_percent, scale=scale, use_matlab=use_matlab, eng=eng, enforce_assert=enforce_assert, return_assert=return_assert, return_xs=return_xs, debug=debug)
    else:
        raise ValueError("Invalid method specified.")

def variance_prior(r, eta, scale=1):
    beta = (eta + 1.5)/r 
    var_prior = scale * special.gamma(beta + 1 / r) / special.gamma(beta)
    return var_prior

# Main Script

# Lists of r and η values for level sets
r_ellipses = [0.5, 0.75, 1, 1.25, 1.5, 1.75, 2, 2.25, 2.5, 2.75, 3, 3.25, 3.5, 3.75, 4]
eta_ellipses = [0, 0.5, 1, 1.5, 2, 2.5, 3, 3.5, 4, 4.5, 5, 5.5, 6, 6.5, 7, 7.5, 8]

# Define ε
epsilon = 0.00001

# Define θ values from 0 to 2π
theta_values = np.linspace(0, 2 * np.pi, num=100)  # Granularity specified here

# Define x values for CDF evaluation
xs = np.linspace(-10, 10, 1000)

# KS statistic level for level set
KS_level = 0.0001  # You can change this value to adjust the level set

# Directory to save gradient data
gradient_data_dir = 'ks_gradient_data'
os.makedirs(gradient_data_dir, exist_ok=True)

# Function to format numbers for filenames
def format_number(x, multiplier):
    return int(np.round(x * multiplier))

# Initialize lists for plotting level sets
all_r_values = []
all_eta_values = []

# Grid values for contour plot
r_contour = [round(i*0.01 + 0.5, sigfigs=2) for i in range(-10, 360)]
eta_contour = [round(j*0.02 + 1, sigfigs=2) for j in range(-50, 400)]
R_contour, Eta_contour = np.meshgrid(r_contour, eta_contour)

# Compute variance_prior values for the contour plot
var_prior_values = variance_prior(R_contour, Eta_contour)

# Loop over all (r0, η0) pairs
for r0 in r_ellipses:
    for eta0 in eta_ellipses:
        print(f"Processing r0={r0}, eta0={eta0}")
        
        # Format numbers for filenames
        r0_int = format_number(r0, 100)
        eta0_int = format_number(eta0, 100)
        epsilon_int = format_number(epsilon, 1e6)
        theta_num = len(theta_values)
        
        # File name for gradient data
        gradient_file = os.path.join(
            gradient_data_dir,
            f'gradient_data_r{r0_int}_eta{eta0_int}_eps{epsilon_int}_theta{theta_num}.pkl'
        )
        
        # Try to load existing gradient data
        if os.path.exists(gradient_file):
            print(f"Loading existing gradient data from {gradient_file}")
            with open(gradient_file, 'rb') as f:
                gradient_data = pickle.load(f)
            theta_values = gradient_data['theta_values']
            KS_derivatives = gradient_data['KS_derivatives']
        else:
            print(f"Computing gradient data for r0={r0}, eta0={eta0}")
            # Compute reference CDF at (r0, η0)
            try:
                cdf_p0 = compute_prior_cdf(r=r0, eta=eta0, n_samples=1000, use_matlab=True, eng=eng, debug=False)
                cdf_p0_values = cdf_p0(xs)
            except Exception as e:
                print(f"Error computing reference CDF for r={r0}, eta={eta0}: {e}")
                continue  # Skip this pair if there's an error

            # Initialize array to store derivatives
            KS_derivatives = np.zeros_like(theta_values)
            
            # Loop over θ values and compute derivatives
            for idx, theta in tqdm(enumerate(theta_values), total=len(theta_values), desc='Computing derivatives'):
                delta_r = epsilon * np.cos(theta)
                delta_eta = epsilon * np.sin(theta)
                r_prime = r0 + delta_r
                eta_prime = eta0 + delta_eta
                # Compute CDF for (r', η')
                try:
                    cdf_p_prime = compute_prior_cdf(r=r_prime, eta=eta_prime, n_samples=1000, use_matlab=True, eng=eng, debug=False)
                    cdf_p_prime_values = cdf_p_prime(xs)
                    # Compute KS statistic
                    ks_stat = np.max(np.abs(cdf_p_prime_values - cdf_p0_values))
                    # Approximate derivative as ks_stat / epsilon
                    ks_derivative = ks_stat / epsilon
                    # Store derivative
                    KS_derivatives[idx] = ks_derivative
                except Exception as e:
                    print(f"Error computing CDF for r={r_prime}, eta={eta_prime}: {e}")
                    KS_derivatives[idx] = np.nan
            
            # Save gradient data
            gradient_data = {
                'theta_values': theta_values,
                'KS_derivatives': KS_derivatives,
                'epsilon': epsilon,
                'theta_num': theta_num,
                'r0': r0,
                'eta0': eta0
            }
            with open(gradient_file, 'wb') as f:
                pickle.dump(gradient_data, f)
        
        # Now, use the gradient data to draw a level set
        # For each θ, compute the distance s where KS_statistic equals KS_level
        # Approximate s = KS_level / KS_derivative
        s_values = KS_level / KS_derivatives  # s = KS_level / derivative
        print(f"KS Derivatives range: {np.nanmin(KS_derivatives)}, {np.nanmax(KS_derivatives)}")
        # Handle division by zero or NaN
        s_values = np.nan_to_num(s_values, nan=np.inf, posinf=np.inf, neginf=-np.inf)
        
        # Remove infinite or NaN s_values
        valid_indices = np.isfinite(s_values)
        s_values = s_values[valid_indices]
        theta_values_valid = theta_values[valid_indices]
        
        # Compute the points on the level set
        r_values = r0 + s_values * np.cos(theta_values_valid)
        eta_values = eta0 + s_values * np.sin(theta_values_valid)
        
        # Store the level set points for plotting
        all_r_values.append(r_values)
        all_eta_values.append(eta_values)

# Plotting
fig, ax = plt.subplots(figsize=(10, 8))
ax.set_xlabel('r (shape parameter)', fontsize=18)
ax.set_ylabel('η (scale parameter)', fontsize=18)
# ax.set_title(f'Level Sets of KS Statistic at Level {KS_level}\nε={epsilon}, θ samples={len(theta_values)}')
ax.set_title('KS Statistic', fontsize=20)

ax.set_xlim(0, 4)  # Set x-axis to start from 0, while keeping the upper limit automatic
ax.set_ylim(0, 8)  # Set y-axis to start from 0, while keeping the upper limit automatic


# Plot the variance prior contour
log_levels = np.logspace(np.log10(np.min(var_prior_values)), np.log10(np.max(var_prior_values)), 150)
contour = ax.contour(R_contour, Eta_contour, np.log10(var_prior_values), levels=np.log10(log_levels), cmap='cividis', alpha=0.7, linewidths=0.8)
cbar = fig.colorbar(contour, ax=ax)
cbar.set_label('Log(Variance)', fontsize=18)
cbar.ax.tick_params(labelsize=12)

# Plot level sets
for r_values, eta_values, r0, eta0 in zip(all_r_values, all_eta_values, r_ellipses * len(eta_ellipses), np.repeat(eta_ellipses, len(r_ellipses))):
    ax.plot(r_values, eta_values, color='red', label=f'r0={r0}, η0={eta0}')


ax.tick_params(axis='both', which='major', labelsize=20)


fig.savefig('plots/ks_statistic_plot.png', bbox_inches='tight')
plt.show()
# Out:
# /var/folders/0c/5hhs4r6n7pnc4jcl295d7j_c0000gn/T/ipykernel_26454/1657643050.py:155: UserWarning: 2 significant figures requested from number with only 1 significant figures
#   r_contour = [round(i*0.01 + 0.5, sigfigs=2) for i in range(-10, 360)]
# /var/folders/0c/5hhs4r6n7pnc4jcl295d7j_c0000gn/T/ipykernel_26454/1657643050.py:156: UserWarning: 2 significant figures requested from number with only 1 significant figures
#   eta_contour = [round(j*0.02 + 1, sigfigs=2) for j in range(-50, 400)]
# Processing r0=0.5, eta0=0
# Loading existing gradient data from ks_gradient_data/gradient_data_r50_eta0_eps10_theta100.pkl
# KS Derivatives range: 0.022075759099210442, 0.7914887269477865
# Processing r0=0.5, eta0=0.5
# Loading existing gradient data from ks_gradient_data/gradient_data_r50_eta50_eps10_theta100.pkl
# KS Derivatives range: 0.013870231829749, 0.9391626459687162
# Processing r0=0.5, eta0=1
# Loading existing gradient data from ks_gradient_data/gradient_data_r50_eta100_eps10_theta100.pkl
# KS Derivatives range: 0.010009018214240939, 1.0604514940504295
# Processing r0=0.5, eta0=1.5
# Loading existing gradient data from ks_gradient_data/gradient_data_r50_eta150_eps10_theta100.pkl
# KS Derivatives range: 0.020745471407401794, 1.162211134958513
# Processing r0=0.5, eta0=2
# Loading existing gradient data from ks_gradient_data/gradient_data_r50_eta200_eps10_theta100.pkl
# KS Derivatives range: 0.00741100764645175, 1.249205444120438
# Processing r0=0.5, eta0=2.5
# Loading existing gradient data from ks_gradient_data/gradient_data_r50_eta250_eps10_theta100.pkl
# KS Derivatives range: 0.008797402961668865, 1.325138856811403
# Processing r0=0.5, eta0=3
# Loading existing gradient data from ks_gradient_data/gradient_data_r50_eta300_eps10_theta100.pkl
# KS Derivatives range: 0.016547286929569083, 1.392222129581455
# Processing r0=0.5, eta0=3.5
# Loading existing gradient data from ks_gradient_data/gradient_data_r50_eta350_eps10_theta100.pkl
# KS Derivatives range: 0.02311530303833464, 1.4521449978488474
# Processing r0=0.5, eta0=4
# Loading existing gradient data from ks_gradient_data/gradient_data_r50_eta400_eps10_theta100.pkl
# KS Derivatives range: 0.018259665346409548, 1.506214418717233
# Processing r0=0.5, eta0=4.5
# Loading existing gradient data from ks_gradient_data/gradient_data_r50_eta450_eps10_theta100.pkl
# KS Derivatives range: 0.014126591063590153, 1.5465495806887828
# Processing r0=0.5, eta0=5
# Loading existing gradient data from ks_gradient_data/gradient_data_r50_eta500_eps10_theta100.pkl
# KS Derivatives range: 0.010562541080672005, 1.5648450699345948
# Processing r0=0.5, eta0=5.5
# Loading existing gradient data from ks_gradient_data/gradient_data_r50_eta550_eps10_theta100.pkl
# KS Derivatives range: 0.007439774052375724, 1.5666282873527668
# Processing r0=0.5, eta0=6
# Loading existing gradient data from ks_gradient_data/gradient_data_r50_eta600_eps10_theta100.pkl
# KS Derivatives range: 0.004720686072601232, 1.556467796381966
# Processing r0=0.5, eta0=6.5
# Loading existing gradient data from ks_gradient_data/gradient_data_r50_eta650_eps10_theta100.pkl
# KS Derivatives range: 0.0023834620610507784, 1.5379129376658083
# Processing r0=0.5, eta0=7
# Loading existing gradient data from ks_gradient_data/gradient_data_r50_eta700_eps10_theta100.pkl
# KS Derivatives range: 0.00048277358777326635, 1.5136415421668212
# Processing r0=0.5, eta0=7.5
# Loading existing gradient data from ks_gradient_data/gradient_data_r50_eta750_eps10_theta100.pkl
# KS Derivatives range: 0.0012975366669998323, 1.4856795308659796
# Processing r0=0.5, eta0=8
# Loading existing gradient data from ks_gradient_data/gradient_data_r50_eta800_eps10_theta100.pkl
# KS Derivatives range: 0.0027241436661995517, 1.4554312899039965
# Processing r0=0.75, eta0=0
# Loading existing gradient data from ks_gradient_data/gradient_data_r75_eta0_eps10_theta100.pkl
# KS Derivatives range: 0.01891184076008301, 0.3172571225340537
# Processing r0=0.75, eta0=0.5
# Loading existing gradient data from ks_gradient_data/gradient_data_r75_eta50_eps10_theta100.pkl
# KS Derivatives range: 0.012182355579870572, 0.37307923008711436
# Processing r0=0.75, eta0=1
# Loading existing gradient data from ks_gradient_data/gradient_data_r75_eta100_eps10_theta100.pkl
# KS Derivatives range: 0.009097301745253361, 0.42154016937634425
# Processing r0=0.75, eta0=1.5
# Loading existing gradient data from ks_gradient_data/gradient_data_r75_eta150_eps10_theta100.pkl
# KS Derivatives range: 0.00577055120909442, 0.4630216228596051
# Processing r0=0.75, eta0=2
# Loading existing gradient data from ks_gradient_data/gradient_data_r75_eta200_eps10_theta100.pkl
# KS Derivatives range: 0.008101146642403023, 0.49896328700171905
# Processing r0=0.75, eta0=2.5
# Loading existing gradient data from ks_gradient_data/gradient_data_r75_eta250_eps10_theta100.pkl
# KS Derivatives range: 0.004717474776788633, 0.530358706041234
# Processing r0=0.75, eta0=3
# Loading existing gradient data from ks_gradient_data/gradient_data_r75_eta300_eps10_theta100.pkl
# KS Derivatives range: 0.009518935641106285, 0.5582830655326276
# Processing r0=0.75, eta0=3.5
# Loading existing gradient data from ks_gradient_data/gradient_data_r75_eta350_eps10_theta100.pkl
# KS Derivatives range: 0.005157138596723065, 0.5832545885708917
# Processing r0=0.75, eta0=4
# Loading existing gradient data from ks_gradient_data/gradient_data_r75_eta400_eps10_theta100.pkl
# KS Derivatives range: 0.0016731521106094769, 0.6058228687932932
# Processing r0=0.75, eta0=4.5
# Loading existing gradient data from ks_gradient_data/gradient_data_r75_eta450_eps10_theta100.pkl
# KS Derivatives range: 0.003742360581149295, 0.6264886100559863
# Processing r0=0.75, eta0=5
# Loading existing gradient data from ks_gradient_data/gradient_data_r75_eta500_eps10_theta100.pkl
# KS Derivatives range: 0.0062392487842899405, 0.645458175141389
# Processing r0=0.75, eta0=5.5
# Loading existing gradient data from ks_gradient_data/gradient_data_r75_eta550_eps10_theta100.pkl
# KS Derivatives range: 0.008673796048075388, 0.6629750706699244
# Processing r0=0.75, eta0=6
# Loading existing gradient data from ks_gradient_data/gradient_data_r75_eta600_eps10_theta100.pkl
# KS Derivatives range: 0.010825637797307051, 0.6792445816139469
# Processing r0=0.75, eta0=6.5
# Loading existing gradient data from ks_gradient_data/gradient_data_r75_eta650_eps10_theta100.pkl
# KS Derivatives range: 0.009235689746311948, 0.6944208881892732
# Processing r0=0.75, eta0=7
# Loading existing gradient data from ks_gradient_data/gradient_data_r75_eta700_eps10_theta100.pkl
# KS Derivatives range: 0.007819939895625794, 0.7086434153424913
# Processing r0=0.75, eta0=7.5
# Loading existing gradient data from ks_gradient_data/gradient_data_r75_eta750_eps10_theta100.pkl
# KS Derivatives range: 0.006550285835960067, 0.722020973339954
# Processing r0=0.75, eta0=8
# Loading existing gradient data from ks_gradient_data/gradient_data_r75_eta800_eps10_theta100.pkl
# KS Derivatives range: 0.005404600314506957, 0.7346486118275929
# Processing r0=1, eta0=0
# Loading existing gradient data from ks_gradient_data/gradient_data_r100_eta0_eps10_theta100.pkl
# KS Derivatives range: 0.01705657590722609, 0.17020622583574505
# Processing r0=1, eta0=0.5
# Loading existing gradient data from ks_gradient_data/gradient_data_r100_eta50_eps10_theta100.pkl
# KS Derivatives range: 0.010167938757632555, 0.19274937669011558
# Processing r0=1, eta0=1
# Loading existing gradient data from ks_gradient_data/gradient_data_r100_eta100_eps10_theta100.pkl
# KS Derivatives range: 0.006978673239288468, 0.21600334688398612
# Processing r0=1, eta0=1.5
# Loading existing gradient data from ks_gradient_data/gradient_data_r100_eta150_eps10_theta100.pkl
# KS Derivatives range: 0.004721096047433093, 0.23710646640529018
# Processing r0=1, eta0=2
# Loading existing gradient data from ks_gradient_data/gradient_data_r100_eta200_eps10_theta100.pkl
# KS Derivatives range: 0.003957359981376918, 0.25582539494861667
# Processing r0=1, eta0=2.5
# Loading existing gradient data from ks_gradient_data/gradient_data_r100_eta250_eps10_theta100.pkl
# KS Derivatives range: 0.0030146247942397504, 0.27247009877218176
# Processing r0=1, eta0=3
# Loading existing gradient data from ks_gradient_data/gradient_data_r100_eta300_eps10_theta100.pkl
# KS Derivatives range: 0.005162263252977972, 0.28737748394291884
# Processing r0=1, eta0=3.5
# Loading existing gradient data from ks_gradient_data/gradient_data_r100_eta350_eps10_theta100.pkl
# KS Derivatives range: 0.002180142560925802, 0.3007741887328663
# Processing r0=1, eta0=4
# Loading existing gradient data from ks_gradient_data/gradient_data_r100_eta400_eps10_theta100.pkl
# KS Derivatives range: 0.002997439066398932, 0.31296061350771787
# Processing r0=1, eta0=4.5
# Loading existing gradient data from ks_gradient_data/gradient_data_r100_eta450_eps10_theta100.pkl
# KS Derivatives range: 0.005246648504542151, 0.3241305611023648
# Processing r0=1, eta0=5
# Loading existing gradient data from ks_gradient_data/gradient_data_r100_eta500_eps10_theta100.pkl
# KS Derivatives range: 0.003540046544792119, 0.33439373885724155
# Processing r0=1, eta0=5.5
# Loading existing gradient data from ks_gradient_data/gradient_data_r100_eta550_eps10_theta100.pkl
# KS Derivatives range: 0.001744685870774809, 0.34388725627110256
# Processing r0=1, eta0=6
# Loading existing gradient data from ks_gradient_data/gradient_data_r100_eta600_eps10_theta100.pkl
# KS Derivatives range: 0.0009967150951806225, 0.3527303946315729
# Processing r0=1, eta0=6.5
# Loading existing gradient data from ks_gradient_data/gradient_data_r100_eta650_eps10_theta100.pkl
# KS Derivatives range: 0.0019719428978604014, 0.36102185945463544
# Processing r0=1, eta0=7
# Loading existing gradient data from ks_gradient_data/gradient_data_r100_eta700_eps10_theta100.pkl
# KS Derivatives range: 0.003103734229348287, 0.3688010096924987
# Processing r0=1, eta0=7.5
# Loading existing gradient data from ks_gradient_data/gradient_data_r100_eta750_eps10_theta100.pkl
# KS Derivatives range: 0.004213822993315297, 0.3761214205921792
# Processing r0=1, eta0=8
# Loading existing gradient data from ks_gradient_data/gradient_data_r100_eta800_eps10_theta100.pkl
# KS Derivatives range: 0.00525117860306068, 0.3830403795479497
# Processing r0=1.25, eta0=0
# Loading existing gradient data from ks_gradient_data/gradient_data_r125_eta0_eps10_theta100.pkl
# KS Derivatives range: 0.013885688887604884, 0.11207002382773722
# Processing r0=1.25, eta0=0.5
# Loading existing gradient data from ks_gradient_data/gradient_data_r125_eta50_eps10_theta100.pkl
# KS Derivatives range: 0.00945157040410649, 0.11762972740303466
# Processing r0=1.25, eta0=1
# Loading existing gradient data from ks_gradient_data/gradient_data_r125_eta100_eps10_theta100.pkl
# KS Derivatives range: 0.006187786094624669, 0.12881597334091222
# Processing r0=1.25, eta0=1.5
# Loading existing gradient data from ks_gradient_data/gradient_data_r125_eta150_eps10_theta100.pkl
# KS Derivatives range: 0.005468587244150668, 0.1404293970885817
# Processing r0=1.25, eta0=2
# Loading existing gradient data from ks_gradient_data/gradient_data_r125_eta200_eps10_theta100.pkl
# KS Derivatives range: 0.0038266915303175604, 0.15129519894685473
# Processing r0=1.25, eta0=2.5
# Loading existing gradient data from ks_gradient_data/gradient_data_r125_eta250_eps10_theta100.pkl
# KS Derivatives range: 0.0037449061816852143, 0.16122859760880903
# Processing r0=1.25, eta0=3
# Loading existing gradient data from ks_gradient_data/gradient_data_r125_eta300_eps10_theta100.pkl
# KS Derivatives range: 0.0027302965333042546, 0.1702361094202409
# Processing r0=1.25, eta0=3.5
# Loading existing gradient data from ks_gradient_data/gradient_data_r125_eta350_eps10_theta100.pkl
# KS Derivatives range: 0.0018124718503820245, 0.17844027490332423
# Processing r0=1.25, eta0=4
# Loading existing gradient data from ks_gradient_data/gradient_data_r125_eta400_eps10_theta100.pkl
# KS Derivatives range: 0.0026542767428416876, 0.1859568358020258
# Processing r0=1.25, eta0=4.5
# Loading existing gradient data from ks_gradient_data/gradient_data_r125_eta450_eps10_theta100.pkl
# KS Derivatives range: 0.0022380702874302827, 0.19285793728951448
# Processing r0=1.25, eta0=5
# Loading existing gradient data from ks_gradient_data/gradient_data_r125_eta500_eps10_theta100.pkl
# KS Derivatives range: 0.0010186986434956857, 0.1992161326125341
# Processing r0=1.25, eta0=5.5
# Loading existing gradient data from ks_gradient_data/gradient_data_r125_eta550_eps10_theta100.pkl
# KS Derivatives range: 0.0020617467288985836, 0.20515469518755933
# Processing r0=1.25, eta0=6
# Loading existing gradient data from ks_gradient_data/gradient_data_r125_eta600_eps10_theta100.pkl
# KS Derivatives range: 0.0032995344345643214, 0.2106853543071274
# Processing r0=1.25, eta0=6.5
# Loading existing gradient data from ks_gradient_data/gradient_data_r125_eta650_eps10_theta100.pkl
# KS Derivatives range: 0.00253328786836704, 0.21585659942258137
# Processing r0=1.25, eta0=7
# Loading existing gradient data from ks_gradient_data/gradient_data_r125_eta700_eps10_theta100.pkl
# KS Derivatives range: 0.001540608951522415, 0.22070917320426983
# Processing r0=1.25, eta0=7.5
# Loading existing gradient data from ks_gradient_data/gradient_data_r125_eta750_eps10_theta100.pkl
# KS Derivatives range: 0.0006805473462545563, 0.22528975073266008
# Processing r0=1.25, eta0=8
# Loading existing gradient data from ks_gradient_data/gradient_data_r125_eta800_eps10_theta100.pkl
# KS Derivatives range: 0.0006562933640985591, 0.22962860739550447
# Processing r0=1.5, eta0=0
# Loading existing gradient data from ks_gradient_data/gradient_data_r150_eta0_eps10_theta100.pkl
# KS Derivatives range: 0.010927111926406495, 0.08610771965456009
# Processing r0=1.5, eta0=0.5
# Loading existing gradient data from ks_gradient_data/gradient_data_r150_eta50_eps10_theta100.pkl
# KS Derivatives range: 0.008068588741583227, 0.08150532729289672
# Processing r0=1.5, eta0=1
# Loading existing gradient data from ks_gradient_data/gradient_data_r150_eta100_eps10_theta100.pkl
# KS Derivatives range: 0.005501628819182257, 0.08558571959194071
# Processing r0=1.5, eta0=1.5
# Loading existing gradient data from ks_gradient_data/gradient_data_r150_eta150_eps10_theta100.pkl
# KS Derivatives range: 0.004089362531933816, 0.09184700789366394
# Processing r0=1.5, eta0=2
# Loading existing gradient data from ks_gradient_data/gradient_data_r150_eta200_eps10_theta100.pkl
# KS Derivatives range: 0.003000795167906744, 0.09838292334141129
# Processing r0=1.5, eta0=2.5
# Loading existing gradient data from ks_gradient_data/gradient_data_r150_eta250_eps10_theta100.pkl
# KS Derivatives range: 0.00263448951542955, 0.10466178081147691
# Processing r0=1.5, eta0=3
# Loading existing gradient data from ks_gradient_data/gradient_data_r150_eta300_eps10_theta100.pkl
# KS Derivatives range: 0.0018413432723018983, 0.11050937707701712
# Processing r0=1.5, eta0=3.5
# Loading existing gradient data from ks_gradient_data/gradient_data_r150_eta350_eps10_theta100.pkl
# KS Derivatives range: 0.002021544853736401, 0.11592271587090862
# Processing r0=1.5, eta0=4
# Loading existing gradient data from ks_gradient_data/gradient_data_r150_eta400_eps10_theta100.pkl
# KS Derivatives range: 0.0019824016678215983, 0.12092323531387449
# Processing r0=1.5, eta0=4.5
# Loading existing gradient data from ks_gradient_data/gradient_data_r150_eta450_eps10_theta100.pkl
# KS Derivatives range: 0.0011972097480050792, 0.12554717361557
# Processing r0=1.5, eta0=5
# Loading existing gradient data from ks_gradient_data/gradient_data_r150_eta500_eps10_theta100.pkl
# KS Derivatives range: 0.0015093457039760947, 0.12985295393397323
# Processing r0=1.5, eta0=5.5
# Loading existing gradient data from ks_gradient_data/gradient_data_r150_eta550_eps10_theta100.pkl
# KS Derivatives range: 0.002010999755608367, 0.13386506148849175
# Processing r0=1.5, eta0=6
# Loading existing gradient data from ks_gradient_data/gradient_data_r150_eta600_eps10_theta100.pkl
# KS Derivatives range: 0.0008821095076605444, 0.1376057235907835
# Processing r0=1.5, eta0=6.5
# Loading existing gradient data from ks_gradient_data/gradient_data_r150_eta650_eps10_theta100.pkl
# KS Derivatives range: 0.000828784585404918, 0.14111993002219325
# Processing r0=1.5, eta0=7
# Loading existing gradient data from ks_gradient_data/gradient_data_r150_eta700_eps10_theta100.pkl
# KS Derivatives range: 0.0015105972986373393, 0.1444442541909119
# Processing r0=1.5, eta0=7.5
# Loading existing gradient data from ks_gradient_data/gradient_data_r150_eta750_eps10_theta100.pkl
# KS Derivatives range: 0.0022628939611024634, 0.14757878434024096
# Processing r0=1.5, eta0=8
# Loading existing gradient data from ks_gradient_data/gradient_data_r150_eta800_eps10_theta100.pkl
# KS Derivatives range: 0.0018891036956958371, 0.1505422574932247
# Processing r0=1.75, eta0=0
# Loading existing gradient data from ks_gradient_data/gradient_data_r175_eta0_eps10_theta100.pkl
# KS Derivatives range: 0.008538452811457375, 0.0733057038515561
# Processing r0=1.75, eta0=0.5
# Loading existing gradient data from ks_gradient_data/gradient_data_r175_eta50_eps10_theta100.pkl
# KS Derivatives range: 0.006872165325688683, 0.0625844098323114
# Processing r0=1.75, eta0=1
# Loading existing gradient data from ks_gradient_data/gradient_data_r175_eta100_eps10_theta100.pkl
# KS Derivatives range: 0.004867536095715108, 0.06200294949687545
# Processing r0=1.75, eta0=1.5
# Loading existing gradient data from ks_gradient_data/gradient_data_r175_eta150_eps10_theta100.pkl
# KS Derivatives range: 0.003795524627925317, 0.06480587269042104
# Processing r0=1.75, eta0=2
# Loading existing gradient data from ks_gradient_data/gradient_data_r175_eta200_eps10_theta100.pkl
# KS Derivatives range: 0.0028719230160678673, 0.06864121725458361
# Processing r0=1.75, eta0=2.5
# Loading existing gradient data from ks_gradient_data/gradient_data_r175_eta250_eps10_theta100.pkl
# KS Derivatives range: 0.0021436443620181933, 0.07266678626050016
# Processing r0=1.75, eta0=3
# Loading existing gradient data from ks_gradient_data/gradient_data_r175_eta300_eps10_theta100.pkl
# KS Derivatives range: 0.001939084826041437, 0.0765855424633699
# Processing r0=1.75, eta0=3.5
# Loading existing gradient data from ks_gradient_data/gradient_data_r175_eta350_eps10_theta100.pkl
# KS Derivatives range: 0.001836973806401687, 0.08031083797988003
# Processing r0=1.75, eta0=4
# Loading existing gradient data from ks_gradient_data/gradient_data_r175_eta400_eps10_theta100.pkl
# KS Derivatives range: 0.0013772647779186629, 0.08380104261629384
# Processing r0=1.75, eta0=4.5
# Loading existing gradient data from ks_gradient_data/gradient_data_r175_eta450_eps10_theta100.pkl
# KS Derivatives range: 0.0009330012984420931, 0.08706939820246616
# Processing r0=1.75, eta0=5
# Loading existing gradient data from ks_gradient_data/gradient_data_r175_eta500_eps10_theta100.pkl
# KS Derivatives range: 0.0015055201085800716, 0.09012803007246716
# Processing r0=1.75, eta0=5.5
# Loading existing gradient data from ks_gradient_data/gradient_data_r175_eta550_eps10_theta100.pkl
# KS Derivatives range: 0.0008451494393213465, 0.0929856360354364
# Processing r0=1.75, eta0=6
# Loading existing gradient data from ks_gradient_data/gradient_data_r175_eta600_eps10_theta100.pkl
# KS Derivatives range: 0.0009220291252720613, 0.09567767944584914
# Processing r0=1.75, eta0=6.5
# Loading existing gradient data from ks_gradient_data/gradient_data_r175_eta650_eps10_theta100.pkl
# KS Derivatives range: 0.0016419568926728798, 0.09821466283588264
# Processing r0=1.75, eta0=7
# Loading existing gradient data from ks_gradient_data/gradient_data_r175_eta700_eps10_theta100.pkl
# KS Derivatives range: 0.0009706113829333062, 0.1006030683647907
# Processing r0=1.75, eta0=7.5
# Loading existing gradient data from ks_gradient_data/gradient_data_r175_eta750_eps10_theta100.pkl
# KS Derivatives range: 0.00033457987873297673, 0.10285473683868672
# Processing r0=1.75, eta0=8
# Loading existing gradient data from ks_gradient_data/gradient_data_r175_eta800_eps10_theta100.pkl
# KS Derivatives range: 0.0006910575049701161, 0.10500653548350945
# Processing r0=2, eta0=0
# Loading existing gradient data from ks_gradient_data/gradient_data_r200_eta0_eps10_theta100.pkl
# KS Derivatives range: 0.006810298026904692, 0.0662277499730024
# Processing r0=2, eta0=0.5
# Loading existing gradient data from ks_gradient_data/gradient_data_r200_eta50_eps10_theta100.pkl
# KS Derivatives range: 0.005651013229579504, 0.0520391243874485
# Processing r0=2, eta0=1
# Loading existing gradient data from ks_gradient_data/gradient_data_r200_eta100_eps10_theta100.pkl
# KS Derivatives range: 0.004213316573409287, 0.0482971782789221
# Processing r0=2, eta0=1.5
# Loading existing gradient data from ks_gradient_data/gradient_data_r200_eta150_eps10_theta100.pkl
# KS Derivatives range: 0.003419377105073895, 0.04869227606674186
# Processing r0=2, eta0=2
# Loading existing gradient data from ks_gradient_data/gradient_data_r200_eta200_eps10_theta100.pkl
# KS Derivatives range: 0.0023836679297062346, 0.0506557455870471
# Processing r0=2, eta0=2.5
# Loading existing gradient data from ks_gradient_data/gradient_data_r200_eta250_eps10_theta100.pkl
# KS Derivatives range: 0.0021129789584684033, 0.05316263628207806
# Processing r0=2, eta0=3
# Loading existing gradient data from ks_gradient_data/gradient_data_r200_eta300_eps10_theta100.pkl
# KS Derivatives range: 0.0019363917469483736, 0.05580899910540004
# Processing r0=2, eta0=3.5
# Loading existing gradient data from ks_gradient_data/gradient_data_r200_eta350_eps10_theta100.pkl
# KS Derivatives range: 0.0011090604989938413, 0.05841625917990533
# Processing r0=2, eta0=4
# Loading existing gradient data from ks_gradient_data/gradient_data_r200_eta400_eps10_theta100.pkl
# KS Derivatives range: 0.0009196471157518759, 0.06091965158439016
# Processing r0=2, eta0=4.5
# Loading existing gradient data from ks_gradient_data/gradient_data_r200_eta450_eps10_theta100.pkl
# KS Derivatives range: 0.000944409850323069, 0.0633043032771674
# Processing r0=2, eta0=5
# Loading existing gradient data from ks_gradient_data/gradient_data_r200_eta500_eps10_theta100.pkl
# KS Derivatives range: 0.0013008957196192217, 0.06555469516111856
# Processing r0=2, eta0=5.5
# Loading existing gradient data from ks_gradient_data/gradient_data_r200_eta550_eps10_theta100.pkl
# KS Derivatives range: 0.000589129190917137, 0.06767192727574756
# Processing r0=2, eta0=6
# Loading existing gradient data from ks_gradient_data/gradient_data_r200_eta600_eps10_theta100.pkl
# KS Derivatives range: 0.0011863226623276546, 0.06967955233916356
# Processing r0=2, eta0=6.5
# Loading existing gradient data from ks_gradient_data/gradient_data_r200_eta650_eps10_theta100.pkl
# KS Derivatives range: 0.0006267960261929773, 0.07157152150938373
# Processing r0=2, eta0=7
# Loading existing gradient data from ks_gradient_data/gradient_data_r200_eta700_eps10_theta100.pkl
# KS Derivatives range: 0.0005943263436947177, 0.07336530438717404
# Processing r0=2, eta0=7.5
# Loading existing gradient data from ks_gradient_data/gradient_data_r200_eta750_eps10_theta100.pkl
# KS Derivatives range: 0.0010755374035831267, 0.0750721766640261
# Processing r0=2, eta0=8
# Loading existing gradient data from ks_gradient_data/gradient_data_r200_eta800_eps10_theta100.pkl
# KS Derivatives range: 0.0009488117486133872, 0.07668927516357726
# Processing r0=2.25, eta0=0
# Loading existing gradient data from ks_gradient_data/gradient_data_r225_eta0_eps10_theta100.pkl
# KS Derivatives range: 0.005493375490606133, 0.0618687244990923
# Processing r0=2.25, eta0=0.5
# Loading existing gradient data from ks_gradient_data/gradient_data_r225_eta50_eps10_theta100.pkl
# KS Derivatives range: 0.004462347757971941, 0.04579081193945011
# Processing r0=2.25, eta0=1
# Loading existing gradient data from ks_gradient_data/gradient_data_r225_eta100_eps10_theta100.pkl
# KS Derivatives range: 0.003724487129819209, 0.039962840786555986
# Processing r0=2.25, eta0=1.5
# Loading existing gradient data from ks_gradient_data/gradient_data_r225_eta150_eps10_theta100.pkl
# KS Derivatives range: 0.002781833574605485, 0.03861331265841983
# Processing r0=2.25, eta0=2
# Loading existing gradient data from ks_gradient_data/gradient_data_r225_eta200_eps10_theta100.pkl
# KS Derivatives range: 0.0022970091828611316, 0.03920864420914327
# Processing r0=2.25, eta0=2.5
# Loading existing gradient data from ks_gradient_data/gradient_data_r225_eta250_eps10_theta100.pkl
# KS Derivatives range: 0.001904183583728569, 0.04061701526225647
# Processing r0=2.25, eta0=3
# Loading existing gradient data from ks_gradient_data/gradient_data_r225_eta300_eps10_theta100.pkl
# KS Derivatives range: 0.0016125171087288945, 0.042353279333662286
# Processing r0=2.25, eta0=3.5
# Loading existing gradient data from ks_gradient_data/gradient_data_r225_eta350_eps10_theta100.pkl
# KS Derivatives range: 0.0013083687244730413, 0.0441765914960257
# Processing r0=2.25, eta0=4
# Loading existing gradient data from ks_gradient_data/gradient_data_r225_eta400_eps10_theta100.pkl
# KS Derivatives range: 0.0012050126230178648, 0.045996575759321694
# Processing r0=2.25, eta0=4.5
# Loading existing gradient data from ks_gradient_data/gradient_data_r225_eta450_eps10_theta100.pkl
# KS Derivatives range: 0.0010613926293423503, 0.04776407791784453
# Processing r0=2.25, eta0=5
# Loading existing gradient data from ks_gradient_data/gradient_data_r225_eta500_eps10_theta100.pkl
# KS Derivatives range: 0.0010469100586441016, 0.04945532819933262
# Processing r0=2.25, eta0=5.5
# Loading existing gradient data from ks_gradient_data/gradient_data_r225_eta550_eps10_theta100.pkl
# KS Derivatives range: 0.0006246031469814284, 0.05106221576955949
# Processing r0=2.25, eta0=6
# Loading existing gradient data from ks_gradient_data/gradient_data_r225_eta600_eps10_theta100.pkl
# KS Derivatives range: 0.000838633384958598, 0.05259979659888447
# Processing r0=2.25, eta0=6.5
# Loading existing gradient data from ks_gradient_data/gradient_data_r225_eta650_eps10_theta100.pkl
# KS Derivatives range: 0.0005056649654555656, 0.05405035776728794
# Processing r0=2.25, eta0=7
# Loading existing gradient data from ks_gradient_data/gradient_data_r225_eta700_eps10_theta100.pkl
# KS Derivatives range: 0.0009626861641187644, 0.0554407269426349
# Processing r0=2.25, eta0=7.5
# Loading existing gradient data from ks_gradient_data/gradient_data_r225_eta750_eps10_theta100.pkl
# KS Derivatives range: 0.0004825954552645228, 0.05675704122243274
# Processing r0=2.25, eta0=8
# Loading existing gradient data from ks_gradient_data/gradient_data_r225_eta800_eps10_theta100.pkl
# KS Derivatives range: 0.0003993649300149115, 0.05801184529419245
# Processing r0=2.5, eta0=0
# Loading existing gradient data from ks_gradient_data/gradient_data_r250_eta0_eps10_theta100.pkl
# KS Derivatives range: 0.004319100740252102, 0.058918207423985784
# Processing r0=2.5, eta0=0.5
# Loading existing gradient data from ks_gradient_data/gradient_data_r250_eta50_eps10_theta100.pkl
# KS Derivatives range: 0.0037760643445405857, 0.0418532493579038
# Processing r0=2.5, eta0=1
# Loading existing gradient data from ks_gradient_data/gradient_data_r250_eta100_eps10_theta100.pkl
# KS Derivatives range: 0.003418091687468205, 0.03468360176839269
# Processing r0=2.5, eta0=1.5
# Loading existing gradient data from ks_gradient_data/gradient_data_r250_eta150_eps10_theta100.pkl
# KS Derivatives range: 0.002781440699983761, 0.032071508532238724
# Processing r0=2.5, eta0=2
# Loading existing gradient data from ks_gradient_data/gradient_data_r250_eta200_eps10_theta100.pkl
# KS Derivatives range: 0.002118430664221904, 0.031637485375934915
# Processing r0=2.5, eta0=2.5
# Loading existing gradient data from ks_gradient_data/gradient_data_r250_eta250_eps10_theta100.pkl
# KS Derivatives range: 0.0015578728529419548, 0.03221935974961898
# Processing r0=2.5, eta0=3
# Loading existing gradient data from ks_gradient_data/gradient_data_r250_eta300_eps10_theta100.pkl
# KS Derivatives range: 0.0015115572793433783, 0.03326530267355743
# Processing r0=2.5, eta0=3.5
# Loading existing gradient data from ks_gradient_data/gradient_data_r250_eta350_eps10_theta100.pkl
# KS Derivatives range: 0.0012671701965505378, 0.034510270774390506
# Processing r0=2.5, eta0=4
# Loading existing gradient data from ks_gradient_data/gradient_data_r250_eta400_eps10_theta100.pkl
# KS Derivatives range: 0.0008927762751298473, 0.0358220258789288
# Processing r0=2.5, eta0=4.5
# Loading existing gradient data from ks_gradient_data/gradient_data_r250_eta450_eps10_theta100.pkl
# KS Derivatives range: 0.0009175344622969205, 0.0371388000741657
# Processing r0=2.5, eta0=5
# Loading existing gradient data from ks_gradient_data/gradient_data_r250_eta500_eps10_theta100.pkl
# KS Derivatives range: 0.0008075010014818583, 0.038426533288671294
# Processing r0=2.5, eta0=5.5
# Loading existing gradient data from ks_gradient_data/gradient_data_r250_eta550_eps10_theta100.pkl
# KS Derivatives range: 0.0005776696676562665, 0.039668190948694004
# Processing r0=2.5, eta0=6
# Loading existing gradient data from ks_gradient_data/gradient_data_r250_eta600_eps10_theta100.pkl
# KS Derivatives range: 0.0005664765989621401, 0.04086583382800768
# Processing r0=2.5, eta0=6.5
# Loading existing gradient data from ks_gradient_data/gradient_data_r250_eta650_eps10_theta100.pkl
# KS Derivatives range: 0.0006367698313081149, 0.04200790785779951
# Processing r0=2.5, eta0=7
# Loading existing gradient data from ks_gradient_data/gradient_data_r250_eta700_eps10_theta100.pkl
# KS Derivatives range: 0.0004828389132960353, 0.04310123652428998
# Processing r0=2.5, eta0=7.5
# Loading existing gradient data from ks_gradient_data/gradient_data_r250_eta750_eps10_theta100.pkl
# KS Derivatives range: 0.00044141400534769554, 0.04414348411252433
# Processing r0=2.5, eta0=8
# Loading existing gradient data from ks_gradient_data/gradient_data_r250_eta800_eps10_theta100.pkl
# KS Derivatives range: 0.0007909429222685559, 0.0451439631010686
# Processing r0=2.75, eta0=0
# Loading existing gradient data from ks_gradient_data/gradient_data_r275_eta0_eps10_theta100.pkl
# KS Derivatives range: 0.003092975375817985, 0.0567896353581565
# Processing r0=2.75, eta0=0.5
# Loading existing gradient data from ks_gradient_data/gradient_data_r275_eta50_eps10_theta100.pkl
# KS Derivatives range: 0.0031851786763681385, 0.03919527242768339
# Processing r0=2.75, eta0=1
# Loading existing gradient data from ks_gradient_data/gradient_data_r275_eta100_eps10_theta100.pkl
# KS Derivatives range: 0.0028819389430445592, 0.031198434460866228
# Processing r0=2.75, eta0=1.5
# Loading existing gradient data from ks_gradient_data/gradient_data_r275_eta150_eps10_theta100.pkl
# KS Derivatives range: 0.00237132028388376, 0.0277012757843309
# Processing r0=2.75, eta0=2
# Loading existing gradient data from ks_gradient_data/gradient_data_r275_eta200_eps10_theta100.pkl
# KS Derivatives range: 0.001937031799542632, 0.02647798100774423
# Processing r0=2.75, eta0=2.5
# Loading existing gradient data from ks_gradient_data/gradient_data_r275_eta250_eps10_theta100.pkl
# KS Derivatives range: 0.0015599425973178425, 0.0264136857941466
# Processing r0=2.75, eta0=3
# Loading existing gradient data from ks_gradient_data/gradient_data_r275_eta300_eps10_theta100.pkl
# KS Derivatives range: 0.0013088237854619322, 0.02692468363540978
# Processing r0=2.75, eta0=3.5
# Loading existing gradient data from ks_gradient_data/gradient_data_r275_eta350_eps10_theta100.pkl
# KS Derivatives range: 0.001046816255900751, 0.027724120740812982
# Processing r0=2.75, eta0=4
# Loading existing gradient data from ks_gradient_data/gradient_data_r275_eta400_eps10_theta100.pkl
# KS Derivatives range: 0.0010200620903511037, 0.028648980687773214
# Processing r0=2.75, eta0=4.5
# Loading existing gradient data from ks_gradient_data/gradient_data_r275_eta450_eps10_theta100.pkl
# KS Derivatives range: 0.0006244687211776068, 0.029622713448862466
# Processing r0=2.75, eta0=5
# Loading existing gradient data from ks_gradient_data/gradient_data_r275_eta500_eps10_theta100.pkl
# KS Derivatives range: 0.0006057272246284828, 0.030604084705343478
# Processing r0=2.75, eta0=5.5
# Loading existing gradient data from ks_gradient_data/gradient_data_r275_eta550_eps10_theta100.pkl
# KS Derivatives range: 0.0004959485933042629, 0.03157143103060811
# Processing r0=2.75, eta0=6
# Loading existing gradient data from ks_gradient_data/gradient_data_r275_eta600_eps10_theta100.pkl
# KS Derivatives range: 0.00045203155663031675, 0.0325150583124767
# Processing r0=2.75, eta0=6.5
# Loading existing gradient data from ks_gradient_data/gradient_data_r275_eta650_eps10_theta100.pkl
# KS Derivatives range: 0.0006700470955856018, 0.03342493170299665
# Processing r0=2.75, eta0=7
# Loading existing gradient data from ks_gradient_data/gradient_data_r275_eta700_eps10_theta100.pkl
# KS Derivatives range: 0.00032287962303811923, 0.03429584523040319
# Processing r0=2.75, eta0=7.5
# Loading existing gradient data from ks_gradient_data/gradient_data_r275_eta750_eps10_theta100.pkl
# KS Derivatives range: 0.0006376022293475003, 0.03513830707513321
# Processing r0=2.75, eta0=8
# Loading existing gradient data from ks_gradient_data/gradient_data_r275_eta800_eps10_theta100.pkl
# KS Derivatives range: 0.00027212035957902003, 0.035940526318944954
# Processing r0=3, eta0=0
# Loading existing gradient data from ks_gradient_data/gradient_data_r300_eta0_eps10_theta100.pkl
# KS Derivatives range: 0.0025413834148224623, 0.055161737100295476
# Processing r0=3, eta0=0.5
# Loading existing gradient data from ks_gradient_data/gradient_data_r300_eta50_eps10_theta100.pkl
# KS Derivatives range: 0.002644585295197288, 0.03730451079153596
# Processing r0=3, eta0=1
# Loading existing gradient data from ks_gradient_data/gradient_data_r300_eta100_eps10_theta100.pkl
# KS Derivatives range: 0.0023409491900494572, 0.028805205287696364
# Processing r0=3, eta0=1.5
# Loading existing gradient data from ks_gradient_data/gradient_data_r300_eta150_eps10_theta100.pkl
# KS Derivatives range: 0.00210260472227608, 0.024689630873098164
# Processing r0=3, eta0=2
# Loading existing gradient data from ks_gradient_data/gradient_data_r300_eta200_eps10_theta100.pkl
# KS Derivatives range: 0.0017921832351497355, 0.02287884666163364
# Processing r0=3, eta0=2.5
# Loading existing gradient data from ks_gradient_data/gradient_data_r300_eta250_eps10_theta100.pkl
# KS Derivatives range: 0.0014057957908875094, 0.022301718927142385
# Processing r0=3, eta0=3
# Loading existing gradient data from ks_gradient_data/gradient_data_r300_eta300_eps10_theta100.pkl
# KS Derivatives range: 0.0010956655478733257, 0.02239122579572594
# Processing r0=3, eta0=3.5
# Loading existing gradient data from ks_gradient_data/gradient_data_r300_eta350_eps10_theta100.pkl
# KS Derivatives range: 0.0009429609926225878, 0.02282792722629878
# Processing r0=3, eta0=4
# Loading existing gradient data from ks_gradient_data/gradient_data_r300_eta400_eps10_theta100.pkl
# KS Derivatives range: 0.0007387273570635954, 0.023449354957794096
# Processing r0=3, eta0=4.5
# Loading existing gradient data from ks_gradient_data/gradient_data_r300_eta450_eps10_theta100.pkl
# KS Derivatives range: 0.000820042869720261, 0.024156666544872248
# Processing r0=3, eta0=5
# Loading existing gradient data from ks_gradient_data/gradient_data_r300_eta500_eps10_theta100.pkl
# KS Derivatives range: 0.0005340184849877971, 0.02490154101808528
# Processing r0=3, eta0=5.5
# Loading existing gradient data from ks_gradient_data/gradient_data_r300_eta550_eps10_theta100.pkl
# KS Derivatives range: 0.0004068192227535405, 0.02565368990292693
# Processing r0=3, eta0=6
# Loading existing gradient data from ks_gradient_data/gradient_data_r300_eta600_eps10_theta100.pkl
# KS Derivatives range: 0.00041897657565570506, 0.026398095195889756
# Processing r0=3, eta0=6.5
# Loading existing gradient data from ks_gradient_data/gradient_data_r300_eta650_eps10_theta100.pkl
# KS Derivatives range: 0.0005630127419831155, 0.027125179546949593
# Processing r0=3, eta0=7
# Loading existing gradient data from ks_gradient_data/gradient_data_r300_eta700_eps10_theta100.pkl
# KS Derivatives range: 0.00039589233835624066, 0.02783115239657352
# Processing r0=3, eta0=7.5
# Loading existing gradient data from ks_gradient_data/gradient_data_r300_eta750_eps10_theta100.pkl
# KS Derivatives range: 0.00037557581489267017, 0.028515472741408306
# Processing r0=3, eta0=8
# Loading existing gradient data from ks_gradient_data/gradient_data_r300_eta800_eps10_theta100.pkl
# KS Derivatives range: 0.0003474665333236259, 0.02917142581937426
# Processing r0=3.25, eta0=0
# Loading existing gradient data from ks_gradient_data/gradient_data_r325_eta0_eps10_theta100.pkl
# KS Derivatives range: 0.0020141087520020307, 0.05390232129531824
# Processing r0=3.25, eta0=0.5
# Loading existing gradient data from ks_gradient_data/gradient_data_r325_eta50_eps10_theta100.pkl
# KS Derivatives range: 0.0021750911960438657, 0.03589095416423049
# Processing r0=3.25, eta0=1
# Loading existing gradient data from ks_gradient_data/gradient_data_r325_eta100_eps10_theta100.pkl
# KS Derivatives range: 0.0021421001639154724, 0.027088488674387175
# Processing r0=3.25, eta0=1.5
# Loading existing gradient data from ks_gradient_data/gradient_data_r325_eta150_eps10_theta100.pkl
# KS Derivatives range: 0.0017664608442657934, 0.02255974330678256
# Processing r0=3.25, eta0=2
# Loading existing gradient data from ks_gradient_data/gradient_data_r325_eta200_eps10_theta100.pkl
# KS Derivatives range: 0.0015035419909104062, 0.020307205508829362
# Processing r0=3.25, eta0=2.5
# Loading existing gradient data from ks_gradient_data/gradient_data_r325_eta250_eps10_theta100.pkl
# KS Derivatives range: 0.0012457114006991787, 0.01933219189453883
# Processing r0=3.25, eta0=3
# Loading existing gradient data from ks_gradient_data/gradient_data_r325_eta300_eps10_theta100.pkl
# KS Derivatives range: 0.001033316032739151, 0.01907574856407912
# Processing r0=3.25, eta0=3.5
# Loading existing gradient data from ks_gradient_data/gradient_data_r325_eta350_eps10_theta100.pkl
# KS Derivatives range: 0.0008923259409154837, 0.019222952252206937
# Processing r0=3.25, eta0=4
# Loading existing gradient data from ks_gradient_data/gradient_data_r325_eta400_eps10_theta100.pkl
# KS Derivatives range: 0.0006965752356868914, 0.019593430222730746
# Processing r0=3.25, eta0=4.5
# Loading existing gradient data from ks_gradient_data/gradient_data_r325_eta450_eps10_theta100.pkl
# KS Derivatives range: 0.0005508426492717433, 0.0200853462223316
# Processing r0=3.25, eta0=5
# Loading existing gradient data from ks_gradient_data/gradient_data_r325_eta500_eps10_theta100.pkl
# KS Derivatives range: 0.0006569624066976587, 0.020638297315578313
# Processing r0=3.25, eta0=5.5
# Loading existing gradient data from ks_gradient_data/gradient_data_r325_eta550_eps10_theta100.pkl
# KS Derivatives range: 0.000498017682648566, 0.02121933552479138
# Processing r0=3.25, eta0=6
# Loading existing gradient data from ks_gradient_data/gradient_data_r325_eta600_eps10_theta100.pkl
# KS Derivatives range: 0.0004293604360938729, 0.021807995509437458
# Processing r0=3.25, eta0=6.5
# Loading existing gradient data from ks_gradient_data/gradient_data_r325_eta650_eps10_theta100.pkl
# KS Derivatives range: 0.0004739449499524539, 0.02239406915183206
# Processing r0=3.25, eta0=7
# Loading existing gradient data from ks_gradient_data/gradient_data_r325_eta700_eps10_theta100.pkl
# KS Derivatives range: 0.0004218165261526962, 0.022967485691083308
# Processing r0=3.25, eta0=7.5
# Loading existing gradient data from ks_gradient_data/gradient_data_r325_eta750_eps10_theta100.pkl
# KS Derivatives range: 0.00023187016751080589, 0.023525688902514826
# Processing r0=3.25, eta0=8
# Loading existing gradient data from ks_gradient_data/gradient_data_r325_eta800_eps10_theta100.pkl
# KS Derivatives range: 0.00046529560204788817, 0.02407144485960799
# Processing r0=3.5, eta0=0
# Loading existing gradient data from ks_gradient_data/gradient_data_r350_eta0_eps10_theta100.pkl
# KS Derivatives range: 0.0018781589818106512, 0.05287263687980825
# Processing r0=3.5, eta0=0.5
# Loading existing gradient data from ks_gradient_data/gradient_data_r350_eta50_eps10_theta100.pkl
# KS Derivatives range: 0.0019496146808073431, 0.03479571037967588
# Processing r0=3.5, eta0=1
# Loading existing gradient data from ks_gradient_data/gradient_data_r350_eta100_eps10_theta100.pkl
# KS Derivatives range: 0.0017571063493093673, 0.0258106813005865
# Processing r0=3.5, eta0=1.5
# Loading existing gradient data from ks_gradient_data/gradient_data_r350_eta150_eps10_theta100.pkl
# KS Derivatives range: 0.001627897761036223, 0.021005791295269916
# Processing r0=3.5, eta0=2
# Loading existing gradient data from ks_gradient_data/gradient_data_r350_eta200_eps10_theta100.pkl
# KS Derivatives range: 0.0013648307595204299, 0.018435475124256584
# Processing r0=3.5, eta0=2.5
# Loading existing gradient data from ks_gradient_data/gradient_data_r350_eta250_eps10_theta100.pkl
# KS Derivatives range: 0.001182781533826116, 0.017147169045772515
# Processing r0=3.5, eta0=3
# Loading existing gradient data from ks_gradient_data/gradient_data_r350_eta300_eps10_theta100.pkl
# KS Derivatives range: 0.0010461646202108987, 0.016611731595839174
# Processing r0=3.5, eta0=3.5
# Loading existing gradient data from ks_gradient_data/gradient_data_r350_eta350_eps10_theta100.pkl
# KS Derivatives range: 0.0008609206569865079, 0.016518953879773868
# Processing r0=3.5, eta0=4
# Loading existing gradient data from ks_gradient_data/gradient_data_r350_eta400_eps10_theta100.pkl
# KS Derivatives range: 0.0006986933899499891, 0.016683170211972964
# Processing r0=3.5, eta0=4.5
# Loading existing gradient data from ks_gradient_data/gradient_data_r350_eta450_eps10_theta100.pkl
# KS Derivatives range: 0.0006304524367839459, 0.01699479519612357
# Processing r0=3.5, eta0=5
# Loading existing gradient data from ks_gradient_data/gradient_data_r350_eta500_eps10_theta100.pkl
# KS Derivatives range: 0.00046762266281419324, 0.017392228471302396
# Processing r0=3.5, eta0=5.5
# Loading existing gradient data from ks_gradient_data/gradient_data_r350_eta550_eps10_theta100.pkl
# KS Derivatives range: 0.0005344451090016911, 0.017832586141075524
# Processing r0=3.5, eta0=6
# Loading existing gradient data from ks_gradient_data/gradient_data_r350_eta600_eps10_theta100.pkl
# KS Derivatives range: 0.0004630126615445817, 0.018295688875014093
# Processing r0=3.5, eta0=6.5
# Loading existing gradient data from ks_gradient_data/gradient_data_r350_eta650_eps10_theta100.pkl
# KS Derivatives range: 0.00043673531457955045, 0.01876580031368036
# Processing r0=3.5, eta0=7
# Loading existing gradient data from ks_gradient_data/gradient_data_r350_eta700_eps10_theta100.pkl
# KS Derivatives range: 0.00041473159559379796, 0.019232022308024455
# Processing r0=3.5, eta0=7.5
# Loading existing gradient data from ks_gradient_data/gradient_data_r350_eta750_eps10_theta100.pkl
# KS Derivatives range: 0.00027737751748246886, 0.019692130992510215
# Processing r0=3.5, eta0=8
# Loading existing gradient data from ks_gradient_data/gradient_data_r350_eta800_eps10_theta100.pkl
# KS Derivatives range: 0.00028779970628889373, 0.02014424764773537
# Processing r0=3.75, eta0=0
# Loading existing gradient data from ks_gradient_data/gradient_data_r375_eta0_eps10_theta100.pkl
# KS Derivatives range: 0.0014164700579133436, 0.05202184379105023
# Processing r0=3.75, eta0=0.5
# Loading existing gradient data from ks_gradient_data/gradient_data_r375_eta50_eps10_theta100.pkl
# KS Derivatives range: 0.0016709116423818669, 0.03391952887454863
# Processing r0=3.75, eta0=1
# Loading existing gradient data from ks_gradient_data/gradient_data_r375_eta100_eps10_theta100.pkl
# KS Derivatives range: 0.0014523883484773845, 0.024829487535460434
# Processing r0=3.75, eta0=1.5
# Loading existing gradient data from ks_gradient_data/gradient_data_r375_eta150_eps10_theta100.pkl
# KS Derivatives range: 0.0014271237080976105, 0.01984170356905679
# Processing r0=3.75, eta0=2
# Loading existing gradient data from ks_gradient_data/gradient_data_r375_eta200_eps10_theta100.pkl
# KS Derivatives range: 0.0011448182624107517, 0.017040237534904357
# Processing r0=3.75, eta0=2.5
# Loading existing gradient data from ks_gradient_data/gradient_data_r375_eta250_eps10_theta100.pkl
# KS Derivatives range: 0.0010725203808403805, 0.015513503551223272
# Processing r0=3.75, eta0=3
# Loading existing gradient data from ks_gradient_data/gradient_data_r375_eta300_eps10_theta100.pkl
# KS Derivatives range: 0.0008946265776799133, 0.014754463803501315
# Processing r0=3.75, eta0=3.5
# Loading existing gradient data from ks_gradient_data/gradient_data_r375_eta350_eps10_theta100.pkl
# KS Derivatives range: 0.0008301211495975734, 0.014461024633316553
# Processing r0=3.75, eta0=4
# Loading existing gradient data from ks_gradient_data/gradient_data_r375_eta400_eps10_theta100.pkl
# KS Derivatives range: 0.0006811403108208934, 0.014453158520000285
# Processing r0=3.75, eta0=4.5
# Loading existing gradient data from ks_gradient_data/gradient_data_r375_eta450_eps10_theta100.pkl
# KS Derivatives range: 0.0005932704716382631, 0.014616351926011182
# Processing r0=3.75, eta0=5
# Loading existing gradient data from ks_gradient_data/gradient_data_r375_eta500_eps10_theta100.pkl
# KS Derivatives range: 0.0005599944952194846, 0.014880650861526233
# Processing r0=3.75, eta0=5.5
# Loading existing gradient data from ks_gradient_data/gradient_data_r375_eta550_eps10_theta100.pkl
# KS Derivatives range: 0.0004016342813883966, 0.015203747341652194
# Processing r0=3.75, eta0=6
# Loading existing gradient data from ks_gradient_data/gradient_data_r375_eta600_eps10_theta100.pkl
# KS Derivatives range: 0.0004406593069605779, 0.01556095521326739
# Processing r0=3.75, eta0=6.5
# Loading existing gradient data from ks_gradient_data/gradient_data_r375_eta650_eps10_theta100.pkl
# KS Derivatives range: 0.00042984453219041535, 0.015935998198823853
# Processing r0=3.75, eta0=7
# Loading existing gradient data from ks_gradient_data/gradient_data_r375_eta700_eps10_theta100.pkl
# KS Derivatives range: 0.0003878609031171542, 0.01631521124867419
# Processing r0=3.75, eta0=7.5
# Loading existing gradient data from ks_gradient_data/gradient_data_r375_eta750_eps10_theta100.pkl
# KS Derivatives range: 0.0002970098167409674, 0.016694624216384568
# Processing r0=3.75, eta0=8
# Loading existing gradient data from ks_gradient_data/gradient_data_r375_eta800_eps10_theta100.pkl
# KS Derivatives range: 0.00018272532688323737, 0.017069198568475663
# Processing r0=4, eta0=0
# Loading existing gradient data from ks_gradient_data/gradient_data_r400_eta0_eps10_theta100.pkl
# KS Derivatives range: 0.0014316017329929485, 0.05130038063516639
# Processing r0=4, eta0=0.5
# Loading existing gradient data from ks_gradient_data/gradient_data_r400_eta50_eps10_theta100.pkl
# KS Derivatives range: 0.0013585568559015824, 0.0331970704703366
# Processing r0=4, eta0=1
# Loading existing gradient data from ks_gradient_data/gradient_data_r400_eta100_eps10_theta100.pkl
# KS Derivatives range: 0.0011815682765536906, 0.02404869659522468
# Processing r0=4, eta0=1.5
# Loading existing gradient data from ks_gradient_data/gradient_data_r400_eta150_eps10_theta100.pkl
# KS Derivatives range: 0.001181571362973699, 0.018943738155918766
# Processing r0=4, eta0=2
# Loading existing gradient data from ks_gradient_data/gradient_data_r400_eta200_eps10_theta100.pkl
# KS Derivatives range: 0.001009391770168122, 0.015979737766347313
# Processing r0=4, eta0=2.5
# Loading existing gradient data from ks_gradient_data/gradient_data_r400_eta250_eps10_theta100.pkl
# KS Derivatives range: 0.0009294638794732356, 0.014270731535370727
# Processing r0=4, eta0=3
# Loading existing gradient data from ks_gradient_data/gradient_data_r400_eta300_eps10_theta100.pkl
# KS Derivatives range: 0.0007837953907435801, 0.013332804943422259
# Processing r0=4, eta0=3.5
# Loading existing gradient data from ks_gradient_data/gradient_data_r400_eta350_eps10_theta100.pkl
# KS Derivatives range: 0.0007650389079183472, 0.012874773214210931
# Processing r0=4, eta0=4
# Loading existing gradient data from ks_gradient_data/gradient_data_r400_eta400_eps10_theta100.pkl
# KS Derivatives range: 0.0006557816768781866, 0.012721730746623193
# Processing r0=4, eta0=4.5
# Loading existing gradient data from ks_gradient_data/gradient_data_r400_eta450_eps10_theta100.pkl
# KS Derivatives range: 0.0004642257307729824, 0.012757791917339388
# Processing r0=4, eta0=5
# Loading existing gradient data from ks_gradient_data/gradient_data_r400_eta500_eps10_theta100.pkl
# KS Derivatives range: 0.0004103869910565549, 0.01291038120854182
# Processing r0=4, eta0=5.5
# Loading existing gradient data from ks_gradient_data/gradient_data_r400_eta550_eps10_theta100.pkl
# KS Derivatives range: 0.0004012447041290556, 0.013135449739021253
# Processing r0=4, eta0=6
# Loading existing gradient data from ks_gradient_data/gradient_data_r400_eta600_eps10_theta100.pkl
# KS Derivatives range: 0.00034856656935811076, 0.013401871468143865
# Processing r0=4, eta0=6.5
# Loading existing gradient data from ks_gradient_data/gradient_data_r400_eta650_eps10_theta100.pkl
# KS Derivatives range: 0.00036773681877377834, 0.013696519479688972
# Processing r0=4, eta0=7
# Loading existing gradient data from ks_gradient_data/gradient_data_r400_eta700_eps10_theta100.pkl
# KS Derivatives range: 0.0003508571877475219, 0.014003325077283078
# Processing r0=4, eta0=7.5
# Loading existing gradient data from ks_gradient_data/gradient_data_r400_eta750_eps10_theta100.pkl
# KS Derivatives range: 0.00029711909599328123, 0.0143147113496056
# Processing r0=4, eta0=8
# Loading existing gradient data from ks_gradient_data/gradient_data_r400_eta800_eps10_theta100.pkl
# KS Derivatives range: 0.0002141127435073553, 0.01462599885926341

# %% [markdown]
# # KL Plot

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import scipy.special
import os
import pickle
from tqdm import tqdm
from sigfig import round
import git
from pathlib import Path
import cv2
from glob import glob

ROOT_DIR = Path(git.Repo('.', search_parent_directories=True).working_tree_dir)
CWD = os.getcwd()
os.chdir(os.path.join(ROOT_DIR, "utilities"))
from testing import *
os.chdir(CWD)


# Grid values for ellipses
r_ellipses = [0.5, 0.75, 1, 1.25, 1.5, 1.75, 2, 2.25, 2.5, 2.75, 3, 3.25, 3.5, 3.75, 4]
eta_ellipses = [0, 0.5, 1, 1.5, 2, 2.5, 3, 3.5, 4, 4.5, 5, 5.5, 6, 6.5, 7, 7.5, 8]
R_ellipses, Eta_ellipses = np.meshgrid(r_ellipses, eta_ellipses)

# Finer grid values for the contour plot
r_contour = [round(i*0.01 + 0.5, sigfigs=2) for i in range(-10, 360)]
eta_contour = [round(j*0.02 + 1, sigfigs=2) for j in range(-50, 400)]
R_contour, Eta_contour = np.meshgrid(r_contour, eta_contour)

# Directory for storing Hessian matrices
hessian_dir = 'kl_hessian_matrices'
os.makedirs(hessian_dir, exist_ok=True)

# Function to generate a file path for a given (r, eta) pair
def get_hessian_path(r_val, eta_val):
    return os.path.join(hessian_dir, f'hessian_R{r_val}_Eta{eta_val}.pkl')

# Function to calculate variance_prior
def variance_prior(r, eta, scale=1):
    beta = (eta + 1.5) / r
    var_prior = scale * scipy.special.gamma(beta + 1 / r) / scipy.special.gamma(beta)
    return var_prior

# Hessian function
def hessian(r, eta):
    return np.array([[r, 0], [0, eta]])

# Example function to check if a matrix is positive definite
def is_pos_def(matrix):
    return np.all(np.linalg.eigvals(matrix) > 0)

# Initialize grid for var_prior values for the contour plot
var_prior_values = variance_prior(R_contour, Eta_contour)

# Plotting
fig, ax = plt.subplots(figsize=(10, 8))
ax.set_xlabel('r (shape parameter)', fontsize=18)
ax.set_ylabel('η (scale parameter)', fontsize=18)
ax.set_title('KL Divergence', fontsize=20)

# Set x and y axis limits
ax.set_xlim(0, 4)
ax.set_ylim(0, 8)

# Overlay contour plot with reduced opacity and no labels
log_levels = np.logspace(np.log10(np.min(var_prior_values)), np.log10(np.max(var_prior_values)), 150)
contour = ax.contour(R_contour, Eta_contour, np.log10(var_prior_values), levels=np.log10(log_levels), cmap='cividis', alpha=0.7, linewidths=0.8)

# Add colorbar
cbar = fig.colorbar(contour, ax=ax)
cbar.set_label('Log(Variance)', fontsize=20)
cbar.ax.tick_params(labelsize=16)

# Plot ellipses
scale_factor = 0.01
rows, cols = R_ellipses.shape  # Get correct dimensions of the meshgrid

for i in range(rows):  # Loop over rows
    for j in range(cols):  # Loop over columns
        hessian_path = get_hessian_path(R_ellipses[i, j], Eta_ellipses[i, j])
        
        # Check if the Hessian matrix is already stored
        if os.path.exists(hessian_path):
            with open(hessian_path, 'rb') as f:
                H = pickle.load(f)
        else:
            #print(i, j)
            # Calculate the Hessian matrix if not already stored
            H = hessian(R_ellipses[i, j], Eta_ellipses[i, j])
            # Store the Hessian matrix in a pickle file
            with open(hessian_path, 'wb') as f:
                pickle.dump(H, f)
        
        U, s, Vt = np.linalg.svd(H)
        angle = np.arctan2(U[0, 1], U[0, 0]) * 180 / np.pi  # Convert radian to degree
        width, height = scale_factor / np.sqrt(s[0]), scale_factor / np.sqrt(s[1])  # Axis lengths
        ellipse = patches.Ellipse((R_ellipses[i, j], Eta_ellipses[i, j]), width, height, angle=angle, edgecolor='red', facecolor='none')
        ax.add_patch(ellipse)

# Customize tick parameters
ax.tick_params(axis='both', which='major', labelsize=20)

# Show the plot
plt.show()
fig.savefig('plots/kl_divergence_plot.png', bbox_inches='tight')
# Out:
# /var/folders/0c/5hhs4r6n7pnc4jcl295d7j_c0000gn/T/ipykernel_26454/634042565.py:15: UserWarning: 2 significant figures requested from number with only 1 significant figures
#   r_contour = [round(i*0.01 + 0.5, sigfigs=2) for i in range(-10, 360)]
# /var/folders/0c/5hhs4r6n7pnc4jcl295d7j_c0000gn/T/ipykernel_26454/634042565.py:16: UserWarning: 2 significant figures requested from number with only 1 significant figures
#   eta_contour = [round(j*0.02 + 1, sigfigs=2) for j in range(-50, 400)]
# /var/folders/0c/5hhs4r6n7pnc4jcl295d7j_c0000gn/T/ipykernel_26454/634042565.py:85: RuntimeWarning: divide by zero encountered in scalar divide
#   width, height = scale_factor / np.sqrt(s[0]), scale_factor / np.sqrt(s[1])  # Axis lengths

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import scipy.special
import os
import pickle
from sigfig import round


ROOT_DIR = Path(git.Repo('.', search_parent_directories=True).working_tree_dir)
CWD = os.getcwd()
os.chdir(os.path.join(ROOT_DIR, "utilities"))
from testing import *
from reporting import *
os.chdir(CWD)


SAVE_FIGS = True
plots_path = os.path.join(ROOT_DIR, "publication", "paper", "final_plots")
fontsize = 20

fig, axes = plt.subplots(ncols=2, figsize=(20, 8), sharey=True)
fontsize = 20
# KS Statistic plot
ax_ks = axes[0]
ax_ks.set_xlabel(r'$r$', fontsize=fontsize)
ax_ks.set_ylabel(r'$\eta$', fontsize=fontsize)
ax_ks.set_title('KS Statistic', fontsize=fontsize)
ax_ks.set_xlim(0, 4)
ax_ks.set_ylim(0, 8)
log_levels = np.logspace(np.log10(np.min(var_prior_values)), np.log10(np.max(var_prior_values)), 150)
contour_ks = ax_ks.contour(R_contour, Eta_contour, np.log10(var_prior_values), levels=np.log10(log_levels), cmap='cividis', alpha=0.7, linewidths=0.8)
for r_values, eta_values in zip(all_r_values, all_eta_values):
    ax_ks.plot(r_values, eta_values, color='red', linewidth=2, label='KS Level Set')
ax_ks.set_xticks(np.arange(0, 5, 1))
ax_ks.tick_params(axis='both', which='major', labelsize=20)



#cbar_ks = fig.colorbar(contour_ks, ax=ax_ks)
#cbar_ks.set_label('Log(Variance)', fontsize=18)
#cbar_ks.ax.tick_params(labelsize=12)

# KL Divergence plot
ax_kl = axes[1]
ax_kl.set_xlabel(r'$r$', fontsize=fontsize)
#ax_kl.set_ylabel(r'$\eta$', fontsize=18)
ax_kl.set_title('KL Divergence', fontsize=fontsize)
ax_kl.set_xlim(0, 4)
ax_kl.set_ylim(0, 8)
contour_kl = ax_kl.contour(R_contour, Eta_contour, np.log10(var_prior_values), levels=np.log10(log_levels), cmap='cividis', alpha=0.7, linewidths=0.8)
scale_factor = 0.01
rows, cols = R_ellipses.shape
for i in range(rows):
    for j in range(cols):
        hessian_path = get_hessian_path(R_ellipses[i, j], Eta_ellipses[i, j])
        if os.path.exists(hessian_path):
            with open(hessian_path, 'rb') as f:
                H = pickle.load(f)
        else:
            H = hessian(R_ellipses[i, j], Eta_ellipses[i, j])
            with open(hessian_path, 'wb') as f:
                pickle.dump(H, f)
        U, s, Vt = np.linalg.svd(H)
        angle = np.arctan2(U[0, 1], U[0, 0]) * 180 / np.pi
        width, height = scale_factor / np.sqrt(s[0]), scale_factor / np.sqrt(s[1])
        ellipse = patches.Ellipse((R_ellipses[i, j], Eta_ellipses[i, j]), width, height, angle=angle, edgecolor='red', facecolor='none')
        ax_kl.add_patch(ellipse)
ax_kl.tick_params(axis='both', which='major', labelsize=20)
ax_kl.set_xticks(np.arange(0, 5, 1))
cbar_kl = fig.colorbar(contour_kl, ax=ax_kl)
cbar_kl.set_label('Log Variance', fontsize=18)
cbar_kl.ax.tick_params(labelsize=12)

plt.tight_layout()
plt.show()
if SAVE_FIGS:
    fig.savefig(os.path.join(plots_path, "ks_kl_sensitivity.jpg"), bbox_inches='tight', dpi=DPI)
# Out:
# /var/folders/0c/5hhs4r6n7pnc4jcl295d7j_c0000gn/T/ipykernel_26454/928059242.py:43: RuntimeWarning: divide by zero encountered in scalar divide
#   width, height = scale_factor / np.sqrt(s[0]), scale_factor / np.sqrt(s[1])
# /Users/brandonmarks/opt/anaconda3/envs/HBMV/lib/python3.10/site-packages/matplotlib/transforms.py:2070: RuntimeWarning: invalid value encountered in scalar multiply
#   self._mtx[1, 0] *= sy
# /Users/brandonmarks/opt/anaconda3/envs/HBMV/lib/python3.10/site-packages/matplotlib/transforms.py:2072: RuntimeWarning: invalid value encountered in scalar multiply
#   self._mtx[1, 2] *= sy
